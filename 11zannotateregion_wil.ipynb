# %%
import pandas as pd
import re
import os
import glob
import snapatac2 as snap
from statsmodels.stats.multitest import multipletests

import seaborn as sns
import numpy as np
import utils
import subprocess

from pybedtools import BedTool
import matplotlib.pyplot as plt
from upsetplot import UpSet, from_contents
from matplotlib_venn import venn2
#import pyBigWig

# %%
annotations = [
    "/data2st1/junyi/generegion_vM23/intron_selected.bed",
    "/data2st1/junyi/generegion_vM23/exon_selected.bed",
    "/data2st1/junyi/generegion_vM23/promoter2k.bed",
    #"/data2st1/junyi/generegion_vM23/repeat.bed",
    "/data2st1/junyi/output/atac0416/cCRE/LINE.bed",
    "/data2st1/junyi/output/atac0416/cCRE/SINE.bed",
    "/data2st1/junyi/output/atac0416/cCRE/LTR.bed",
    "/data2st1/junyi/output/atac0416/cCRE/cpg.bed",
    "/data2st1/junyi/output/atac0416/cCRE/Other_repeats.bed",    
    "/data2st1/junyi/generegion_vM23/UTR.bed",
    "/data2st1/junyi/generegion_vM23/CDS.bed",
    "/data2st1/junyi/generegion_vM23/genebody.bed",
    "/data2st1/junyi/output/atac0416/cCRE/intergenic.bed",
    "/data2st1/junyi/output/atac0416/cCRE/mm10-cCREs.bed"

]

# %%
def merge_region(region='PFC',condition="MC",folder='/data2st1/junyi/output/atac0627/dar/region_nt/',method='mementob',blacklist=['Doublet','NN',"Neuron"]):
    df_result = pd.DataFrame()
    files = glob.glob(f'{folder}/{region}*{condition}_{method}.csv')
    for file in files:
        if any([file.find(black) > -1 for black in blacklist]):
            continue
        df_dar = pd.read_csv(file,index_col=0)

        ctname = file.split('/')[-1].replace('.csv', '')
        ctname = "_".join(ctname.split('_')[1:-2])
        if len(df_dar) == 0:
            continue
        df_dar['ctname'] = ctname
        df_result = pd.concat([df_result, df_dar], axis=0, ignore_index=True)
    df_result['region'] = region
    df_result['condition'] = condition
    return df_result

def intersect_bed_files(bed_file1, bed_file2):
    bed1 = BedTool(bed_file1)
    bed2 = BedTool(bed_file2)

    # Intersect and split regions
    # Retain annotations from bed_file2 for overlapping regions
    merged = bed1.intersect(bed2, wa=True, wb=True)#.saveas("output/temp_intersect.bed")

    # Split non-overlapping regions from bed_file1
    non_overlapping = bed1.subtract(bed2)#.saveas("output/temp_non_overlapping.bed")

    return merged, non_overlapping

def intersect_bed_objects(bed_file1, bed_file2):
    bed1 = bed_file1
    bed2 = bed_file2

    # Intersect and split regions
    # Retain annotations from bed_file2 for overlapping regions
    merged = bed1.intersect(bed2, wa=True, wb=True)#.saveas("output/temp_intersect.bed")

    # Split non-overlapping regions from bed_file1
    non_overlapping = bed1.subtract(bed2)#.saveas("output/temp_non_overlapping.bed")

    return merged, non_overlapping

def get_proity_region(df_in, priority = [
    "promoter",
    "UTR",
    "exon",
    "intron",
    "intergenic"   ]

):
    df_in['annotation'] = priority[-1]
    df_in = df_in.loc[:,priority+['id']]
    priorityi = priority[::-1]
    for column in priorityi:
        df_in.loc[df_in[column]==True,"annotation"] = column
    return df_in


def is_promoter(row,interval_col="names"):
    # 解析第一个区间
    chrom_part, pos_part = row[interval_col].split(':')
    start1, end1 = map(int, pos_part.split('-'))
    strand = row['strand']

    if strand == "+":
        # 如果是正链，start1和end1不变
        # 获取第二个区间
        start2 = row['gstart']-2000
        end2 = row['gstart']
    else:
        strand = "-"
        start2 = row['gend']
        end2 = row['gend']+2000
    # 判断是否有交集
    return not (end1 < start2 or end2 < start1)

# %%
method = 'WILCOXON'
folder = '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2'

# %%
# df_PFC_MC = merge_region(region='PFC',condition="MC",folder=folder,method=method)
# df_PFC_MW = merge_region(region='PFC',condition="MW", folder=folder, method=method)
# df_HIP_MC = merge_region(region='HIP',condition="MC",folder=folder,method=method)
# df_HIP_MW = merge_region(region='HIP',condition="MW", folder=folder, method=method)
# df_AMY_MC = merge_region(region='AMY',condition="MC",folder=folder,method=method)
# df_AMY_MW = merge_region(region='AMY',condition="MW", folder=folder, method=method)
# df_DAR_ALL = pd.concat([df_PFC_MC, df_PFC_MW, df_HIP_MC, df_HIP_MW, df_AMY_MC, df_AMY_MW], axis=0, ignore_index=True)

# %%
files = glob.glob(f'{folder}/*wilcoxon.csv')

# %%
files
# Out:
# ['/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_Sst_Chodl_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Pvalb_Vipr2_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Meis1_Abi3bp_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_CA2_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Npas1_Rgs12_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Foxp2_Penk_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_L5_NP_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_L6_IT_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Esr2_Gldn_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_Car3_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_Pvalb_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Tcf7l2_Gm20713_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Vip_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Subiculum_CT_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Zbtb7c_Vwa5b1_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Subiculum_NP_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_L5_ET_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Trabd2b_Coch_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_L6_CT_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Subiculum_IT_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_Lamp5_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Sncg_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_L2-3_IT_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_L5_IT_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_L6b_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Rai14_Foxp2_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Subiculum_SUB_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_Sncg_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_CA3_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Zfhx4_Pde7b_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Lamp5_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Hcrtr2_Hapln1_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Ccdc3_Acvr1c_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_Sst_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Maf_Pthlh_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Cav1_Frmpd1_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Cdh23_Hmcn1_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Rspo2_Gm11639_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Ndnf_Lamp5_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Piezo2_Cpa6_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_DG_GC_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_CA1_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Cajal-Retzius_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Rorb_Smoc1_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Sst_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Zfhx3_Glra1_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_Pvalb_Vipr2_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Fign_Ostm1_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/AMY_AMY_Crhbp_Maf_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Mossy_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Subiculum_ProS_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/HIP_HPF_Pvalb_GABA_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_L4-5_IT_Glut_wilcoxon.csv',
#  '/data2st1/junyi/output/atac1112/dar/celltype.L2/wil/celltype.L2/PFC_PFC_Vip_GABA_wilcoxon.csv']

# %%
df_DAR_ALL = pd.DataFrame()
for file in files:
    ctname = os.path.basename(file).replace('.csv', '').replace('_wilcoxon','').replace('HIP','HPF')
    region = ctname.split('_')[0]
    df_tmp = pd.read_csv(file, index_col=0)
    df_tmp['region'] = region
    df_tmp['ctname'] = ctname
    df_tmp['fdr'] = multipletests(df_tmp['pvals'], method='fdr_bh')[1]
    df_DAR_ALL = pd.concat([df_DAR_ALL, df_tmp], axis=0, ignore_index=True)

# %%
df_DAR_ALL
# Out:
#                              names    scores  logfoldchanges     pvals  \
# 0           chr2:98666919-98667420  2.887307        1.489856  0.003886
# 1         chr7:126377225-126377726  2.472138        2.393066  0.013431
# 2         chr8:122443288-122443789  2.434396        2.122708  0.014917
# 3           chr9:35305177-35305678  2.396653        1.703857  0.016546
# 4           chr2:98662051-98662552  2.302297        1.412491  0.021318
# ...                            ...       ...             ...       ...
# 34187128    chr3:41082941-41083442 -4.139641       -0.662424  0.000035
# 34187129      chr8:4165942-4166443 -4.335513       -0.662157  0.000015
# 34187130    chr4:55843676-55844177 -4.359705       -1.520980  0.000013
# 34187131   chr11:51943092-51943593 -4.663189       -0.985756  0.000003
# 34187132  chr9:110408037-110408538 -4.710858       -0.825508  0.000002
#
#           pvals_adj  pct_nz_group  pct_nz_reference region  \
# 0          0.849975      1.000000          0.875000    PFC
# 1          0.849975      0.518519          0.166667    PFC
# 2          0.849975      0.555556          0.166667    PFC
# 3          0.849975      0.703704          0.416667    PFC
# 4          0.849975      0.925926          0.708333    PFC
# ...             ...           ...               ...    ...
# 34187128   0.999938      0.362799          0.480865    PFC
# 34187129   0.577918      0.373849          0.505824    PFC
# 34187130   0.569337      0.110497          0.252912    PFC
# 34187131   0.194436      0.211786          0.366057    PFC
# 34187132   0.179725      0.267035          0.415973    PFC
#
#                           ctname       fdr
# 0         PFC_PFC_Sst_Chodl_GABA  0.849975
# 1         PFC_PFC_Sst_Chodl_GABA  0.849975
# 2         PFC_PFC_Sst_Chodl_GABA  0.849975
# 3         PFC_PFC_Sst_Chodl_GABA  0.849975
# 4         PFC_PFC_Sst_Chodl_GABA  0.849975
# ...                          ...       ...
# 34187128        PFC_PFC_Vip_GABA  0.999938
# 34187129        PFC_PFC_Vip_GABA  0.577918
# 34187130        PFC_PFC_Vip_GABA  0.569337
# 34187131        PFC_PFC_Vip_GABA  0.194436
# 34187132        PFC_PFC_Vip_GABA  0.179725
#
# [34187133 rows x 10 columns]

# %%
df_DAR_ALL['status'] = df_DAR_ALL['logfoldchanges'].map(lambda x: 'Up' if x > 0 else 'Down')

# %%
df_DAR_ALL= df_DAR_ALL[df_DAR_ALL.pvals < 0.05]

# %%
df_DAR_ALL
# Out:
#                              names    scores  logfoldchanges     pvals  \
# 0           chr2:98666919-98667420  2.887307        1.489856  0.003886
# 1         chr7:126377225-126377726  2.472138        2.393066  0.013431
# 2         chr8:122443288-122443789  2.434396        2.122708  0.014917
# 3           chr9:35305177-35305678  2.396653        1.703857  0.016546
# 4           chr2:98662051-98662552  2.302297        1.412491  0.021318
# ...                            ...       ...             ...       ...
# 34187128    chr3:41082941-41083442 -4.139641       -0.662424  0.000035
# 34187129      chr8:4165942-4166443 -4.335513       -0.662157  0.000015
# 34187130    chr4:55843676-55844177 -4.359705       -1.520980  0.000013
# 34187131   chr11:51943092-51943593 -4.663189       -0.985756  0.000003
# 34187132  chr9:110408037-110408538 -4.710858       -0.825508  0.000002
#
#           pvals_adj  pct_nz_group  pct_nz_reference region  \
# 0          0.849975      1.000000          0.875000    PFC
# 1          0.849975      0.518519          0.166667    PFC
# 2          0.849975      0.555556          0.166667    PFC
# 3          0.849975      0.703704          0.416667    PFC
# 4          0.849975      0.925926          0.708333    PFC
# ...             ...           ...               ...    ...
# 34187128   0.999938      0.362799          0.480865    PFC
# 34187129   0.577918      0.373849          0.505824    PFC
# 34187130   0.569337      0.110497          0.252912    PFC
# 34187131   0.194436      0.211786          0.366057    PFC
# 34187132   0.179725      0.267035          0.415973    PFC
#
#                           ctname       fdr status
# 0         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# 1         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# 2         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# 3         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# 4         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# ...                          ...       ...    ...
# 34187128        PFC_PFC_Vip_GABA  0.999938   Down
# 34187129        PFC_PFC_Vip_GABA  0.577918   Down
# 34187130        PFC_PFC_Vip_GABA  0.569337   Down
# 34187131        PFC_PFC_Vip_GABA  0.194436   Down
# 34187132        PFC_PFC_Vip_GABA  0.179725   Down
#
# [269505 rows x 11 columns]

# %%
df_annotattion = utils.annotate_region(df_DAR_ALL,region_col='names', bedfile='/data2st1/junyi/generegion_vM23/genebody_selected.bed')

# %%
df_annotattion
# Out:
#                            names    scores  logfoldchanges     pvals  \
# 0         chr2:98666919-98667420  2.887307        1.489856  0.003886
# 1       chr7:126377225-126377726  2.472138        2.393066  0.013431
# 2       chr8:122443288-122443789  2.434396        2.122708  0.014917
# 3         chr9:35305177-35305678  2.396653        1.703857  0.016546
# 4         chr2:98662051-98662552  2.302297        1.412491  0.021318
# ...                          ...       ...             ...       ...
# 269500    chr3:41082941-41083442 -4.139641       -0.662424  0.000035
# 269501      chr8:4165942-4166443 -4.335513       -0.662157  0.000015
# 269502    chr4:55843676-55844177 -4.359705       -1.520980  0.000013
# 269503   chr11:51943092-51943593 -4.663189       -0.985756  0.000003
# 269504  chr9:110408037-110408538 -4.710858       -0.825508  0.000002
#
#         pvals_adj  pct_nz_group  pct_nz_reference region  \
# 0        0.849975      1.000000          0.875000    PFC
# 1        0.849975      0.518519          0.166667    PFC
# 2        0.849975      0.555556          0.166667    PFC
# 3        0.849975      0.703704          0.416667    PFC
# 4        0.849975      0.925926          0.708333    PFC
# ...           ...           ...               ...    ...
# 269500   0.999938      0.362799          0.480865    PFC
# 269501   0.577918      0.373849          0.505824    PFC
# 269502   0.569337      0.110497          0.252912    PFC
# 269503   0.194436      0.211786          0.366057    PFC
# 269504   0.179725      0.267035          0.415973    PFC
#
#                         ctname       fdr status      gene_name  \
# 0       PFC_PFC_Sst_Chodl_GABA  0.849975     Up        Gm10800
# 1       PFC_PFC_Sst_Chodl_GABA  0.849975     Up          Spns1
# 2       PFC_PFC_Sst_Chodl_GABA  0.849975     Up        Gm20388
# 3       PFC_PFC_Sst_Chodl_GABA  0.849975     Up        Gm33838
# 4       PFC_PFC_Sst_Chodl_GABA  0.849975     Up        Gm10801
# ...                        ...       ...    ...            ...
# 269500        PFC_PFC_Vip_GABA  0.999938   Down         Pgrmc2
# 269501        PFC_PFC_Vip_GABA  0.577918   Down  4932443L11Rik
# 269502        PFC_PFC_Vip_GABA  0.569337   Down        Gm12519
# 269503        PFC_PFC_Vip_GABA  0.194436   Down        Gm26061
# 269504        PFC_PFC_Vip_GABA  0.179725   Down         Ptpn23
#
#                       gene_id     gstart       gend strand annotation  \
# 0        ENSMUSG00000075014.1   98666546   98667301      -   genebody
# 1       ENSMUSG00000030741.15  126370059  126377450      -   genebody
# 2        ENSMUSG00000092329.1  119910840  124345722      +   genebody
# 3        ENSMUSG00000111059.1   35301721   35307599      -   genebody
# 4        ENSMUSG00000075015.3   98662236   98664083      +   genebody
# ...                       ...        ...        ...    ...        ...
# 269500   ENSMUSG00000049940.7   41066325   41083046      -   genebody
# 269501   ENSMUSG00000086805.9    4162521    4206882      -   genebody
# 269502   ENSMUSG00000085643.1   55969022   55993739      -   genebody
# 269503   ENSMUSG00000093325.1   51964381   51964489      +   genebody
# 269504  ENSMUSG00000036057.11  110385081  110408213      -   genebody
#
#         distance
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 269500         0
# 269501         0
# 269502    124846
# 269503     20789
# 269504         0
#
# [269505 rows x 18 columns]

# %%
df_DAR_ALL
# Out:
#                              names    scores  logfoldchanges     pvals  \
# 0           chr2:98666919-98667420  2.887307        1.489856  0.003886
# 1         chr7:126377225-126377726  2.472138        2.393066  0.013431
# 2         chr8:122443288-122443789  2.434396        2.122708  0.014917
# 3           chr9:35305177-35305678  2.396653        1.703857  0.016546
# 4           chr2:98662051-98662552  2.302297        1.412491  0.021318
# ...                            ...       ...             ...       ...
# 34187128    chr3:41082941-41083442 -4.139641       -0.662424  0.000035
# 34187129      chr8:4165942-4166443 -4.335513       -0.662157  0.000015
# 34187130    chr4:55843676-55844177 -4.359705       -1.520980  0.000013
# 34187131   chr11:51943092-51943593 -4.663189       -0.985756  0.000003
# 34187132  chr9:110408037-110408538 -4.710858       -0.825508  0.000002
#
#           pvals_adj  pct_nz_group  pct_nz_reference region  \
# 0          0.849975      1.000000          0.875000    PFC
# 1          0.849975      0.518519          0.166667    PFC
# 2          0.849975      0.555556          0.166667    PFC
# 3          0.849975      0.703704          0.416667    PFC
# 4          0.849975      0.925926          0.708333    PFC
# ...             ...           ...               ...    ...
# 34187128   0.999938      0.362799          0.480865    PFC
# 34187129   0.577918      0.373849          0.505824    PFC
# 34187130   0.569337      0.110497          0.252912    PFC
# 34187131   0.194436      0.211786          0.366057    PFC
# 34187132   0.179725      0.267035          0.415973    PFC
#
#                           ctname       fdr status
# 0         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# 1         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# 2         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# 3         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# 4         PFC_PFC_Sst_Chodl_GABA  0.849975     Up
# ...                          ...       ...    ...
# 34187128        PFC_PFC_Vip_GABA  0.999938   Down
# 34187129        PFC_PFC_Vip_GABA  0.577918   Down
# 34187130        PFC_PFC_Vip_GABA  0.569337   Down
# 34187131        PFC_PFC_Vip_GABA  0.194436   Down
# 34187132        PFC_PFC_Vip_GABA  0.179725   Down
#
# [269505 rows x 11 columns]

# %%
df_counts = df_DAR_ALL.groupby(['ctname','status','region']).size().reset_index(name='counts')

# %%
df_counts
# Out:
#                         ctname status region  counts
# 0     AMY_AMY_Cav1_Frmpd1_Glut   Down    AMY      91
# 1     AMY_AMY_Cav1_Frmpd1_Glut     Up    AMY     198
# 2    AMY_AMY_Ccdc3_Acvr1c_Glut   Down    AMY    1190
# 3    AMY_AMY_Ccdc3_Acvr1c_Glut     Up    AMY      42
# 4     AMY_AMY_Cdh23_Hmcn1_Glut   Down    AMY      62
# ..                         ...    ...    ...     ...
# 103     PFC_PFC_Sst_Chodl_GABA     Up    PFC       8
# 104           PFC_PFC_Sst_GABA   Down    PFC    3652
# 105           PFC_PFC_Sst_GABA     Up    PFC      26
# 106           PFC_PFC_Vip_GABA   Down    PFC    1336
# 107           PFC_PFC_Vip_GABA     Up    PFC      16
#
# [108 rows x 4 columns]

# %%
sns.barplot(data=df_counts, y='ctname', x='counts', hue='status', palette=['#FF7F0E','#1F77B4'], dodge=True,ci=None)
#plt.xlim(0, 5000)
# Out:
# /tmp/ipykernel_236077/3067550217.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_counts, y='ctname', x='counts', hue='status', palette=['#FF7F0E','#1F77B4'], dodge=True,ci=None)
# <Axes: xlabel='counts', ylabel='ctname'>

# %%
sns.catplot(x="status",y='counts', hue="status",estimator='sum',ci=None, col="region",order=['Up','Down'],hue_order=['Up','Down'], data=df_counts, kind="bar", height=4, aspect=1.5,sharey=False)
# Out:
# /tmp/ipykernel_236077/1752185037.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(x="status",y='counts', hue="status",estimator='sum',ci=None, col="region",order=['Up','Down'],hue_order=['Up','Down'], data=df_counts, kind="bar", height=4, aspect=1.5,sharey=False)

# %%
df_annotattion.names.str.split(r"[:-]",expand=True).to_csv(f"{folder}{method}_dar.bed",index=False,header=False, sep="\t")

# %%
df_annotattion
# Out:
#                             names    Pr(>Chisq)      coef     ci.hi     ci.lo  \
# 0       chr10:100456562-100457063  4.696654e-03  0.002657  0.014730 -0.009417
# 1       chr10:100487209-100487710  4.226688e-12  0.080716  0.103431  0.058001
# 2       chr10:100588995-100589496  4.672594e-08  0.019354  0.037042  0.001667
# 3       chr10:100617158-100617659  5.977000e-05 -0.002521  0.012405 -0.017448
# 4       chr10:100642797-100643298  1.338039e-02 -0.008394  0.002009 -0.018797
# ...                           ...           ...       ...       ...       ...
# 330510     chrX:98937053-98937554  5.231994e-12  0.089193  0.113645  0.064742
# 330511     chrX:99505795-99506296  6.136253e-03  0.013835  0.026267  0.001404
# 330512     chrY:90761439-90761940  1.848159e-10  0.044403  0.057215  0.031591
# 330513     chrY:90808582-90809083  1.669850e-10  0.054262  0.069888  0.038636
# 330514    chr13:43171217-43171718  1.262087e-06       NaN       NaN       NaN
#
#              padjust             celltype.L2 region                  ctname  \
# 0       1.000000e+00            HPF_CA3_Glut    HPF            HPF_CA3_Glut
# 1       1.371518e-07            HPF_CA3_Glut    HPF            HPF_CA3_Glut
# 2       1.516210e-03            HPF_CA3_Glut    HPF            HPF_CA3_Glut
# 3       1.000000e+00            HPF_CA3_Glut    HPF            HPF_CA3_Glut
# 4       1.000000e+00            HPF_CA3_Glut    HPF            HPF_CA3_Glut
# ...              ...                     ...    ...                     ...
# 330510  1.226536e-07  AMY_Zbtb7c_Vwa5b1_Glut    AMY  AMY_Zbtb7c_Vwa5b1_Glut
# 330511  1.000000e+00  AMY_Zbtb7c_Vwa5b1_Glut    AMY  AMY_Zbtb7c_Vwa5b1_Glut
# 330512  4.332639e-06  AMY_Zbtb7c_Vwa5b1_Glut    AMY  AMY_Zbtb7c_Vwa5b1_Glut
# 330513  3.914629e-06  AMY_Zbtb7c_Vwa5b1_Glut    AMY  AMY_Zbtb7c_Vwa5b1_Glut
# 330514  1.157712e-02      PFC_Sst_Chodl_GABA    PFC      PFC_Sst_Chodl_GABA
#
#                  fdr status      gene_name                gene_id     gstart  \
# 0       8.837957e-03     Up          Tmtc3  ENSMUSG00000036676.14  100443901
# 1       1.878792e-09     Up          Tmtc3  ENSMUSG00000036676.14  100443901
# 2       1.675370e-06     Up  4930430F08Rik  ENSMUSG00000046567.10  100572264
# 3       3.083919e-04   Down  1700017N19Rik  ENSMUSG00000056912.12  100590483
# 4       2.072305e-02   Down        Gm47325   ENSMUSG00000112328.1  100651629
# ...              ...    ...            ...                    ...        ...
# 330510  1.072788e-09     Up          Yipf6  ENSMUSG00000047694.12   98936315
# 330511  2.356687e-02     Up           Pja1  ENSMUSG00000034403.16   99465733
# 330512  2.256583e-08     Up       Mid1-ps1   ENSMUSG00000095134.2   90753056
# 330513  2.071232e-08     Up        Gm47283   ENSMUSG00000096768.8   90784737
# 330514  1.157712e-02   Down         Tbc1d7  ENSMUSG00000021368.15   43151739
#
#              gend strand annotation  distance
# 0       100487350      -   genebody         0
# 1       100487350      -   genebody         0
# 2       100590423      -   genebody         0
# 3       100618401      +   genebody         0
# 4       100651942      +   genebody      8332
# ...           ...    ...        ...       ...
# 330510   98949017      +   genebody         0
# 330511   99471273      -   genebody    -34523
# 330512   90763485      +   genebody         0
# 330513   90816465      +   genebody         0
# 330514   43171501      -   genebody         0
#
# [330515 rows x 18 columns]

# %%
dict_annot = {}
for file in annotations:
    name = file.split('/')[-1].replace('.bed', '')
    try:
        inte_dar_intron,non_overlapping_in = intersect_bed_files(f"{folder}{method}_dar.bed", file)
        df_annot = inte_dar_intron.to_dataframe()
        df_annot['names'] = df_annot["chrom"] + ":" + df_annot["start"].astype(str) + "-" + df_annot['end'].astype(str)
        df_annot['gene_name'] = df_annot['itemRgb']
        df_annot['cCRE'] = name
        dict_annot[name] = df_annot
        print(f"Processed {file},{len(dict_annot[name])}")
    except Exception as e:
        print(f"Error processing {file}, {e}")
        continue
# Out:
# Processed /data2st1/junyi/generegion_vM23/intron_selected.bed,719512
# Processed /data2st1/junyi/generegion_vM23/exon_selected.bed,665881
# Processed /data2st1/junyi/generegion_vM23/promoter2k.bed,342855
# Processed /data2st1/junyi/output/atac0416/cCRE/LINE.bed,18238
# Processed /data2st1/junyi/output/atac0416/cCRE/SINE.bed,51166
# Processed /data2st1/junyi/output/atac0416/cCRE/LTR.bed,21806
# Processed /data2st1/junyi/output/atac0416/cCRE/cpg.bed,146698
# Processed /data2st1/junyi/output/atac0416/cCRE/Other_repeats.bed,124680
# ***** WARNING: File /data2st1/junyi/generegion_vM23/UTR.bed has inconsistent naming convention for record:
# KZ289081.1	123732	123914	.	+	Slfn2	ENSMUSG00000116022.1	basic
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/UTR.bed has inconsistent naming convention for record:
# KZ289081.1	123732	123914	.	+	Slfn2	ENSMUSG00000116022.1	basic
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/UTR.bed has inconsistent naming convention for record:
# KZ289081.1	123732	123914	.	+	Slfn2	ENSMUSG00000116022.1	basic
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/UTR.bed has inconsistent naming convention for record:
# KZ289081.1	123732	123914	.	+	Slfn2	ENSMUSG00000116022.1	basic
# Processed /data2st1/junyi/generegion_vM23/UTR.bed,392880
# ***** WARNING: File /data2st1/junyi/generegion_vM23/CDS.bed has inconsistent naming convention for record:
# KZ289080.1	76374	76525	.	-	LT629147.3	ENSMUSG00000116214.1	CDS
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/CDS.bed has inconsistent naming convention for record:
# KZ289080.1	76374	76525	.	-	LT629147.3	ENSMUSG00000116214.1	CDS
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/CDS.bed has inconsistent naming convention for record:
# KZ289080.1	76374	76525	.	-	LT629147.3	ENSMUSG00000116214.1	CDS
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/CDS.bed has inconsistent naming convention for record:
# KZ289080.1	76374	76525	.	-	LT629147.3	ENSMUSG00000116214.1	CDS
# Processed /data2st1/junyi/generegion_vM23/CDS.bed,203954
# ***** WARNING: File /data2st1/junyi/generegion_vM23/genebody.bed has inconsistent naming convention for record:
# KZ289080.1	7804	8459	.	-	LT629147.1	ENSMUSG00000115879.1	genebody
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/genebody.bed has inconsistent naming convention for record:
# KZ289080.1	7804	8459	.	-	LT629147.1	ENSMUSG00000115879.1	genebody
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/genebody.bed has inconsistent naming convention for record:
# KZ289080.1	7804	8459	.	-	LT629147.1	ENSMUSG00000115879.1	genebody
#
# ***** WARNING: File /data2st1/junyi/generegion_vM23/genebody.bed has inconsistent naming convention for record:
# KZ289080.1	7804	8459	.	-	LT629147.1	ENSMUSG00000115879.1	genebody
# Processed /data2st1/junyi/generegion_vM23/genebody.bed,321978
# Processed /data2st1/junyi/output/atac0416/cCRE/intergenic.bed,218465
# Processed /data2st1/junyi/output/atac0416/cCRE/mm10-cCREs.bed,402707

# %%
memento_primary_regions = {
    'intron': set(dict_annot['intron_selected'].names),
    'exon': set(dict_annot['exon_selected'].names),
    'promoter': set(dict_annot['promoter2k'].names),
    'UTR': set(dict_annot['UTR'].names),
    'intergenic': set(dict_annot['intergenic'].names),
    # 'LINE': set(dict_annot['LINE'].names+"_"+dict_annot['LINE'].gene_name),
    # 'SINE': set(dict_annot['SINE'].names+"_"+dict_annot['SINE'].gene_name),
    # 'LTR': set(dict_annot['LTR'].names+"_"+dict_annot['LTR'].gene_name),
    # 'repeat': set(dict_annot['Other_repeats'].names+"_"+dict_annot['Other_repeats'].gene_name),
    # 'cpg': set(dict_annot['cpg'].names+"_"+dict_annot['cpg'].gene_name)

    # 'intron': set(dict_annot['intron_selected'].names),
    # 'exon': set(dict_annot['exon_selected'].names),
    # 'promoter': set(dict_annot['promoter2k'].names),
    # 'UTR': set(dict_annot['UTR'].names),
    # 'repeat': set(dict_annot['repeat'].names),
    # 'cpg': set(dict_annot['cpg'].names),
}
memento_primary_regions = from_contents(memento_primary_regions)
ax_dict = UpSet(memento_primary_regions, subset_size="count", sort_by="cardinality", show_counts=True).plot()

# %%
df_memnto_primary = memento_primary_regions.reset_index()
df_memnto_primary = get_proity_region(df_memnto_primary)

# %%
df_memnto_primary.rename(columns={'id': 'names'}, inplace=True)
df_memnto_primary.set_index('names', inplace=True)
df_merge = df_annotattion.merge(df_memnto_primary[['annotation']], on="names", how="left")

df_merge.loc[(df_merge.apply(is_promoter, axis=1),"annotation_y")] = "promoter"
#df_merge.loc[((df_merge.annotation_y.isna()) | (df_merge.annotation_y=="intergenic")) & (df_merge.apply(is_promoter, axis=1)),"annotation_y"] = "promoter"
df_merge.loc[((df_merge.annotation_y.isna()) | (df_merge.annotation_y=="intergenic")) & (df_merge.strand=="+") & (df_merge.distance<0),"annotation_y"] = "downstream"
df_merge.loc[((df_merge.annotation_y.isna()) | (df_merge.annotation_y=="intergenic")) & (df_merge.strand=="-") & (df_merge.distance>0),"annotation_y"] = "downstream"
df_merge.loc[((df_merge.annotation_y.isna()) | (df_merge.annotation_y=="intergenic")) & (df_merge.strand=="+") & (df_merge.distance>2000),"annotation_y"] = "distal"
df_merge.loc[((df_merge.annotation_y.isna()) | (df_merge.annotation_y=="intergenic")) & (df_merge.strand=="-") & (df_merge.distance<-2000),"annotation_y"] = "distal"
#assert df_merge[df_merge.annotation_y=="intergenic"].distance.values.min() == df_merge[df_merge.annotation_y=="intergenic"].distance.values.max() ==0
df_merge.loc[(df_merge.annotation_x=="genebody") & (df_merge.distance==0) & ((df_merge.annotation_y.isna()) | (df_merge.annotation_y=="intergenic")),"annotation_y"] = "genebody"
df_merge.rename(columns={"annotation_y":"primary_region"}, inplace=True)

# %%
df_memnto_primary_c = df_merge.groupby(['primary_region']).size().reset_index(name='counts')
df_memnto_primary_c.set_index('primary_region').plot.pie(
    y='counts',
    autopct=lambda p: f'{p:.1f}%' if p >= 5 else '',
    legend=False
)
# Out:
# <Axes: ylabel='counts'>

# %%
memento_secondary_regions = {
    'LINE': set(dict_annot['LINE'].names),
    'SINE': set(dict_annot['SINE'].names),
    'LTR': set(dict_annot['LTR'].names),
    'repeat': set(dict_annot['Other_repeats'].names),
    'cpg': set(dict_annot['cpg'].names)
}
memento_secondary_regions = from_contents(memento_secondary_regions)
ax_dict = UpSet(memento_secondary_regions, subset_size="count", sort_by="cardinality", show_counts=True).plot()

# %%
df_memnto_secondary_regions = memento_secondary_regions.reset_index()
second_priority =[
    "cpg",
    "LTR",
    "LINE",
    "SINE",
    "repeat"
]
df_memnto_secondary_regions = get_proity_region(df_memnto_secondary_regions,priority=second_priority)
df_memnto_secondary_regions.rename(columns={"id":"names","annotation":"secondary_region"}, inplace=True)

# %%
df_2nd_merge = df_merge.merge(df_memnto_secondary_regions[["names",'secondary_region']], on="names", how="left")

# %%
df_2nd_merge_c = df_2nd_merge.groupby(['secondary_region']).size().reset_index(name='counts')
df_2nd_merge_c.set_index('secondary_region').plot.pie(
    y='counts',
    autopct=lambda p: f'{p:.1f}%' if p >= 5 else '',
    legend=False
)
# Out:
# <Axes: ylabel='counts'>

# %%
df_3rd_merge = df_2nd_merge.merge(dict_annot['mm10-cCREs'][['names','itemRgb']], on="names", how="left", suffixes=('', 'encodeCCRE'))

# %%
df_3rd_merge = df_3rd_merge.drop_duplicates()

# %%
df_3nd_merge_c = df_3rd_merge.groupby(['itemRgb']).size().reset_index(name='counts')
df_3nd_merge_c.set_index('itemRgb').plot.pie(
    y='counts',
    autopct=lambda p: f'{p:.1f}%' if p >= 5 else '',
    legend=False
)
# Out:
# <Axes: ylabel='counts'>

# %%
df_3rd_merge.rename(columns={'itemRgb': 'encodeCCRE'}, inplace=True)

# %%
df_3rd_merge['Region'] = df_3rd_merge['region']
df_3rd_merge['Subclass'] = df_3rd_merge['celltype.L2']
df_3rd_merge['Sex'] = 'M'
df_3rd_merge['Region subclass'] = df_3rd_merge['region'] +"_"+ df_3rd_merge['celltype.L2']
df_3rd_merge['Region subclass'] = df_3rd_merge['Region subclass'].str.replace("AMY_AMY_", "AMY_")
df_3rd_merge['Region subclass'] = df_3rd_merge['Region subclass'].str.replace("HPF_HPF_", "HPF_")
df_3rd_merge['Region subclass'] = df_3rd_merge['Region subclass'].str.replace("PFC_PFC_", "PFC_")
df_3rd_merge['Ensemble'] = df_3rd_merge['gene_id']
df_3rd_merge['Gene'] = df_3rd_merge['names']
df_3rd_merge['log2FC'] = df_3rd_merge['coef']
df_3rd_merge['Direction'] = df_3rd_merge['status']
df_3rd_merge['Neurotransmitter'] = df_3rd_merge['celltype.L2'].apply(
    lambda x: 'Glut' if 'Glut' in x else ('GABA' if 'GABA' in x else 'NN')
)
df_3rd_merge['Gene_name'] = df_3rd_merge['names']
df_3rd_merge['FDR'] = df_3rd_merge['fdr']

# %%
df_3rd_merge
# Out:
#                              names    Pr(>Chisq)      coef     ci.hi  \
# 0        chr10:100456562-100457063  4.696654e-03  0.002657  0.014730
# 1        chr10:100487209-100487710  4.226688e-12  0.080716  0.103431
# 2        chr10:100487209-100487710  4.226688e-12  0.080716  0.103431
# 64       chr10:100588995-100589496  4.672594e-08  0.019354  0.037042
# 74       chr10:100617158-100617659  5.977000e-05 -0.002521  0.012405
# ...                            ...           ...       ...       ...
# 4613656     chrX:99505795-99506296  6.136253e-03  0.013835  0.026267
# 4613657     chrY:90761439-90761940  1.848159e-10  0.044403  0.057215
# 4613658     chrY:90808582-90809083  1.669850e-10  0.054262  0.069888
# 4613659    chr13:43171217-43171718  1.262087e-06       NaN       NaN
# 4613661    chr13:43171217-43171718  1.262087e-06       NaN       NaN
#
#             ci.lo       padjust             celltype.L2 region  \
# 0       -0.009417  1.000000e+00            HPF_CA3_Glut    HPF
# 1        0.058001  1.371518e-07            HPF_CA3_Glut    HPF
# 2        0.058001  1.371518e-07            HPF_CA3_Glut    HPF
# 64       0.001667  1.516210e-03            HPF_CA3_Glut    HPF
# 74      -0.017448  1.000000e+00            HPF_CA3_Glut    HPF
# ...           ...           ...                     ...    ...
# 4613656  0.001404  1.000000e+00  AMY_Zbtb7c_Vwa5b1_Glut    AMY
# 4613657  0.031591  4.332639e-06  AMY_Zbtb7c_Vwa5b1_Glut    AMY
# 4613658  0.038636  3.914629e-06  AMY_Zbtb7c_Vwa5b1_Glut    AMY
# 4613659       NaN  1.157712e-02      PFC_Sst_Chodl_GABA    PFC
# 4613661       NaN  1.157712e-02      PFC_Sst_Chodl_GABA    PFC
#
#                          ctname           fdr  ...                Subclass  \
# 0                  HPF_CA3_Glut  8.837957e-03  ...            HPF_CA3_Glut
# 1                  HPF_CA3_Glut  1.878792e-09  ...            HPF_CA3_Glut
# 2                  HPF_CA3_Glut  1.878792e-09  ...            HPF_CA3_Glut
# 64                 HPF_CA3_Glut  1.675370e-06  ...            HPF_CA3_Glut
# 74                 HPF_CA3_Glut  3.083919e-04  ...            HPF_CA3_Glut
# ...                         ...           ...  ...                     ...
# 4613656  AMY_Zbtb7c_Vwa5b1_Glut  2.356687e-02  ...  AMY_Zbtb7c_Vwa5b1_Glut
# 4613657  AMY_Zbtb7c_Vwa5b1_Glut  2.256583e-08  ...  AMY_Zbtb7c_Vwa5b1_Glut
# 4613658  AMY_Zbtb7c_Vwa5b1_Glut  2.071232e-08  ...  AMY_Zbtb7c_Vwa5b1_Glut
# 4613659      PFC_Sst_Chodl_GABA  1.157712e-02  ...      PFC_Sst_Chodl_GABA
# 4613661      PFC_Sst_Chodl_GABA  1.157712e-02  ...      PFC_Sst_Chodl_GABA
#
#         Sex         Region subclass               Ensemble  \
# 0         M            HPF_CA3_Glut  ENSMUSG00000036676.14
# 1         M            HPF_CA3_Glut  ENSMUSG00000036676.14
# 2         M            HPF_CA3_Glut  ENSMUSG00000036676.14
# 64        M            HPF_CA3_Glut  ENSMUSG00000046567.10
# 74        M            HPF_CA3_Glut  ENSMUSG00000056912.12
# ...      ..                     ...                    ...
# 4613656   M  AMY_Zbtb7c_Vwa5b1_Glut  ENSMUSG00000034403.16
# 4613657   M  AMY_Zbtb7c_Vwa5b1_Glut   ENSMUSG00000095134.2
# 4613658   M  AMY_Zbtb7c_Vwa5b1_Glut   ENSMUSG00000096768.8
# 4613659   M      PFC_Sst_Chodl_GABA  ENSMUSG00000021368.15
# 4613661   M      PFC_Sst_Chodl_GABA  ENSMUSG00000021368.15
#
#                               Gene    log2FC Direction  Neurotransmitter  \
# 0        chr10:100456562-100457063  0.002657        Up              Glut
# 1        chr10:100487209-100487710  0.080716        Up              Glut
# 2        chr10:100487209-100487710  0.080716        Up              Glut
# 64       chr10:100588995-100589496  0.019354        Up              Glut
# 74       chr10:100617158-100617659 -0.002521      Down              Glut
# ...                            ...       ...       ...               ...
# 4613656     chrX:99505795-99506296  0.013835        Up              Glut
# 4613657     chrY:90761439-90761940  0.044403        Up              Glut
# 4613658     chrY:90808582-90809083  0.054262        Up              Glut
# 4613659    chr13:43171217-43171718       NaN      Down              GABA
# 4613661    chr13:43171217-43171718       NaN      Down              GABA
#
#                          Gene_name           FDR
# 0        chr10:100456562-100457063  8.837957e-03
# 1        chr10:100487209-100487710  1.878792e-09
# 2        chr10:100487209-100487710  1.878792e-09
# 64       chr10:100588995-100589496  1.675370e-06
# 74       chr10:100617158-100617659  3.083919e-04
# ...                            ...           ...
# 4613656     chrX:99505795-99506296  2.356687e-02
# 4613657     chrY:90761439-90761940  2.256583e-08
# 4613658     chrY:90808582-90809083  2.071232e-08
# 4613659    chr13:43171217-43171718  1.157712e-02
# 4613661    chr13:43171217-43171718  1.157712e-02
#
# [377988 rows x 32 columns]

# %%
df_3rd_merge.to_csv(f"{folder}{method}_dar_annotated.csv",index=False)

# %%
# subsey by de_val < 0.05
df_2nd_merge_selcted = df_3rd_merge[df_3rd_merge.fdr < 0.05].copy()

# %%
df_2nd_merge_selcted.rename(columns={"gene_name":"gene"}, inplace=True)

# %%
df_repeat = df_2nd_merge_selcted.loc[df_2nd_merge_selcted.ctname.isin(set(df_2nd_merge_selcted.ctname)),['ctname','status','gene']].groupby(['status','gene']).nunique().reset_index()

# %%
df_repeat.rename(columns={'ctname': 'n_celltype'}, inplace=True)

# %%
df_ct = df_2nd_merge_selcted.loc[df_2nd_merge_selcted.ctname.isin(set(df_2nd_merge_selcted.ctname)),['ctname','status','gene']].groupby(
    ['status','gene']).aggregate(lambda x: '/'.join(set(x))).reset_index()

# %%
df_ct_repeat = df_ct.merge(df_repeat, how='inner', on=['status', 'gene'])

# %%
df_ct_repeat.rename(columns={'ctname': 'darct'}, inplace=True)

# %%
df_2nd_merge_selcted.merge(df_ct_repeat, how='left', on=['status', 'gene']).to_csv(f'{folder}{method}_dar_ncelltype.csv', index=False)
