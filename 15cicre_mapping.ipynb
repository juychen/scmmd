# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline

#import seaborn as sns


import os, sys, shutil, importlib, glob
from tqdm.notebook import tqdm
# from celloracle import motif_analysis as ma
# import celloracle as co

# %%
import glob as glob

# %%
networks = glob.glob('/data2st1/junyi/output/atac1112/cicre/*network.csv')
df_peaks = pd.read_csv('/data2st1/junyi/output/atac1112/cCRE/cCRE_annotated.csv')

# %%
df_peaks.primary_region.value_counts()
# Out:
# primary_region
# genebody      886180
# downstream    367739
# distal        308672
# promoter       63154
# intron         30464
# exon            6628
# UTR             4495
# Name: count, dtype: int64

# %%
# peaks = df_peaks.names.str.replace("[:-]","_")
# tss_annotated = ma.get_tss_info(peak_str_list=peaks, ref_genome="mm10")

# %%
df_peaks_promoter = df_peaks[df_peaks['primary_region']=='promoter']
df_peaks_promoter['Peakp'] = df_peaks_promoter['names'].str.replace("[:-]","_", regex=True)
# Out:
# /tmp/ipykernel_2695510/815865365.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_peaks_promoter['Peakp'] = df_peaks_promoter['names'].str.replace("[:-]","_", regex=True)

# %%
df_peaks_promoter
# Out:
#           chr     start       end                   names      gene_name  \
# 20       chr1   3071402   3071903    chr1:3071402-3071903  4933401J01Rik
# 21       chr1   3072947   3073448    chr1:3072947-3073448  4933401J01Rik
# 32       chr1   3100678   3101179    chr1:3100678-3101179        Gm26206
# 224      chr1   3368193   3368694    chr1:3368193-3368694        Gm37180
# 306      chr1   3466283   3466784    chr1:3466283-3466784         Gm1992
# ...       ...       ...       ...                     ...            ...
# 1667202  chrY  72822100  72822601  chrY:72822100-72822601        Gm20846
# 1667239  chrY  86219218  86219719  chrY:86219218-86219719        Gm28218
# 1667246  chrY  86870132  86870633  chrY:86870132-86870633        Gm21462
# 1667262  chrY  88052253  88052754  chrY:88052253-88052754        Gm28102
# 1667288  chrY  90606500  90607001  chrY:90606500-90607001        Gm28300
#
#                       gene_id    gstart      gend strand annotation_x  \
# 20       ENSMUSG00000102693.1   3073252   3074322      +     genebody
# 21       ENSMUSG00000102693.1   3073252   3074322      +     genebody
# 32       ENSMUSG00000064842.1   3102015   3102125      +     genebody
# 224      ENSMUSG00000103377.1   3365730   3368549      -     genebody
# 306      ENSMUSG00000089699.1   3466586   3513553      +     genebody
# ...                       ...       ...       ...    ...          ...
# 1667202  ENSMUSG00000100869.1  72819637  72820330      -     genebody
# 1667239  ENSMUSG00000099824.1  86219343  86222581      +     genebody
# 1667246  ENSMUSG00000100655.1  86869359  86870055      -     genebody
# 1667262  ENSMUSG00000101915.1  88053314  88079494      +     genebody
# 1667288  ENSMUSG00000099619.6  90603500  90605864      -     genebody
#
#          distance primary_region secondary_region encodeCCRE Sex  \
# 20           1350       promoter              NaN        NaN   M
# 21              0       promoter              NaN        NaN   M
# 32            837       promoter              NaN        NaN   M
# 224             0       promoter              NaN        NaN   M
# 306             0       promoter              NaN        NaN   M
# ...           ...            ...              ...        ...  ..
# 1667202     -1771       promoter              NaN        NaN   M
# 1667239         0       promoter              NaN        NaN   M
# 1667246       -78       promoter              NaN        NaN   M
# 1667262       561       promoter              NaN        NaN   M
# 1667288      -637       promoter              NaN        NaN   M
#
#                      Ensemble                    Gene                   Peakp
# 20       ENSMUSG00000102693.1    chr1:3071402-3071903    chr1_3071402_3071903
# 21       ENSMUSG00000102693.1    chr1:3072947-3073448    chr1_3072947_3073448
# 32       ENSMUSG00000064842.1    chr1:3100678-3101179    chr1_3100678_3101179
# 224      ENSMUSG00000103377.1    chr1:3368193-3368694    chr1_3368193_3368694
# 306      ENSMUSG00000089699.1    chr1:3466283-3466784    chr1_3466283_3466784
# ...                       ...                     ...                     ...
# 1667202  ENSMUSG00000100869.1  chrY:72822100-72822601  chrY_72822100_72822601
# 1667239  ENSMUSG00000099824.1  chrY:86219218-86219719  chrY_86219218_86219719
# 1667246  ENSMUSG00000100655.1  chrY:86870132-86870633  chrY_86870132_86870633
# 1667262  ENSMUSG00000101915.1  chrY:88052253-88052754  chrY_88052253_88052754
# 1667288  ENSMUSG00000099619.6  chrY:90606500-90607001  chrY_90606500_90607001
#
# [63154 rows x 18 columns]

# %%
network = networks[4]
df_cire_tmp = pd.read_csv(network,index_col=0)
df_cire_selected = df_cire_tmp[df_cire_tmp.pval_adj<0.05]
#df_cire_selected = df_cire_selected.rename({"score":"coaccess"},axis=1)

df_enh1 = df_cire_selected.merge(df_peaks_promoter[['Peakp','gene_name']],left_on='Peak1',right_on='Peakp',how='inner')[['Peak2','Peakp','score','gene_name']]

# %%
    df_enh1.columns = ['peak_id','promoter','coaccess','gene_short_name']

# %%
    df_enh2 = df_cire_selected.merge(df_peaks_promoter[['Peakp','gene_name']],left_on='Peak2',right_on='Peakp',how='inner')[['Peak1','Peakp','score','gene_name']]
    df_enh2.columns = ['peak_id','promoter','coaccess','gene_short_name']
    integrated_enhancer = pd.concat([df_enh1,df_enh2],axis=0)

# %%
integrated_enhancer
# Out:
#                         peak_id                  promoter  coaccess  \
# 0       chr13_27583619_27584120   chr13_27565832_27566333  0.760965
# 1       chr13_27801754_27802255   chr13_27565832_27566333  0.726945
# 2          chrX_9125362_9125863      chrX_9121281_9121782  0.707122
# 3       chr14_41105278_41105779   chr14_41104700_41105201  0.700104
# 4        chr2_98666919_98667420    chr2_98662051_98662552  0.692709
# ...                         ...                       ...       ...
# 57712    chr5_18793107_18793608    chr5_19226494_19226995  0.022237
# 57713   chr10_81522918_81523419   chr10_81602743_81603244  0.022235
# 57714    chr3_60051632_60052133    chr3_60079488_60079989  0.022235
# 57715   chr16_78863610_78864111   chr16_78930508_78931009  0.022235
# 57716  chrX_137016868_137017369  chrX_137150278_137150779  0.022234
#
#       gene_short_name
# 0              Prl8a9
# 1              Prl8a9
# 2          Fthl17-ps3
# 3               Mat1a
# 4             Gm10801
# ...               ...
# 57712   4921504A21Rik
# 57713            Tle6
# 57714          Sucnr1
# 57715           Chodl
# 57716         Gm23679
#
# [116274 rows x 4 columns]

# %%
integrated_enhancer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 integrated_enhancer
#
# NameError: name 'integrated_enhancer' is not defined

# %%
enhancers = pd.DataFrame()
for network in networks:
    df_cire_tmp = pd.read_csv(network,index_col=0)
    df_cire_selected = df_cire_tmp[df_cire_tmp.pval_adj<0.05]
    #df_cire_selected = df_cire_selected.rename({"score":"coaccess"},axis=1)

    df_enh1 = df_cire_selected.merge(df_peaks_promoter[['Peakp','gene_name']],left_on='Peak1',right_on='Peakp',how='inner')[['Peak2','Peakp','score','gene_name']]
    df_enh1.columns = ['peak_id','promoter','coaccess','gene_short_name']
    df_enh2 = df_cire_selected.merge(df_peaks_promoter[['Peakp','gene_name']],left_on='Peak2',right_on='Peakp',how='inner')[['Peak1','Peakp','score','gene_name']]
    df_enh2.columns = ['peak_id','promoter','coaccess','gene_short_name']
    integrated_enhancer = pd.concat([df_enh1,df_enh2],axis=0)
    integrated_enhancer.sort_values(by='coaccess',ascending=False,inplace=True)
    integrated_enhancer.drop_duplicates(subset='peak_id', inplace=True)

    if df_cire_selected.shape[0]==0:
        continue
    # integrated = ma.integrate_tss_peak_with_cicero(tss_peak=tss_annotated,
    #                                             cicero_connections=df_cire_selected)
    # integrated_enhancer = integrated[integrated.coaccess<1]
    integrated_enhancer_split = integrated_enhancer.peak_id.str.split("_",expand=True)
    integrated_enhancer['names'] = integrated_enhancer_split[0] + ":" + integrated_enhancer_split[1].astype(str) + "-" + integrated_enhancer_split[2].astype(str)
    region_subclass = network.split('/')[-1].replace('_ALL_circe_network.csv','').replace('HIP','HPF').replace('AMY_AMY','AMY').replace('HPF_HPF','HPF').replace('PFC_PFC','PFC')
    integrated_enhancer['Region Subclass'] = region_subclass
    #integrated_enhancer.to_csv(network.replace('_ALL_circe_network.csv','_enhancers.csv'))
    enhancers = pd.concat([enhancers,integrated_enhancer],axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/snapatac2/lib/python3.10/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 21
#      17 # integrated = ma.integrate_tss_peak_with_cicero(tss_peak=tss_annotated,
#      18 #                                             cicero_connections=df_cire_selected)
#      19 # integrated_enhancer = integrated[integrated.coaccess<1]
#      20 integrated_enhancer_split = integrated_enhancer.peak_id.str.split("_",expand=True)
# ---> 21 integrated_enhancer['names'] = integrated_enhancer_split[0] + ":" + integrated_enhancer_split[1].astype(str) + "-" + integrated_enhancer_split[2].astype(str)
#      22 region_subclass = network.split('/')[-1].replace('_ALL_circe_network.csv','').replace('HIP','HPF').replace('AMY_AMY','AMY').replace('HPF_HPF','HPF').replace('PFC_PFC','PFC')
#      23 integrated_enhancer['Region Subclass'] = region_subclass
#
# File ~/anaconda3/envs/snapatac2/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/anaconda3/envs/snapatac2/lib/python3.10/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 0

# %%
fenhancers = glob.glob('/data2st1/junyi/output/atac1112/cicre/*enhancers.csv')
enhancers = pd.DataFrame()
for enhancer in fenhancers:
    df_tmp = pd.read_csv(enhancer,index_col=0)
    enhancers = pd.concat([enhancers,df_tmp],axis=0)

# %%
df_DAR = pd.read_csv('/data2st1/junyi/output/atac1112/dar/celltype.L2/MASTNG_dar_annotated.csv')

# %%
df_DAR.merge(enhancers,left_on=['names','Region Subclass'],right_on=['names','Region Subclass'],how='left',suffixes=('_dar','_enhancer'))
# Out:
#                             names    Pr(>Chisq)      coef     ci.hi     ci.lo  \
# 0       chr10:100456562-100457063  1.414898e-02 -0.006031  0.006165 -0.018226
# 1       chr10:100487209-100487710  1.702931e-10  0.068210  0.093457  0.042963
# 2       chr10:100487209-100487710  1.702931e-10  0.068210  0.093457  0.042963
# 3       chr10:100642797-100643298  6.163128e-03 -0.014478 -0.004093 -0.024864
# 4         chr10:10107158-10107659  5.303556e-07  0.030881  0.045954  0.015808
# ...                           ...           ...       ...       ...       ...
# 334132     chr7:99535252-99535753  4.700413e-06  0.001785  0.060391 -0.056820
# 334133   chr9:103365644-103366145  8.286317e-05  0.028069  0.108636 -0.052498
# 334134     chr9:99436435-99436936  3.917479e-05 -0.054067 -0.014330 -0.093805
# 334135    chr13:43171217-43171718  2.009124e-06       NaN       NaN       NaN
# 334136    chr13:43171217-43171718  2.009124e-06       NaN       NaN       NaN
#
#          padjust           celltype.L2 region                ctname  \
# 0       1.000000          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 1       0.000006          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 2       0.000006          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 3       1.000000          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 4       0.017210          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# ...          ...                   ...    ...                   ...
# 334132  0.079099  AMY_Npas1_Rgs12_GABA    AMY  AMY_Npas1_Rgs12_GABA
# 334133  1.000000  AMY_Npas1_Rgs12_GABA    AMY  AMY_Npas1_Rgs12_GABA
# 334134  0.659233  AMY_Npas1_Rgs12_GABA    AMY  AMY_Npas1_Rgs12_GABA
# 334135  0.018430    PFC_Sst_Chodl_GABA    PFC    PFC_Sst_Chodl_GABA
# 334136  0.018430    PFC_Sst_Chodl_GABA    PFC    PFC_Sst_Chodl_GABA
#
#                  fdr  ...                       Gene    log2FC Direction  \
# 0       2.751694e-02  ...  chr10:100456562-100457063 -0.006031      Down
# 1       9.867574e-08  ...  chr10:100487209-100487710  0.068210        Up
# 2       9.867574e-08  ...  chr10:100487209-100487710  0.068210        Up
# 3       1.490774e-02  ...  chr10:100642797-100643298 -0.014478      Down
# 4       2.347109e-05  ...    chr10:10107158-10107659  0.030881        Up
# ...              ...  ...                        ...       ...       ...
# 334132  1.977464e-02  ...     chr7:99535252-99535753  0.001785        Up
# 334133  4.904168e-02  ...   chr9:103365644-103366145  0.028069        Up
# 334134  3.488255e-02  ...     chr9:99436435-99436936 -0.054067      Down
# 334135  1.842970e-02  ...    chr13:43171217-43171718       NaN      Down
# 334136  1.842970e-02  ...    chr13:43171217-43171718       NaN      Down
#
#         Neurotransmitter                  Gene_name           FDR peak_id  \
# 0                   Glut  chr10:100456562-100457063  2.751694e-02     NaN
# 1                   Glut  chr10:100487209-100487710  9.867574e-08     NaN
# 2                   Glut  chr10:100487209-100487710  9.867574e-08     NaN
# 3                   Glut  chr10:100642797-100643298  1.490774e-02     NaN
# 4                   Glut    chr10:10107158-10107659  2.347109e-05     NaN
# ...                  ...                        ...           ...     ...
# 334132              GABA     chr7:99535252-99535753  1.977464e-02     NaN
# 334133              GABA   chr9:103365644-103366145  4.904168e-02     NaN
# 334134              GABA     chr9:99436435-99436936  3.488255e-02     NaN
# 334135              GABA    chr13:43171217-43171718  1.842970e-02     NaN
# 334136              GABA    chr13:43171217-43171718  1.842970e-02     NaN
#
#         promoter coaccess gene_short_name
# 0            NaN      NaN             NaN
# 1            NaN      NaN             NaN
# 2            NaN      NaN             NaN
# 3            NaN      NaN             NaN
# 4            NaN      NaN             NaN
# ...          ...      ...             ...
# 334132       NaN      NaN             NaN
# 334133       NaN      NaN             NaN
# 334134       NaN      NaN             NaN
# 334135       NaN      NaN             NaN
# 334136       NaN      NaN             NaN
#
# [334137 rows x 36 columns]

# %%
# --- DAR vs enhancers 匹配统计 ---
df_DAR_enhtmp = df_DAR.merge(
    enhancers,
    left_on=['names', 'Region Subclass'],
    right_on=['names', 'Region Subclass'],
    how='left',
    suffixes=('_dar', '_enhancer')
)

total_dar = df_DAR.shape[0]
matched_dar = df_DAR_enhtmp['coaccess'].notna().sum()
unmatched_dar = total_dar - matched_dar

print(f"总 DAR: {total_dar}")
print(f"匹配到 enhancer 的 DAR: {matched_dar} ({matched_dar/total_dar*100:.1f}%)")
print(f"未匹配的 DAR: {unmatched_dar} ({unmatched_dar/total_dar*100:.1f}%)")
print()

# 按 Region Subclass 统计
print("=== 按 Region Subclass ===")
region_stats = df_DAR_enhtmp.groupby('Region Subclass').agg(
    total_dar=('coaccess', 'size'),
    matched=('coaccess', lambda s: s.notna().sum()),
).assign(match_rate=lambda x: (x['matched'] / x['total_dar'] * 100).round(1))
print(region_stats.to_string())
print()

# 按 primary_region 统计
print("=== 按 primary_region ===")
if 'primary_region' in df_DAR_enhtmp.columns:
    pr_col = 'primary_region'
elif 'primary_region_dar' in df_DAR_enhtmp.columns:
    pr_col = 'primary_region_dar'
else:
    pr_col = None

if pr_col:
    pr_stats = df_DAR_enhtmp.groupby(pr_col).agg(
        total_dar=('coaccess', 'size'),
        matched=('coaccess', lambda s: s.notna().sum()),
    ).assign(match_rate=lambda x: (x['matched'] / x['total_dar'] * 100).round(1))
    print(pr_stats.to_string())
# Out:
# 总 DAR: 334137
# 匹配到 enhancer 的 DAR: 11180 (3.3%)
# 未匹配的 DAR: 322957 (96.7%)
#
# === 按 Region Subclass ===
#                          total_dar  matched  match_rate
# Region Subclass
# AMY_Astrocyte-1                346       81        23.4
# AMY_Astrocyte-2                341       29         8.5
# AMY_Cav1_Frmpd1_Glut           131       39        29.8
# AMY_Ccdc3_Acvr1c_Glut        21187      694         3.3
# AMY_Crhbp_Maf_GABA           16797      988         5.9
# AMY_Esr2_Gldn_GABA             360       43        11.9
# AMY_Fign_Ostm1_GABA          19158      644         3.4
# AMY_Foxp2_Penk_GABA           4923      340         6.9
# AMY_MOL-1                      136       36        26.5
# AMY_MOL-2                        8        7        87.5
# AMY_Meis1_Abi3bp_Glut         9767      261         2.7
# AMY_Microglia-1                359       34         9.5
# AMY_Ndnf_Lamp5_GABA              1        0         0.0
# AMY_Npas1_Rgs12_GABA            35        5        14.3
# AMY_Piezo2_Cpa6_Glut         30440      962         3.2
# AMY_Rai14_Foxp2_GABA            38       13        34.2
# AMY_Rorb_Smoc1_Glut            269       10         3.7
# AMY_Rspo2_Gm11639_Glut       16053      488         3.0
# AMY_Tcf7l2_Gm20713_Glut        772       84        10.9
# AMY_Trabd2b_Coch_Glut        25460      800         3.1
# AMY_Zbtb7c_Vwa5b1_Glut       26808      798         3.0
# AMY_Zfhx4_Pde7b_GABA         17788      573         3.2
# HPF_Astrocyte-2                137       15        10.9
# HPF_CA1_Glut                 24700      652         2.6
# HPF_CA2_Glut                     3        0         0.0
# HPF_CA3_Glut                 22789      624         2.7
# HPF_DG_GC_Glut               10387      270         2.6
# HPF_Ependymal_cell               1        0         0.0
# HPF_MOL-1                        4        2        50.0
# HPF_MOL-2                       10        5        50.0
# HPF_Microglia-1                 27       13        48.1
# HPF_Microglia-2                  4        1        25.0
# HPF_Sncg_GABA                    1        0         0.0
# HPF_VLMC                         2        2       100.0
# PFC_Astrocyte-2              14421      506         3.5
# PFC_Astrocyte-4                  2        2       100.0
# PFC_L2-3_IT_Glut             24787      561         2.3
# PFC_L4-5_IT_Glut             13686      283         2.1
# PFC_L5_ET_Glut                 192       12         6.2
# PFC_L5_IT_Glut                2949       97         3.3
# PFC_L5_NP_Glut                  29        8        27.6
# PFC_L6_CT_Glut               12248      337         2.8
# PFC_L6_IT_Glut                1717       53         3.1
# PFC_Lamp5_GABA                   4        3        75.0
# PFC_MOL-1                     4167      274         6.6
# PFC_MOL-2                      122       40        32.8
# PFC_Microglia-1               3601      137         3.8
# PFC_Pvalb_GABA                5817      269         4.6
# PFC_Sst_Chodl_GABA               2        0         0.0
# PFC_Sst_GABA                  1116       76         6.8
# PFC_Vip_GABA                    35        9        25.7
#
# === 按 primary_region ===
#                 total_dar  matched  match_rate
# primary_region
# UTR                 18810      543         2.9
# distal              21888      635         2.9
# downstream          27927      717         2.6
# exon                19345      983         5.1
# genebody             4282       82         1.9
# intron              62220      644         1.0
# promoter           179665     7576         4.2

# %%
df_DAR_promoter=df_DAR[df_DAR.primary_region.isin(['promoter'])]

# %%
df_DAR_promoter.to_csv('/data2st1/junyi/output/atac1112/dar/celltype.L2/MASTNG_dar_promoter.csv')

# %%
df_DAR_np = df_DAR[~df_DAR.primary_region.isin(['promoter'])]

# %%
df_DAR_np.primary_region.value_counts()
# Out:
# primary_region
# intron        62220
# downstream    27927
# distal        21888
# exon          19345
# UTR           18810
# genebody       4282
# Name: count, dtype: int64

# %%
df_DAR_enh = enhancers.merge(df_DAR_np,left_on=['names','Region Subclass'],right_on=['names','Region Subclass'],how='inner')

# %%
df_DAR_promoter.columns
# Out:
# Index(['names', 'Pr(>Chisq)', 'coef', 'ci.hi', 'ci.lo', 'padjust',
#        'celltype.L2', 'region', 'ctname', 'fdr', 'status', 'gene_name',
#        'gene_id', 'gstart', 'gend', 'strand', 'annotation_x', 'distance',
#        'primary_region', 'secondary_region', 'encodeCCRE', 'Region',
#        'Subclass', 'Sex', 'Region Subclass', 'Ensemble', 'Gene', 'log2FC',
#        'Direction', 'Neurotransmitter', 'Gene_name', 'FDR'],
#       dtype='object')

# %%
df_DAR_enh['gene_name_back'] = df_DAR_enh['gene_name']
df_DAR_enh['gene_name'] = df_DAR_enh['gene_short_name']

# %%
df_DAR_enh
# Out:
#                       peak_id                 promoter  coaccess  \
# 0      chr2_98666416_98666917   chr2_98666919_98667420  0.791526
# 1     chr17_39846962_39847463  chr17_39847628_39848129  0.534815
# 2      chr7_17059964_17060465   chr7_17058088_17058589  0.126435
# 3      chr1_97619895_97620396   chr1_97660492_97660993  0.118572
# 4     chr16_23226583_23227084  chr16_23107149_23107650  0.099572
# ...                       ...                      ...       ...
# 3599  chr10_40036669_40037170  chr10_40302018_40302519  0.096327
# 3600   chr7_61877693_61878194   chr7_62078518_62079019  0.094265
# 3601   chr8_47932265_47932766   chr8_47533307_47533808  0.076851
# 3602   chr8_47932265_47932766   chr8_47533307_47533808  0.076851
# 3603   chr1_58739495_58739996   chr1_58504780_58505281  0.062279
#
#      gene_short_name                    names       Region Subclass  \
# 0            Gm10800   chr2:98666416-98666917             AMY_MOL-1
# 1           AY036118  chr17:39846962-39847463             AMY_MOL-1
# 2              Hif3a   chr7:17059964-17060465             AMY_MOL-1
# 3         AC099860.1   chr1:97619895-97620396             AMY_MOL-1
# 4             Eif4a2  chr16:23226583-23227084             AMY_MOL-1
# ...              ...                      ...                   ...
# 3599            Amd1  chr10:40036669-40037170  AMY_Cav1_Frmpd1_Glut
# 3600         Gm24923   chr7:61877693-61878194  AMY_Cav1_Frmpd1_Glut
# 3601        Trappc11   chr8:47932265-47932766  AMY_Cav1_Frmpd1_Glut
# 3602        Trappc11   chr8:47932265-47932766  AMY_Cav1_Frmpd1_Glut
# 3603            Orc2   chr1:58739495-58739996  AMY_Cav1_Frmpd1_Glut
#
#         Pr(>Chisq)      coef     ci.hi     ci.lo  ...              Subclass  \
# 0     1.349448e-06  0.321748  0.441525  0.201972  ...                 MOL-1
# 1     4.237458e-07  0.187343  0.280142  0.094544  ...                 MOL-1
# 2     1.428372e-04 -0.042598  0.005754 -0.090949  ...                 MOL-1
# 3     1.664866e-04 -0.072083 -0.034311 -0.109855  ...                 MOL-1
# 4     2.489431e-04 -0.055621  0.001494 -0.112736  ...                 MOL-1
# ...            ...       ...       ...       ...  ...                   ...
# 3599  1.458363e-04 -0.046541 -0.010809 -0.082274  ...  AMY_Cav1_Frmpd1_Glut
# 3600  1.098422e-04  0.001559  0.064133 -0.061016  ...  AMY_Cav1_Frmpd1_Glut
# 3601  3.779453e-05 -0.033994  0.011897 -0.079885  ...  AMY_Cav1_Frmpd1_Glut
# 3602  3.779453e-05 -0.033994  0.011897 -0.079885  ...  AMY_Cav1_Frmpd1_Glut
# 3603  1.054427e-05 -0.076828 -0.016892 -0.136763  ...  AMY_Cav1_Frmpd1_Glut
#
#      Sex               Ensemble                     Gene    log2FC Direction  \
# 0      M   ENSMUSG00000075014.1   chr2:98666416-98666917  0.321748        Up
# 1      M   ENSMUSG00000106106.2  chr17:39846962-39847463  0.187343        Up
# 2      M  ENSMUSG00000004328.15   chr7:17059964-17060465 -0.042598      Down
# 3      M  ENSMUSG00000044768.16   chr1:97619895-97620396 -0.072083      Down
# 4      M  ENSMUSG00000022885.16  chr16:23226583-23227084 -0.055621      Down
# ...   ..                    ...                      ...       ...       ...
# 3599   M  ENSMUSG00000019838.11  chr10:40036669-40037170 -0.046541      Down
# 3600   M   ENSMUSG00000109394.2   chr7:61877693-61878194  0.001559        Up
# 3601   M   ENSMUSG00000031563.8   chr8:47932265-47932766 -0.033994      Down
# 3602   M   ENSMUSG00000031563.8   chr8:47932265-47932766 -0.033994      Down
# 3603   M  ENSMUSG00000026031.15   chr1:58739495-58739996 -0.076828      Down
#
#      Neurotransmitter                Gene_name       FDR  gene_name_back
# 0                  NN   chr2:98666416-98666917  0.001452         Gm10800
# 1                  NN  chr17:39846962-39847463  0.000608      CT010467.1
# 2                  NN   chr7:17059964-17060465  0.029747           Hif3a
# 3                  NN   chr1:97619895-97620396  0.032085      D1Ertd622e
# 4                  NN  chr16:23226583-23227084  0.039701         St6gal1
# ...               ...                      ...       ...             ...
# 3599             Glut  chr10:40036669-40037170  0.048545        Slc16a10
# 3600             Glut   chr7:61877693-61878194  0.044969   A230057D06Rik
# 3601             Glut   chr8:47932265-47932766  0.031673            Wwc2
# 3602             Glut   chr8:47932265-47932766  0.031673            Wwc2
# 3603             Glut   chr1:58739495-58739996  0.020967           Cflar
#
# [3604 rows x 37 columns]

# %%
df_DAR_enh[list(df_DAR_promoter.columns)+['promoter','coaccess']]
# Out:
#                         names    Pr(>Chisq)      coef     ci.hi     ci.lo  \
# 0      chr2:98666416-98666917  1.349448e-06  0.321748  0.441525  0.201972
# 1     chr17:39846962-39847463  4.237458e-07  0.187343  0.280142  0.094544
# 2      chr7:17059964-17060465  1.428372e-04 -0.042598  0.005754 -0.090949
# 3      chr1:97619895-97620396  1.664866e-04 -0.072083 -0.034311 -0.109855
# 4     chr16:23226583-23227084  2.489431e-04 -0.055621  0.001494 -0.112736
# ...                       ...           ...       ...       ...       ...
# 3599  chr10:40036669-40037170  1.458363e-04 -0.046541 -0.010809 -0.082274
# 3600   chr7:61877693-61878194  1.098422e-04  0.001559  0.064133 -0.061016
# 3601   chr8:47932265-47932766  3.779453e-05 -0.033994  0.011897 -0.079885
# 3602   chr8:47932265-47932766  3.779453e-05 -0.033994  0.011897 -0.079885
# 3603   chr1:58739495-58739996  1.054427e-05 -0.076828 -0.016892 -0.136763
#
#        padjust           celltype.L2 region                ctname       fdr  \
# 0     0.017424                 MOL-1    AMY             AMY_MOL.1  0.001452
# 1     0.005471                 MOL-1    AMY             AMY_MOL.1  0.000608
# 2     1.000000                 MOL-1    AMY             AMY_MOL.1  0.029747
# 3     1.000000                 MOL-1    AMY             AMY_MOL.1  0.032085
# 4     1.000000                 MOL-1    AMY             AMY_MOL.1  0.039701
# ...        ...                   ...    ...                   ...       ...
# 3599  1.000000  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut  0.048545
# 3600  1.000000  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut  0.044969
# 3601  1.000000  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut  0.031673
# 3602  1.000000  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut  0.031673
# 3603  0.367742  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut  0.020967
#
#       ...       Region Subclass               Ensemble  \
# 0     ...             AMY_MOL-1   ENSMUSG00000075014.1
# 1     ...             AMY_MOL-1   ENSMUSG00000106106.2
# 2     ...             AMY_MOL-1  ENSMUSG00000004328.15
# 3     ...             AMY_MOL-1  ENSMUSG00000044768.16
# 4     ...             AMY_MOL-1  ENSMUSG00000022885.16
# ...   ...                   ...                    ...
# 3599  ...  AMY_Cav1_Frmpd1_Glut  ENSMUSG00000019838.11
# 3600  ...  AMY_Cav1_Frmpd1_Glut   ENSMUSG00000109394.2
# 3601  ...  AMY_Cav1_Frmpd1_Glut   ENSMUSG00000031563.8
# 3602  ...  AMY_Cav1_Frmpd1_Glut   ENSMUSG00000031563.8
# 3603  ...  AMY_Cav1_Frmpd1_Glut  ENSMUSG00000026031.15
#
#                          Gene    log2FC  Direction Neurotransmitter  \
# 0      chr2:98666416-98666917  0.321748         Up               NN
# 1     chr17:39846962-39847463  0.187343         Up               NN
# 2      chr7:17059964-17060465 -0.042598       Down               NN
# 3      chr1:97619895-97620396 -0.072083       Down               NN
# 4     chr16:23226583-23227084 -0.055621       Down               NN
# ...                       ...       ...        ...              ...
# 3599  chr10:40036669-40037170 -0.046541       Down             Glut
# 3600   chr7:61877693-61878194  0.001559         Up             Glut
# 3601   chr8:47932265-47932766 -0.033994       Down             Glut
# 3602   chr8:47932265-47932766 -0.033994       Down             Glut
# 3603   chr1:58739495-58739996 -0.076828       Down             Glut
#
#                     Gene_name       FDR                 promoter  coaccess
# 0      chr2:98666416-98666917  0.001452   chr2_98666919_98667420  0.791526
# 1     chr17:39846962-39847463  0.000608  chr17_39847628_39848129  0.534815
# 2      chr7:17059964-17060465  0.029747   chr7_17058088_17058589  0.126435
# 3      chr1:97619895-97620396  0.032085   chr1_97660492_97660993  0.118572
# 4     chr16:23226583-23227084  0.039701  chr16_23107149_23107650  0.099572
# ...                       ...       ...                      ...       ...
# 3599  chr10:40036669-40037170  0.048545  chr10_40302018_40302519  0.096327
# 3600   chr7:61877693-61878194  0.044969   chr7_62078518_62079019  0.094265
# 3601   chr8:47932265-47932766  0.031673   chr8_47533307_47533808  0.076851
# 3602   chr8:47932265-47932766  0.031673   chr8_47533307_47533808  0.076851
# 3603   chr1:58739495-58739996  0.020967   chr1_58504780_58505281  0.062279
#
# [3604 rows x 34 columns]

# %%
df_DAR_coaccess = pd.concat([df_DAR_promoter, df_DAR_enh[list(df_DAR_promoter.columns)+['promoter','coaccess']]], axis=0)

# %%
df_DAR_coaccess
# Out:
#                           names    Pr(>Chisq)      coef     ci.hi     ci.lo  \
# 1     chr10:100487209-100487710  1.702931e-10  0.068210  0.093457  0.042963
# 2     chr10:100487209-100487710  1.702931e-10  0.068210  0.093457  0.042963
# 13    chr10:105574236-105574737  5.820625e-03  0.022180  0.039572  0.004789
# 14    chr10:105574236-105574737  5.820625e-03  0.022180  0.039572  0.004789
# 15      chr10:10557982-10558483  5.707527e-03  0.006923  0.018519 -0.004673
# ...                         ...           ...       ...       ...       ...
# 3599    chr10:40036669-40037170  1.458363e-04 -0.046541 -0.010809 -0.082274
# 3600     chr7:61877693-61878194  1.098422e-04  0.001559  0.064133 -0.061016
# 3601     chr8:47932265-47932766  3.779453e-05 -0.033994  0.011897 -0.079885
# 3602     chr8:47932265-47932766  3.779453e-05 -0.033994  0.011897 -0.079885
# 3603     chr1:58739495-58739996  1.054427e-05 -0.076828 -0.016892 -0.136763
#
#        padjust           celltype.L2 region                ctname  \
# 1     0.000006          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 2     0.000006          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 13    1.000000          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 14    1.000000          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 15    1.000000          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# ...        ...                   ...    ...                   ...
# 3599  1.000000  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut
# 3600  1.000000  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut
# 3601  1.000000  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut
# 3602  1.000000  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut
# 3603  0.367742  AMY_Cav1_Frmpd1_Glut    AMY  AMY_Cav1_Frmpd1_Glut
#
#                fdr  ...       Region Subclass               Ensemble  \
# 1     9.867574e-08  ...          HPF_CA3_Glut  ENSMUSG00000036676.14
# 2     9.867574e-08  ...          HPF_CA3_Glut  ENSMUSG00000036676.14
# 13    1.431510e-02  ...          HPF_CA3_Glut   ENSMUSG00000036019.8
# 14    1.431510e-02  ...          HPF_CA3_Glut   ENSMUSG00000036019.8
# 15    1.412667e-02  ...          HPF_CA3_Glut   ENSMUSG00000019832.5
# ...            ...  ...                   ...                    ...
# 3599  4.854489e-02  ...  AMY_Cav1_Frmpd1_Glut  ENSMUSG00000019838.11
# 3600  4.496906e-02  ...  AMY_Cav1_Frmpd1_Glut   ENSMUSG00000109394.2
# 3601  3.167262e-02  ...  AMY_Cav1_Frmpd1_Glut   ENSMUSG00000031563.8
# 3602  3.167262e-02  ...  AMY_Cav1_Frmpd1_Glut   ENSMUSG00000031563.8
# 3603  2.096670e-02  ...  AMY_Cav1_Frmpd1_Glut  ENSMUSG00000026031.15
#
#                            Gene    log2FC  Direction Neurotransmitter  \
# 1     chr10:100487209-100487710  0.068210         Up             Glut
# 2     chr10:100487209-100487710  0.068210         Up             Glut
# 13    chr10:105574236-105574737  0.022180         Up             Glut
# 14    chr10:105574236-105574737  0.022180         Up             Glut
# 15      chr10:10557982-10558483  0.006923         Up             Glut
# ...                         ...       ...        ...              ...
# 3599    chr10:40036669-40037170 -0.046541       Down             Glut
# 3600     chr7:61877693-61878194  0.001559         Up             Glut
# 3601     chr8:47932265-47932766 -0.033994       Down             Glut
# 3602     chr8:47932265-47932766 -0.033994       Down             Glut
# 3603     chr1:58739495-58739996 -0.076828       Down             Glut
#
#                       Gene_name           FDR                 promoter  \
# 1     chr10:100487209-100487710  9.867574e-08                      NaN
# 2     chr10:100487209-100487710  9.867574e-08                      NaN
# 13    chr10:105574236-105574737  1.431510e-02                      NaN
# 14    chr10:105574236-105574737  1.431510e-02                      NaN
# 15      chr10:10557982-10558483  1.412667e-02                      NaN
# ...                         ...           ...                      ...
# 3599    chr10:40036669-40037170  4.854489e-02  chr10_40302018_40302519
# 3600     chr7:61877693-61878194  4.496906e-02   chr7_62078518_62079019
# 3601     chr8:47932265-47932766  3.167262e-02   chr8_47533307_47533808
# 3602     chr8:47932265-47932766  3.167262e-02   chr8_47533307_47533808
# 3603     chr1:58739495-58739996  2.096670e-02   chr1_58504780_58505281
#
#       coaccess
# 1          NaN
# 2          NaN
# 13         NaN
# 14         NaN
# 15         NaN
# ...        ...
# 3599  0.096327
# 3600  0.094265
# 3601  0.076851
# 3602  0.076851
# 3603  0.062279
#
# [183269 rows x 34 columns]

# %%
df_DAR_coaccess.to_csv('/data2st1/junyi/output/atac1112/dar/celltype.L2/MASTNG_dar_coaccess.csv')

# %%
df_encher_deg_merged = df_enhcer_deg.merge(df_DAR_np,left_on=['names','Region Subclass','Direction'],right_on=['names','Region Subclass','Direction'],how='inner')

# %%
from sys import prefix


df_encher_deg_merged = df_enhcer_deg.merge(df_DAR_np,left_on=['names','Region Subclass','Direction'],right_on=['names','Region Subclass','Direction'],how='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 from sys import prefix
# ----> 4 df_encher_deg_merged = df_enhcer_deg.merge(df_DAR_np,left_on=['names','Region Subclass','Direction'],right_on=['names','Region Subclass','Direction'],how='inner')
#
# NameError: name 'df_enhcer_deg' is not defined

# %%
df_DAR_enh = enhancers.merge(df_DAR_np,left_on=['names','Region Subclass'],right_on=['names','Region Subclass'],how='inner')

# %%
df_DAR
# Out:
#                             names    Pr(>Chisq)      coef     ci.hi     ci.lo  \
# 0       chr10:100456562-100457063  1.414898e-02 -0.006031  0.006165 -0.018226
# 1       chr10:100487209-100487710  1.702931e-10  0.068210  0.093457  0.042963
# 2       chr10:100487209-100487710  1.702931e-10  0.068210  0.093457  0.042963
# 3       chr10:100642797-100643298  6.163128e-03 -0.014478 -0.004093 -0.024864
# 4         chr10:10107158-10107659  5.303556e-07  0.030881  0.045954  0.015808
# ...                           ...           ...       ...       ...       ...
# 334132     chr7:99535252-99535753  4.700413e-06  0.001785  0.060391 -0.056820
# 334133   chr9:103365644-103366145  8.286317e-05  0.028069  0.108636 -0.052498
# 334134     chr9:99436435-99436936  3.917479e-05 -0.054067 -0.014330 -0.093805
# 334135    chr13:43171217-43171718  2.009124e-06       NaN       NaN       NaN
# 334136    chr13:43171217-43171718  2.009124e-06       NaN       NaN       NaN
#
#          padjust           celltype.L2 region                ctname  \
# 0       1.000000          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 1       0.000006          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 2       0.000006          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 3       1.000000          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# 4       0.017210          HPF_CA3_Glut    HPF          HPF_CA3_Glut
# ...          ...                   ...    ...                   ...
# 334132  0.079099  AMY_Npas1_Rgs12_GABA    AMY  AMY_Npas1_Rgs12_GABA
# 334133  1.000000  AMY_Npas1_Rgs12_GABA    AMY  AMY_Npas1_Rgs12_GABA
# 334134  0.659233  AMY_Npas1_Rgs12_GABA    AMY  AMY_Npas1_Rgs12_GABA
# 334135  0.018430    PFC_Sst_Chodl_GABA    PFC    PFC_Sst_Chodl_GABA
# 334136  0.018430    PFC_Sst_Chodl_GABA    PFC    PFC_Sst_Chodl_GABA
#
#                  fdr  ...              Subclass Sex       Region Subclass  \
# 0       2.751694e-02  ...          HPF_CA3_Glut   M          HPF_CA3_Glut
# 1       9.867574e-08  ...          HPF_CA3_Glut   M          HPF_CA3_Glut
# 2       9.867574e-08  ...          HPF_CA3_Glut   M          HPF_CA3_Glut
# 3       1.490774e-02  ...          HPF_CA3_Glut   M          HPF_CA3_Glut
# 4       2.347109e-05  ...          HPF_CA3_Glut   M          HPF_CA3_Glut
# ...              ...  ...                   ...  ..                   ...
# 334132  1.977464e-02  ...  AMY_Npas1_Rgs12_GABA   M  AMY_Npas1_Rgs12_GABA
# 334133  4.904168e-02  ...  AMY_Npas1_Rgs12_GABA   M  AMY_Npas1_Rgs12_GABA
# 334134  3.488255e-02  ...  AMY_Npas1_Rgs12_GABA   M  AMY_Npas1_Rgs12_GABA
# 334135  1.842970e-02  ...    PFC_Sst_Chodl_GABA   M    PFC_Sst_Chodl_GABA
# 334136  1.842970e-02  ...    PFC_Sst_Chodl_GABA   M    PFC_Sst_Chodl_GABA
#
#                      Ensemble                       Gene    log2FC Direction  \
# 0       ENSMUSG00000036676.14  chr10:100456562-100457063 -0.006031      Down
# 1       ENSMUSG00000036676.14  chr10:100487209-100487710  0.068210        Up
# 2       ENSMUSG00000036676.14  chr10:100487209-100487710  0.068210        Up
# 3        ENSMUSG00000112328.1  chr10:100642797-100643298 -0.014478      Down
# 4        ENSMUSG00000112713.1    chr10:10107158-10107659  0.030881        Up
# ...                       ...                        ...       ...       ...
# 334132  ENSMUSG00000018909.15     chr7:99535252-99535753  0.001785        Up
# 334133  ENSMUSG00000032803.15   chr9:103365644-103366145  0.028069        Up
# 334134  ENSMUSG00000032470.17     chr9:99436435-99436936 -0.054067      Down
# 334135  ENSMUSG00000021368.15    chr13:43171217-43171718       NaN      Down
# 334136  ENSMUSG00000021368.15    chr13:43171217-43171718       NaN      Down
#
#         Neurotransmitter                  Gene_name           FDR
# 0                   Glut  chr10:100456562-100457063  2.751694e-02
# 1                   Glut  chr10:100487209-100487710  9.867574e-08
# 2                   Glut  chr10:100487209-100487710  9.867574e-08
# 3                   Glut  chr10:100642797-100643298  1.490774e-02
# 4                   Glut    chr10:10107158-10107659  2.347109e-05
# ...                  ...                        ...           ...
# 334132              GABA     chr7:99535252-99535753  1.977464e-02
# 334133              GABA   chr9:103365644-103366145  4.904168e-02
# 334134              GABA     chr9:99436435-99436936  3.488255e-02
# 334135              GABA    chr13:43171217-43171718  1.842970e-02
# 334136              GABA    chr13:43171217-43171718  1.842970e-02
#
# [334137 rows x 32 columns]

# %%
df_promoter_deg_merged = df_deg.merge(df_DAR_promoter,left_on=['Gene','Region Subclass','Direction'],right_on=['gene_name','Region Subclass','Direction'],how='left')

# %%
df_promoter_deg_merged
# Out:
#               Gene_x          pval  log2FC_x   ci.hi_x   ci.lo_x     FDR_x  \
# 0      1810062O18Rik  5.808074e-03  0.070354  0.120168  0.020540  0.040524
# 1      2610035D17Rik  7.490775e-04  0.088500  0.139018  0.037981  0.009548
# 2      4732471J01Rik  8.759375e-04  0.053831  0.097587  0.010075  0.010621
# 3      4833420G17Rik  4.983856e-03  0.040075  0.087102 -0.006953  0.036435
# 4      4930402H24Rik  7.804847e-04  0.105143  0.164551  0.045736  0.009823
# ...              ...           ...       ...       ...       ...       ...
# 80669         Zswim6  4.582351e-03 -0.098474 -0.027546 -0.169402  0.039133
# 80670           Apoe  4.143067e-07  0.876975  1.205846  0.548104  0.000844
# 80671           Meg3  3.685718e-07  0.896927  1.220253  0.573601  0.000844
# 80672        Slc6a13  3.642790e-06  0.890118  1.255269  0.524966  0.004949
# 80673         Snhg11  4.418882e-05  0.729364  1.051926  0.406802  0.045028
#
#        Bonferroni   Subclass_x Region_x Sex_x  ... encodeCCRE Region_y  \
# 0        1.000000  Astrocyte-2      PFC     M  ...        NaN      NaN
# 1        1.000000  Astrocyte-2      PFC     M  ...        NaN      NaN
# 2        1.000000  Astrocyte-2      PFC     M  ...        NaN      NaN
# 3        1.000000  Astrocyte-2      PFC     M  ...        NaN      NaN
# 4        1.000000  Astrocyte-2      PFC     M  ...        NaN      NaN
# ...           ...          ...      ...   ...  ...        ...      ...
# 80669    1.000000          OPC      AMY     M  ...        NaN      NaN
# 80670    0.001689         VLMC      AMY     M  ...        NaN      NaN
# 80671    0.001502         VLMC      AMY     M  ...        NaN      NaN
# 80672    0.014848         VLMC      AMY     M  ...        NaN      NaN
# 80673    0.180114         VLMC      AMY     M  ...        NaN      NaN
#
#       Subclass_y Sex_y Ensemble_y Gene_y log2FC_y Neurotransmitter_y  \
# 0            NaN   NaN        NaN    NaN      NaN                NaN
# 1            NaN   NaN        NaN    NaN      NaN                NaN
# 2            NaN   NaN        NaN    NaN      NaN                NaN
# 3            NaN   NaN        NaN    NaN      NaN                NaN
# 4            NaN   NaN        NaN    NaN      NaN                NaN
# ...          ...   ...        ...    ...      ...                ...
# 80669        NaN   NaN        NaN    NaN      NaN                NaN
# 80670        NaN   NaN        NaN    NaN      NaN                NaN
# 80671        NaN   NaN        NaN    NaN      NaN                NaN
# 80672        NaN   NaN        NaN    NaN      NaN                NaN
# 80673        NaN   NaN        NaN    NaN      NaN                NaN
#
#        Gene_name_y  FDR_y
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
# ...            ...    ...
# 80669          NaN    NaN
# 80670          NaN    NaN
# 80671          NaN    NaN
# 80672          NaN    NaN
# 80673          NaN    NaN
#
# [80674 rows x 47 columns]

# %%
#write cross on Direction_y AND Direction_x 
df_crosstab = pd.crosstab(df_DAR_enh['Direction_x'], df_DAR_enh['Direction_y'])

# %%
df_crosstab
# Out:
# Direction_y  Down   Up
# Direction_x
# Down          151  149
# Up            137  195

# %%
df_promoter_deg_merged.corr()
# Out:
# /tmp/ipykernel_2725342/857190339.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_promoter_deg_merged.corr()
#                 pval  log2FC_x   ci.hi_x   ci.lo_x     FDR_x  Bonferroni  \
# pval        1.000000 -0.029112 -0.058810  0.002183  0.823400    0.475565
# log2FC_x   -0.029112  1.000000  0.972361  0.972382 -0.031283   -0.049555
# ci.hi_x    -0.058810  0.972361  1.000000  0.891013 -0.016543   -0.055678
# ci.lo_x     0.002183  0.972382  0.891013  1.000000 -0.044290   -0.040696
# FDR_x       0.823400 -0.031283 -0.016543 -0.044290  1.000000    0.602009
# Bonferroni  0.475565 -0.049555 -0.055678 -0.040696  0.602009    1.000000
# Pr(>Chisq) -0.001201 -0.028780 -0.028964 -0.027963  0.007609    0.007770
# coef        0.042815  0.022625  0.016692  0.028044  0.026711    0.054352
# ci.hi_y     0.041531  0.054591  0.073984  0.034048  0.051032    0.076521
# ci.lo_y     0.037868 -0.023166 -0.061676  0.015751 -0.009603    0.016596
# padjust    -0.017586 -0.045869 -0.040369 -0.050343  0.014495    0.006878
# fdr        -0.018948 -0.026666 -0.020884 -0.031846  0.022490    0.013750
# gstart      0.002499  0.037438  0.034011  0.040032  0.004233    0.006276
# gend        0.002115  0.035778  0.032496  0.038264  0.003838    0.005610
# distance   -0.002890 -0.020699 -0.020093 -0.020848 -0.003408    0.000424
# log2FC_y    0.042815  0.022625  0.016692  0.028044  0.026711    0.054352
# FDR_y      -0.018948 -0.026666 -0.020884 -0.031846  0.022490    0.013750
#
#             Pr(>Chisq)      coef   ci.hi_y   ci.lo_y   padjust       fdr  \
# pval         -0.001201  0.042815  0.041531  0.037868 -0.017586 -0.018948
# log2FC_x     -0.028780  0.022625  0.054591 -0.023166 -0.045869 -0.026666
# ci.hi_x      -0.028964  0.016692  0.073984 -0.061676 -0.040369 -0.020884
# ci.lo_x      -0.027963  0.028044  0.034048  0.015751 -0.050343 -0.031846
# FDR_x         0.007609  0.026711  0.051032 -0.009603  0.014495  0.022490
# Bonferroni    0.007770  0.054352  0.076521  0.016596  0.006878  0.013750
# Pr(>Chisq)    1.000000 -0.156196 -0.188175 -0.089661  0.362867  0.908887
# coef         -0.156196  1.000000  0.950069  0.910857 -0.316985 -0.159289
# ci.hi_y      -0.188175  0.950069  1.000000  0.736591 -0.330270 -0.159490
# ci.lo_y      -0.089661  0.910857  0.736591  1.000000 -0.250223 -0.134304
# padjust       0.362867 -0.316985 -0.330270 -0.250223  1.000000  0.424315
# fdr           0.908887 -0.159289 -0.159490 -0.134304  0.424315  1.000000
# gstart       -0.007382 -0.012055 -0.011334 -0.011137 -0.002612 -0.007317
# gend         -0.007162 -0.012415 -0.011791 -0.011313 -0.002225 -0.007076
# distance     -0.012474  0.008910  0.006125  0.011211 -0.005240 -0.012829
# log2FC_y     -0.156196  1.000000  0.950069  0.910857 -0.316985 -0.159289
# FDR_y         0.908887 -0.159289 -0.159490 -0.134304  0.424315  1.000000
#
#               gstart      gend  distance  log2FC_y     FDR_y
# pval        0.002499  0.002115 -0.002890  0.042815 -0.018948
# log2FC_x    0.037438  0.035778 -0.020699  0.022625 -0.026666
# ci.hi_x     0.034011  0.032496 -0.020093  0.016692 -0.020884
# ci.lo_x     0.040032  0.038264 -0.020848  0.028044 -0.031846
# FDR_x       0.004233  0.003838 -0.003408  0.026711  0.022490
# Bonferroni  0.006276  0.005610  0.000424  0.054352  0.013750
# Pr(>Chisq) -0.007382 -0.007162 -0.012474 -0.156196  0.908887
# coef       -0.012055 -0.012415  0.008910  1.000000 -0.159289
# ci.hi_y    -0.011334 -0.011791  0.006125  0.950069 -0.159490
# ci.lo_y    -0.011137 -0.011313  0.011211  0.910857 -0.134304
# padjust    -0.002612 -0.002225 -0.005240 -0.316985  0.424315
# fdr        -0.007317 -0.007076 -0.012829 -0.159289  1.000000
# gstart      1.000000  0.999984 -0.004745 -0.012055 -0.007317
# gend        0.999984  1.000000 -0.004738 -0.012415 -0.007076
# distance   -0.004745 -0.004738  1.000000  0.008910 -0.012829
# log2FC_y   -0.012055 -0.012415  0.008910  1.000000 -0.159289
# FDR_y      -0.007317 -0.007076 -0.012829 -0.159289  1.000000

# %%
df_encher_deg_merged.primary_region.value_counts()
# Out:
# exon          254
# intron        115
# UTR            95
# downstream     78
# distal         76
# genebody       14
# Name: primary_region, dtype: int64

# %%
df_tobias = pd.read_parquet('/data2st1/junyi/output/atac1112/tobias/annotated_filtered.parquet')

# %%
set(enhancers['Region Subclass']).difference(set(df_tobias['Region Subclass']))
# Out:
# {'AMY_Arachnoid_Barrier_cell',
#  'AMY_Ependymal_cell',
#  'AMY_MOL-3',
#  'AMY_NFOL',
#  'AMY_Perivascular_Macrophage',
#  'AMY_VLMC',
#  'HPF_Astrocyte-3',
#  'HPF_COP',
#  'HPF_Ependymal_cell',
#  'HPF_Immature_cell',
#  'HPF_Subiculum_CT_Glut',
#  'HPF_VLMC',
#  'PFC_Astrocyte-3',
#  'PFC_COP',
#  'PFC_MOL-3',
#  'PFC_Perivascular_Macrophage',
#  'PFC_Pvalb_Vipr2_GABA',
#  'PFC_VLMC'}

# %%
set(df_tobias['Region Subclass']).difference(set(enhancers['Region Subclass']))
# Out:
# {'HPF_OPC'}

# %%
df_tobias_enhancers = pd.merge(df_tobias,enhancers,on=['names','Region Subclass'],how='left')

# %%
df_tobias_enhancers.head()
# Out:
#   TFBS_chr  TFBS_start  TFBS_end  \
# 0     chr1     3309945   3309954
# 1     chr1     3309945   3309954
# 2     chr1     3309945   3309954
# 3     chr1     3310134   3310143
# 4     chr1     3309944   3309955
#
#                                        TFBS_name  TFBS_score TFBS_strand  \
# 0            metacluster_137.2cisbp__M01001_None     9.25971           -
# 1            metacluster_137.2cisbp__M01001_None     9.34861           -
# 2            metacluster_137.2cisbp__M01001_None     9.26355           -
# 3             metacluster_68.2cisbp__M00407_None     7.61715           +
# 4  metacluster_137.2transfac_public__M00173_None     7.82886           -
#
#   peak_chr  peak_start  peak_end  MC_score  ...  primary_region  \
# 0     chr1     3309937   3310438   0.11586  ...          intron
# 1     chr1     3309937   3310438   0.36816  ...          intron
# 2     chr1     3309937   3310438   0.46053  ...          intron
# 3     chr1     3309937   3310438   0.20840  ...          intron
# 4     chr1     3309937   3310438   0.11586  ...          intron
#
#    secondary_region  encodeCCRE  Sex              Ensemble  \
# 0            repeat        None    M  ENSMUSG00000051951.5
# 1            repeat        None    M  ENSMUSG00000051951.5
# 2            repeat        None    M  ENSMUSG00000051951.5
# 3            repeat        None    M  ENSMUSG00000051951.5
# 4            repeat        None    M  ENSMUSG00000051951.5
#
#                    Gene peak_id promoter coaccess gene_short_name
# 0  chr1:3309937-3310438     NaN      NaN      NaN             NaN
# 1  chr1:3309937-3310438     NaN      NaN      NaN             NaN
# 2  chr1:3309937-3310438     NaN      NaN      NaN             NaN
# 3  chr1:3309937-3310438     NaN      NaN      NaN             NaN
# 4  chr1:3309937-3310438     NaN      NaN      NaN             NaN
#
# [5 rows x 40 columns]

# %%
df_tobias_enhancers_candidate = df_tobias_enhancers[df_tobias_enhancers.coaccess.notnull()]

# %%
import re
import numpy as np
import pandas as pd

_interval_re = re.compile(r"^(chr[^_]+)_(\d+)_(\d+)$")

def _parse_interval_str(s: str):
    """Parse 'chr1_3309937_3310438' -> (chrom, start, end); invalid -> (None, None, None)."""
    if s is None or (isinstance(s, float) and np.isnan(s)):
        return (None, None, None)
    m = _interval_re.match(str(s).strip())
    if not m:
        return (None, None, None)
    chrom = m.group(1)
    start = int(m.group(2))
    end = int(m.group(3))
    if start > end:
        start, end = end, start
    return (chrom, start, end)

def add_pedistance(df: pd.DataFrame, peak_col: str = "peak_id", promoter_col: str = "promoter") -> pd.DataFrame:
    """
    In-place add column 'pedistance' = nearest boundary gap between df[peak_col] and df[promoter_col].

    Rules:
      - Different chromosome -> inf
      - Overlap or touch -> 0
      - Else -> start_right - end_left
      - Invalid interval string -> NaN
    """
    peak_parsed = df[peak_col].map(_parse_interval_str)
    prom_parsed = df[promoter_col].map(_parse_interval_str)

    peak_chr = peak_parsed.map(lambda x: x[0])
    peak_start = peak_parsed.map(lambda x: x[1])
    peak_end = peak_parsed.map(lambda x: x[2])

    prom_chr = prom_parsed.map(lambda x: x[0])
    prom_start = prom_parsed.map(lambda x: x[1])
    prom_end = prom_parsed.map(lambda x: x[2])

    pedist = pd.Series(np.nan, index=df.index, dtype="float64")

    valid = peak_chr.notna() & prom_chr.notna()

    # Different chromosomes -> inf
    pedist.loc[valid & (peak_chr != prom_chr)] = np.inf

    # Same chromosome -> compute nearest boundary gap
    same = valid & (peak_chr == prom_chr)
    ps = peak_start[same].to_numpy()
    pe = peak_end[same].to_numpy()
    rs = prom_start[same].to_numpy()
    re_ = prom_end[same].to_numpy()

    # Ensure left interval is the one with smaller start
    left_end = np.where(ps <= rs, pe, re_)
    right_start = np.where(ps <= rs, rs, ps)

    pedist.loc[same] = np.where(right_start <= left_end, 0.0, (right_start - left_end).astype(float))

    df["pedistance"] = pedist
    return df

# %%
df_tobias_enhancers_candidate = add_pedistance(df_tobias_enhancers_candidate, peak_col='peak_id', promoter_col='promoter')
# Out:
# /tmp/ipykernel_3635406/718569337.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["pedistance"] = pedist

# %%
promoter_prox = df_tobias_enhancers_candidate[(df_tobias_enhancers_candidate.primary_region!='promoter')&(df_tobias_enhancers_candidate.pedistance<=200)]
promoter_prox['PEstatus'] = 'promoter_proximal'
near_prox = df_tobias_enhancers_candidate[(df_tobias_enhancers_candidate.primary_region.isin(['distal','intron']))&\
                                          (df_tobias_enhancers_candidate.pedistance>200)&(df_tobias_enhancers_candidate.pedistance<=2000)]
near_prox['PEstatus'] = 'near_proximal_enhancer'
distal = df_tobias_enhancers_candidate[(df_tobias_enhancers_candidate.primary_region.isin(['distal','intron']))&(df_tobias_enhancers_candidate.pedistance>2000)&(df_tobias_enhancers_candidate.pedistance<=500_000)]
distal['PEstatus'] = 'distal_enhancer'
addcolumns = ['promoter','coaccess','gene_short_name','pedistance','PEstatus']
for addcol in addcolumns:
    df_tobias[addcol] = np.nan
df_tobias[df_tobias.primary_region=='promoter']['PEstatus'] = 'promoter'
for df, name in zip([promoter_prox, near_prox, distal],
                    ['promoter_proximal_enhancers','near_promoter_enhancers','distal_enhancers']):
    print(f"Saving {name} with shape {df.shape}")

    # 确保按 index 对齐写回
    df_tobias.loc[df.index, addcolumns] = df.loc[df.index, addcolumns]
# Out:
# /tmp/ipykernel_3635406/3927001270.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   promoter_prox['PEstatus'] = 'promoter_proximal'

# %%
df_tobias.to_parquet('/data2st1/junyi/output/atac1112/tobias/annotated_filtered_with_enhancers.parquet')

# %%
df_tobias_raw = pd.read_parquet('/data2st1/junyi/output/atac1112/tobias/annotated_filtered.parquet')
