# %%
import scanpy as sc
import pycisTopic
from pycisTopic.cistopic_class import *
import pickle
import os
import anndata
import mudata
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.patches import ArrowStyle
from scipy.stats import fisher_exact
import seaborn as sns
import glob
import PyComplexHeatmap as pch
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib_venn import venn2
from ast import literal_eval
from scipy.stats import hypergeom
from scipy.stats import pearsonr
import numpy as np
from scipy.stats import pearsonr, spearmanr
import warnings
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import SpectralCoclustering,SpectralBiclustering
from sklearn.metrics import consensus_score
from statsmodels.stats.multitest import multipletests
import glob as glob
from scenicplus.RSS import (regulon_specificity_scores, plot_rss)
from scenicplus.plotting.dotplot import heatmap_dotplot

# %% [markdown]
# # Read the meta data

# %%
if os.path.exists("/data2st2/junyi/output/stg1028/combined_ALL_meta.csv"):
    df_meta = pd.read_csv("/data2st2/junyi/output/stg1028/combined_ALL_meta.csv", index_col=0)
    df_meta.drop_duplicates(inplace=True)
else:
    df_meta = pd.DataFrame()
    h5ads = glob.glob('/data2st2/junyi/output/stg1028/*_4VN/*.h5ad')
    for h5ad in h5ads:
        adata = sc.read_h5ad(h5ad, backed='r')
        df_meta = pd.concat([df_meta, pd.DataFrame(adata.obs)], axis=0)
    df_meta.to_csv("/data2st2/junyi/output/stg1028/combined_ALL_meta.csv")
    df_meta.drop_duplicates(inplace=True)
# Out:
# /tmp/ipykernel_1413356/3001891177.py:2: DtypeWarning: Columns (20,56,57,58,67,68) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
# Read the meta data and create a map between desired maps
df_meta['Region Subclass'] = df_meta['region'] + "_" + df_meta['celltype.L2']
df_meta_match = df_meta.drop_duplicates(subset=['Region Subclass'])
df_meta_match['ctname'] = df_meta_match['Region Subclass'].str.replace('/', '-').str.replace(' ', '_')

# %%
def gen_map_from_meta(df_meta_match=df_meta_match,iput_col='ctname',output_col='Region Subclass'):
    df_meta_match = df_meta_match.dropna(subset=[iput_col, output_col])
    df_meta_match = df_meta_match.drop_duplicates(subset=[iput_col, output_col])
    map_dict = dict(zip(df_meta_match[iput_col], df_meta_match[output_col]))
    return map_dict

# %% [markdown]
# # Read the wilcoxon result for the AUC calculation

# %%
df_all= pd.read_csv('/data2/junyi/stg0901/scenic_wilcoxon_all/combined_wilcoxon_DEGs.csv')

# %%
# Select the SUS samples in HPF, AMY, and PFC regions
df_all_SUS3RM = df_all[(df_all['status'] == 'SUS') & (df_all['region'].isin(['HPF','AMY','PFC'])) & (df_all['sex'] == 'M')].copy()
df_all_SUS3RM['TF_up'] = df_all_SUS3RM['TF'].str.replace('(+)', '', regex=False)
df_all_SUS3RM['TF_up'] = df_all_SUS3RM['TF_up'].str.upper()

# %%
df_all_SUS3RM.head()
# Out:
#               TF    scores    log2FC      pval       FDR  pct_nz_group  \
# 13657  Bclaf1(+)  2.610856  0.225434  0.009032  0.708474      1.000000
# 13658  Zfp523(+)  2.556463  0.436495  0.010574  0.708474      1.000000
# 13659     Yy1(+)  2.230106  0.384923  0.025740  0.985490      1.000000
# 13660   Runx1(+)  1.767767  0.900603  0.077100  1.000000      0.923077
# 13661  Zfp239(+)  1.631785  0.446139  0.102725  1.000000      1.000000
#
#        pct_nz_reference comparison celltype.L2 region sex  \
# 13657          1.000000      SUS_M        NFOL    AMY   M
# 13658          1.000000      SUS_M        NFOL    AMY   M
# 13659          1.000000      SUS_M        NFOL    AMY   M
# 13660          0.750000      SUS_M        NFOL    AMY   M
# 13661          0.916667      SUS_M        NFOL    AMY   M
#
#       Neurotransmitter_celltype Direction status   TF_up
# 13657                        NN        Up    SUS  BCLAF1
# 13658                        NN        Up    SUS  ZFP523
# 13659                        NN        Up    SUS     YY1
# 13660                        NN        Up    SUS   RUNX1
# 13661                        NN        Up    SUS  ZFP239

# %%
df_all_filtered = df_all[df_all['FDR']<0.05]
df_all_filtered = df_all_filtered[df_all_filtered['pct_nz_group']>0.1]
df_all_filtered = df_all_filtered[df_all_filtered['pct_nz_reference']>0.1]
df_all_filtered['nlogp'] = -np.log10(df_all_filtered['FDR']+1e-300) * np.sign(df_all_filtered['log2FC'])
# #df_all_filtered.to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/all_scenic_wilcoxon_results_filtered.csv',index=False)
# df_all_filtered_CUSUS = df_all_filtered[df_all_filtered['status']=='SUS']
# df_all_filtered_CUSUS['Gene'] = df_all_filtered_CUSUS['TF']
# df_all_filtered_CUSUS['Gene_name'] = df_all_filtered_CUSUS['TF']
# df_all_filtered_CUSUS['Ensemble'] = df_all_filtered_CUSUS['TF']
# df_all_filtered_CUSUS.rename(columns={"Neurotransmitter_celltype":"Neurotransmitter","region":"Region","sex":"Sex",'celltype.L2':'Subclass'},inplace=True)
# df_all_filtered_CUSUS['Region subclass'] = df_all_filtered_CUSUS['Subclass']
# # if neurotransmitter is 'NN',set df_input['Region subclass'] = df_input['Region']+"_"df_all_filtered_CSSUS['Subclass']
# df_all_filtered_CUSUS.loc[df_all_filtered_CUSUS['Neurotransmitter']=='NN','Region subclass'] = df_all_filtered_CUSUS.loc[df_all_filtered_CUSUS['Neurotransmitter']=='NN'].apply(lambda row: row['Region'] + " " + row['Subclass'], axis=1)

# %%
# if not os.path.exists('/data2st2/junyi/output/stg1028/CSDS_4VN/scenic_tfs_fdr_log2fc0'):
#     os.mkdir('/data2st2/junyi/output/stg1028/CSDS_4VN/scenic_tfs_fdr_log2fc0')
# if not os.path.exists('/data2st2/junyi/output/stg1028/CUMS_4VN/scenic_tfs_fdr_log2fc0'):
#     os.mkdir('/data2st2/junyi/output/stg1028/CUMS_4VN/scenic_tfs_fdr_log2fc0')
# df_all_filtered_CSSUS.to_csv('/data2st2/junyi/output/stg1028/CSDS_4VN/scenic_tfs_fdr_log2fc0/scenic_tfs_fdr_log2fc0.csv',index=False)
# df_all_filtered_CUSUS.to_csv('/data2st2/junyi/output/stg1028/CUMS_4VN/scenic_tfs_fdr_log2fc0/scenic_tfs_fdr_log2fc0.csv',index=False)
# df_all_filtered_CSSUS = pd.read_csv('/data2st2/junyi/output/stg1028/CSDS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_tfs_fdr_log2fc0.csv')
# df_all_filtered_CUSUS = pd.read_csv('/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_tfs_fdr_log2fc0.csv')

# %%
def draw_venndiagram(df1, df2,savepath=None):
    # df1 = df[df['exp'] == exp1]
    # df2 = df[df['exp'] == exp2]
    gene_list1 = df1['TF']+"_"+df1['Direction']+"_"+df1['Region subclass']+"_"+df1['Sex']
    gene_list2 = df2['TF']+"_"+df2['Direction']+"_"+df2['Region subclass']+"_"+df2['Sex']
    set1 = set(gene_list1)
    set2 = set(gene_list2)
    venn2([set1, set2], set_labels = ("CSSUS", "CUSUS"))
    plt.show()
    if savepath:
        plt.savefig(savepath,dpi=300)
    plt.close()

    return set1, set2

# %%
nt_colors = {
    'Glutamatergic': '#FFC000',
    'GABAergic': '#00B050',
    'Dopaminergic': '#ff7f0e',
    'Cholinergic': '#1f77b4',
    'Histaminergic': '#aa40fc',
    'Serotonergic': '#e377c2',
    'NN':   '#8c564b',
    'OPC':"#8194AC", 
    'Oligo':"#7030A0", 'Astrocyte':"#17becf", 'Microglia':"#ff9896",
    'Epen':"#FF7F50", 'Vascular':"#5F8BB2", 'Immune':"#EF6347",

}

# -------- Region colors (including duplicates you provided) --------
region_colors = {
    "AMY": "#1f77b4",
    "iCTX": "#ff7f0e",
    "HPF": "#009E73",
    "HY": "#d62728",
    "MB": "#9467bd",
    "PFC": "#8c564b",
    "STR": "#e377c2",
    "TH": "#bcbd22",
    # "Astro_Epen": "#17becf",
    # "OPC_Oligo": "#7f7f7f",
    # "Astro-Epen": "#17becf",   # same as above
    # "OPC-Oligo": "#7f7f7f",
    # "Immune": "#ff9896",
    # "Vascular": "#c5b0d5"
}

region_colors = {
    "HPF": "#E13127",
    "AMY": "#6DA1D5",
    "TH":  "#863220",
    "STR": "#8A60AA",
    "HY":  "#D88A91",
    "PFC": "#F57E20",
    "MB":  "#E0B362",
    'iCTX':"#82C341"   
}

# -------- Sex colors --------
sex_colors = {
    "M": "#0080FF",
    "F": "#E800E8"
}
def plot_heatmap(df,col_split='Region',row_cluster=True,col_cluster=True,pdf_file=None,region_order=None,fig_size=None,clip=(-10,10)):
    df = df.copy()
    df['nlogp'] = df['nlogp'].clip(clip[0], clip[1])
    mat = (
        df.pivot_table(
            index="TF",
            columns="Region subclass",
            values="nlogp",
            aggfunc="max"
        )
    )

    col_meta = (
        df[["Region subclass", "Region", "Neurotransmitter", "Sex"]]
        .drop_duplicates(subset="Region subclass")
        .set_index("Region subclass")
    )

    col_meta = col_meta.loc[mat.columns]
    if region_order is not None:
        col_meta['Region'] = pd.Categorical(col_meta['Region'], categories=region_order, ordered=True)
    col_meta = col_meta.sort_values(['Region', 'Region subclass'])
    mat = mat[col_meta.index]

    nt = col_meta["Neurotransmitter"]
    sex = col_meta["Sex"]
    region = col_meta["Region"]
    col_ha = pch.HeatmapAnnotation(
        Region=pch.anno_simple(region, colors=region_colors, add_text=True),
        Neurotransmitter=pch.anno_simple(nt, colors=nt_colors, add_text=False),
        Sex=pch.anno_simple(sex, colors=sex_colors, add_text=True),
        axis=1
    )

    if pdf_file is not None:
        pdf = PdfPages(pdf_file)
    else:
        pdf = None

    if col_split==None:
        region = None
    if fig_size is not None:
        fig_width, fig_height = fig_size
    else:
        fig_width = max(12, min(42, mat.shape[1] * 0.45 + 6))
        fig_height = max(12, min(48, mat.shape[0] * 0.22 + 6))
    plt.figure(figsize=(fig_width, fig_height))

    cmap = LinearSegmentedColormap.from_list(
        "blue_red",
        ["blue", "white", "red"]
    )
    cm = pch.ClusterMapPlotter(
        data=mat,
        top_annotation=col_ha,
        col_split=region,
        row_cluster=row_cluster,
        row_dendrogram=True,
        col_cluster=col_cluster,
        col_dendrogram=True,
        show_rownames=True,
        show_colnames=True,
        col_split_order=region_order,
        cmap=cmap,
        label="-log10(p)",
        yticklabels_kws={'labelsize': 6},
        yticklabels=True,
        xticklabels_kws={'labelsize': 6},
        xticklabels=True,
        rasterized=True
    )

    if hasattr(cm, "ax_row_names"):
        for text in cm.ax_row_names.texts:
            text.set_fontsize(6)
            text.set_rotation(0)
            text.set_clip_on(False)

    if hasattr(cm, "ax_col_names"):
        for text in cm.ax_col_names.texts:
            text.set_fontsize(6)
            text.set_rotation(90)
            text.set_clip_on(False)

    if hasattr(cm, "ax_heatmap"):
        cm.ax_heatmap.tick_params(axis='x', labelsize=6, pad=2)
        cm.ax_heatmap.tick_params(axis='y', labelsize=6, pad=2)

    plt.subplots_adjust(left=0.28, bottom=0.05, right=0.90, top=0.96)

    if pdf:
        pdf.savefig(plt.gcf(), bbox_inches='tight', pad_inches=0.4)
        pdf.close()
    plt.show()
    plt.close()

# %%
def process_df_TF(df_input,type='N',output_path=None, n_thres=5,ovlp=True):
    
    if type=='N':
        df_input = df_input[df_input.Neurotransmitter!='NN']
        tfcountMN = df_input[(df_input.Neurotransmitter!='NN') & (df_input.Sex=='M')].groupby(['TF','Sex','Direction']).nunique()
        tfcountFN = df_input[(df_input.Neurotransmitter!='NN') & (df_input.Sex=='F')].groupby(['TF','Sex','Direction']).nunique()
    elif type=='NN':
        df_input = df_input[df_input.Neurotransmitter=='NN']
        tfcountMN = df_input[(df_input.Neurotransmitter=='NN') & (df_input.Sex=='M')].groupby(['TF','Sex','Direction']).nunique()
        tfcountFN = df_input[(df_input.Neurotransmitter=='NN') & (df_input.Sex=='F')].groupby(['TF','Sex','Direction']).nunique()
    else:
        tfcountMN = df_input[(df_input.Sex=='M')].groupby(['TF','Sex','Direction']).nunique()
        tfcountFN = df_input[(df_input.Sex=='F')].groupby(['TF','Sex','Direction']).nunique()

    # Only select TFs with more than 5 significant region subclasses in male
    if type == 'ALL':
        df_input.loc[df_input.Neurotransmitter=='NN','Region']='NN'
    comTFMN = tfcountMN[tfcountMN['Region subclass']>n_thres].reset_index().TF.unique()
    comTFFN = tfcountFN[tfcountFN['Region subclass']>n_thres].reset_index().TF.unique()
    
    if ovlp==True:
        comTF = set(comTFMN).intersection(set(comTFFN))
    else:
        comTF = set(comTFMN).union(set(comTFFN))
    df_TFN_CUSUS = df_input[(df_input.TF.isin(comTF))]
    df_TFN_CUSUS['nlogp'] = -1 * np.log10(df_TFN_CUSUS['FDR']+1e-300)
    df_TFN_CUSUS.loc[df_TFN_CUSUS['Direction']=='Down', 'nlogp'] = -1 * df_TFN_CUSUS.loc[df_TFN_CUSUS['Direction']=='Down', 'nlogp']
    #df_TFN_CUSUS.to_csv('/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_tfs_fdr_log2fc0_TFNmore5region.csv',index=False)
    if output_path:
        df_TFN_CUSUS.to_csv(output_path,index=False)
    return df_TFN_CUSUS

# %%
# df_CUSUS = process_df_TF(df_all_filtered_CUSUS,n_thres=5,ovlp=True)
# df_CUSUSNN = process_df_TF(df_all_filtered_CUSUS,type='NN',n_thres=5,ovlp=False)

# %%
# plot_heatmap(df_CUSUSNN,pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_tfs_fdr_log2fc0_TFNNregion_heatmap.pdf')
# plot_heatmap(df_CSSUSNN,pdf_file='/data2st2/junyi/output/stg1028/CSDS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_tfs_fdr_log2fc0_TFNNregion_heatmap.pdf')

# %%
df_all.status.value_counts()
# Out:
# SUS      113242
# RES      104321
# CSRES     53036
# CSDS      52328
# Name: status, dtype: int64

# %% [markdown]
# # Plot the Heatmap for all differential regulons

# %%
status_colors = {
    'RES': '#4DAF4A',
    'SUS': '#E41A1C',
    'CSRES': '#377EB8',
    'CSDS': '#984EA3'
}

status_order = ['RES', 'SUS', 'CSRES', 'CSDS']
region_order = ['AMY', 'HPF', 'HY', 'iCTX', 'MB', 'PFC', 'STR', 'TH']

def plot_status_region_heatmap(
    df_input,
    output_path,
    use_col_split=True,
    col_cluster=False,
    row_cluster=True,
    row_dendrogram=None,
    col_dendrogram=None,
    fig_height=70,
    clip_value=10,
    show_colnames=True,
    show_rownames=True
):
    df_all_status = df_input.copy()
    rename_map = {}
    if 'region' in df_all_status.columns and 'Region' not in df_all_status.columns:
        rename_map['region'] = 'Region'
    if 'sex' in df_all_status.columns and 'Sex' not in df_all_status.columns:
        rename_map['sex'] = 'Sex'
    if 'Neurotransmitter_celltype' in df_all_status.columns and 'Neurotransmitter' not in df_all_status.columns:
        rename_map['Neurotransmitter_celltype'] = 'Neurotransmitter'
    if rename_map:
        df_all_status = df_all_status.rename(columns=rename_map)

    if 'Region subclass' not in df_all_status.columns:
        if 'Subclass' in df_all_status.columns:
            df_all_status['Region subclass'] = df_all_status['Subclass'].astype(str)
        elif 'celltype.L2' in df_all_status.columns:
            df_all_status['Region subclass'] = df_all_status['celltype.L2'].astype(str)
        elif 'fname' in df_all_status.columns:
            df_all_status['Region subclass'] = df_all_status['fname'].astype(str)
        else:
            raise ValueError('Cannot determine Region subclass column from input dataframe.')

    if {'Neurotransmitter', 'Region'}.issubset(df_all_status.columns):
        nn_mask = df_all_status['Neurotransmitter'] == 'NN'
        if 'Subclass' in df_all_status.columns:
            subclass_values = df_all_status['Subclass'].astype(str)
        elif 'celltype.L2' in df_all_status.columns:
            subclass_values = df_all_status['celltype.L2'].astype(str)
        else:
            subclass_values = df_all_status['Region subclass'].astype(str)
        df_all_status.loc[nn_mask, 'Region subclass'] = (
            df_all_status.loc[nn_mask, 'Region'].astype(str) + ' ' + subclass_values.loc[nn_mask]
        )

    if 'nlogp' not in df_all_status.columns:
        df_all_status['nlogp'] = -np.log10(df_all_status['FDR'] + 1e-300)
        df_all_status.loc[df_all_status['Direction'] == 'Down', 'nlogp'] *= -1

    df_all_status['Status Region subclass'] = (
        df_all_status['status'].astype(str) + ' | ' + df_all_status['Region subclass'].astype(str)
    )

    mat_all_status = df_all_status.pivot_table(
        index='TF',
        columns='Status Region subclass',
        values='nlogp',
        aggfunc='max'
    )

    col_meta_all_status = (
        df_all_status[['Status Region subclass', 'status', 'Region', 'Neurotransmitter', 'Sex']]
        .drop_duplicates(subset='Status Region subclass')
        .set_index('Status Region subclass')
    )
    col_meta_all_status = col_meta_all_status.loc[mat_all_status.columns]
    col_meta_all_status['status'] = pd.Categorical(
        col_meta_all_status['status'],
        categories=[status for status in status_order if status in col_meta_all_status['status'].unique()],
        ordered=True
    )
    col_meta_all_status['Region'] = pd.Categorical(
        col_meta_all_status['Region'],
        categories=[region for region in region_order if region in col_meta_all_status['Region'].unique()],
        ordered=True
    )
    col_meta_all_status = col_meta_all_status.sort_values(['status', 'Region', 'Sex', 'Neurotransmitter'])
    mat_all_status = mat_all_status[col_meta_all_status.index]

    col_ha_all_status = pch.HeatmapAnnotation(
        Status=pch.anno_simple(col_meta_all_status['status'], colors=status_colors, add_text=True),
        Region=pch.anno_simple(col_meta_all_status['Region'], colors=region_colors, add_text=True),
        Neurotransmitter=pch.anno_simple(col_meta_all_status['Neurotransmitter'], colors=nt_colors, add_text=False),
        Sex=pch.anno_simple(col_meta_all_status['Sex'], colors=sex_colors, add_text=True),
        axis=1
    )

    fig_width = max(14, min(52, mat_all_status.shape[1] * 0.30 + 8))
    plt.figure(figsize=(fig_width, fig_height))

    cmap = LinearSegmentedColormap.from_list('blue_red', ['blue', 'white', 'red'])
    if row_dendrogram is None:
        row_dendrogram = row_cluster
    if col_dendrogram is None:
        col_dendrogram = use_col_split or col_cluster

    plot_kwargs = dict(
        data=mat_all_status.clip(-clip_value, clip_value),
        top_annotation=col_ha_all_status,
        row_cluster=row_cluster,
        row_dendrogram=row_dendrogram,
        col_cluster=col_cluster,
        col_dendrogram=col_dendrogram,
        show_rownames=show_rownames,
        show_colnames=show_colnames,
        cmap=cmap,
        label='-log10(p)',
        yticklabels_kws={'labelsize': 6},
        yticklabels=True,
        xticklabels_kws={'labelsize': 5},
        xticklabels=True,
        rasterized=True
    )
    if use_col_split:
        plot_kwargs['col_split'] = col_meta_all_status['status']
        plot_kwargs['col_split_order'] = [
            status for status in status_order if status in col_meta_all_status['status'].unique()
        ]

    cm = pch.ClusterMapPlotter(**plot_kwargs)

    if hasattr(cm, 'ax_row_names'):
        for text in cm.ax_row_names.texts:
            text.set_fontsize(6)
            text.set_rotation(0)
            text.set_clip_on(False)

    if hasattr(cm, 'ax_col_names'):
        for text in cm.ax_col_names.texts:
            text.set_fontsize(5)
            text.set_rotation(90)
            text.set_clip_on(False)

    if hasattr(cm, 'ax_heatmap'):
        cm.ax_heatmap.tick_params(axis='x', labelsize=5, pad=2)
        cm.ax_heatmap.tick_params(axis='y', labelsize=6, pad=2)

    plt.subplots_adjust(left=0.28, bottom=0.08, right=0.90, top=0.96)
    plt.savefig(output_path, bbox_inches='tight', pad_inches=0.4, dpi=300)
    plt.close('all')
    print(f'Saved heatmap to: {output_path}')
    return mat_all_status, col_meta_all_status

mat_all_status, col_meta_all_status = plot_status_region_heatmap(
    df_input=df_all_filtered,
    output_path='/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_wilcoxon_all_TF_status_region_heatmap.pdf',
    use_col_split=True,
    col_cluster=False,
    row_cluster=True
)
# Out:
# Starting..
# Calculating row orders..
# Reordering rows..
# /home/junyichen/anaconda3/envs/scenicplus/lib/python3.11/site-packages/PyComplexHeatmap/clustermap.py:835: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
# Calculating col orders..
# Reordering cols..
# Plotting matrix..
# Plotting HeatmapAnnotations
# Collecting legends..
# Collecting annotation legends..
# Plotting legends..
# Estimated legend width: 39.68888888888889 mm
# Saved heatmap to: /data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_wilcoxon_all_TF_status_region_heatmap.pdf

# %%
mat_all_status, col_meta_all_status = plot_status_region_heatmap(
    df_input=df_all_filtered,
    output_path='/data2/junyi/stg0901/scenic_wilcoxon_all/scenic_wilcoxon_all_TF_status_region_cluster_heatmap.pdf',
    use_col_split=False,
    col_cluster=True,
    row_cluster=True
)
# Out:
# Starting..
# Calculating row orders..
# Reordering rows..
# /home/junyichen/anaconda3/envs/scenicplus/lib/python3.11/site-packages/PyComplexHeatmap/clustermap.py:835: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
# /home/junyichen/anaconda3/envs/scenicplus/lib/python3.11/site-packages/PyComplexHeatmap/clustermap.py:835: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
# Calculating col orders..
# Reordering cols..
# Plotting matrix..
# Plotting HeatmapAnnotations
# Collecting legends..
# Collecting annotation legends..
# Plotting legends..
# Estimated legend width: 39.68888888888889 mm
# Saved heatmap to: /data2/junyi/stg0901/scenic_wilcoxon_all/scenic_wilcoxon_all_TF_status_region_cluster_heatmap.pdf

# %%
#pd.DataFrame(df_CUSUS.TF.str.replace("(+)", '',regex=False).unique()).to_csv('/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/significant_TFlist.csv',header=False,index=False)

# %%
# plot_heatmap(df_CUSUS,col_split=None,pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_tfs_fdr_log2fc0_TFNmore5region_heatmap.pdf')
# plot_heatmap(df_CSSUS,col_split=None,pdf_file='/data2st2/junyi/output/stg1028/CSDS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_tfs_fdr_log2fc0_TFNmore5region_heatmap.pdf')

# %%
# df_CUSUS_M3R = df_CUSUS[df_CUSUS.Sex=='M']
# df_CUSUS_M3R = df_CUSUS_M3R[df_CUSUS_M3R.Region.isin(['AMY','PFC','HPF'])]
# plot_heatmap(df_CUSUS_M3R,col_split=None,pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/M3R_ns_heatmap.pdf')

# %%
# df_CUSUS_M3R = df_CUSUS[df_CUSUS.Sex=='M']
# df_CUSUS_M3R = df_CUSUS_M3R[df_CUSUS_M3R.Region.isin(['AMY','PFC','HPF'])]
# plot_heatmap(df_CUSUS_M3R,col_split="Region",region_order=['AMY', 'PFC', 'HPF'],fig_size=(12, 12),pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/M3R_heatmap.pdf')

# %%
# plot_heatmap(df_CUSUS,col_split="Region",pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_splits_tfs_fdr_log2fc0_TFNmore5region_heatmap.pdf')

# %%
# plot_heatmap(df_CUSUS,col_split="Region",pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_splits_tfs_fdr_log2fc0_TFNmore5region_heatmap.pdf')
# plot_heatmap(df_CSSUS,col_split="Region",pdf_file='/data2st2/junyi/output/stg1028/CSDS_4VN/scenicwil_tfs_fdr_log2fc0/scenicwil_splits_tfs_fdr_log2fc0_TFNmore5region_heatmap.pdf')

# %%
# plot_heatmap_merged_cusus_cssus(
#     df_CUSUS,
#     df_CSSUS,
#     col_split=None,
#     pdf_file='/data2st2/junyi/output/stg1028/scenicwil_tfs_fdr_log2fc0_CUSUS_CSSUS_merged_not_heatmap.pdf'
#     )

# %%
# plot_heatmap_merged_cusus_cssus(
#     df_CUSUS,
#     df_CSSUS,
#     col_split='Region',
#     pdf_file='/data2st2/junyi/output/stg1028/scenicwil_tfs_fdr_log2fc0_CUSUS_CSSUS_merged_heatmap.pdf'
#     )

# %%
# plot_heatmap_merged_cusus_cssus(
#     df_CUSUSNN,
#     df_CSSUSNN,
#     col_split='Region',
#     pdf_file='/data2st2/junyi/output/stg1028/scenicwil_tfs_fdr_log2fc0_CUSUSNN_CSSUSNN_merged_heatmap.pdf'
#     )

# %%
# plot_heatmap_merged_cusus_cssus(
#     df_CUSUSNN,
#     df_CSSUSNN,
#     col_split=None,
#     pdf_file='/data2st2/junyi/output/stg1028/scenicwil_tfs_fdr_log2fc0_CUSUSNN_CSSUSNN_merged_ns_heatmap.pdf'
#     )

# %% [markdown]
# # Function to read ctx results

# %%
def parse_enrichment_list(value):
    if isinstance(value, list):
        return value
    if pd.isna(value):
        return []
    return literal_eval(value)

def Process_tf_target(df_tf):

    df_tf_enrichment6 = df_tf[['Unnamed: 0', 'Unnamed: 1', 'Enrichment.6']].copy()
    df_tf_enrichment6 = df_tf_enrichment6.rename(columns={'Unnamed: 0': 'TF', 'Unnamed: 1': 'motif'})


    df_tf_enrichment6['Enrichment.6'] = df_tf_enrichment6['Enrichment.6'].apply(parse_enrichment_list)
    df_tf_enrichment6 = df_tf_enrichment6.explode('Enrichment.6').dropna(subset=['Enrichment.6']).copy()
    df_tf_enrichment6[['targetgene', 'importance']] = pd.DataFrame(
        df_tf_enrichment6['Enrichment.6'].tolist(),
        index=df_tf_enrichment6.index
    )
    df_tf_enrichment6 = df_tf_enrichment6[['TF', 'targetgene', 'importance', 'motif']]
    df_tf_enrichment6
    return df_tf_enrichment6

# %%
df_all = df_all_filtered.copy()
df_all['fname'] = df_all['region'] + "_" + df_all['celltype.L2']
df_all['fname'] = df_all['fname'].str.replace('/', '-')
df_all['fname'] = df_all['fname'].str.replace(' ', '_')
df_all['TF'] = df_all['TF'].str.replace("(+)", '', regex=False)
df_all_sig = df_all[df_all['FDR'] < 0.05].copy()
df_all_sig = df_all[df_all['FDR']<0.05].copy()
df_sig_TF = df_all_sig[['TF','fname']]

# %%
df_all
# Out:
#             TF     scores    log2FC          pval           FDR  pct_nz_group  \
# 910      Nr3c1  16.773270  0.133140  3.828552e-63  4.345406e-61      1.000000
# 911      Esrrg  13.782314  0.205303  3.256636e-43  1.056080e-41      1.000000
# 912       Cux1  13.377188  0.110867  8.219903e-41  2.073242e-39      1.000000
# 913       Zeb1  12.755778  0.073490  2.894689e-37  5.973585e-36      1.000000
# 914     Zfp148  12.234419  0.081241  2.035554e-34  3.850590e-33      1.000000
# ...        ...        ...       ...           ...           ...           ...
# 322922    Egr1  -4.091880 -0.284268  4.278903e-05  1.014100e-03      0.890511
# 322923  Thap11  -4.137089 -0.172783  3.517402e-05  9.262493e-04      0.998175
# 322924  Zfp239  -4.824187 -0.411706  1.405753e-06  6.663267e-05      0.748175
# 322925    Bmyc  -4.895475 -0.180326  9.806846e-07  5.810556e-05      1.000000
# 322926     Fos  -5.116363 -0.164195  3.114833e-07  2.460718e-05      1.000000
#
#         pct_nz_reference comparison            celltype.L2 region sex  \
# 910             1.000000      RES_M  TH Fgf10_Gm16263 Glut     TH   M
# 911             1.000000      RES_M  TH Fgf10_Gm16263 Glut     TH   M
# 912             1.000000      RES_M  TH Fgf10_Gm16263 Glut     TH   M
# 913             1.000000      RES_M  TH Fgf10_Gm16263 Glut     TH   M
# 914             1.000000      RES_M  TH Fgf10_Gm16263 Glut     TH   M
# ...                  ...        ...                    ...    ...  ..
# 322922          0.918991      SUS_M   MB Gabrr2_Pcbp3 GABA     MB   M
# 322923          0.992032      SUS_M   MB Gabrr2_Pcbp3 GABA     MB   M
# 322924          0.819389      SUS_M   MB Gabrr2_Pcbp3 GABA     MB   M
# 322925          1.000000      SUS_M   MB Gabrr2_Pcbp3 GABA     MB   M
# 322926          1.000000      SUS_M   MB Gabrr2_Pcbp3 GABA     MB   M
#
#        Neurotransmitter_celltype Direction status      nlogp  \
# 910                Glutamatergic        Up    RES  60.361970
# 911                Glutamatergic        Up    RES  40.976303
# 912                Glutamatergic        Up    RES  38.683350
# 913                Glutamatergic        Up    RES  35.223765
# 914                Glutamatergic        Up    RES  32.414473
# ...                          ...       ...    ...        ...
# 322922                 GABAergic      Down    SUS  -2.993919
# 322923                 GABAergic      Down    SUS  -3.033272
# 322924                 GABAergic      Down    SUS  -4.176313
# 322925                 GABAergic      Down    SUS  -4.235782
# 322926                 GABAergic      Down    SUS  -4.608938
#
#                            fname
# 910     TH_TH_Fgf10_Gm16263_Glut
# 911     TH_TH_Fgf10_Gm16263_Glut
# 912     TH_TH_Fgf10_Gm16263_Glut
# 913     TH_TH_Fgf10_Gm16263_Glut
# 914     TH_TH_Fgf10_Gm16263_Glut
# ...                          ...
# 322922   MB_MB_Gabrr2_Pcbp3_GABA
# 322923   MB_MB_Gabrr2_Pcbp3_GABA
# 322924   MB_MB_Gabrr2_Pcbp3_GABA
# 322925   MB_MB_Gabrr2_Pcbp3_GABA
# 322926   MB_MB_Gabrr2_Pcbp3_GABA
#
# [59407 rows x 16 columns]

# %%
df_deg_all = pd.read_excel("/data2st2/junyi/output/six_dataset_3v3final_merged_mast_ng_wilcox_degs_fdr_log2fc0.1_filtered_7regions_rmMB_annotation.xlsx",index_col=0)

# %%
df_deg_CU3RM = df_deg_all[df_deg_all['Model'].str.contains('CUSUS M')].copy()
df_deg_CU3RM = df_deg_CU3RM[df_deg_CU3RM['Region'].isin(['AMY','HPF','PFC'])].copy()
df_deg_CU3RM['ctname'] = df_deg_CU3RM['Region'] + "_" + df_deg_CU3RM['Subclass']
df_deg_CU3RM['ctname'] = df_deg_CU3RM['ctname'].str.replace('/', '-')
df_deg_CU3RM['ctname'] = df_deg_CU3RM['ctname'].str.replace(' ', '_')
df_deg_CU3RM['targetgene'] = df_deg_CU3RM.Gene

# %%
# # L2 group DEGs
# l2deg = sorted(glob.glob('/data2st1/junyi/output/atac1112/0 gene_list_Group_L1_v426/*.xlsx'))
# group_frames = []
# for file in l2deg:
#     df_tmp = pd.read_excel(file).copy()
#     group_name = os.path.basename(file).replace('.xlsx', '')
#     df_tmp['Group'] = group_name
#     group_frames.append(df_tmp)

# df_group_deg_nogroup = pd.concat(group_frames, axis=0, ignore_index=True) if group_frames else pd.DataFrame(columns=['Gene', 'Group'])
# df_group_deg_nogroup

# df_group_deg_nogroup = pd.DataFrame()
# for file in l2deg:
#     df_tmp = pd.read_excel(file)
#     gropu_name = os.path.basename(file).replace('.xlsx','')
#     df_tmp['Group'] = gropu_name
#     df_group_deg_nogroup = pd.concat([df_group_deg_nogroup, df_tmp], axis=0)

# %%
l2deg = glob.glob('/data2st1/junyi/output/atac1112/0 gene_list_Group_L1_v426/*.xlsx')

# %% [markdown]
# # Compute Reguon for each TF in each region subclasst

# %%
compute_regulon = True
df_gs= glob.glob('/data1st1/junyi/output/sn0827/scenic_ctx/*.csv')

# %%
if compute_regulon:
    output_regulon = '/data1st1/junyi/output/sn0827/tf_regulon/'

    # ignore warnings in this cell
    for file_gs in df_gs:
        try:
            df_tf = pd.read_csv(file_gs)
        except Exception as e:
            print(f"Error reading file {file_gs}: {e}")
            continue
        df_tf=df_tf.dropna()
        df_tf_list = Process_tf_target(df_tf)
        fname = file_gs.split('/')[-1].replace('.csv','')
        fname = fname.replace('ctx_','')
        df_all['fname'] = df_all['region'] + "_"+ df_all['celltype.L2']
        df_all['fname'] = df_all['fname'].str.replace('/', '-')
        df_all['fname'] = df_all['fname'].str.replace(' ', '_')
        df_all['TF'] = df_all['TF'].str.replace("(+)", '',regex=False)

        df_tf_list['fname'] = fname
        df_tf_list.to_csv(os.path.join(output_regulon, f"{fname}_tf_target.csv"), index=False)
# Out:
# Error reading file /data1st1/junyi/output/sn0827/scenic_ctx/ctx_PFC_Ependymal_cell.csv: No columns to parse from file
# Error reading file /data1st1/junyi/output/sn0827/scenic_ctx/ctx_STR_Choroid_plexus_cell.csv: No columns to parse from file

# %%
ignore_warnings = True
output_sigregulon = '/data1st1/junyi/output/sn0827/sig_regulon/'

# ignore warnings in this cell
if compute_regulon:
    if ignore_warnings:
        import warnings
        warnings.filterwarnings("ignore")

    if not os.path.exists(output_sigregulon):
        os.makedirs(output_sigregulon)

    if compute_regulon == False:
        # Do not excute the step in this cell
        pass
    # 
    for file_gs in df_gs:
        try:
            df_tf = pd.read_csv(file_gs)
        except Exception as e:
            print(f"Error reading file {file_gs}: {e}")
            continue
        df_tf=df_tf.dropna()
        df_tf_list = Process_tf_target(df_tf)
        fname = file_gs.split('/')[-1].replace('.csv','')
        fname = fname.replace('ctx_','')
        df_all['fname'] = df_all['region'] + "_"+ df_all['celltype.L2']
        df_all['fname'] = df_all['fname'].str.replace('/', '-')
        df_all['fname'] = df_all['fname'].str.replace(' ', '_')
        df_all['TF'] = df_all['TF'].str.replace("(+)", '',regex=False)

        df_tf_list['fname'] = fname
        df_tf_list_sig = df_tf_list.merge(df_sig_TF.drop_duplicates(), on=['TF','fname'], how='inner')
        tf_gene_sets = (
            df_tf_list_sig[['TF', 'targetgene']]
            .dropna()
            .drop_duplicates()
            .groupby('TF')['targetgene']
            .apply(set)
        )

        df_tf_list_sig.to_csv(os.path.join(output_sigregulon,f'{fname}_Sig_tf_regulon.csv'))
# Out:
# Error reading file /data1st1/junyi/output/sn0827/scenic_ctx/ctx_PFC_Ependymal_cell.csv: No columns to parse from file
# Error reading file /data1st1/junyi/output/sn0827/scenic_ctx/ctx_STR_Choroid_plexus_cell.csv: No columns to parse from file

# %%
# df_NT = pd.read_excel('/data2st1/junyi/output/atac1112/genefunction/01_NT_and_ion_v0511.xlsx')
# df_G317 = pd.read_excel('/data2st1/junyi/output/atac1112/genefunction/G03-G17_merged_v05013_full_final.xlsx')

# %%
df_sig_TF_d = df_all_sig[['TF','fname','Direction']]

# %%
scenic_tfs = df_all_filtered.TF.str.replace("(+)", '',regex=False).unique()

# %%
df_deg_all
# Out:
#             Gene          pval    log2FC     ci.hi     ci.lo       FDR  \
# 0        Gm20642  2.924672e-05 -0.268020 -0.153979 -0.382061  0.037039
# 1         Pced1b  7.429092e-06 -0.233513 -0.129907 -0.337119  0.016465
# 2          Srsf2  1.307530e-05 -0.282352 -0.167793 -0.396910  0.023183
# 3          Ube3a  7.446378e-07 -0.215217 -0.137482 -0.292952  0.006601
# 4       AY036118  1.258864e-08 -0.353253 -0.240474 -0.466032  0.000064
# ...          ...           ...       ...       ...       ...       ...
# 464967    Zfp148  1.598237e-03 -0.185759 -0.085587 -0.285931  0.017375
# 464968    Zfp462  7.230957e-03 -0.136580 -0.005329 -0.267832  0.048891
# 464969     Zfpm2  3.977225e-03 -0.217178 -0.082556 -0.351800  0.033180
# 464970    Zswim5  7.364664e-03 -0.157864 -0.055429 -0.260299  0.049534
# 464971      Zzz3  2.113168e-04 -0.166418 -0.076382 -0.256455  0.003661
#
#         Bonferroni        celltype.L2           Subclass  Comparison  ...  \
# 0         0.259272           STR Chol           STR Chol  SUS_vs_CON  ...
# 1         0.065859           STR Chol           STR Chol  SUS_vs_CON  ...
# 2         0.115913           STR Chol           STR Chol  SUS_vs_CON  ...
# 3         0.006601           STR Chol           STR Chol  SUS_vs_CON  ...
# 4         0.000064  STR D1 Chst9 GABA  STR D1 Chst9 GABA  SUS_vs_CON  ...
# ...            ...                ...                ...         ...  ...
# 464967    1.000000                OPC                OPC  SUS_vs_CON  ...
# 464968    1.000000                OPC                OPC  SUS_vs_CON  ...
# 464969    1.000000                OPC                OPC  SUS_vs_CON  ...
# 464970    1.000000                OPC                OPC  SUS_vs_CON  ...
# 464971    0.820121                OPC                OPC  SUS_vs_CON  ...
#
#                                                      DGL1  \
# 0                                     DG12 Noncoding Gene
# 1           DG08 Vesicle Trafficking & Membrane Transport
# 2       DG02 RNA Processing & Surveillance and Transla...
# 3                                       DG04 Proteostasis
# 4                                     DG12 Noncoding Gene
# ...                                                   ...
# 464967        DG01 Chromatin & Transcriptional Regulation
# 464968        DG01 Chromatin & Transcriptional Regulation
# 464969        DG01 Chromatin & Transcriptional Regulation
# 464970                                              other
# 464971                                              other
#
#                                                      DGL2  \
# 0       DG12-01 Predicted, RIK, Gm and clone/accession...
# 1       DG08-04 ER-Golgi trafficking and secretory pro...
# 2             DG02-03 Spliceosome and splicing regulation
# 3       DG04-03 Ubiquitin-proteasome protein quality c...
# 4       DG12-01 Predicted, RIK, Gm and clone/accession...
# ...                                                   ...
# 464967  DG01-03 Epigenetic and chromatin remodeling re...
# 464968  DG01-03 Epigenetic and chromatin remodeling re...
# 464969  DG01-02 Developmental transcription factors, n...
# 464970                                              other
# 464971                                              other
#
#                                                      DGL3 Class  \
# 0       Predicted_RIK_Gm_or_clone_accession_like_nonco...  Chol
# 1                          V01_ER_Golgi_secretory_traffic  Chol
# 2                           Spliceosome_pre_mRNA_splicing  Chol
# 3                 PM03_Ubiquitin_proteasome_SUMO_turnover  Chol
# 4       Predicted_RIK_Gm_or_clone_accession_like_nonco...  GABA
# ...                                                   ...   ...
# 464967              Broad_chromatin_epigenetic_regulation   OPC
# 464968              Broad_chromatin_epigenetic_regulation   OPC
# 464969                Neurodevelopment_fate_transcription   OPC
# 464970                                              other   OPC
# 464971                                              other   OPC
#
#        mean_UMI_raw_Region_Class mean_UMI_norm_Region_Class  \
# 0                       1.570796                   1.205789
# 1                       0.823008                   0.550897
# 2                       1.159291                   0.781294
# 3                       9.969027                   9.025716
# 4                       0.646397                   0.546702
# ...                          ...                        ...
# 464967                  0.259341                   0.449517
# 464968                  1.254947                   2.993772
# 464969                  1.283519                   2.893135
# 464970                  0.283516                   0.461474
# 464971                  0.191209                   0.340028
#
#        mean_log1p_Region_Class mean_UMI_raw_Region_subclass  \
# 0                     0.791085                     1.570796
# 1                     0.438834                     0.823008
# 2                     0.577340                     1.159291
# 3                     2.305153                     9.969027
# 4                     0.436125                     0.332454
# ...                        ...                          ...
# 464967                0.371230                     0.259341
# 464968                1.384736                     1.254947
# 464969                1.359215                     1.283519
# 464970                0.379445                     0.283516
# 464971                0.292691                     0.191209
#
#        mean_UMI_norm_Region_subclass mean_log1p_Region_subclass
# 0                           1.205789                   0.791085
# 1                           0.550897                   0.438834
# 2                           0.781294                   0.577340
# 3                           9.025716                   2.305153
# 4                           0.396675                   0.334094
# ...                              ...                        ...
# 464967                      0.449517                   0.371230
# 464968                      2.993772                   1.384736
# 464969                      2.893135                   1.359215
# 464970                      0.461474                   0.379445
# 464971                      0.340028                   0.292691
#
# [464972 rows x 46 columns]

# %%
deg_tfs = intersection_tfs = set(scenic_tfs).intersection(set(df_deg_all.Gene))

# %%
deg_tfs
# Out:
# {'2010315B03Rik',
#  'AU041133',
#  'Abl1',
#  'Acaa1a',
#  'Adarb1',
#  'Adnp',
#  'Agap2',
#  'Ahctf1',
#  'Ahr',
#  'Akr1a1',
#  'Ar',
#  'Arid5b',
#  'Arnt',
#  'Arnt2',
#  'Arntl',
#  'Atf2',
#  'Atf4',
#  'Atf6',
#  'Atf6b',
#  'Atf7',
#  'B230307C23Rik',
#  'BC005561',
#  'Bach1',
#  'Bach2',
#  'Banp',
#  'Barx2',
#  'Bbx',
#  'Bcl11a',
#  'Bcl11b',
#  'Bcl6',
#  'Bclaf1',
#  'Bdp1',
#  'Bhlhe40',
#  'Bmyc',
#  'Bnc2',
#  'Bptf',
#  'Brf1',
#  'Canx',
#  'Carf',
#  'Cbfa2t2',
#  'Cbfb',
#  'Cbx3',
#  'Cbx7',
#  'Ccnt2',
#  'Cd59a',
#  'Cdc5l',
#  'Cebpd',
#  'Cebpz',
#  'Celf5',
#  'Cers2',
#  'Cers4',
#  'Cers5',
#  'Cers6',
#  'Cfl2',
#  'Chd1',
#  'Chd2',
#  'Ckmt1',
#  'Clk1',
#  'Clock',
#  'Cnot3',
#  'Cnot4',
#  'Cpeb1',
#  'Creb1',
#  'Creb3',
#  'Creb3l2',
#  'Creb5',
#  'Crebzf',
#  'Crem',
#  'Csnk2b',
#  'Ctbp1',
#  'Ctcf',
#  'Ctnnb1',
#  'Cux1',
#  'Cux2',
#  'Cxxc1',
#  'Cycs',
#  'D130040H23Rik',
#  'Dbp',
#  'Dbx2',
#  'Deaf1',
#  'Dgcr8',
#  'Dnajc21',
#  'Dnmt3a',
#  'Dnttip1',
#  'Dus3l',
#  'E2f3',
#  'E2f5',
#  'E2f6',
#  'E4f1',
#  'Ebf1',
#  'Ebf3',
#  'Ebf4',
#  'Egr1',
#  'Egr3',
#  'Egr4',
#  'Elf1',
#  'Elf2',
#  'Elf4',
#  'Elk3',
#  'Emx2',
#  'Ep300',
#  'Epas1',
#  'Esr1',
#  'Esrra',
#  'Esrrg',
#  'Etv1',
#  'Etv4',
#  'Etv5',
#  'Etv6',
#  'Ewsr1',
#  'Ezr',
#  'Fbxl19',
#  'Fez1',
#  'Fli1',
#  'Fos',
#  'Fosl2',
#  'Foxj1',
#  'Foxj3',
#  'Foxk1',
#  'Foxk2',
#  'Foxn2',
#  'Foxn3',
#  'Foxo1',
#  'Foxo3',
#  'Foxp1',
#  'Foxp2',
#  'Foxp4',
#  'Fubp1',
#  'Gabpa',
#  'Gabpb1',
#  'Gli2',
#  'Gli3',
#  'Glis1',
#  'Glis2',
#  'Glis3',
#  'Gm14399',
#  'Gm15446',
#  'Gmeb1',
#  'Gmeb2',
#  'Gpam',
#  'Gpd1',
#  'Grhl1',
#  'Gtf2a1',
#  'Gtf2ird1',
#  'Gtf3c2',
#  'H2afy',
#  'Hbp1',
#  'Hdac1',
#  'Hdac2',
#  'Hdac3',
#  'Hdx',
#  'Hes1',
#  'Hes5',
#  'Hif1a',
#  'Hivep1',
#  'Hivep2',
#  'Hivep3',
#  'Hlf',
#  'Hltf',
#  'Hmbox1',
#  'Hmgb1',
#  'Hmgn3',
#  'Hnrnpc',
#  'Hnrnph3',
#  'Hsf2',
#  'Hspa5',
#  'Id1',
#  'Id2',
#  'Id4',
#  'Ikzf1',
#  'Ikzf2',
#  'Ikzf4',
#  'Ilf2',
#  'Ing4',
#  'Irf2',
#  'Irf3',
#  'Irf8',
#  'Jazf1',
#  'Jdp2',
#  'Jun',
#  'Junb',
#  'Jund',
#  'Kcnip1',
#  'Kdm2a',
#  'Kdm2b',
#  'Kdm4a',
#  'Kdm4b',
#  'Kdm4c',
#  'Kdm5a',
#  'Kdm5b',
#  'Kdm7a',
#  'Klf10',
#  'Klf12',
#  'Klf13',
#  'Klf3',
#  'Klf5',
#  'Klf6',
#  'Klf7',
#  'Klf8',
#  'Klf9',
#  'Kmt2a',
#  'Larp1',
#  'Las1l',
#  'Lcorl',
#  'Lef1',
#  'Lhx2',
#  'Lin28b',
#  'Lmo2',
#  'Lmx1b',
#  'Lrrfip1',
#  'Luzp2',
#  'Maf',
#  'Mafb',
#  'Mafg',
#  'Map4k2',
#  'Max',
#  'Maz',
#  'Mbd1',
#  'Mbd2',
#  'Mbnl2',
#  'Mbtps2',
#  'Mecp2',
#  'Mef2a',
#  'Mef2c',
#  'Mef2d',
#  'Meis1',
#  'Meis2',
#  'Meis3',
#  'Mga',
#  'Mios',
#  'Mitf',
#  'Mkx',
#  'Mlx',
#  'Mlxip',
#  'Mlxipl',
#  'Mrpl1',
#  'Msi2',
#  'Mta3',
#  'Mxd4',
#  'Mxi1',
#  'Myb',
#  'Myef2',
#  'Mynn',
#  'Nap1l1',
#  'Ncor1',
#  'Ncor2',
#  'Neurod2',
#  'Nf1',
#  'Nfat5',
#  'Nfatc2',
#  'Nfatc3',
#  'Nfe2l1',
#  'Nfe2l2',
#  'Nfe2l3',
#  'Nfia',
#  'Nfib',
#  'Nfic',
#  'Nfix',
#  'Nfkb1',
#  'Nfyb',
#  'Nfyc',
#  'Nkx2-2',
#  'Nkx6-2',
#  'Noc2l',
#  'Nono',
#  'Npas2',
#  'Npas4',
#  'Npdc1',
#  'Nr1d2',
#  'Nr2c1',
#  'Nr2c2',
#  'Nr2e1',
#  'Nr2f1',
#  'Nr2f2',
#  'Nr3c1',
#  'Nr3c2',
#  'Nr4a1',
#  'Nr4a2',
#  'Nr4a3',
#  'Nr6a1',
#  'Nrf1',
#  'Nuak1',
#  'Nxph3',
#  'Olig1',
#  'Olig2',
#  'Onecut2',
#  'Otx1',
#  'Parp1',
#  'Pax6',
#  'Pbx1',
#  'Pbx3',
#  'Pbx4',
#  'Pds5a',
#  'Peg3',
#  'Pgr',
#  'Phf21a',
#  'Phf8',
#  'Phtf1',
#  'Pik3c3',
#  'Pknox1',
#  'Pknox2',
#  'Plagl1',
#  'Polr3a',
#  'Pou2f1',
#  'Pou3f1',
#  'Pou3f2',
#  'Pou3f3',
#  'Pou3f4',
#  'Pou6f1',
#  'Pou6f2',
#  'Ppara',
#  'Ppard',
#  'Pparg',
#  'Ppargc1a',
#  'Prdm10',
#  'Prdm11',
#  'Prdm16',
#  'Prdm5',
#  'Prdx5',
#  'Prkaa2',
#  'Prnp',
#  'Prox1',
#  'Prox2',
#  'Prrx1',
#  'Psma6',
#  'Psmc2',
#  'Psmd12',
#  'Pura',
#  'Purg',
#  'Rab14',
#  'Rab2a',
#  'Rab7',
#  'Rad21',
#  'Rarb',
#  'Rb1',
#  'Rbbp5',
#  'Rbm17',
#  'Rbm42',
#  'Rbms1',
#  'Rbpj',
#  'Rcor1',
#  'Rela',
#  'Rfx2',
#  'Rfx3',
#  'Rfx4',
#  'Rfx7',
#  'Rnf114',
#  'Rora',
#  'Rorb',
#  'Rreb1',
#  'Runx1',
#  'Runx2',
#  'Rxrb',
#  'Rxrg',
#  'Satb1',
#  'Setbp1',
#  'Setdb1',
#  'Sf1',
#  'Sf3b1',
#  'Sfpq',
#  'Sin3a',
#  'Sirt6',
#  'Smad1',
#  'Smad2',
#  'Smad3',
#  'Smad4',
#  'Smad7',
#  'Smap2',
#  'Smarca1',
#  'Smarca4',
#  'Smarca5',
#  'Smarcb1',
#  'Smarcc1',
#  'Smarcc2',
#  'Smc3',
#  'Snapc4',
#  'Snrnp70',
#  'Sod1',
#  'Sox1',
#  'Sox10',
#  'Sox11',
#  'Sox2',
#  'Sox4',
#  'Sox5',
#  'Sox6',
#  'Sox8',
#  'Sox9',
#  'Sp3',
#  'Sp4',
#  'Srebf1',
#  'Srebf2',
#  'Ssbp3',
#  'Stat2',
#  'Stat3',
#  'Stat5b',
#  'Stau2',
#  'Supt20',
#  'Suz12',
#  'Taf1',
#  'Tbl1xr1',
#  'Tceal5',
#  'Tceal6',
#  'Tcf12',
#  'Tcf3',
#  'Tcf4',
#  'Tcf7l1',
#  'Tcf7l2',
#  'Tead1',
#  'Tef',
#  'Terf1',
#  'Terf2',
#  'Tet1',
#  'Tfcp2',
#  'Tfdp1',
#  'Tfdp2',
#  'Tfeb',
#  'Thoc2',
#  'Thra',
#  'Thrb',
#  'Tia1',
#  'Tmem33',
#  'Tob2',
#  'Tppp',
#  'Traf4',
#  'Trerf1',
#  'Trim24',
#  'Trim28',
#  'Trp63',
#  'Trps1',
#  'Tsc22d4',
#  'Ube2k',
#  'Ube2v1',
#  'Ubp1',
#  'Ubtf',
#  'Uqcrb',
#  'Usf2',
#  'Vezf1',
#  'Vps4b',
#  'Xbp1',
#  'Xrcc4',
#  'Ybx1',
#  'Yy1',
#  'Zbtb11',
#  'Zbtb16',
#  'Zbtb17',
#  'Zbtb18',
#  'Zbtb20',
#  'Zbtb38',
#  'Zbtb4',
#  'Zbtb43',
#  'Zbtb7a',
#  'Zbtb7c',
#  'Zcchc14',
#  'Zdhhc24',
#  'Zeb1',
#  'Zfhx2',
#  'Zfhx3',
#  'Zfp1',
#  'Zfp112',
#  'Zfp131',
#  'Zfp146',
#  'Zfp148',
#  'Zfp160',
#  'Zfp182',
#  'Zfp2',
#  'Zfp207',
#  'Zfp236',
#  'Zfp239',
#  'Zfp24',
#  'Zfp251',
#  'Zfp260',
#  'Zfp266',
#  'Zfp27',
#  'Zfp276',
#  'Zfp282',
#  'Zfp286',
#  'Zfp30',
#  'Zfp322a',
#  'Zfp329',
#  'Zfp354c',
#  'Zfp362',
#  'Zfp369',
#  'Zfp397',
#  'Zfp398',
#  'Zfp407',
#  'Zfp426',
#  'Zfp445',
#  'Zfp46',
#  'Zfp516',
#  'Zfp521',
#  'Zfp523',
#  'Zfp532',
#  'Zfp536',
#  'Zfp553',
#  'Zfp560',
#  'Zfp57',
#  'Zfp579',
#  'Zfp61',
#  'Zfp612',
#  'Zfp62',
#  'Zfp639',
#  'Zfp64',
#  'Zfp641',
#  'Zfp652',
#  'Zfp654',
#  'Zfp664',
#  'Zfp672',
#  'Zfp697',
#  'Zfp704',
#  'Zfp710',
#  'Zfp711',
#  'Zfp74',
#  'Zfp740',
#  'Zfp746',
#  'Zfp770',
#  'Zfp771',
#  'Zfp821',
#  'Zfp831',
#  'Zfp846',
#  'Zfp850',
#  'Zfp869',
#  'Zfp90',
#  'Zfp91',
#  'Zfp93',
#  'Zfp933',
#  'Zfp938',
#  'Zfp941',
#  'Zfp949',
#  'Zfp950',
#  'Zfp958',
#  'Zfp961',
#  'Zfp975',
#  'Zfp976',
#  'Zfx',
#  'Zic1',
#  'Zic4',
#  'Zkscan1',
#  'Zkscan16',
#  'Zmat2',
#  'Zmat4',
#  'Zmiz1',
#  'Zscan22',
#  'Zscan26',
#  'Zzz3'}

# %%
df_deg_tfs = df_deg_all.loc[df_deg_all.Gene.isin(deg_tfs)].copy()

# %%
df_deg_tfs
# Out:
#           Gene          pval    log2FC     ci.hi     ci.lo           FDR  \
# 20       Bach2  1.556862e-05  0.118943  0.175206  0.062679  6.639806e-04
# 26       Cebpz  1.298781e-05 -0.108031 -0.061607 -0.154455  5.773174e-04
# 42      Hnrnpc  8.955876e-08 -0.101525 -0.058343 -0.144706  9.686171e-06
# 44        Junb  7.847833e-06 -0.121302 -0.072491 -0.170112  3.869963e-04
# 67        Sox8  5.513144e-10 -0.141100 -0.097705 -0.184494  1.270493e-07
# ...        ...           ...       ...       ...       ...           ...
# 464905    Sox8  1.937252e-03  0.152616  0.263153  0.042078  2.010287e-02
# 464914  Stat5b  1.829857e-03 -0.139798 -0.058005 -0.221590  1.929803e-02
# 464965  Zbtb16  1.018507e-15 -0.415345 -0.320498 -0.510192  1.976412e-13
# 464967  Zfp148  1.598237e-03 -0.185759 -0.085587 -0.285931  1.737467e-02
# 464971    Zzz3  2.113168e-04 -0.166418 -0.076382 -0.256455  3.661253e-03
#
#           Bonferroni       celltype.L2          Subclass  Comparison  ...  \
# 20      9.826913e-02  STR D1 Fbn2 GABA  STR D1 Fbn2 GABA  SUS_vs_CON  ...
# 26      8.197907e-02  STR D1 Fbn2 GABA  STR D1 Fbn2 GABA  SUS_vs_CON  ...
# 42      5.652949e-04  STR D1 Fbn2 GABA  STR D1 Fbn2 GABA  SUS_vs_CON  ...
# 44      4.953552e-02  STR D1 Fbn2 GABA  STR D1 Fbn2 GABA  SUS_vs_CON  ...
# 67      3.479897e-06  STR D1 Fbn2 GABA  STR D1 Fbn2 GABA  SUS_vs_CON  ...
# ...              ...               ...               ...         ...  ...
# 464905  1.000000e+00               OPC               OPC  SUS_vs_CON  ...
# 464914  1.000000e+00               OPC               OPC  SUS_vs_CON  ...
# 464965  3.952825e-12               OPC               OPC  SUS_vs_CON  ...
# 464967  1.000000e+00               OPC               OPC  SUS_vs_CON  ...
# 464971  8.201206e-01               OPC               OPC  SUS_vs_CON  ...
#
#                                                      DGL1  \
# 20            DG01 Chromatin & Transcriptional Regulation
# 26            DG01 Chromatin & Transcriptional Regulation
# 42      DG02 RNA Processing & Surveillance and Transla...
# 44            DG01 Chromatin & Transcriptional Regulation
# 67            DG01 Chromatin & Transcriptional Regulation
# ...                                                   ...
# 464905        DG01 Chromatin & Transcriptional Regulation
# 464914        DG01 Chromatin & Transcriptional Regulation
# 464965        DG01 Chromatin & Transcriptional Regulation
# 464967        DG01 Chromatin & Transcriptional Regulation
# 464971                                              other
#
#                                                      DGL2  \
# 20      DG01-03 Epigenetic and chromatin remodeling re...
# 26      DG01-03 Epigenetic and chromatin remodeling re...
# 42            DG02-03 Spliceosome and splicing regulation
# 44      DG01-02 Developmental transcription factors, n...
# 67      DG01-02 Developmental transcription factors, n...
# ...                                                   ...
# 464905  DG01-02 Developmental transcription factors, n...
# 464914  DG01-03 Epigenetic and chromatin remodeling re...
# 464965  DG01-03 Epigenetic and chromatin remodeling re...
# 464967  DG01-03 Epigenetic and chromatin remodeling re...
# 464971                                              other
#
#                                          DGL3 Class mean_UMI_raw_Region_Class  \
# 20      Broad_chromatin_epigenetic_regulation  GABA                  0.608801
# 26      Broad_chromatin_epigenetic_regulation  GABA                  0.569218
# 42              Spliceosome_pre_mRNA_splicing  GABA                  0.449352
# 44           Sequence_specific_TF_coregulator  GABA                  0.314338
# 67        Neurodevelopment_fate_transcription  GABA                  0.346032
# ...                                       ...   ...                       ...
# 464905    Neurodevelopment_fate_transcription   OPC                  0.505495
# 464914  Broad_chromatin_epigenetic_regulation   OPC                  0.149451
# 464965  Broad_chromatin_epigenetic_regulation   OPC                  0.171429
# 464967  Broad_chromatin_epigenetic_regulation   OPC                  0.259341
# 464971                                  other   OPC                  0.191209
#
#        mean_UMI_norm_Region_Class mean_log1p_Region_Class  \
# 20                       0.563965                0.447224
# 26                       0.580687                0.457859
# 42                       0.466099                0.382605
# 44                       0.261403                0.232224
# 67                       0.352995                0.302320
# ...                           ...                     ...
# 464905                   1.003382                0.694837
# 464914                   0.269288                0.238456
# 464965                   0.279077                0.246138
# 464967                   0.449517                0.371230
# 464971                   0.340028                0.292691
#
#        mean_UMI_raw_Region_subclass mean_UMI_norm_Region_subclass  \
# 20                         1.296572                      1.360101
# 26                         0.546571                      0.559495
# 42                         0.413012                      0.434750
# 44                         0.506847                      0.443169
# 67                         0.398628                      0.423859
# ...                             ...                           ...
# 464905                     0.505495                      1.003382
# 464914                     0.149451                      0.269288
# 464965                     0.171429                      0.279077
# 464967                     0.259341                      0.449517
# 464971                     0.191209                      0.340028
#
#        mean_log1p_Region_subclass
# 20                       0.858704
# 26                       0.444362
# 42                       0.360991
# 44                       0.366842
# 67                       0.353371
# ...                           ...
# 464905                   0.694837
# 464914                   0.238456
# 464965                   0.246138
# 464967                   0.371230
# 464971                   0.292691
#
# [23208 rows x 46 columns]

# %%
df_deg_tfs['TF'] = df_deg_tfs.Gene

# %%
df_deg_tfs
# Out:
#          Gene          pval    log2FC     ci.hi     ci.lo           FDR  \
# 80442   Nr3c1  5.843911e-05  0.166124  0.238805  0.093443  3.444879e-04
# 394271  Nr3c1  2.874404e-03  0.107868  0.180492  0.035243  5.591051e-03
# 393067  Nr3c1  3.609684e-07  0.119489  0.187046  0.051932  1.394936e-06
# 268385  Nr3c1  2.378542e-05  0.111097  0.158792  0.063403  1.217739e-04
# 123212  Nr3c1  4.095433e-03  0.112879  0.185037  0.040720  1.668858e-02
# ...       ...           ...       ...       ...       ...           ...
# 311692   Cbx7  5.061673e-07  0.137943  0.188760  0.087125  1.206449e-05
# 315932   Cbx7  3.929879e-12  0.121210  0.153301  0.089120  5.698325e-11
# 318050   Cbx7  2.067177e-04  0.135891  0.200877  0.070906  3.001721e-03
# 310513   Cbx7  1.033877e-11  0.105704  0.134492  0.076917  9.638855e-11
# 91400    Cbx7  9.210413e-06  0.104233  0.145302  0.063164  4.237048e-05
#
#           Bonferroni                  celltype.L2  \
# 80442   4.454229e-01        HY Lef1_Slc16a10 GABA
# 394271  1.000000e+00                        MOL-2
# 393067  1.121529e-03                        MOL-1
# 268385  2.177318e-01        TH Cald1_Gm39185 Glut
# 123212  1.000000e+00         TH Ccdc192_Gli3 Glut
# ...              ...                          ...
# 311692  3.655540e-03  HY Myo5b_B230323A14Rik Glut
# 315932  2.507263e-08          HY Prr5l_Vipr2 GABA
# 318050  1.000000e+00             HY Sst_Agrp GABA
# 310513  7.788195e-08        HY Meis2_Adamts3 GABA
# 91400   6.042031e-02          HY Prr5l_Vipr2 GABA
#
#                            Subclass    Comparison  ...  Class  \
# 80442         HY Lef1_Slc16a10 GABA    RES_vs_CON  ...   GABA
# 394271                        MOL-2   CSDS_vs_CON  ...  Oligo
# 393067                        MOL-1   CSDS_vs_CON  ...  Oligo
# 268385        TH Cald1_Gm39185 Glut  CSRES_vs_CON  ...   Glut
# 123212         TH Ccdc192_Gli3 Glut    RES_vs_CON  ...   Glut
# ...                             ...           ...  ...    ...
# 311692  HY Myo5b_B230323A14Rik Glut  CSRES_vs_CON  ...   Glut
# 315932          HY Prr5l_Vipr2 GABA  CSRES_vs_CON  ...   GABA
# 318050             HY Sst_Agrp GABA  CSRES_vs_CON  ...   GABA
# 310513        HY Meis2_Adamts3 GABA  CSRES_vs_CON  ...   GABA
# 91400           HY Prr5l_Vipr2 GABA    RES_vs_CON  ...   GABA
#
#        mean_UMI_raw_Region_Class mean_UMI_norm_Region_Class  \
# 80442                   0.548054                   0.525179
# 394271                  0.360818                   0.709860
# 393067                  0.360818                   0.709860
# 268385                  3.585666                   1.764042
# 123212                  2.723364                   1.726897
# ...                          ...                        ...
# 311692                  0.283070                   0.283412
# 315932                  0.232284                   0.257313
# 318050                  0.232284                   0.257313
# 310513                  0.232284                   0.257313
# 91400                   0.241184                   0.242966
#
#        mean_log1p_Region_Class mean_UMI_raw_Region_subclass  \
# 80442                 0.422112                     0.457685
# 394271                0.536411                     0.347544
# 393067                0.536411                     0.349310
# 268385                1.016694                     4.330854
# 123212                1.003164                     1.947131
# ...                        ...                          ...
# 311692                0.249522                     0.258589
# 315932                0.228977                     0.217337
# 318050                0.228977                     0.303241
# 310513                0.228977                     0.257553
# 91400                 0.217500                     0.215450
#
#        mean_UMI_norm_Region_subclass mean_log1p_Region_subclass     TF  \
# 80442                       0.454060                   0.374360  Nr3c1
# 394271                      0.697012                   0.528869  Nr3c1
# 393067                      0.769145                   0.570496  Nr3c1
# 268385                      2.082638                   1.125786  Nr3c1
# 123212                      1.361900                   0.859466  Nr3c1
# ...                              ...                        ...    ...
# 311692                      0.277790                   0.245132   Cbx7
# 315932                      0.262651                   0.233213   Cbx7
# 318050                      0.311373                   0.271075   Cbx7
# 310513                      0.266126                   0.235962   Cbx7
# 91400                       0.239877                   0.215013   Cbx7
#
#                                 ctname      nlogp
# 80442         HY_HY_Lef1_Slc16a10_GABA   3.462826
# 394271                       STR_MOL-2   2.252507
# 393067                       STR_MOL-1   5.855446
# 268385        TH_TH_Cald1_Gm39185_Glut   3.914446
# 123212         TH_TH_Ccdc192_Gli3_Glut   1.777581
# ...                                ...        ...
# 311692  HY_HY_Myo5b_B230323A14Rik_Glut   4.918491
# 315932          HY_HY_Prr5l_Vipr2_GABA  10.244253
# 318050             HY_HY_Sst_Agrp_GABA   2.522630
# 310513        HY_HY_Meis2_Adamts3_GABA  10.015975
# 91400           HY_HY_Prr5l_Vipr2_GABA   4.372937
#
# [23208 rows x 49 columns]

# %%
# draw complex heatmap of log2FC of deg_tfs across regions
df_deg_tfs['ctname'] = df_deg_tfs['Region'] + "_" + df_deg_tfs['Subclass']
df_deg_tfs['ctname'] = df_deg_tfs['ctname'].str.replace('/', '-')
df_deg_tfs['ctname'] = df_deg_tfs['ctname'].str.replace(' ', '_')
df_deg_tfs['ctname'] = df_deg_tfs['ctname'].str.replace('HIP', 'HPF')   
df_deg_tfs['nlogp'] = -1 * np.log10(df_deg_tfs['FDR'] + 1e-300)
df_deg_tfs.loc[df_deg_tfs['Direction'] == 'Down', 'nlogp'] *= -1

tf_order_source = None
for candidate_name in ['df_all_TFs', 'df_all']:
    if candidate_name in globals():
        tf_order_source = globals()[candidate_name]
        break

if tf_order_source is not None:
    if 'TF' in tf_order_source.columns:
        tf_order = tf_order_source['TF'].dropna().astype(str).drop_duplicates().tolist()
    else:
        tf_order = pd.Index(tf_order_source.index).dropna().astype(str).drop_duplicates().tolist()

    tf_order_deg = [tf for tf in tf_order if tf in set(df_deg_tfs['TF'].astype(str))]
    remaining_tfs = [
        tf
        for tf in df_deg_tfs['TF'].astype(str).drop_duplicates().tolist()
        if tf not in tf_order_deg
    ]
    df_deg_tfs['TF'] = pd.Categorical(
        df_deg_tfs['TF'].astype(str),
        categories=tf_order_deg + remaining_tfs,
        ordered=True
    )
    df_deg_tfs = df_deg_tfs.sort_values('TF').copy()
else:
    print('df_all_TFs / df_all not found, keep current TF order.')

plot_heatmap(
    df_deg_tfs,
    col_split='Region',
    row_cluster=False,
    col_cluster=True,
    pdf_file='/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_wilcoxon_all_DEG_TFs_heatmap.pdf',
    region_order=['AMY', 'HPF', 'HY', 'iCTX', 'MB', 'PFC', 'STR', 'TH'],
    fig_size=(14, 70),
    clip=(-5, 5)
)
# Out:
# Starting..
# Calculating row orders..
# Reordering rows..
# Calculating col orders..
# Reordering cols..
# Plotting matrix..
# Plotting HeatmapAnnotations
# Collecting legends..
# Collecting annotation legends..
# Plotting legends..
# Estimated legend width: 39.68888888888889 mm

# %%
df_deg_CU3RM
# Out:
#                  Gene          pval    log2FC     ci.hi     ci.lo  \
# 18959   4930587E11Rik  4.979281e-05 -0.477901 -0.273399 -0.682402
# 18960   5330438D12Rik  4.689805e-05 -0.377034 -0.215016 -0.539053
# 18961        AY036118  5.525016e-06 -0.447369 -0.276481 -0.618257
# 18962        Cacna2d3  1.889082e-06 -0.391569 -0.238783 -0.544355
# 18963            Fgf1  3.178173e-06 -0.359748 -0.220231 -0.499266
# ...               ...           ...       ...       ...       ...
# 356562           Ugdh  8.143051e-05  0.136016  0.200889  0.071143
# 356563          Vegfa  9.346487e-13 -0.190746 -0.137492 -0.244001
# 356564         Vstm2b  1.868124e-05  0.120238  0.182141  0.058336
# 356565           Apoe  1.396287e-07  0.752230  1.078455  0.426004
# 356566           Meg3  6.940024e-07  0.818887  1.122733  0.515040
#
#                  FDR    Bonferroni    celltype.L2       Subclass  Comparison  \
# 18959   2.395034e-02  3.832054e-01  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# 18960   2.395034e-02  3.609274e-01  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# 18961   5.259256e-03  4.252053e-02  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# 18962   2.907674e-03  1.453837e-02  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# 18963   3.494174e-03  2.445922e-02  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# ...              ...           ...            ...            ...         ...
# 356562  3.214227e-03  3.532455e-01            OPC            OPC  SUS_vs_CON
# 356563  5.792152e-10  4.054506e-09            OPC            OPC  SUS_vs_CON
# 356564  9.572672e-04  8.103922e-02            OPC            OPC  SUS_vs_CON
# 356565  5.639602e-04  5.639602e-04           VLMC           VLMC  SUS_vs_CON
# 356566  1.401538e-03  2.803076e-03           VLMC           VLMC  SUS_vs_CON
#
#         ...                                               DGL3     Class  \
# 18959   ...  Predicted_RIK_Gm_or_clone_accession_like_nonco...      Glut
# 18960   ...  Predicted_RIK_Gm_or_clone_accession_like_nonco...      Glut
# 18961   ...  Predicted_RIK_Gm_or_clone_accession_like_nonco...      Glut
# 18962   ...                                                 Ca      Glut
# 18963   ...         PM09_Signaling_receptor_protein_regulation      Glut
# ...     ...                                                ...       ...
# 356562  ...               EP01_Glycolysis_lactate_carbohydrate       OPC
# 356563  ...            PM03_Ubiquitin_proteasome_SUMO_turnover       OPC
# 356564  ...             SIG04_mTOR_nutrient_lysosome_signaling       OPC
# 356565  ...             LM13_Lipoprotein_cholesterol_transport  Vascular
# 356566  ...              Transcription_RNA_processing_coupling  Vascular
#
#        mean_UMI_raw_Region_Class mean_UMI_norm_Region_Class  \
# 18959                   1.144637                   0.876635
# 18960                   2.641405                   2.795462
# 18961                   2.700016                   2.814399
# 18962                   4.585070                   3.477626
# 18963                   0.451440                   0.318779
# ...                          ...                        ...
# 356562                  0.511659                   0.896961
# 356563                  0.168905                   0.248821
# 356564                  0.445229                   0.752784
# 356565                  3.396551                   7.075729
# 356566                  2.724138                   8.167181
#
#        mean_log1p_Region_Class mean_UMI_raw_Region_subclass  \
# 18959                 0.629480                     0.495238
# 18960                 1.333806                     1.809525
# 18961                 1.338783                     2.257144
# 18962                 1.499093                     6.638097
# 18963                 0.276707                     0.180952
# ...                        ...                          ...
# 356562                0.640253                     0.511659
# 356563                0.222200                     0.168905
# 356564                0.561206                     0.445229
# 356565                2.088863                     4.671053
# 356566                2.215630                     2.631579
#
#        mean_UMI_norm_Region_subclass mean_log1p_Region_subclass  \
# 18959                       0.343224                   0.295073
# 18960                       1.677223                   0.984780
# 18961                       1.943927                   1.079744
# 18962                       6.400530                   2.001552
# 18963                       0.119373                   0.112768
# ...                              ...                        ...
# 356562                      0.896961                   0.640253
# 356563                      0.248821                   0.222200
# 356564                      0.752784                   0.561206
# 356565                     12.813697                   2.625661
# 356566                      8.154373                   2.214232
#
#                    ctname targetgene
# 18959   PFC_PFC_Car3_Glut      18959
# 18960   PFC_PFC_Car3_Glut      18960
# 18961   PFC_PFC_Car3_Glut      18961
# 18962   PFC_PFC_Car3_Glut      18962
# 18963   PFC_PFC_Car3_Glut      18963
# ...                   ...        ...
# 356562            AMY_OPC     356562
# 356563            AMY_OPC     356563
# 356564            AMY_OPC     356564
# 356565           AMY_VLMC     356565
# 356566           AMY_VLMC     356566
#
# [9209 rows x 48 columns]

# %%
deg_all_common_s = df_deg_CU3RM.copy()

# %%
# deg_all_common_s = deg_all_common_s[deg_all_common_s.Region.isin(['AMY', 'HPF', 'PFC'])].copy()
# deg_all_common_s = deg_all_common_s[deg_all_common_s.Model=='CUSUS M']
# deg_all_common_s['TF'] = deg_all_common_s.index
# deg_all_common_s['ctname'] = deg_all_common_s['Region'] + "_" + deg_all_common_s['Subclass']
# deg_all_common_s['ctname'] = deg_all_common_s['ctname'].str.replace('/', '-')
# deg_all_common_s['ctname'] = deg_all_common_s['ctname'].str.replace(' ', '_')
# deg_all_common_s['ctname'] = deg_all_common_s['ctname'].str.replace('HIP', 'HPF')

# %%
deg_all_common_s.columns = ['TF','TF_name','Direction','log2FC','ctname','Neurotransmitter','Region','FDR']

# %%
deg_all_common_s

# %%
df_scenic_all = df_all.copy()
df_scenic_all['Gene'] = df_all['TF']
df_scenic_all['Subclass'] = df_all['celltype.L2']
df_scenic_all['Region subclass'] = df_all['celltype.L2']
# Only when Neurotransmitter_celltype == 'NN', then Region subclass = Region + celltype.L2, otherwise just celltype.L2
nn_mask = df_scenic_all['Neurotransmitter_celltype'] == 'NN'
df_scenic_all.loc[nn_mask, 'Region subclass'] = df_scenic_all.loc[nn_mask, 'region'] + " " + df_scenic_all.loc[nn_mask, 'celltype.L2']
df_scenic_all['Neurotransmitter'] = df_scenic_all['Neurotransmitter_celltype'].str[:4]
df_scenic_all['Model'] = df_scenic_all['comparison'].str.replace('_', ' ')
df_scenic_all.to_csv('/data2/junyi/stg0901/scenic_wilcoxon_all/all_SCENIC_TFs.csv', index=False)

# %%
df_deg_tfs.to_csv('/data2/junyi/stg0901/scenic_wilcoxon_all/all_DEG_TFs.csv', index=False)

# %%
# select overlapped TFs between df_deg_tfs and df_scenic_all
overlap_deg_scenic_tfs = set(df_deg_tfs['TF'].astype(str)).intersection(set(df_scenic_all['Gene'].astype(str)))
print(f'Number of overlapping TFs between DEGs and SCENIC: {len(overlap_deg_scenic_tfs)}')
print(f'Overlapping TFs between DEGs and SCENIC: {overlap_deg_scenic_tfs}')
df_deg_tfs_common = df_deg_tfs[df_deg_tfs['TF'].astype(str).isin(overlap_deg_scenic_tfs)].copy()
df_scenic_all_common = df_scenic_all[df_scenic_all['Gene'].astype(str).isin(overlap_deg_scenic_tfs)].copy()
# Out:
# Number of overlapping TFs between DEGs and SCENIC: 544
# Overlapping TFs between DEGs and SCENIC: {'Zfp369', 'Hsf2', 'Fbxl19', 'Canx', 'Rfx4', 'Rfx7', 'Cux1', 'Zfhx2', 'Rb1', 'Cxxc1', 'Uqcrb', 'Chd1', 'Cers6', 'Esr1', 'Ikzf1', 'Pbx3', 'Nfyb', 'Zfp362', 'Mga', 'Nono', 'Clk1', 'Zfp57', 'Tcf3', 'Lmx1b', 'Zeb1', 'Setdb1', 'Sox11', 'Cebpd', 'Tppp', 'Bptf', 'Mlxip', 'Xrcc4', 'Mlxipl', 'Foxo3', 'Bbx', 'Thrb', 'Carf', 'Mef2d', 'Elf2', 'Creb1', 'Emx2', 'Kdm4a', 'Nfe2l3', 'Zfp536', 'Runx1', 'Ctnnb1', 'Lin28b', 'Zfp579', 'Rbm17', 'Smarca1', 'Map4k2', 'Meis1', 'Creb5', 'Mios', 'Cpeb1', 'Zfp664', 'Zfp148', 'Junb', 'Zfp46', 'Dgcr8', 'Zic4', 'Zfp711', 'Prdx5', 'BC005561', 'Prdm10', 'Purg', 'Zfp850', 'E2f5', 'Dbx2', 'Fosl2', 'Rbm42', 'Sox4', 'Neurod2', 'Pou2f1', 'Klf8', 'Adarb1', 'Rorb', 'Zfp30', 'Phtf1', 'Tef', 'Smad7', 'Zbtb43', 'Zfp846', 'Acaa1a', 'Nfatc3', 'Snrnp70', 'Zfp266', 'Sod1', 'Zfp950', 'Zfp426', 'Hivep3', 'Maf', 'Zfp329', 'Gpd1', 'Zfp976', 'Id2', 'Terf2', 'Zfp160', 'Noc2l', 'Npas2', 'Ppara', 'Tfeb', 'Foxk1', 'Gmeb1', 'Ctcf', 'Ilf2', 'Id4', 'Tbl1xr1', 'Pik3c3', 'Prkaa2', 'Mrpl1', 'Adnp', 'Smc3', 'Mbd2', 'Hltf', 'Msi2', 'Smad3', 'Cbx7', 'Ep300', 'Mlx', 'Bclaf1', 'Mkx', 'Hivep2', 'Gm15446', 'Foxj3', 'Zfp553', 'Elf1', 'Zfp24', 'Hif1a', 'Hes1', 'Zbtb7c', 'Kdm4c', 'Psmc2', 'Rab14', 'Trp63', 'Smap2', 'Klf9', 'Sfpq', 'Parp1', 'H2afy', 'Dus3l', 'Prox2', 'Cers5', 'Zfp1', 'E2f3', 'Nr2c2', 'Jund', 'Nfat5', 'Kdm7a', 'Bhlhe40', 'E4f1', 'Ebf4', 'Arnt', 'Sp4', 'Foxo1', 'Zfp770', 'Polr3a', 'Elf4', 'Kdm2b', 'Ezr', 'Zfp532', 'Etv4', 'Terf1', 'Irf8', 'Rxrg', 'Larp1', 'Mef2c', 'Atf6b', 'Zfp958', 'Cers4', 'Lmo2', 'Satb1', 'Jun', 'Zzz3', 'Gtf2ird1', 'Foxk2', 'Kdm2a', 'Hbp1', 'Hmgb1', 'Abl1', 'Gm14399', 'Stat3', 'Celf5', 'Srebf2', 'Psmd12', 'Kdm5b', 'Pbx4', 'Vezf1', 'Trerf1', 'Mbd1', 'Zfp131', 'Myb', 'Egr4', 'Peg3', 'Tsc22d4', 'Zfp407', 'Tmem33', 'Nr4a3', 'Prdm5', 'Hdac3', 'Nuak1', 'Dnttip1', 'Klf7', 'Pds5a', 'Rbpj', 'Setbp1', 'Zbtb7a', 'Zfp869', 'Max', 'Sf3b1', 'Ncor1', 'Hlf', 'Bcl11b', 'Las1l', 'Zbtb18', 'Cd59a', 'Trps1', 'Hmbox1', 'Smad2', 'Stat5b', 'Zfp975', 'Esrrg', 'Grhl1', 'Rfx2', 'Nkx2-2', 'Pura', 'Gli2', 'Gtf2a1', 'Smarca4', 'B230307C23Rik', 'Mxd4', 'Phf21a', 'Glis1', 'Tceal5', 'Tfcp2', 'Tcf7l1', 'Pou3f3', 'Zic1', 'Sox8', 'Crebzf', 'Zfp93', 'Pou6f1', 'Suz12', 'Zkscan1', 'Etv1', 'Myef2', 'Hnrnpc', 'Atf7', 'Bmyc', 'Sox1', 'Ebf1', 'Zfp641', 'Plagl1', 'Fubp1', 'Hdx', 'Hnrnph3', 'Gpam', 'Mecp2', 'Zbtb16', 'Sox6', 'Zfp740', 'Sp3', 'Etv5', 'Yy1', 'Foxn2', 'Ppard', 'Ybx1', 'AU041133', 'Cfl2', 'Prox1', 'Zmat2', 'Zfp961', 'Zfp64', 'Trim24', 'Trim28', 'Olig1', 'Nr4a1', 'Cnot3', 'Chd2', 'D130040H23Rik', 'Kmt2a', 'Meis3', 'Kdm5a', 'Zscan22', 'Zfp612', 'Hivep1', 'Cdc5l', 'Sf1', 'Bcl6', 'Glis2', 'Ube2v1', 'Smarca5', 'Cnot4', 'Zfp62', 'Bcl11a', 'Nr3c1', 'Zfp516', 'Phf8', 'Zfp521', 'Brf1', 'Klf10', 'Zfp941', 'Smarcb1', 'Ube2k', 'Otx1', 'Rora', 'Pbx1', 'Pknox2', 'Cycs', 'Zfp704', 'Arid5b', 'Foxp1', 'Rad21', 'Smad1', 'Pknox1', 'Nfe2l1', 'Mafb', 'Tcf4', 'Bnc2', 'Ncor2', 'Klf5', 'Foxn3', 'Zfp672', 'Lrrfip1', 'Lhx2', 'Sox5', 'Jdp2', 'Sox2', 'Taf1', 'Pou3f1', 'Hes5', 'Zdhhc24', 'Kcnip1', 'Nr6a1', 'Olig2', 'Zfp652', 'Cebpz', 'Ebf3', 'Prnp', 'Fli1', 'Zfp523', 'Etv6', 'Cers2', 'Glis3', 'Smarcc1', 'Foxj1', 'Tia1', 'Arnt2', 'Kdm4b', 'Zfp61', 'Mbnl2', 'Mitf', 'Agap2', 'Tceal6', 'Zfhx3', 'Rab7', 'Zfp654', 'Zbtb17', 'Zfp354c', 'Clock', 'Tet1', 'Rreb1', 'Nr1d2', 'Mynn', 'Hmgn3', 'Mta3', 'Smad4', 'Maz', 'Arntl', 'Dnajc21', 'Crem', 'Zmat4', 'Nr2e1', 'Mafg', 'E2f6', 'Tob2', 'Egr1', 'Ar', 'Zfp27', 'Barx2', 'Nfyc', 'Zfx', 'Sox10', 'Tfdp1', 'Mbtps2', 'Zfp91', 'Nr2f1', 'Atf2', 'Ccnt2', 'Stat2', 'Ssbp3', 'Rarb', 'Deaf1', 'Ubp1', 'Meis2', 'Pou6f2', 'Lef1', 'Nr2c1', 'Zfp771', 'Nr3c2', 'Thoc2', 'Xbp1', 'Rcor1', 'Jazf1', 'Zfp938', 'Zfp949', 'Nxph3', 'Gmeb2', 'Zfp207', 'Zbtb11', 'Srebf1', 'Ahctf1', 'Gabpb1', 'Zfp276', 'Zfp112', 'Atf6', 'Ubtf', 'Fos', 'Pax6', 'Sox9', 'Tfdp2', 'Zfp821', 'Zfp182', 'Npas4', 'Klf12', 'Elk3', 'Smarcc2', 'Esrra', 'Cbfa2t2', 'Irf3', 'Mef2a', 'Zfp560', '2010315B03Rik', 'Gabpa', 'Rnf114', 'Zfp697', 'Rab2a', 'Usf2', 'Zfp2 ...

# %%
df_deg_tfs_common
# Out:
#          Gene          pval    log2FC     ci.hi     ci.lo           FDR  \
# 80442   Nr3c1  5.843911e-05  0.166124  0.238805  0.093443  3.444879e-04
# 394271  Nr3c1  2.874404e-03  0.107868  0.180492  0.035243  5.591051e-03
# 393067  Nr3c1  3.609684e-07  0.119489  0.187046  0.051932  1.394936e-06
# 268385  Nr3c1  2.378542e-05  0.111097  0.158792  0.063403  1.217739e-04
# 123212  Nr3c1  4.095433e-03  0.112879  0.185037  0.040720  1.668858e-02
# ...       ...           ...       ...       ...       ...           ...
# 311692   Cbx7  5.061673e-07  0.137943  0.188760  0.087125  1.206449e-05
# 315932   Cbx7  3.929879e-12  0.121210  0.153301  0.089120  5.698325e-11
# 318050   Cbx7  2.067177e-04  0.135891  0.200877  0.070906  3.001721e-03
# 310513   Cbx7  1.033877e-11  0.105704  0.134492  0.076917  9.638855e-11
# 91400    Cbx7  9.210413e-06  0.104233  0.145302  0.063164  4.237048e-05
#
#           Bonferroni                  celltype.L2  \
# 80442   4.454229e-01        HY Lef1_Slc16a10 GABA
# 394271  1.000000e+00                        MOL-2
# 393067  1.121529e-03                        MOL-1
# 268385  2.177318e-01        TH Cald1_Gm39185 Glut
# 123212  1.000000e+00         TH Ccdc192_Gli3 Glut
# ...              ...                          ...
# 311692  3.655540e-03  HY Myo5b_B230323A14Rik Glut
# 315932  2.507263e-08          HY Prr5l_Vipr2 GABA
# 318050  1.000000e+00             HY Sst_Agrp GABA
# 310513  7.788195e-08        HY Meis2_Adamts3 GABA
# 91400   6.042031e-02          HY Prr5l_Vipr2 GABA
#
#                            Subclass    Comparison  ...  Class  \
# 80442         HY Lef1_Slc16a10 GABA    RES_vs_CON  ...   GABA
# 394271                        MOL-2   CSDS_vs_CON  ...  Oligo
# 393067                        MOL-1   CSDS_vs_CON  ...  Oligo
# 268385        TH Cald1_Gm39185 Glut  CSRES_vs_CON  ...   Glut
# 123212         TH Ccdc192_Gli3 Glut    RES_vs_CON  ...   Glut
# ...                             ...           ...  ...    ...
# 311692  HY Myo5b_B230323A14Rik Glut  CSRES_vs_CON  ...   Glut
# 315932          HY Prr5l_Vipr2 GABA  CSRES_vs_CON  ...   GABA
# 318050             HY Sst_Agrp GABA  CSRES_vs_CON  ...   GABA
# 310513        HY Meis2_Adamts3 GABA  CSRES_vs_CON  ...   GABA
# 91400           HY Prr5l_Vipr2 GABA    RES_vs_CON  ...   GABA
#
#        mean_UMI_raw_Region_Class mean_UMI_norm_Region_Class  \
# 80442                   0.548054                   0.525179
# 394271                  0.360818                   0.709860
# 393067                  0.360818                   0.709860
# 268385                  3.585666                   1.764042
# 123212                  2.723364                   1.726897
# ...                          ...                        ...
# 311692                  0.283070                   0.283412
# 315932                  0.232284                   0.257313
# 318050                  0.232284                   0.257313
# 310513                  0.232284                   0.257313
# 91400                   0.241184                   0.242966
#
#        mean_log1p_Region_Class mean_UMI_raw_Region_subclass  \
# 80442                 0.422112                     0.457685
# 394271                0.536411                     0.347544
# 393067                0.536411                     0.349310
# 268385                1.016694                     4.330854
# 123212                1.003164                     1.947131
# ...                        ...                          ...
# 311692                0.249522                     0.258589
# 315932                0.228977                     0.217337
# 318050                0.228977                     0.303241
# 310513                0.228977                     0.257553
# 91400                 0.217500                     0.215450
#
#        mean_UMI_norm_Region_subclass mean_log1p_Region_subclass     TF  \
# 80442                       0.454060                   0.374360  Nr3c1
# 394271                      0.697012                   0.528869  Nr3c1
# 393067                      0.769145                   0.570496  Nr3c1
# 268385                      2.082638                   1.125786  Nr3c1
# 123212                      1.361900                   0.859466  Nr3c1
# ...                              ...                        ...    ...
# 311692                      0.277790                   0.245132   Cbx7
# 315932                      0.262651                   0.233213   Cbx7
# 318050                      0.311373                   0.271075   Cbx7
# 310513                      0.266126                   0.235962   Cbx7
# 91400                       0.239877                   0.215013   Cbx7
#
#                                 ctname      nlogp
# 80442         HY_HY_Lef1_Slc16a10_GABA   3.462826
# 394271                       STR_MOL-2   2.252507
# 393067                       STR_MOL-1   5.855446
# 268385        TH_TH_Cald1_Gm39185_Glut   3.914446
# 123212         TH_TH_Ccdc192_Gli3_Glut   1.777581
# ...                                ...        ...
# 311692  HY_HY_Myo5b_B230323A14Rik_Glut   4.918491
# 315932          HY_HY_Prr5l_Vipr2_GABA  10.244253
# 318050             HY_HY_Sst_Agrp_GABA   2.522630
# 310513        HY_HY_Meis2_Adamts3_GABA  10.015975
# 91400           HY_HY_Prr5l_Vipr2_GABA   4.372937
#
# [23208 rows x 49 columns]

# %%
df_scenic_all_common['Model'] = df_scenic_all_common['comparison'].str.replace('_', ' ')

# %%
comparison_to_status = {
    'CSDS_M': 'CSSUS_M',
    'RES_M': 'CURES_M',
    'RES_F': 'CURES_F',
    'CSDS_F': 'CSSUS_F',
    'SUS_M': 'CUSUS_M',
    'SUS_F': 'CUSUS_F',
    'CSRES_M': 'CSRES_M',
}

# %%
df_scenic_all_common['Model'] = df_scenic_all_common['Model'].str.replace(" ","_").map(comparison_to_status)

# %%
df_deg_tfs_common['Model'] = df_deg_tfs_common['Model'].str.replace(" ","_")

# %%
df_merge_deg_scenic = pd.merge(
    df_deg_tfs_common,
    df_scenic_all_common,
    left_on=['TF', 'ctname','Model', 'Neurotransmitter', 'Region'],
    right_on=['TF', 'fname','Model', 'Neurotransmitter', 'region'],
    suffixes=('_deg', '_scenic'),
    how='inner'
)

# %%
df_deg_tfs_common.Model.value_counts()
# Out:
# CSRES_M    6308
# CSSUS_M    6019
# CURES_F    4902
# CURES_M    3527
# CUSUS_F    1416
# CUSUS_M    1036
# Name: Model, dtype: int64

# %%
df_scenic_all_common.Model.value_counts()
# Out:
# CSRES_M    9687
# CURES_F    9579
# CSSUS_M    8833
# CURES_M    7765
# CUSUS_M    4974
# CUSUS_F    4020
# Name: Model, dtype: int64

# %%
df_merge_deg_scenic.Model.value_counts()
# Out:
# CSRES_M    1060
# CSSUS_M     772
# CURES_F     769
# CURES_M     550
# CUSUS_F     252
# CUSUS_M     178
# Name: Model, dtype: int64

# %%
df_all_s = df_all_filtered.copy()
df_all_s.rename(columns={'TF': 'TF_name_scenic'}, inplace=True)
df_all_s['ctname'] = df_all_s['region'] + "_" + df_all_s['celltype.L2']
df_all_s['ctname'] = df_all_s['ctname'].str.replace('/', '-')
df_all_s['ctname'] = df_all_s['ctname'].str.replace(' ', '_')
df_all_s['TF'] = df_all_s['TF_name_scenic'].str.upper().str.replace("(+)", '', regex=False)
df_all_s.comparison.value_counts()
# Make a dictionary to map comparison to status
comparison_to_status = {
    'CSDS_M': 'CSSUS_M',
    'RES_M': 'CURES_M',
    'RES_F': 'CURES_F',
    'CSDS_F': 'CSSUS_F',
    'SUS_M': 'CUSUS_M',
    'SUS_F': 'CUSUS_F',
    'CSRES_M': 'CSRES_M',
}
df_all_s['comparison'] = df_all_s['comparison'].map(comparison_to_status)
df_deg_all['ctname'] = df_deg_all['Region'] + "_" + df_deg_all['Subclass']
df_deg_all['ctname'] = df_deg_all['ctname'].str.replace('/', '-')
df_deg_all['ctname'] = df_deg_all['ctname'].str.replace(' ', '_')
df_deg_all['targetgene'] = df_deg_all.Gene
df_deg_all['comparison'] = df_deg_all['Model'].str.replace(' ', '_')

# %% [markdown]
# ## Summarize TF target and DEG overlap
#
# This cell builds a TF-by-comparison summary table that links regulon targets with differential expression results.
#
# - Detects the gene-name columns in `df_s_regulon` and `df_deg_all` and standardizes gene symbols to uppercase.
# - Creates a cleaned DEG table with unique target genes per `ctname`, `comparison`, and `Direction`.
# - Aggregates total DEG counts, including separate counts for up- and down-regulated genes.
# - Reshapes the regulon table into a long format with one TF-target gene pair per row while retaining metadata such as `log2FC`, `FDR`, `sex`, `region`, and `Neurotransmitter_celltype`.
# - Merges regulon targets with DEG targets to identify overlaps for each TF within each cell type and comparison.
# - Summarizes the overlap into comma-separated target lists and numeric counts, then joins DEG totals for context.
#
# The final output, `df_tf_target_deg_overlap_summary`, reports the TF target gene set, overlapping up/down DEG lists, and the corresponding overlap counts for each `ctname`, `TF`, and `comparison`.

# %%
df_deg_CU3RM
# Out:
#                  Gene          pval    log2FC     ci.hi     ci.lo  \
# 18959   4930587E11Rik  4.979281e-05 -0.477901 -0.273399 -0.682402
# 18960   5330438D12Rik  4.689805e-05 -0.377034 -0.215016 -0.539053
# 18961        AY036118  5.525016e-06 -0.447369 -0.276481 -0.618257
# 18962        Cacna2d3  1.889082e-06 -0.391569 -0.238783 -0.544355
# 18963            Fgf1  3.178173e-06 -0.359748 -0.220231 -0.499266
# ...               ...           ...       ...       ...       ...
# 356562           Ugdh  8.143051e-05  0.136016  0.200889  0.071143
# 356563          Vegfa  9.346487e-13 -0.190746 -0.137492 -0.244001
# 356564         Vstm2b  1.868124e-05  0.120238  0.182141  0.058336
# 356565           Apoe  1.396287e-07  0.752230  1.078455  0.426004
# 356566           Meg3  6.940024e-07  0.818887  1.122733  0.515040
#
#                  FDR    Bonferroni    celltype.L2       Subclass  Comparison  \
# 18959   2.395034e-02  3.832054e-01  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# 18960   2.395034e-02  3.609274e-01  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# 18961   5.259256e-03  4.252053e-02  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# 18962   2.907674e-03  1.453837e-02  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# 18963   3.494174e-03  2.445922e-02  PFC Car3 Glut  PFC Car3 Glut  SUS_vs_CON
# ...              ...           ...            ...            ...         ...
# 356562  3.214227e-03  3.532455e-01            OPC            OPC  SUS_vs_CON
# 356563  5.792152e-10  4.054506e-09            OPC            OPC  SUS_vs_CON
# 356564  9.572672e-04  8.103922e-02            OPC            OPC  SUS_vs_CON
# 356565  5.639602e-04  5.639602e-04           VLMC           VLMC  SUS_vs_CON
# 356566  1.401538e-03  2.803076e-03           VLMC           VLMC  SUS_vs_CON
#
#         ...                                               DGL3     Class  \
# 18959   ...  Predicted_RIK_Gm_or_clone_accession_like_nonco...      Glut
# 18960   ...  Predicted_RIK_Gm_or_clone_accession_like_nonco...      Glut
# 18961   ...  Predicted_RIK_Gm_or_clone_accession_like_nonco...      Glut
# 18962   ...                                                 Ca      Glut
# 18963   ...         PM09_Signaling_receptor_protein_regulation      Glut
# ...     ...                                                ...       ...
# 356562  ...               EP01_Glycolysis_lactate_carbohydrate       OPC
# 356563  ...            PM03_Ubiquitin_proteasome_SUMO_turnover       OPC
# 356564  ...             SIG04_mTOR_nutrient_lysosome_signaling       OPC
# 356565  ...             LM13_Lipoprotein_cholesterol_transport  Vascular
# 356566  ...              Transcription_RNA_processing_coupling  Vascular
#
#        mean_UMI_raw_Region_Class mean_UMI_norm_Region_Class  \
# 18959                   1.144637                   0.876635
# 18960                   2.641405                   2.795462
# 18961                   2.700016                   2.814399
# 18962                   4.585070                   3.477626
# 18963                   0.451440                   0.318779
# ...                          ...                        ...
# 356562                  0.511659                   0.896961
# 356563                  0.168905                   0.248821
# 356564                  0.445229                   0.752784
# 356565                  3.396551                   7.075729
# 356566                  2.724138                   8.167181
#
#        mean_log1p_Region_Class mean_UMI_raw_Region_subclass  \
# 18959                 0.629480                     0.495238
# 18960                 1.333806                     1.809525
# 18961                 1.338783                     2.257144
# 18962                 1.499093                     6.638097
# 18963                 0.276707                     0.180952
# ...                        ...                          ...
# 356562                0.640253                     0.511659
# 356563                0.222200                     0.168905
# 356564                0.561206                     0.445229
# 356565                2.088863                     4.671053
# 356566                2.215630                     2.631579
#
#        mean_UMI_norm_Region_subclass mean_log1p_Region_subclass  \
# 18959                       0.343224                   0.295073
# 18960                       1.677223                   0.984780
# 18961                       1.943927                   1.079744
# 18962                       6.400530                   2.001552
# 18963                       0.119373                   0.112768
# ...                              ...                        ...
# 356562                      0.896961                   0.640253
# 356563                      0.248821                   0.222200
# 356564                      0.752784                   0.561206
# 356565                     12.813697                   2.625661
# 356566                      8.154373                   2.214232
#
#                    ctname targetgene
# 18959   PFC_PFC_Car3_Glut      18959
# 18960   PFC_PFC_Car3_Glut      18960
# 18961   PFC_PFC_Car3_Glut      18961
# 18962   PFC_PFC_Car3_Glut      18962
# 18963   PFC_PFC_Car3_Glut      18963
# ...                   ...        ...
# 356562            AMY_OPC     356562
# 356563            AMY_OPC     356563
# 356564            AMY_OPC     356564
# 356565           AMY_VLMC     356565
# 356566           AMY_VLMC     356566
#
# [9209 rows x 48 columns]

# %%
# Calculate the interaction between Tobias and SCENIC results, and the overlap with DEGs in CUSUS M3R
write_TS_regulon_overlap = False
if write_TS_regulon_overlap:
    # tf regulons from SCENIC
    file_regulon = glob.glob('/data2st2/junyi/output/stg1028/scenic_ctxregulon/tf_regulon/*_tf_target.csv')
    # only keep files with 'AMY,HPF,PFC' in the name
    file_regulon = [f for f in file_regulon if any(region in f for region in ['AMY', 'HPF', 'PFC'])]
    df_regulon_all = pd.DataFrame()
    for file in file_regulon:
        df_tmp = pd.read_csv(file)
        df_regulon_all = pd.concat([df_regulon_all, df_tmp], axis=0, ignore_index=True)
    # group by TF, fname, and join unique target genes as a comma-separated list sorted by name
    df_regulon_summary = (
        df_regulon_all.groupby(['TF', 'fname'])['targetgene']
        .apply(lambda x: ','.join(sorted({str(gene) for gene in x.dropna()})))
        .reset_index()
    )
    df_regulon_summary['TF_up'] = df_regulon_summary['TF'].str.upper()
    df_regulon_summary.rename(columns={'fname': 'ctname'}, inplace=True)
    df_merge_ts_regulon = pd.merge(
        df_merge_ts, df_regulon_summary[['TF_up', 'ctname','targetgene']], left_on=['TF', 'ctname'], right_on=['TF_up', 'ctname'], how='left'
    )
    gene_col = 'targetgene' if 'targetgene' in df_deg_CU3RM.columns else 'Gene'
    regulon_ct_col = 'ctname' if 'ctname' in df_regulon_all.columns else 'fname'

    def _normalize_gene_series(series):
        return (
            series.dropna()
            .astype(str)
            .str.strip()
            .loc[lambda s: s.ne('')]
            #.str.upper()
        )

    deg_overlap_summary = (
        df_deg_CU3RM.loc[:, ['ctname', 'Direction', gene_col]]
        .dropna(subset=['ctname', 'Direction', gene_col])
        .assign(**{gene_col: lambda df: _normalize_gene_series(df[gene_col])})
        .merge(
            df_regulon_all.loc[:, ['TF', regulon_ct_col, 'targetgene']]
            .dropna(subset=['TF', regulon_ct_col, 'targetgene'])
            .assign(
                TF=lambda df: df['TF'].astype(str).str.upper(),
                targetgene=lambda df: _normalize_gene_series(df['targetgene']),
                ctname=lambda df: df[regulon_ct_col].astype(str)
            )
            .loc[:, ['TF', 'ctname', 'targetgene']]
            .drop_duplicates(),
            left_on=['ctname', gene_col],
            right_on=['ctname', 'targetgene'],
            how='inner'
        )
        .drop_duplicates(['TF', 'ctname', 'Direction', gene_col])
        .groupby(['TF', 'ctname', 'Direction'])[gene_col]
        .apply(lambda x: ','.join(sorted(set(x))))
        .unstack(fill_value='')
        .rename(columns={'Up': 'deg_in_regulon_up', 'Down': 'deg_in_regulon_down'})
        .reset_index()
    )

    for col in ['deg_in_regulon_up', 'deg_in_regulon_down']:
        if col not in deg_overlap_summary.columns:
            deg_overlap_summary[col] = ''

    deg_overlap_summary['n_deg_in_regulon_up'] = deg_overlap_summary['deg_in_regulon_up'].map(lambda x: 0 if x == '' else len(x.split(',')))
    deg_overlap_summary['n_deg_in_regulon_down'] = deg_overlap_summary['deg_in_regulon_down'].map(lambda x: 0 if x == '' else len(x.split(',')))

    deg_overlap_summary = deg_overlap_summary[
        ['TF', 'ctname', 'deg_in_regulon_up', 'n_deg_in_regulon_up', 'deg_in_regulon_down', 'n_deg_in_regulon_down']
    ].sort_values(['TF', 'ctname']).reset_index(drop=True)


    # df_merge_ts_regulon.merge(
    #     deg_overlap_summary,
    #     on=['TF', 'ctname'],
    #     how='left'
    # ).to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_wilcoxon_all_TF_tobias_merged_with_regulon_deg_overlap.csv', index=False)

# %%
df_deg_all
# Out:
#             Gene          pval    log2FC     ci.hi     ci.lo       FDR  \
# 0        Gm20642  2.924672e-05 -0.268020 -0.153979 -0.382061  0.037039
# 1         Pced1b  7.429092e-06 -0.233513 -0.129907 -0.337119  0.016465
# 2          Srsf2  1.307530e-05 -0.282352 -0.167793 -0.396910  0.023183
# 3          Ube3a  7.446378e-07 -0.215217 -0.137482 -0.292952  0.006601
# 4       AY036118  1.258864e-08 -0.353253 -0.240474 -0.466032  0.000064
# ...          ...           ...       ...       ...       ...       ...
# 464967    Zfp148  1.598237e-03 -0.185759 -0.085587 -0.285931  0.017375
# 464968    Zfp462  7.230957e-03 -0.136580 -0.005329 -0.267832  0.048891
# 464969     Zfpm2  3.977225e-03 -0.217178 -0.082556 -0.351800  0.033180
# 464970    Zswim5  7.364664e-03 -0.157864 -0.055429 -0.260299  0.049534
# 464971      Zzz3  2.113168e-04 -0.166418 -0.076382 -0.256455  0.003661
#
#         Bonferroni        celltype.L2           Subclass  Comparison  ...  \
# 0         0.259272           STR Chol           STR Chol  SUS_vs_CON  ...
# 1         0.065859           STR Chol           STR Chol  SUS_vs_CON  ...
# 2         0.115913           STR Chol           STR Chol  SUS_vs_CON  ...
# 3         0.006601           STR Chol           STR Chol  SUS_vs_CON  ...
# 4         0.000064  STR D1 Chst9 GABA  STR D1 Chst9 GABA  SUS_vs_CON  ...
# ...            ...                ...                ...         ...  ...
# 464967    1.000000                OPC                OPC  SUS_vs_CON  ...
# 464968    1.000000                OPC                OPC  SUS_vs_CON  ...
# 464969    1.000000                OPC                OPC  SUS_vs_CON  ...
# 464970    1.000000                OPC                OPC  SUS_vs_CON  ...
# 464971    0.820121                OPC                OPC  SUS_vs_CON  ...
#
#        Class mean_UMI_raw_Region_Class mean_UMI_norm_Region_Class  \
# 0       Chol                  1.570796                   1.205789
# 1       Chol                  0.823008                   0.550897
# 2       Chol                  1.159291                   0.781294
# 3       Chol                  9.969027                   9.025716
# 4       GABA                  0.646397                   0.546702
# ...      ...                       ...                        ...
# 464967   OPC                  0.259341                   0.449517
# 464968   OPC                  1.254947                   2.993772
# 464969   OPC                  1.283519                   2.893135
# 464970   OPC                  0.283516                   0.461474
# 464971   OPC                  0.191209                   0.340028
#
#        mean_log1p_Region_Class mean_UMI_raw_Region_subclass  \
# 0                     0.791085                     1.570796
# 1                     0.438834                     0.823008
# 2                     0.577340                     1.159291
# 3                     2.305153                     9.969027
# 4                     0.436125                     0.332454
# ...                        ...                          ...
# 464967                0.371230                     0.259341
# 464968                1.384736                     1.254947
# 464969                1.359215                     1.283519
# 464970                0.379445                     0.283516
# 464971                0.292691                     0.191209
#
#        mean_UMI_norm_Region_subclass mean_log1p_Region_subclass  \
# 0                           1.205789                   0.791085
# 1                           0.550897                   0.438834
# 2                           0.781294                   0.577340
# 3                           9.025716                   2.305153
# 4                           0.396675                   0.334094
# ...                              ...                        ...
# 464967                      0.449517                   0.371230
# 464968                      2.993772                   1.384736
# 464969                      2.893135                   1.359215
# 464970                      0.461474                   0.379445
# 464971                      0.340028                   0.292691
#
#                        ctname targetgene comparison
# 0                STR_STR_Chol          0    CUSUS_F
# 1                STR_STR_Chol          1    CUSUS_F
# 2                STR_STR_Chol          2    CUSUS_F
# 3                STR_STR_Chol          3    CUSUS_F
# 4       STR_STR_D1_Chst9_GABA          4    CUSUS_F
# ...                       ...        ...        ...
# 464967                HPF_OPC     464967    CUSUS_F
# 464968                HPF_OPC     464968    CUSUS_F
# 464969                HPF_OPC     464969    CUSUS_F
# 464970                HPF_OPC     464970    CUSUS_F
# 464971                HPF_OPC     464971    CUSUS_F
#
# [464972 rows x 49 columns]

# %%
write_TS_regulon_overlap = False
if write_TS_regulon_overlap:
    file_regulon = glob.glob('/data2st2/junyi/output/stg1028/scenic_ctxregulon/tf_regulon/*_tf_target.csv')
    # only keep files with 'AMY,HPF,PFC' in the name
    df_regulon_full = pd.DataFrame()
    for file in file_regulon:
        df_tmp = pd.read_csv(file)
        df_regulon_full = pd.concat([df_regulon_full, df_tmp], axis=0, ignore_index=True)
    df_regulon_full.rename(columns={'fname': 'ctname'}, inplace=True)
    df_regulon_full['TF_up'] = df_regulon_full['TF'].str.upper()
    df_regulon_full.rename(columns={'fname': 'ctname'}, inplace=True)
    df_regulon_full.rename(columns={'TF': 'TF_name_scenic'}, inplace=True)
    df_regulon_full.rename(columns={'TF_up': 'TF'}, inplace=True)
    df_s_regulon = df_all_s.merge(
        df_regulon_full,
        on=['TF', 'ctname'],
        how='left',
        suffixes=('_scenic', '_regulon')
    )
    # Find the column that stores target gene names in the regulon table.
    target_col_regulon = next((
        col for col in ['targetgene', 'Gene_name', 'Gene', 'name']
        if col in df_s_regulon.columns
    ), None)

    # Find the corresponding target gene column in the DEG table.
    target_col_deg = next((
        col for col in ['targetgene', 'Gene_name', 'Gene', 'name']
        if col in df_deg_all.columns
    ), None)

    # Stop early if either input table is missing a recognizable gene column.
    if target_col_regulon is None:
        raise KeyError('No target gene column found in df_s_regulon')
    if target_col_deg is None:
        raise KeyError('No target gene column found in df_deg_all')

    # Standardize gene symbols so joins are not affected by case, whitespace, or missing values.
    def _normalize_gene_series(series):
        return (
            series.dropna()
            .astype(str)
            .str.strip()
            .loc[lambda s: s.ne('')]
            .str.upper()
        )

    # Collapse a list of values into a sorted comma-separated string with duplicates removed.
    def _join_unique(values):
        values = [value for value in values if pd.notna(value) and value != '']
        return ','.join(sorted(set(values)))

    # Keep the first available metadata value within each grouped summary.
    def _first_non_null(series):
        series = series.dropna()
        return series.iloc[0] if not series.empty else pd.NA

    # Clean the DEG table and keep one row per unique cell type, comparison, direction, and target gene.
    df_deg_all_overlap = (
        df_deg_all.loc[:, ['ctname', 'comparison', 'Direction', target_col_deg]]
        .dropna(subset=['ctname', 'comparison', 'Direction', target_col_deg])
        .assign(
            comparison=lambda df: df['comparison'].astype(str),
            Direction=lambda df: df['Direction'].astype(str).str.upper(),
            targetgene=lambda df: _normalize_gene_series(df[target_col_deg])
        )
        .loc[:, ['ctname', 'comparison', 'Direction', 'targetgene']]
        .drop_duplicates()
    )

    # Count total, upregulated, and downregulated DEGs for each cell type and comparison.
    df_deg_counts = (
        df_deg_all_overlap
        .groupby(['ctname', 'comparison'])
        .apply(
            lambda group: pd.Series({
                'n_total_deg': group['targetgene'].nunique(),
                'n_total_up_deg': group.loc[group['Direction'] == 'UP', 'targetgene'].nunique(),
                'n_total_down_deg': group.loc[group['Direction'] == 'DOWN', 'targetgene'].nunique(),
            })
        )
        .reset_index()
    )

    # Expand the regulon table so each row represents one TF-target gene pair with its metadata.
    df_s_regulon_long = (
        df_s_regulon.loc[:, ['ctname', 'TF', 'comparison', target_col_regulon, 'log2FC', 'FDR', 'sex', 'region', 'Neurotransmitter_celltype']]
        .dropna(subset=['ctname', 'TF', 'comparison', target_col_regulon])
        .assign(
            TF=lambda df: df['TF'].astype(str).str.upper(),
            comparison=lambda df: df['comparison'].astype(str),
            targetgene=lambda df: _normalize_gene_series(df[target_col_regulon])
        )
        .loc[:, ['ctname', 'TF', 'comparison', 'targetgene', 'log2FC', 'FDR', 'sex', 'region', 'Neurotransmitter_celltype']]
        .drop_duplicates()
    )

    # Join TF target genes with DEG targets to mark which regulon targets are differentially expressed.
    df_tf_target_deg_overlap_long = df_s_regulon_long.merge(
        df_deg_all_overlap,
        on=['ctname', 'comparison', 'targetgene'],
        how='left'
    )

    # Summarize overlap results per cell type, TF, and comparison, keeping metadata and gene lists.
    df_tf_target_deg_overlap_summary = (
        df_tf_target_deg_overlap_long
        .groupby(['ctname', 'TF', 'comparison'], as_index=False)
        .apply(
            lambda group: pd.Series({
                'log2FC': _first_non_null(group['log2FC']),
                'FDR': _first_non_null(group['FDR']),
                'sex': _first_non_null(group['sex']),
                'region': _first_non_null(group['region']),
                'Neurotransmitter_celltype': _first_non_null(group['Neurotransmitter_celltype']),
                'tf_target_geneset': _join_unique(group['targetgene']),
                'up_deg_list': _join_unique(group.loc[group['Direction'] == 'UP', 'targetgene']),
                'down_deg_list': _join_unique(group.loc[group['Direction'] == 'DOWN', 'targetgene']),
            })
        )
        .reset_index(drop=True)
    )

    # Convert the comma-separated gene lists into numeric overlap counts.
    df_tf_target_deg_overlap_summary['n_target_gene'] = df_tf_target_deg_overlap_summary['tf_target_geneset'].map(lambda x: 0 if x == '' else len(x.split(',')))
    df_tf_target_deg_overlap_summary['n_up_overlap'] = df_tf_target_deg_overlap_summary['up_deg_list'].map(lambda x: 0 if x == '' else len(x.split(',')))
    df_tf_target_deg_overlap_summary['n_down_overlap'] = df_tf_target_deg_overlap_summary['down_deg_list'].map(lambda x: 0 if x == '' else len(x.split(',')))

    # Attach the total DEG counts so overlap values can be interpreted in context.
    df_tf_target_deg_overlap_summary = df_tf_target_deg_overlap_summary.merge(
        df_deg_counts,
        on=['ctname', 'comparison'],
        how='left'
    )

    # Reorder columns and sort rows to produce the final report table.
    df_tf_target_deg_overlap_summary = df_tf_target_deg_overlap_summary[
        ['ctname', 'TF', 'comparison', 'log2FC', 'FDR', 'sex', 'region', 'Neurotransmitter_celltype', 'tf_target_geneset', 'n_target_gene', 'n_total_deg', 'n_total_up_deg', 'n_total_down_deg', 'up_deg_list', 'n_up_overlap', 'down_deg_list', 'n_down_overlap']
    ].sort_values(['ctname', 'TF', 'comparison']).reset_index(drop=True)

    # Display the summarized TF-target versus DEG overlap table.
    df_tf_target_deg_overlap_summary
    n_universe = df_deg_all_overlap['targetgene'].nunique()

    df_tf_target_deg_hypergeom = df_tf_target_deg_overlap_summary.copy()
    df_tf_target_deg_hypergeom['hypergeom_p_up'] = df_tf_target_deg_hypergeom.apply(
        lambda row: hypergeom.sf(
            row['n_up_overlap'] - 1,
            n_universe,
            row['n_target_gene'],
            row['n_total_up_deg']
        ) if row['n_target_gene'] > 0 and row['n_total_up_deg'] > 0 and row['n_up_overlap'] > 0 else 1.0,
        axis=1
    )
    df_tf_target_deg_hypergeom['hypergeom_p_down'] = df_tf_target_deg_hypergeom.apply(
        lambda row: hypergeom.sf(
            row['n_down_overlap'] - 1,
            n_universe,
            row['n_target_gene'],
            row['n_total_down_deg']
        ) if row['n_target_gene'] > 0 and row['n_total_down_deg'] > 0 and row['n_down_overlap'] > 0 else 1.0,
        axis=1
    )

    df_tf_target_deg_hypergeom.sort_values(['hypergeom_p_up', 'hypergeom_p_down', 'ctname', 'TF', 'comparison']).reset_index(drop=True)
    df_meta_match_na = df_meta_match.dropna(subset=['celltype.L1'])
    dict_ct_to_l1 = dict(zip(df_meta_match_na['ctname'], df_meta_match_na['celltype.L1']))
    df_tf_target_deg_hypergeom['celltype.L1'] = df_tf_target_deg_hypergeom['ctname'].map(dict_ct_to_l1)
    df_tf_target_deg_hypergeom.to_csv('/data2/junyi/stg0901/scenic_wilcoxon_all/scenic_wilcoxon_all_TF_regulon_deg_overlap_summary.csv', index=False)
else:
    df_tf_target_deg_hypergeom = pd.read_csv('/data2/junyi/stg0901/scenic_wilcoxon_all/scenic_wilcoxon_all_TF_regulon_deg_overlap_summary.csv')

# %%
df_tf_target_deg_hypergeom
# Out:
#                          ctname       TF comparison    log2FC           FDR  \
# 0      AMY_AMY_Cav1_Frmpd1_Glut    ARNT2    CURES_F  0.214859  5.308597e-07
# 1      AMY_AMY_Cav1_Frmpd1_Glut    ARNT2    CURES_M  0.143422  1.808912e-02
# 2      AMY_AMY_Cav1_Frmpd1_Glut     ATF4    CSRES_M -1.042059  2.414378e-05
# 3      AMY_AMY_Cav1_Frmpd1_Glut    ATF6B    CSRES_M -0.946801  2.119831e-12
# 4      AMY_AMY_Cav1_Frmpd1_Glut     ATF7    CSRES_M -0.493450  6.138779e-07
# ...                         ...      ...        ...       ...           ...
# 34167                   TH_VLMC    SIN3A    CUSUS_M  0.556524  2.430031e-02
# 34168                   TH_VLMC    STAT3    CURES_M  1.379796  4.927868e-02
# 34169                   TH_VLMC  TFCP2L1    CUSUS_M  1.585674  3.861692e-02
# 34170                   TH_VLMC    TGIF1    CSSUS_M -1.828554  4.610178e-02
# 34171                   TH_VLMC   ZBTB7A    CURES_M  0.712717  4.927868e-02
#
#       sex region Neurotransmitter_celltype  \
# 0       F    AMY             Glutamatergic
# 1       M    AMY             Glutamatergic
# 2       M    AMY             Glutamatergic
# 3       M    AMY             Glutamatergic
# 4       M    AMY             Glutamatergic
# ...    ..    ...                       ...
# 34167   M     TH                        NN
# 34168   M     TH                        NN
# 34169   M     TH                        NN
# 34170   M     TH                        NN
# 34171   M     TH                        NN
#
#                                        tf_target_geneset  n_target_gene  \
# 0      1700025G04RIK,AKAP17B,ARNT2,CEMIP,DLGAP4,FHL2,...             19
# 1      1700025G04RIK,AKAP17B,ARNT2,CEMIP,DLGAP4,FHL2,...             19
# 2      1700094D03RIK,2010204K13RIK,2010308F09RIK,2700...            128
# 3      0610005C13RIK,1700110C19RIK,3830406C13RIK,4632...            216
# 4      AK4,AW549877,BMT2,CHFR,EPB41L5,MAPRE3,MPPED1,M...             16
# ...                                                  ...            ...
# 34167  1110019D14RIK,1700003L19RIK,2610027K06RIK,4933...            200
# 34168  ALDH3B1,ANKFN1,ASB18,ASPA,ATP6V0A4,ATP7B,ATR,C...             94
# 34169  1810026B05RIK,5830418P13RIK,ADCY6,BOC,CCDC174,...             32
# 34170  ACAA2,CCDC141,CIB2,CISH,CNTN2,EIF2AK3,EZH1,FBX...             20
# 34171  1700008J07RIK,2610307P16RIK,3010001F23RIK,4932...            114
#
#        n_total_deg  n_total_up_deg  n_total_down_deg  \
# 0            819.0           383.0             436.0
# 1             34.0            16.0              18.0
# 2           1142.0           730.0             412.0
# 3           1142.0           730.0             412.0
# 4           1142.0           730.0             412.0
# ...            ...             ...               ...
# 34167          NaN             NaN               NaN
# 34168          NaN             NaN               NaN
# 34169          NaN             NaN               NaN
# 34170          NaN             NaN               NaN
# 34171          NaN             NaN               NaN
#
#                      up_deg_list  n_up_overlap  \
# 0                            NaN             0
# 1                            NaN             0
# 2                         LRRTM1             1
# 3      HSP90AB1,PPIA,SRP14,TUBB5             4
# 4                            NaN             0
# ...                          ...           ...
# 34167                        NaN             0
# 34168                        NaN             0
# 34169                        NaN             0
# 34170                        NaN             0
# 34171                        NaN             0
#
#                                            down_deg_list  n_down_overlap  \
# 0                                                    NaN               0
# 1                                                    NaN               0
# 2                           CBLN2,GOLGB1,INF2,MAZ,UTP14A               5
# 3      ACVRL1,ADGRB2,CAMKV,CCDC107,ERGIC1,GOLGA7B,GPR...              20
# 4                                                   CHFR               1
# ...                                                  ...             ...
# 34167                                                NaN               0
# 34168                                                NaN               0
# 34169                                                NaN               0
# 34170                                                NaN               0
# 34171                                                NaN               0
#
#        hypergeom_p_up  hypergeom_p_down celltype.L1
# 0            1.000000          1.000000        Glut
# 1            1.000000          1.000000        Glut
# 2            0.999962          0.647382        Glut
# 3            0.999963          0.000968        Glut
# 4            1.000000          0.504308        Glut
# ...               ...               ...         ...
# 34167        1.000000          1.000000    Vascular
# 34168        1.000000          1.000000    Vascular
# 34169        1.000000          1.000000    Vascular
# 34170        1.000000          1.000000    Vascular
# 34171        1.000000          1.000000    Vascular
#
# [34172 rows x 20 columns]

# %%
df_tf_target_deg_hypergeom_filtered = df_tf_target_deg_hypergeom[
    (df_tf_target_deg_hypergeom['hypergeom_p_up'] < 0.05) | (df_tf_target_deg_hypergeom['hypergeom_p_down'] < 0.05)
].copy()
df_deg_info = df_deg_all.copy()
df_deg_info['ctname'] = df_deg_all['Region'] + "_" + df_deg_all['Subclass']
df_deg_info['ctname'] = df_deg_info['ctname'].str.replace('/', '-')
df_deg_info['ctname'] = df_deg_info['ctname'].str.replace(' ', '_')
df_deg_info['TF'] = df_deg_info.Gene
df_deg_info['comparison'] = df_deg_info['Model'].str.replace(' ', '_')
df_deg_info['TF'] = df_deg_info['TF'].str.upper()
df_deg_info['Is_DEG'] = True
df_tf_target_deg_hypergeom_filtered['Direction'] = df_tf_target_deg_hypergeom_filtered['log2FC'].apply(lambda x: 'Up' if x > 0 else ('Down' if x < 0 else 'Ns'))

# %%
df_tf_target_deg_hypergeom_filtered
# Out:
#                          ctname      TF comparison    log2FC           FDR  \
# 3      AMY_AMY_Cav1_Frmpd1_Glut   ATF6B    CSRES_M -0.946801  2.119831e-12
# 7      AMY_AMY_Cav1_Frmpd1_Glut  BCLAF1    CSRES_M -0.159962  1.898612e-31
# 44     AMY_AMY_Cav1_Frmpd1_Glut   ESRRA    CSRES_M -1.278235  3.929004e-33
# 46     AMY_AMY_Cav1_Frmpd1_Glut   ESRRA    CURES_F  0.396919  1.119416e-06
# 50     AMY_AMY_Cav1_Frmpd1_Glut     FOS    CSRES_M -0.192316  2.592711e-10
# ...                         ...     ...        ...       ...           ...
# 33586    TH_TH_Parm1_Mdga1_Glut  ZFP369    CURES_M  0.132317  5.678010e-05
# 33589    TH_TH_Parm1_Mdga1_Glut   ZMIZ1    CSSUS_M  0.105526  1.982095e-09
# 33590    TH_TH_Parm1_Mdga1_Glut   ZMIZ1    CURES_F  0.183133  2.186940e-35
# 33591    TH_TH_Parm1_Mdga1_Glut   ZMIZ1    CURES_M  0.139287  6.650173e-18
# 33593    TH_TH_Parm1_Mdga1_Glut   ZMIZ1    CUSUS_M -0.094274  4.128834e-14
#
#       sex region Neurotransmitter_celltype  \
# 3       M    AMY             Glutamatergic
# 7       M    AMY             Glutamatergic
# 44      M    AMY             Glutamatergic
# 46      F    AMY             Glutamatergic
# 50      M    AMY             Glutamatergic
# ...    ..    ...                       ...
# 33586   M     TH             Glutamatergic
# 33589   M     TH             Glutamatergic
# 33590   F     TH             Glutamatergic
# 33591   M     TH             Glutamatergic
# 33593   M     TH             Glutamatergic
#
#                                        tf_target_geneset  n_target_gene  ...  \
# 3      0610005C13RIK,1700110C19RIK,3830406C13RIK,4632...            216  ...
# 7      0610012G03RIK,0610030E20RIK,1110032A03RIK,1110...            475  ...
# 44     5430405H02RIK,6430548M08RIK,ACOT7,ADCY6,BMP6,C...             77  ...
# 46     5430405H02RIK,6430548M08RIK,ACOT7,ADCY6,BMP6,C...             77  ...
# 50     1110002J07RIK,1110032F04RIK,1810026B05RIK,2410...            243  ...
# ...                                                  ...            ...  ...
# 33586  ABCD3,ARHGAP12,CACNA1C,CEP170,CROCC,EPB41L5,HA...             22  ...
# 33589  1700003M07RIK,A830009L08RIK,A930004D18RIK,AAK1...            212  ...
# 33590  1700003M07RIK,A830009L08RIK,A930004D18RIK,AAK1...            212  ...
# 33591  1700003M07RIK,A830009L08RIK,A930004D18RIK,AAK1...            212  ...
# 33593  1700003M07RIK,A830009L08RIK,A930004D18RIK,AAK1...            212  ...
#
#        n_total_up_deg  n_total_down_deg  \
# 3               730.0             412.0
# 7               730.0             412.0
# 44              730.0             412.0
# 46              383.0             436.0
# 50              730.0             412.0
# ...               ...               ...
# 33586           365.0             112.0
# 33589            72.0              33.0
# 33590           748.0             764.0
# 33591           365.0             112.0
# 33593            43.0              37.0
#
#                                              up_deg_list n_up_overlap  \
# 3                              HSP90AB1,PPIA,SRP14,TUBB5            4
# 7      2210408I21RIK,ACSL4,CCSER1,FER,GRIN3A,KALRN,KC...           17
# 44                                                   NaN            0
# 46     CHERP,DNMT3A,EFTUD2,ESRRA,IGLON5,LARP1,MATK,TB...            8
# 50                                                 PCSK1            1
# ...                                                  ...          ...
# 33586                             CACNA1C,SPTBN4,ZDHHC14            3
# 33589    ARHGAP26,ASTN2,GNAO1,PCDH9,PDE2A,TMEM132B,TRIM9            7
# 33590  AAK1,ARHGAP26,ARL15,ASTN2,ATXN7,DLG5,DLGAP1,DM...           56
# 33591  ADRA1A,ARL15,ASTN2,CAMK2G,DGKZ,DNMT3A,EPB41L4A...           33
# 33593                                                NaN            0
#
#                                            down_deg_list n_down_overlap  \
# 3      ACVRL1,ADGRB2,CAMKV,CCDC107,ERGIC1,GOLGA7B,GPR...             20
# 7      ANKS3,CBLN2,CRIP2,DGAT1,DVL1,FBXO31,FYCO1,GLE1...             39
# 44         DPYSL2,EFTUD2,ESRRA,MATK,TBC1D9B,U2AF1,WDYHV1              7
# 46                                                   NaN              0
# 50     CBLN2,CELF3,DGAT1,EFTUD2,FBXO33,GAL3ST3,HS3ST1...             18
# ...                                                  ...            ...
# 33586                                                NaN              0
# 33589                                                NaN              0
# 33590                                              ARL8A              1
# 33591                                             MEGF11              1
# 33593                                  DLGAP1,NRG3,PDS5B              3
#
#        hypergeom_p_up  hypergeom_p_down  celltype.L1 Direction
# 3        9.999630e-01          0.000968         Glut      Down
# 7        9.999337e-01          0.000067         Glut      Down
# 44       1.000000e+00          0.046496         Glut      Down
# 46       1.131164e-02          1.000000         Glut        Up
# 50       1.000000e+00          0.016832         Glut      Down
# ...               ...               ...          ...       ...
# 33586    4.904840e-02          1.000000         Glut        Up
# 33589    1.007590e-03          1.000000         Glut        Up
# 33590    9.569384e-17          1.000000         Glut        Up
# 33591    3.282861e-12          0.919029         Glut        Up
# 33593    1.000000e+00          0.047518         Glut      Down
#
# [9127 rows x 21 columns]

# %%
df_tf_target_deg_hypergeom_filtered = df_tf_target_deg_hypergeom_filtered.merge(
    df_deg_info.loc[:, ['log2FC', 'FDR', 'TF', 'comparison', 'ctname','Direction','Is_DEG']],
    on=['ctname', 'comparison','TF','Direction'],
    how='left',
    suffixes=('_scenic', '_deg')
)

df_tf_target_deg_hypergeom_filtered['TF_up'] = df_tf_target_deg_hypergeom_filtered['TF']
# Change only the first letter of TF to uppercase, rest is lower case
df_tf_target_deg_hypergeom_filtered['TF'] = df_tf_target_deg_hypergeom_filtered['TF'].str.lower().str.capitalize()

# %%
df_tf_target_deg_hypergeom_filtered['nlogp_scenic'] = -1 * np.log10(df_tf_target_deg_hypergeom_filtered['FDR_scenic'] + 1e-300)
df_tf_target_deg_hypergeom_filtered['nlogp_deg'] = -1 * np.log10(df_tf_target_deg_hypergeom_filtered['FDR_deg'] + 1e-300)

# %%
df_tf_target_deg_hypergeom_filtered.Is_DEG.sum()
# Out:
# 2011

# %%
df_tf_target_deg_hypergeom_filtered_3R = df_tf_target_deg_hypergeom_filtered.loc[df_tf_target_deg_hypergeom_filtered['comparison'].isin(['CUSUS_M'])].copy()

# %%
df_tf_target_deg_hypergeom_filtered_3R = df_tf_target_deg_hypergeom_filtered_3R[df_tf_target_deg_hypergeom_filtered_3R.region.isin(['AMY', 'HPF', 'PFC'])]

# %%
df_tf_target_deg_hypergeom_filtered_3R
# Out:
#                          ctname      TF comparison  log2FC_scenic  \
# 63    AMY_AMY_Ccdc3_Acvr1c_Glut   Esrra    CUSUS_M      -0.244577
# 76    AMY_AMY_Ccdc3_Acvr1c_Glut     Jun    CUSUS_M       0.161682
# 81    AMY_AMY_Ccdc3_Acvr1c_Glut    Jund    CUSUS_M       0.311829
# 98    AMY_AMY_Ccdc3_Acvr1c_Glut     Maz    CUSUS_M      -0.301850
# 131   AMY_AMY_Ccdc3_Acvr1c_Glut    Taf1    CUSUS_M      -0.093990
# ...                         ...     ...        ...            ...
# 5764         PFC_PFC_L6_IT_Glut  Bclaf1    CUSUS_M       0.043654
# 5786         PFC_PFC_L6_IT_Glut    Etv5    CUSUS_M      -0.863144
# 5790         PFC_PFC_L6_IT_Glut     Fos    CUSUS_M      -0.322974
# 5793         PFC_PFC_L6_IT_Glut   Fosl2    CUSUS_M      -0.185596
# 5847         PFC_PFC_L6_IT_Glut  Srebf2    CUSUS_M      -0.087217
#
#         FDR_scenic sex region Neurotransmitter_celltype  \
# 63    8.651608e-07   M    AMY             Glutamatergic
# 76    1.925170e-02   M    AMY             Glutamatergic
# 81    4.646898e-02   M    AMY             Glutamatergic
# 98    5.766906e-09   M    AMY             Glutamatergic
# 131   2.376753e-06   M    AMY             Glutamatergic
# ...            ...  ..    ...                       ...
# 5764  2.090015e-19   M    PFC             Glutamatergic
# 5786  2.217103e-03   M    PFC             Glutamatergic
# 5790  3.054961e-03   M    PFC             Glutamatergic
# 5793  4.449322e-07   M    PFC             Glutamatergic
# 5847  1.351480e-02   M    PFC             Glutamatergic
#
#                                       tf_target_geneset  n_target_gene  ...  \
# 63    AARS,ABHD11,ACSL1,ATP6V0A1,CACNB3,CAMKV,CCZ1,C...             43  ...
# 76    0610030E20RIK,1810026B05RIK,2410004B18RIK,2510...            238  ...
# 81    ACTB,ALDOA,AMD1,AMER2,AP1S2,APOE,APOLD1,ARC,AR...            187  ...
# 98    5430405H02RIK,ACTR1B,AHSA1,AJAP1,ARPC1A,ASCC2,...             71  ...
# 131   9330159F19RIK,AHCYL1,AP2B1,ASCC2,CBX6,CCAR1,CH...             54  ...
# ...                                                 ...            ...  ...
# 5764  AATF,ABHD6,ADSS,AKAP9,ALMS1,ATG2B,BCLAF1,BIN3,...             69  ...
# 5786  AIG1,ARHGAP21,ASAP1,ASAP2,BACH2,BDNF,CDH10,CDK...             40  ...
# 5790  1300002E11RIK,ADAP2,ADRB1,AGPAT4,AP2B1,ARC,ARL...            105  ...
# 5793  1700110K17RIK,2010300C02RIK,4932438A13RIK,4933...            223  ...
# 5847  ADGRB2,ADGRL1,ADGRL3,AUTS2,CACNA1G,CALR,CELF4,...             30  ...
#
#       hypergeom_p_up  hypergeom_p_down  celltype.L1 Direction  log2FC_deg  \
# 63      1.972459e-01      2.252140e-02         Glut      Down         NaN
# 76      1.220271e-07      1.000000e+00         Glut        Up         NaN
# 81      2.615300e-06      1.000000e+00         Glut        Up         NaN
# 98      1.530209e-01      6.596405e-03         Glut      Down         NaN
# 131     1.000000e+00      3.437339e-02         Glut      Down         NaN
# ...              ...               ...          ...       ...         ...
# 5764    3.799215e-02      1.000000e+00         Glut        Up         NaN
# 5786    1.645504e-01      1.082234e-03         Glut      Down         NaN
# 5790    1.000000e+00      1.926571e-04         Glut      Down         NaN
# 5793    6.365184e-01      3.186937e-08         Glut      Down         NaN
# 5847    1.000000e+00      3.543383e-04         Glut      Down         NaN
#
#      FDR_deg  Is_DEG   TF_up  nlogp_scenic nlogp_deg
# 63       NaN     NaN   ESRRA      6.062903       NaN
# 76       NaN     NaN     JUN      1.715531       NaN
# 81       NaN     NaN    JUND      1.332837       NaN
# 98       NaN     NaN     MAZ      8.239057       NaN
# 131      NaN     NaN    TAF1      5.624016       NaN
# ...      ...     ...     ...           ...       ...
# 5764     NaN     NaN  BCLAF1     18.679851       NaN
# 5786     NaN     NaN    ETV5      2.654214       NaN
# 5790     NaN     NaN     FOS      2.514994       NaN
# 5793     NaN     NaN   FOSL2      6.351706       NaN
# 5847     NaN     NaN  SREBF2      1.869190       NaN
#
# [304 rows x 27 columns]

# %%
df_deg_info_filtered = df_deg_info[df_deg_info['TF'].isin(df_tf_target_deg_hypergeom_filtered['TF_up'].unique())]
df_deg_info_filtered['nlogp'] = -1 * np.log10(df_deg_info_filtered['FDR'] + 1e-300)
df_deg_info_filtered.loc[df_deg_info_filtered['Direction'] == 'Down', 'nlogp'] *= -1

# %%
df_deg_info_filtered.to_csv('/data2/junyi/stg0901/scenic_wilcoxon_all/DEG_info_hypergeom_filtered.csv', index=True)

# %%
df_deg_info_filtered_3R = df_deg_info[df_deg_info['comparison'] == 'CUSUS_M']
df_deg_info_filtered_3R = df_deg_info_filtered_3R[df_deg_info_filtered_3R['Region'].isin(['AMY', 'HPF', 'PFC'])]

# %%
df_deg_info_filtered_3R = df_deg_info_filtered_3R[df_deg_info_filtered_3R['TF'].isin(df_tf_target_deg_hypergeom_filtered_3R['TF_up'].unique())]

# %%
df_deg_info_filtered_3R['Class'] = df_deg_info_filtered_3R['ctname'].map(gen_map_from_meta(df_meta_match, 'ctname', 'celltype.L1'))

# %%
df_deg_info_filtered_3R.to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/DEG_hypergeom_filtered_3R.csv', index=True)

# %%
df_tf_target_deg_hypergeom_filtered

# %%
df_tf_target_deg_hypergeom_filtered['nlogp_scenic'] = df_tf_target_deg_hypergeom_filtered['nlogp_scenic'] * np.sign(df_tf_target_deg_hypergeom_filtered['log2FC_scenic'])
df_tf_target_deg_hypergeom_filtered['nlogp_deg'] = df_tf_target_deg_hypergeom_filtered['nlogp_deg'] * np.sign(df_tf_target_deg_hypergeom_filtered['log2FC_deg'])

# %%
df_tf_target_deg_hypergeom_filtered['Region subclass'] = df_tf_target_deg_hypergeom_filtered['ctname'].map(
    gen_map_from_meta(df_deg_info,'ctname','Region subclass')
)

# %%
df_tf_target_deg_hypergeom_filtered['Model'] = df_tf_target_deg_hypergeom_filtered['comparison'].str.replace('_', ' ')

# %%
df_tf_target_deg_hypergeom_filtered.rename(columns={'sex': 'Sex', 'region': 'Region'}, inplace=True)

# %%
df_tf_target_deg_hypergeom_filtered.to_csv('/data2/junyi/stg0901/scenic_wilcoxon_all/scenic_all_TF_regulon_deg_overlap_hypergeom_filtered.csv', index=False)

# %%
plot_df = df_tf_target_deg_hypergeom_filtered.copy()

region_col = 'region' if 'region' in plot_df.columns else 'Region'
if region_col not in plot_df.columns:
    raise KeyError('No region column found in df_tf_target_deg_hypergeom_filtered')

plot_df = plot_df#.dropna(subset=['comparison', 'Direction', region_col]).copy()
plot_df['match_status'] = np.where(plot_df['Is_DEG'].fillna(False), 'Match', 'Mismatch')
plot_df['Direction'] = plot_df['Direction'].astype(str).str.capitalize()
plot_df = plot_df[plot_df['Direction'].isin(['Up', 'Down'])].copy()

summary_df = (
    plot_df.groupby([region_col, 'comparison', 'Direction', 'match_status'], as_index=False)
    .size()
    .rename(columns={'size': 'count'})
)

region_order_plot = [
    region for region in ['PFC', 'HPF', 'AMY', 'STR', 'TH', 'HY', 'MB']
    if region in summary_df[region_col].unique()
]
if not region_order_plot:
    region_order_plot = summary_df[region_col].drop_duplicates().tolist()

comparison_order_preferred = ['CUSUS_F', 'CURES_F', 'CUSUS_M', 'CURES_M', 'CSSUS_M', 'CSRES_M']

comparison_order = []
x_positions = {}
tick_positions = []
tick_labels = []
group_centers = {}
current_x = 0
gap_between_regions = 1.5

for region in region_order_plot:
    region_comparisons_present = (
        summary_df.loc[summary_df[region_col] == region, 'comparison']
        .drop_duplicates()
        .tolist()
    )
    region_comparisons = [
        comparison for comparison in comparison_order_preferred
        if comparison in region_comparisons_present
    ]
    region_comparisons += [
        comparison for comparison in region_comparisons_present
        if comparison not in region_comparisons
    ]
    if not region_comparisons:
        continue
    start_x = current_x
    for comparison in region_comparisons:
        x_positions[(region, comparison)] = current_x
        comparison_order.append((region, comparison))
        tick_positions.append(current_x)
        tick_labels.append(comparison)
        current_x += 1
    end_x = current_x - 1
    group_centers[region] = (start_x + end_x) / 2
    current_x += gap_between_regions

plot_wide = (
    summary_df.pivot_table(
        index=[region_col, 'comparison'],
        columns=['Direction', 'match_status'],
        values='count',
        fill_value=0
    )
    .reindex(comparison_order, fill_value=0)
    if comparison_order else pd.DataFrame()
    )

for col in [('Up', 'Match'), ('Up', 'Mismatch'), ('Down', 'Match'), ('Down', 'Mismatch')]:
    if col not in plot_wide.columns:
        plot_wide[col] = 0

plot_wide = plot_wide[[('Up', 'Match'), ('Up', 'Mismatch'), ('Down', 'Match'), ('Down', 'Mismatch')]]

x_vals = [x_positions[idx] for idx in plot_wide.index]
up_match = plot_wide[('Up', 'Match')].to_numpy()
up_mismatch = plot_wide[('Up', 'Mismatch')].to_numpy()
down_match = -plot_wide[('Down', 'Match')].to_numpy()
down_mismatch = -plot_wide[('Down', 'Mismatch')].to_numpy()

up_match_color = '#d62728'
up_mismatch_color = '#fcae91'
down_match_color = '#1f77b4'
down_mismatch_color = '#9ecae1'

fig, ax = plt.subplots(figsize=(max(12, len(x_vals) * 0.5), 7))

ax.bar(x_vals, up_match, color=up_match_color, label='Up DE+regulon')
ax.bar(x_vals, up_mismatch, bottom=up_match, color=up_mismatch_color, label='Up regulon')
ax.bar(x_vals, down_match, color=down_match_color, label='Down DE+regulon')
ax.bar(x_vals, down_mismatch, bottom=down_match, color=down_mismatch_color, label='Down regulon')

ax.axhline(0, color='black', linewidth=1)
ax.set_xticks(tick_positions)
ax.set_xticklabels(tick_labels, rotation=90, ha='center')
ax.set_ylabel('TF count')
#ax.set_title('Matched vs mismatched TF-DEG counts by comparison and direction')

for region, center in group_centers.items():
    ax.text(center, 1.02, region, transform=ax.get_xaxis_transform(), ha='center', va='bottom', fontsize=11, fontweight='bold')

legend_handles = [
    plt.Rectangle((0, 0), 1, 1, color=up_match_color, label='Up DETF-regulon'),
    plt.Rectangle((0, 0), 1, 1, color=up_mismatch_color, label='Up TF-regulon'),
    plt.Rectangle((0, 0), 1, 1, color=down_match_color, label='Down DETF-regulon'),
    plt.Rectangle((0, 0), 1, 1, color=down_mismatch_color, label='Down TF-regulon'),
]
ax.legend(handles=legend_handles, frameon=False, ncol=2, loc='upper right')
sns.despine(ax=ax, left=False, bottom=False)
plt.tight_layout()
plt.show()

summary_df.sort_values([region_col, 'comparison', 'Direction', 'match_status']).reset_index(drop=True)
# Out:
#     Region comparison Direction match_status  count
# 0      AMY    CSRES_M      Down        Match    117
# 1      AMY    CSRES_M      Down     Mismatch    254
# 2      AMY    CSRES_M        Up        Match     42
# 3      AMY    CSRES_M        Up     Mismatch    156
# 4      AMY    CSSUS_M      Down        Match     26
# ..     ...        ...       ...          ...    ...
# 142     TH    CUSUS_F        Up     Mismatch     51
# 143     TH    CUSUS_M      Down        Match     15
# 144     TH    CUSUS_M      Down     Mismatch     55
# 145     TH    CUSUS_M        Up        Match      1
# 146     TH    CUSUS_M        Up     Mismatch     49
#
# [147 rows x 5 columns]

# %%
plot_prop = plot_wide.copy()

plot_prop.columns = [f'{direction}_{status}'.lower() for direction, status in plot_prop.columns]
plot_prop = plot_prop.reset_index().rename(columns={region_col: 'region'})

plot_prop['up_total'] = plot_prop['up_match'] + plot_prop['up_mismatch']
plot_prop['down_total'] = plot_prop['down_match'] + plot_prop['down_mismatch']

plot_prop['up_match_ratio'] = np.where(
    plot_prop['up_total'] > 0,
    plot_prop['up_match'] / plot_prop['up_total'],
    np.nan
)
plot_prop['down_match_ratio'] = np.where(
    plot_prop['down_total'] > 0,
    plot_prop['down_match'] / plot_prop['down_total'],
    np.nan
)

# %%
plot_prop[['region', 'comparison', 'up_match', 'up_total', 'up_match_ratio', 'down_match', 'down_total', 'down_match_ratio']].to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_all_TF_regulon_deg_overlap_summary_for_plotting.csv', index=False)

# %%
def visualize_regulatory_network(metadata_df, importance_col='importance', weight_col='importance_TF2G', figure_size=(7, 7),
                               top_n=100, output_html='figures/network.html', title='SCENIC+ Regulatory Network', df_deg=None):
    from pyvis.network import Network

    if metadata_df.empty:
        raise ValueError('metadata_df is empty after filtering.')

    if importance_col not in metadata_df.columns:
        raise KeyError(f'{importance_col} not found in metadata_df')

    if weight_col not in metadata_df.columns:
        metadata_df = metadata_df.copy()
        metadata_df[weight_col] = metadata_df[importance_col]

    df = metadata_df.sort_values(importance_col, ascending=False).head(top_n).copy()

    if df_deg is None:
        df_deg_plot = pd.DataFrame(columns=['gene', 'condition', 'de_coef'])
    else:
        df_deg_plot = df_deg.copy()
        if 'gene' not in df_deg_plot.columns:
            gene_col = next((col for col in ['Gene', 'targetgene', 'TF'] if col in df_deg_plot.columns), None)
            if gene_col is None:
                raise KeyError('df_deg must contain a gene-like column.')
            df_deg_plot = df_deg_plot.rename(columns={gene_col: 'gene'})
        if 'de_coef' not in df_deg_plot.columns:
            coef_col = next((col for col in ['de_coef', 'log2FC'] if col in df_deg_plot.columns), None)
            if coef_col is None:
                raise KeyError('df_deg must contain de_coef or log2FC.')
            df_deg_plot = df_deg_plot.rename(columns={coef_col: 'de_coef'})
        if 'condition' not in df_deg_plot.columns:
            df_deg_plot['condition'] = np.where(df_deg_plot['de_coef'] > 0, 'UP', 'DOWN')
        df_deg_plot['gene'] = df_deg_plot['gene'].astype(str).str.upper()
        df_deg_plot = df_deg_plot.sort_values('de_coef', key=lambda s: s.abs(), ascending=False).drop_duplicates('gene')

    df['TF'] = df['TF'].astype(str).str.upper()
    df['Gene'] = df['Gene'].astype(str).str.upper()

    G = nx.DiGraph()
    for _, row in df.iterrows():
        G.add_edge(
            row['TF'],
            row['Gene'],
            weight=row[weight_col],
            title=f"Weight: {row[weight_col]:.2f}"
        )

    def format_label(name):
        name = str(name).strip()
        return name[:1].upper() + name[1:].lower() if name else name

    degrees = dict(G.degree())
    max_degree = max(degrees.values()) if degrees else 1
    tf_nodes = sorted(df['TF'].unique())
    tf_node_set = set(tf_nodes)
    gene_nodes = sorted([node for node in G.nodes() if node not in tf_node_set])
    deg_lookup = df_deg_plot.set_index('gene')[['condition', 'de_coef']].to_dict('index') if not df_deg_plot.empty else {}

    node_colors = {}
    node_edge_colors = {}
    node_edge_widths = {}

    for node in G.nodes():
        deg_info = deg_lookup.get(node)
        if deg_info is not None and deg_info['condition'] == 'UP':
            fill_color = '#E86A33' if node in tf_node_set else '#F3A26D'
            edge_color = '#C9511C'
            edge_width = 3
        elif deg_info is not None and deg_info['condition'] == 'DOWN':
            fill_color = '#3A86C8' if node in tf_node_set else '#8EC0E6'
            edge_color = '#2C6BA0'
            edge_width = 3
        else:
            fill_color = 'lightgray'
            edge_color = 'lightgray'
            edge_width = 0

        node_colors[node] = fill_color
        node_edge_colors[node] = edge_color
        node_edge_widths[node] = edge_width

    plt.figure(figsize=figure_size)
    tf_nodes = sorted(tf_nodes, key=lambda node: (-G.out_degree(node), node))
    pos = {}
    if tf_nodes:
        tf_y = np.linspace(0.9, -0.9, len(tf_nodes)) if len(tf_nodes) > 1 else np.array([0.0])
        for idx, node in enumerate(tf_nodes):
            pos[node] = np.array([-0.15 + 0.1 * (idx % 2), tf_y[idx]])

        tf_to_targets = {}
        for tf in tf_nodes:
            targets = sorted(G.successors(tf))
            tf_to_targets[tf] = targets

        gene_primary_tf = {}
        for gene in gene_nodes:
            parent_tfs = sorted(G.predecessors(gene), key=lambda tf: (-G.out_degree(tf), tf))
            if parent_tfs:
                gene_primary_tf[gene] = parent_tfs[0]

        grouped_genes = {tf: [] for tf in tf_nodes}
        shared_genes = []
        for gene in gene_nodes:
            parent_tfs = list(G.predecessors(gene))
            if len(parent_tfs) <= 1 and gene in gene_primary_tf:
                grouped_genes[gene_primary_tf[gene]].append(gene)
            else:
                shared_genes.append(gene)

        for tf_idx, tf in enumerate(tf_nodes):
            targets = grouped_genes[tf]
            if not targets:
                continue
            x_vals = np.linspace(0.45, 1.45, len(targets)) if len(targets) > 1 else np.array([0.9])
            y_center = pos[tf][1]
            y_offsets = np.linspace(-0.22, 0.22, len(targets)) if len(targets) > 1 else np.array([0.0])
            for gene_idx, gene in enumerate(targets):
                pos[gene] = np.array([x_vals[gene_idx], y_center + y_offsets[gene_idx]])

        if shared_genes:
            shared_y = np.linspace(1.0, -1.0, len(shared_genes)) if len(shared_genes) > 1 else np.array([0.0])
            for gene_idx, gene in enumerate(shared_genes):
                parent_tfs = sorted(G.predecessors(gene), key=lambda tf: (-G.out_degree(tf), tf))
                anchor_y = np.mean([pos[tf][1] for tf in parent_tfs]) if parent_tfs else 0.0
                pos[gene] = np.array([1.75, 0.65 * shared_y[gene_idx] + 0.35 * anchor_y])
    else:
        pos = nx.spring_layout(G, seed=7, k=1.0 / np.sqrt(max(G.number_of_nodes(), 1)))

    node_sizes = []
    for node in G.nodes():
        deg_info = deg_lookup.get(node)
        base_size = 260 if node in tf_node_set else 120
        degree_size = degrees[node] * (900 if node in tf_node_set else 380) / max_degree
        if deg_info is not None:
            fold_change = abs(deg_info['de_coef']) * (520 if node in tf_node_set else 320)
        else:
            fold_change = 0
        node_sizes.append(base_size + degree_size + fold_change)

    node_shapes = {node: 'h' if node in tf_node_set else 'o' for node in G.nodes()}
    for shape in set(node_shapes.values()):
        nx.draw_networkx_nodes(
            G, pos,
            nodelist=[node for node in G.nodes() if node_shapes[node] == shape],
            node_shape=shape,
            node_color=[node_colors[node] for node in G.nodes() if node_shapes[node] == shape],
            edgecolors=[node_edge_colors[node] for node in G.nodes() if node_shapes[node] == shape],
            linewidths=[node_edge_widths[node] for node in G.nodes() if node_shapes[node] == shape],
            node_size=[node_sizes[index] for index, node in enumerate(G.nodes()) if node_shapes[node] == shape],
            alpha=0.9
        )

    for source, target, edge_data in G.edges(data=True):
        edge_weight = edge_data['weight']
        arrowstyle = '-|>' if edge_weight >= 0 else '|-|'
        nx.draw_networkx_edges(
            G, pos, edgelist=[(source, target)],
            width=1,
            edge_color='#9A9A9A',
            alpha=0.5,
            arrowstyle=arrowstyle,
            connectionstyle='arc3, rad=0.12',
            arrowsize=15
        )

    import matplotlib.patheffects as path_effects
    tf_labels = {node: format_label(node) for node in tf_nodes if node in pos}
    gene_labels = {node: format_label(node) for node in gene_nodes if node in pos}
    tf_text_labels = nx.draw_networkx_labels(
        G, pos, labels=tf_labels, font_size=10, font_family='sans-serif',
        bbox=dict(facecolor='none', pad=0.1, edgecolor='none')
    )
    gene_text_labels = nx.draw_networkx_labels(
        G, pos, labels=gene_labels, font_size=7, font_family='sans-serif',
        bbox=dict(facecolor='none', pad=0.05, edgecolor='none')
    )
    for _, label in {**tf_text_labels, **gene_text_labels}.items():
        label.set_path_effects([
            path_effects.Stroke(linewidth=2, foreground='white'),
            path_effects.Normal()
        ])

    plt.title(title)
    plt.axis('off')
    plt.tight_layout()
    output_dir = os.path.dirname(output_html)
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)
    plt.savefig(output_html + '.png', dpi=300)
    plt.show()

    net = Network(height='800px', width='100%', directed=True)
    net.from_nx(G)
    for node in net.nodes:
        node['label'] = format_label(node['id'])
        if node['id'] in tf_node_set:
            node['shape'] = 'triangle'
            node['size'] = 28
        else:
            node['size'] = 16
    net.show_buttons(filter_=['physics'])
    net.save_graph(output_html)
    print(f'Interactive visualization saved to {output_html}')

# %%
available_ctnames = sorted(df_tf_target_deg_hypergeom['ctname'].dropna().unique())
selected_ctnames = [available_ctnames[0]]
selected_comparison = None

if len(selected_ctnames) != 1:
    raise ValueError('Please select exactly one ctname.')

selected_ctname = 'HPF_HPF_Subiculum_ProS_Glut'
network_source = df_tf_target_deg_hypergeom[df_tf_target_deg_hypergeom['ctname'] == selected_ctname].copy()
network_source = network_source[network_source.comparison == 'CUSUS_M']
network_source = pd.concat([
network_source.sort_values('n_up_overlap',ascending=False).head(5),
network_source.sort_values('n_down_overlap',ascending=False).head(5)
])
network_source

if network_source.empty:
    raise ValueError(f'No rows found for ctname: {selected_ctname}')

if selected_comparison is not None:
    network_source = network_source[network_source['comparison'] == selected_comparison].copy()

if network_source['ctname'].nunique() != 1:
    raise ValueError('Network input still contains multiple ctname values.')

network_source = network_source[
    (network_source['n_up_overlap'] > 0) | (network_source['n_down_overlap'] > 0)
].copy()

def split_gene_list(value):
    if pd.isna(value) or value == '':
        return []
    return [gene.strip().upper() for gene in str(value).split(',') if gene.strip()]

edge_records = []
for _, row in network_source.iterrows():
    tf_name = str(row['TF']).upper()
    for gene in split_gene_list(row['up_deg_list']):
        edge_records.append({
            'ctname': row['ctname'],
            'comparison': row['comparison'],
            'TF': tf_name,
            'Gene': gene,
            'importance': 1,
            'importance_TF2G': 1,
            'edge_direction': 'UP'
        })
    for gene in split_gene_list(row['down_deg_list']):
        edge_records.append({
            'ctname': row['ctname'],
            'comparison': row['comparison'],
            'TF': tf_name,
            'Gene': gene,
            'importance': 1,
            'importance_TF2G': -1,
            'edge_direction': 'DOWN'
        })

network_edges = pd.DataFrame(edge_records)
if network_edges.empty:
    raise ValueError(f'No TF-gene edges found for ctname: {selected_ctname}')

network_edges = network_edges.drop_duplicates(['ctname', 'comparison', 'TF', 'Gene', 'edge_direction']).copy()

df_deg_network = df_deg_all.copy()
df_deg_network['ctname'] = df_deg_network['Region'] + '_' + df_deg_network['Subclass']
df_deg_network['ctname'] = df_deg_network['ctname'].str.replace('/', '-', regex=False)
df_deg_network['ctname'] = df_deg_network['ctname'].str.replace(' ', '_', regex=False)
df_deg_network['comparison'] = df_deg_network['Model'].str.replace(' ', '_', regex=False)

gene_col = next((col for col in ['gene', 'Gene', 'targetgene'] if col in df_deg_network.columns), None)
if gene_col is None:
    df_deg_network['gene'] = df_deg_network.index.astype(str)
else:
    df_deg_network['gene'] = df_deg_network[gene_col].astype(str)

coef_col = next((col for col in ['de_coef', 'log2FC'] if col in df_deg_network.columns), None)
if coef_col is None:
    raise KeyError('df_deg_all must contain de_coef or log2FC.')

df_deg_network = df_deg_network[df_deg_network['ctname'] == selected_ctname].copy()
if selected_comparison is not None:
    df_deg_network = df_deg_network[df_deg_network['comparison'] == selected_comparison].copy()

df_deg_network['gene'] = df_deg_network['gene'].str.upper()
df_deg_network['de_coef'] = df_deg_network[coef_col]
df_deg_network['condition'] = np.where(df_deg_network['de_coef'] > 0, 'UP', 'DOWN')
df_deg_network = df_deg_network[['gene', 'de_coef', 'condition']].drop_duplicates('gene')

comparison_label = selected_comparison if selected_comparison is not None else 'all_comparisons'
display(network_edges.head())
print(f'ctname: {selected_ctname}')
print(f'comparison: {comparison_label}')
print(f'n_edges: {len(network_edges)}')
print(f'n_tfs: {network_edges["TF"].nunique()}')
print(f'n_genes: {network_edges["Gene"].nunique()}')

visualize_regulatory_network(
    network_edges,
    importance_col='importance',
    weight_col='importance_TF2G',
    figure_size=(9, 9),
    top_n=min(150, len(network_edges)),
    output_html=f'figures/{selected_ctname}_{comparison_label}_regulatory_network.html',
    title=f'Regulatory network: {selected_ctname} | {comparison_label}',
    df_deg=df_deg_network
)
# Out:
#                         ctname comparison     TF           Gene  importance  \
# 0  HPF_HPF_Subiculum_ProS_Glut    CUSUS_M  NPDC1  1500011B03RIK           1
# 1  HPF_HPF_Subiculum_ProS_Glut    CUSUS_M  NPDC1  2900097C17RIK           1
# 2  HPF_HPF_Subiculum_ProS_Glut    CUSUS_M  NPDC1  6330403K07RIK           1
# 3  HPF_HPF_Subiculum_ProS_Glut    CUSUS_M  NPDC1           ACTB           1
# 4  HPF_HPF_Subiculum_ProS_Glut    CUSUS_M  NPDC1          ACTG1           1
#
#    importance_TF2G edge_direction
# 0                1             UP
# 1                1             UP
# 2                1             UP
# 3                1             UP
# 4                1             UP
# ctname: HPF_HPF_Subiculum_ProS_Glut
# comparison: all_comparisons
# n_edges: 682
# n_tfs: 10
# n_genes: 408
# Interactive visualization saved to figures/HPF_HPF_Subiculum_ProS_Glut_all_comparisons_regulatory_network.html

# %%
def visualize_regulatory_network(metadata_df, importance_col='importance', weight_col='importance_TF2G', figure_size=(7, 7),

                               top_n=100, output_html='figures/network.html', title='SCENIC+ Regulatory Network', df_deg=None):

    from pyvis.network import Network



    if metadata_df.empty:

        raise ValueError('metadata_df is empty after filtering.')



    if importance_col not in metadata_df.columns:

        raise KeyError(f'{importance_col} not found in metadata_df')



    if weight_col not in metadata_df.columns:

        metadata_df = metadata_df.copy()

        metadata_df[weight_col] = metadata_df[importance_col]



    df = metadata_df.sort_values(importance_col, ascending=False).head(top_n).copy()



    if df_deg is None:

        df_deg_plot = pd.DataFrame(columns=['gene', 'condition', 'de_coef'])

    else:

        df_deg_plot = df_deg.copy()

        if 'gene' not in df_deg_plot.columns:

            gene_col = next((col for col in ['Gene', 'targetgene', 'TF'] if col in df_deg_plot.columns), None)

            if gene_col is None:

                raise KeyError('df_deg must contain a gene-like column.')

            df_deg_plot = df_deg_plot.rename(columns={gene_col: 'gene'})

        if 'de_coef' not in df_deg_plot.columns:

            coef_col = next((col for col in ['de_coef', 'log2FC'] if col in df_deg_plot.columns), None)

            if coef_col is None:

                raise KeyError('df_deg must contain de_coef or log2FC.')

            df_deg_plot = df_deg_plot.rename(columns={coef_col: 'de_coef'})

        if 'condition' not in df_deg_plot.columns:

            df_deg_plot['condition'] = np.where(df_deg_plot['de_coef'] > 0, 'UP', 'DOWN')

        df_deg_plot['gene'] = df_deg_plot['gene'].astype(str).str.upper()

        df_deg_plot = df_deg_plot.sort_values('de_coef', key=lambda s: s.abs(), ascending=False).drop_duplicates('gene')



    df['TF'] = df['TF'].astype(str).str.upper()

    df['Gene'] = df['Gene'].astype(str).str.upper()



    G = nx.DiGraph()

    for _, row in df.iterrows():

        G.add_edge(

            row['TF'],

            row['Gene'],

            weight=row[weight_col],

            title=f"Weight: {row[weight_col]:.2f}"

        )



    def format_label(name):

        name = str(name).strip()

        return name[:1].upper() + name[1:].lower() if name else name



    degrees = dict(G.degree())

    max_degree = max(degrees.values()) if degrees else 1

    tf_nodes = sorted(df['TF'].unique())

    tf_node_set = set(tf_nodes)

    gene_nodes = sorted([node for node in G.nodes() if node not in tf_node_set])

    deg_lookup = df_deg_plot.set_index('gene')[['condition', 'de_coef']].to_dict('index') if not df_deg_plot.empty else {}



    node_colors = {}

    node_edge_colors = {}

    node_edge_widths = {}



    for node in G.nodes():

        deg_info = deg_lookup.get(node)

        if deg_info is not None and deg_info['condition'] == 'UP':

            fill_color = '#E86A33' if node in tf_node_set else '#F3A26D'

            edge_color = '#C9511C'

            edge_width = 3

        elif deg_info is not None and deg_info['condition'] == 'DOWN':

            fill_color = '#3A86C8' if node in tf_node_set else '#8EC0E6'

            edge_color = '#2C6BA0'

            edge_width = 3

        else:

            fill_color = 'lightgray'

            edge_color = 'lightgray'

            edge_width = 0



        node_colors[node] = fill_color

        node_edge_colors[node] = edge_color

        node_edge_widths[node] = edge_width



    plt.figure(figsize=figure_size)

    try:

        from fa2 import ForceAtlas2

    except ImportError:

        ForceAtlas2 = None



    if G.number_of_nodes() > 0 and ForceAtlas2 is not None:

        forceatlas2 = ForceAtlas2(

            outboundAttractionDistribution=False,

            linLogMode=False,

            adjustSizes=False,

            edgeWeightInfluence=1.0,

            jitterTolerance=1.0,

            barnesHutOptimize=True,

            barnesHutTheta=1.2,

            scalingRatio=2.5,

            strongGravityMode=False,

            gravity=1.0,

            verbose=False

        )

        pos = forceatlas2.forceatlas2_networkx_layout(G, pos=None, iterations=500)

    else:

        pos = nx.spring_layout(G, seed=7, k=1.2 / np.sqrt(max(G.number_of_nodes(), 1)))



    node_sizes = []

    for node in G.nodes():

        deg_info = deg_lookup.get(node)

        base_size = 260 if node in tf_node_set else 120

        degree_size = degrees[node] * (900 if node in tf_node_set else 380) / max_degree

        if deg_info is not None:

            fold_change = abs(deg_info['de_coef']) * (520 if node in tf_node_set else 320)

        else:

            fold_change = 0

        node_sizes.append(base_size + degree_size + fold_change)



    node_shapes = {node: 'h' if node in tf_node_set else 'o' for node in G.nodes()}

    for shape in set(node_shapes.values()):

        nx.draw_networkx_nodes(

            G, pos,

            nodelist=[node for node in G.nodes() if node_shapes[node] == shape],

            node_shape=shape,

            node_color=[node_colors[node] for node in G.nodes() if node_shapes[node] == shape],

            edgecolors=[node_edge_colors[node] for node in G.nodes() if node_shapes[node] == shape],

            linewidths=[node_edge_widths[node] for node in G.nodes() if node_shapes[node] == shape],

            node_size=[node_sizes[index] for index, node in enumerate(G.nodes()) if node_shapes[node] == shape],

            alpha=0.9

        )



    for source, target, edge_data in G.edges(data=True):

        edge_weight = edge_data['weight']

        arrowstyle = '-|>' if edge_weight >= 0 else '|-|'

        nx.draw_networkx_edges(

            G, pos, edgelist=[(source, target)],

            width=1,

            edge_color='#9A9A9A',

            alpha=0.5,

            arrowstyle=arrowstyle,

            connectionstyle='arc3, rad=0.12',

            arrowsize=15

        )



    import matplotlib.patheffects as path_effects

    tf_labels = {node: format_label(node) for node in tf_nodes if node in pos}

    gene_labels = {node: format_label(node) for node in gene_nodes if node in pos}

    tf_text_labels = nx.draw_networkx_labels(

        G, pos, labels=tf_labels, font_size=10, font_family='sans-serif',

        bbox=dict(facecolor='none', pad=0.1, edgecolor='none')

    )

    gene_text_labels = nx.draw_networkx_labels(

        G, pos, labels=gene_labels, font_size=7, font_family='sans-serif',

        bbox=dict(facecolor='none', pad=0.05, edgecolor='none')

    )

    for _, label in {**tf_text_labels, **gene_text_labels}.items():

        label.set_path_effects([

            path_effects.Stroke(linewidth=2, foreground='white'),

            path_effects.Normal()

        ])



    plt.title(title)

    plt.axis('off')

    plt.tight_layout()

    output_dir = os.path.dirname(output_html)

    if output_dir:

        os.makedirs(output_dir, exist_ok=True)

    plt.savefig(output_html + '.png', dpi=300)

    plt.show()



    net = Network(height='800px', width='100%', directed=True)

    net.from_nx(G)

    for node in net.nodes:

        node['label'] = format_label(node['id'])

        if node['id'] in tf_node_set:

            node['shape'] = 'triangle'

            node['size'] = 28

        else:

            node['size'] = 16

    net.force_atlas_2based(gravity=-30, central_gravity=0.015, spring_length=140, spring_strength=0.08, damping=0.9)

    net.show_buttons(filter_=['physics'])

    net.save_graph(output_html)

    print(f'Interactive visualization saved to {output_html}')

# %%
df_match_rate_region_nt.to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_tobias_direction_match_rate_by_region_nt.csv', index=False)

# %%
def compute_logfc_pearson_by_region_nt_tf(df_scenic, df_tobias):
    scenic_subset = df_scenic.loc[:, ['TF', 'log2FC', 'Region', 'Neurotransmitter', 'ctname']].dropna().copy()
    tobias_subset = df_tobias.loc[:, ['TF', 'log2FC', 'Region', 'Neurotransmitter', 'ctname']].dropna().copy()

    scenic_subset['TF'] = scenic_subset['TF'].astype(str).str.upper()
    tobias_subset['TF'] = tobias_subset['TF'].astype(str).str.upper()

    scenic_subset = scenic_subset.drop_duplicates(['Region', 'Neurotransmitter', 'ctname', 'TF'])
    tobias_subset = tobias_subset.drop_duplicates(['Region', 'Neurotransmitter', 'ctname', 'TF'])

    df_logfc_match = scenic_subset.merge(
        tobias_subset,
        on=['Region', 'Neurotransmitter', 'ctname', 'TF'],
        how='inner',
        suffixes=('_scenic', '_tobias')
    )

    pearson_rows = []
    for (region, neurotransmitter, tf), group in df_logfc_match.groupby(['Region', 'Neurotransmitter', 'TF']):
        scenic_values = group['log2FC_scenic'].astype(float)
        tobias_values = group['log2FC_tobias'].astype(float)
        n_overlap_ctname = len(group)

        if n_overlap_ctname >= 2 and scenic_values.nunique() > 1 and tobias_values.nunique() > 1:
            pearson_r, pearson_p = pearsonr(scenic_values, tobias_values)
        else:
            pearson_r, pearson_p = np.nan, np.nan

        pearson_rows.append({
            'Region': region,
            'Neurotransmitter': neurotransmitter,
            'TF': tf,
            'n_overlap_ctname': n_overlap_ctname,
            'pearson_r_logfc': pearson_r,
            'pearson_p_logfc': pearson_p,
            'mean_abs_logfc_scenic': scenic_values.abs().mean(),
            'mean_abs_logfc_tobias': tobias_values.abs().mean()
        })

    df_tf_logfc_pearson_by_region_nt = pd.DataFrame(pearson_rows)
    if df_tf_logfc_pearson_by_region_nt.empty:
        return df_logfc_match, df_tf_logfc_pearson_by_region_nt

    df_tf_logfc_pearson_by_region_nt = df_tf_logfc_pearson_by_region_nt.sort_values(
        ['Region', 'Neurotransmitter', 'pearson_r_logfc', 'n_overlap_ctname', 'mean_abs_logfc_scenic', 'TF'],
        ascending=[True, True, False, False, False, True]
    ).reset_index(drop=True)

    return df_logfc_match, df_tf_logfc_pearson_by_region_nt

df_logfc_match_region_nt, df_tf_logfc_pearson_by_region_nt = compute_logfc_pearson_by_region_nt_tf(
    scenic_all_common_s,
    tobias_all_common_s
)

df_tf_logfc_pearson_by_region_nt

# %%
df_tf_logfc_pearson_by_region_nt_f = df_tf_logfc_pearson_by_region_nt[df_tf_logfc_pearson_by_region_nt.n_overlap_ctname >= 3]

# %%
df_tf_overlap_by_region_nt = (
    df_match_direction_region_nt
    .assign(
        direction_match=lambda d: d['Direction_scenic'].astype(str).str.upper(),
        is_up=lambda d: d['is_matching'] & d['direction_match'].eq('UP'),
        is_down=lambda d: d['is_matching'] & d['direction_match'].eq('DOWN'),
        is_ns=lambda d: d['is_matching'] & d['direction_match'].eq('NS')
    )
    .groupby(['Region', 'Neurotransmitter', 'TF'], as_index=False)
    .agg(
        n_overlap_pairs=('TF', 'size'),
        n_matching_pairs=('is_matching', 'sum'),
        n_up=('is_up', 'sum'),
        n_down=('is_down', 'sum'),
        n_ns=('is_ns', 'sum'),
        n_ctname=('ctname', 'nunique')
    )
 )
df_tf_overlap_by_region_nt['matching_rate'] = (
    df_tf_overlap_by_region_nt['n_matching_pairs'] / df_tf_overlap_by_region_nt['n_overlap_pairs']
 )
df_tf_overlap_by_region_nt = df_tf_overlap_by_region_nt.sort_values(
    [
        'Region', 'Neurotransmitter', 'n_overlap_pairs', 'n_matching_pairs',
        'n_up', 'n_down', 'n_ns', 'matching_rate', 'TF'
    ],
    ascending=[True, True, False, False, False, False, False, False, True]
).reset_index(drop=True)

top_tf_overlap_by_region_nt = (
    df_tf_overlap_by_region_nt
    .groupby(['Region', 'Neurotransmitter'], group_keys=False)
    .head(20)
    .reset_index(drop=True)
 )

top_tf_overlap_by_region_nt

# %%
direction_counts_region_nt = (
    df_match_direction_region_nt
    .assign(
        Direction_scenic_upper=lambda d: d['Direction_scenic'].astype(str).str.upper(),
        Direction_tobias_upper=lambda d: d['Direction_tobias'].astype(str).str.upper()
    )
    .groupby(['Region', 'Neurotransmitter', 'TF'], as_index=False)
    .agg(
        n_scenic_UP=('Direction_scenic_upper', lambda s: int((s == 'UP').sum())),
        n_scenic_DOWN=('Direction_scenic_upper', lambda s: int((s == 'DOWN').sum())),
        n_tobias_UP=('Direction_tobias_upper', lambda s: int((s == 'UP').sum())),
        n_tobias_DOWN=('Direction_tobias_upper', lambda s: int((s == 'DOWN').sum()))
    )
)

df_tf_overlap_by_region_nt = (
    df_tf_overlap_by_region_nt
    .drop(columns=['n_scenic_UP', 'n_scenic_DOWN', 'n_tobias_UP', 'n_tobias_DOWN'], errors='ignore')
    .merge(direction_counts_region_nt, on=['Region', 'Neurotransmitter', 'TF'], how='left')
)

count_cols = ['n_scenic_UP', 'n_scenic_DOWN', 'n_tobias_UP', 'n_tobias_DOWN']
df_tf_overlap_by_region_nt[count_cols] = df_tf_overlap_by_region_nt[count_cols].fillna(0).astype(int)

top_tf_overlap_by_region_nt = (
    df_tf_overlap_by_region_nt
    .sort_values(['Region', 'Neurotransmitter', 'matching_rate', 'n_matching_pairs'], ascending=[True, True, False, False])
    .groupby(['Region', 'Neurotransmitter'], group_keys=False)
    .head(20)
    .reset_index(drop=True)
)

top_tf_overlap_by_region_nt

# %%
df_tf_overlap_by_region_nt

# %%
df_tf_overlap_by_region_nt.to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_wilcoxon_all_TF_overlap_by_region_nt.csv', index=False)
top_tf_overlap_by_region_nt.to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_wilcoxon_all_top20_TF_overlap_by_region_nt.csv', index=False)

# %%
top_tf_overlap_by_region_nt[top_tf_overlap_by_region_nt.matching_rate>0.3]

# %%
top_tf_overlap_by_region_nt.TF.unique()

# %%
adata_tobias_expanded.var['TF_up'] =adata_tobias_expanded.var['TF_up'].str.upper()

# %%
adata_tobias_expanded.X = adata_tobias_expanded.layers['mean_score'].copy()

# %%
adata_scenic = sc.read_h5ad('/data2st2/junyi/output/stg1028/scenic_auc_all_h5ad/combined_auc_agg.h5ad')

# %%
adata_scenic.var['TF']= adata_scenic.var.index
adata_scenic.var['TF'] = adata_scenic.var['TF'].str[:-3]
adata_scenic.var['TF_up'] = adata_scenic.var['TF'].str.upper()

# %%
# only select the overlap of TF between two adata
common_TFs = set(adata_tobias_expanded.var['TF_up']).intersection(set(adata_scenic.var['TF_up']))

# %%
len(common_TFs)

# %%
adata_tobias_expanded.var

# %%
adata_scenic_com = adata_scenic[:, adata_scenic.var['TF_up'].isin(common_TFs)].copy()
adata_tobias_com = adata_tobias_expanded[:, adata_tobias_expanded.var['TF_up'].isin(common_TFs)].copy()

# %%
adata_sn_com = adata_sn[:, adata_sn.var['TF_up'].isin(common_TFs)].copy()

# %%
adata_sn_com.obs['status'] = adata_sn_com.obs['condition'].map({"MC":"SUS","MW":'CON'})

# %%
adata_sn_com.obs['Re_Sc_St_Se'] = (
    adata_sn_com.obs['region'].astype(str)
    + '_' + adata_sn_com.obs['celltype.L2'].astype(str)
    + '_' + adata_sn_com.obs['status'].astype(str)
    + '_M'
)

# %%
adata_sn_com

# %%
# for adata_scenic_com select Region is in AMY HPF PFC , status in CON SUS, sex= M
adata_scenic_com = adata_scenic_com[
    adata_scenic_com.obs['Region'].isin(['AMY', 'HPF', 'PFC'])
    & adata_scenic_com.obs['status'].isin(['CON', 'SUS'])
    & (adata_scenic_com.obs['sex'] == 'M')
].copy()
adata_scenic_com

# %%
adata_tobias_com.obs['Re_Sc_St_Se']= adata_tobias_com.obs['Region Subclass'].astype(str) +"_" +adata_tobias_com.obs['status'].astype(str)+"_M"

# %%
adata_tobias_com.obs['Re_Sc_St_Se'] = adata_tobias_com.obs['Re_Sc_St_Se'].str.replace('HIP','HPF')

# %%
adata_scenic_com.obs['Re_Sc_St_Se'] = adata_scenic_com.obs['Re_Sc_St_Se'].str.replace("/","-")
adata_scenic_com.obs['Re_Sc_St_Se'] = adata_scenic_com.obs['Re_Sc_St_Se'].str.replace(" ","_")

# %%
df_meta_match.dropna(subset=['Neurotransmitter'], inplace=True)

# %%
df_meta_match['Region Subclass'] = df_meta_match['Region Subclass'].str.replace('/', '-')
df_meta_match['Region Subclass'] = df_meta_match['Region Subclass'].str.replace(' ', '_')

# %%
df_meta_match['celltype_l2'] = df_meta_match['celltype.L2'].str.replace('/', '-').str.replace(' ', '_')

# %%
dict_rs_to_nt = dict(zip(df_meta_match['Region Subclass'], df_meta_match['Neurotransmitter']))

# %%
dict_celltype_L2_to_nt = dict(zip(df_meta_match['celltype.L2'], df_meta_match['Neurotransmitter']))
dict_l2_nt = dict(zip(df_meta_match['celltype_l2'], df_meta_match['Neurotransmitter']))
dict_celltype_L2_nt = dict(zip(df_meta_match['celltype'], df_meta_match['Neurotransmitter']))

# %%
adata_tobias_com.obs['Neurotransmitter'] = adata_tobias_com.obs['Region Subclass'].map(dict_rs_to_nt)
adata_scenic_com.obs['Neurotransmitter'] = adata_scenic_com.obs['celltype.L2'].map(dict_celltype_L2_to_nt)
adata_sn_com.obs['Neurotransmitter'] = adata_sn_com.obs['celltype.L2'].map(dict_l2_nt)

# %%
def matrix_from_grouped_adata(adata, group_col='Re_Sc_St_Se', feature_col='TF_up'):
    group_names = adata.obs[group_col].astype(str) if group_col in adata.obs.columns else adata.obs_names.astype(str)
    df_expr = pd.DataFrame(adata.X, index=group_names, columns=adata.var_names).T
    df_expr['feature_name'] = adata.var[feature_col].values
    return df_expr

def zscore_columns(df):
    values = df.astype(float)
    means = values.mean(axis=0)
    stds = values.std(axis=0).replace(0, np.nan)
    return values.sub(means, axis=1).div(stds, axis=1).fillna(0)

def compute_corr_metrics(values_a, values_b):
    valid_mask = values_a.notna() & values_b.notna()
    n_shared = int(valid_mask.sum())
    if n_shared < 3:
        return n_shared, np.nan, np.nan, np.nan, np.nan
    pearson_corr, pearson_p = pearsonr(values_a[valid_mask], values_b[valid_mask])
    spearman_corr, spearman_p = spearmanr(values_a[valid_mask], values_b[valid_mask])
    return n_shared, pearson_corr, pearson_p, spearman_corr, spearman_p

def shared_columns_by_region(index_a, index_b, region=None):
    shared_columns = sorted(set(index_a).intersection(set(index_b)))
    if region is None:
        return shared_columns
    return [col for col in shared_columns if str(col).split('_')[0] == region]

def build_group_metadata_map(adata, group_col='Re_Sc_St_Se'):
    region_col = 'Region' if 'Region' in adata.obs.columns else 'region'
    group_meta = (
        adata.obs.loc[:, [group_col, region_col, 'Neurotransmitter']]
        .dropna()
        .drop_duplicates(subset=[group_col])
        .copy()
    )
    group_meta[group_col] = group_meta[group_col].astype(str)
    group_meta[region_col] = group_meta[region_col].astype(str)
    group_meta['Neurotransmitter'] = group_meta['Neurotransmitter'].astype(str)
    return {
        group_name: (region, neurotransmitter)
        for group_name, region, neurotransmitter in group_meta.itertuples(index=False, name=None)
    }

def shared_columns_by_region_nt(index_a, index_b, group_map_a, group_map_b, region=None, neurotransmitter=None):
    shared_columns = sorted(set(index_a).intersection(set(index_b)))
    filtered_columns = []
    for col in shared_columns:
        meta_a = group_map_a.get(col)
        meta_b = group_map_b.get(col)
        if meta_a is None or meta_b is None or meta_a != meta_b:
            continue
        col_region, col_nt = meta_a
        if region is not None and col_region != region:
            continue
        if neurotransmitter is not None and col_nt != neurotransmitter:
            continue
        filtered_columns.append(col)
    return filtered_columns

def extract_region_nt_pairs(shared_columns, group_map_a, group_map_b):
    region_nt_pairs = set()
    for col in shared_columns:
        meta_a = group_map_a.get(col)
        meta_b = group_map_b.get(col)
        if meta_a is not None and meta_a == meta_b:
            region_nt_pairs.add(meta_a)
    return region_nt_pairs

def compute_tf_pair_corr(adata_left, left_lookup, right_lookup, shared_columns, result_prefix, left_key='var_name', right_key='TF_up'):
    corr_rows = []
    for var_name, row in adata_left.var.iterrows():
        tf_up = row['TF_up']
        tf_up_original = row['TF_up_original'] if 'TF_up_original' in row.index else row['TF_up']
        result = {
            'var_name': var_name,
            'TF_up_original': tf_up_original,
            'TF_up': tf_up
        }

        left_lookup_key = var_name if left_key == 'var_name' else tf_up
        right_lookup_key = var_name if right_key == 'var_name' else tf_up

        if left_lookup_key in left_lookup.index and right_lookup_key in right_lookup.index:
            n_shared, pearson_corr, pearson_p, spearman_corr, spearman_p = compute_corr_metrics(
                left_lookup.loc[left_lookup_key, shared_columns].astype(float),
                right_lookup.loc[right_lookup_key, shared_columns].astype(float)
            )
        else:
            n_shared, pearson_corr, pearson_p, spearman_corr, spearman_p = 0, np.nan, np.nan, np.nan, np.nan

        result.update({
            f'n_celltypes_{result_prefix}': n_shared,
            f'pearson_r_{result_prefix}': pearson_corr,
            f'pearson_p_{result_prefix}': pearson_p,
            f'spearman_r_{result_prefix}': spearman_corr,
            f'spearman_p_{result_prefix}': spearman_p
        })
        corr_rows.append(result)

    return pd.DataFrame(corr_rows)

def compute_region_corr_tables(adata_tobias_com, adata_scenic_com, adata_sn_com, use_zscore=False):
    adata_tobias_com  = adata_tobias_com[adata_tobias_com.obs['Neurotransmitter']!= 'NN'].copy()
    adata_scenic_com = adata_scenic_com[adata_scenic_com.obs['Neurotransmitter']!= 'NN'].copy()
    adata_sn_com = adata_sn_com[adata_sn_com.obs['Neurotransmitter']!= 'NN'].copy()
    tobias_matrix = matrix_from_grouped_adata(adata_tobias_com, group_col='Re_Sc_St_Se', feature_col='TF_up')
    scenic_matrix = matrix_from_grouped_adata(adata_scenic_com, group_col='Re_Sc_St_Se', feature_col='TF_up')
    sn_matrix = matrix_from_grouped_adata(adata_sn_com, group_col='Re_Sc_St_Se', feature_col='TF_up')

    tobias_lookup = tobias_matrix.drop(columns='feature_name')
    scenic_lookup = scenic_matrix.groupby('feature_name').first()
    sn_lookup = sn_matrix.groupby('feature_name').first()

    if use_zscore:
        tobias_lookup = zscore_columns(tobias_lookup)
        scenic_lookup = zscore_columns(scenic_lookup)
        sn_lookup = zscore_columns(sn_lookup)

    tobias_group_map = build_group_metadata_map(adata_tobias_com)
    scenic_group_map = build_group_metadata_map(adata_scenic_com)
    sn_group_map = build_group_metadata_map(adata_sn_com)

    regions = sorted({str(col).split('_')[0] for col in tobias_lookup.columns})

    shared_tobias_scenic_all = shared_columns_by_region(tobias_lookup.columns, scenic_lookup.columns)
    shared_sn_scenic_all = shared_columns_by_region(sn_lookup.columns, scenic_lookup.columns)
    shared_sn_tobias_all = shared_columns_by_region(sn_lookup.columns, tobias_lookup.columns)

    region_nt_pairs = sorted(
        extract_region_nt_pairs(shared_tobias_scenic_all, tobias_group_map, scenic_group_map)
        | extract_region_nt_pairs(shared_sn_scenic_all, sn_group_map, scenic_group_map)
        | extract_region_nt_pairs(shared_sn_tobias_all, sn_group_map, tobias_group_map)
    )

    df_tobias_scenic_corr = compute_tf_pair_corr(
        adata_left=adata_tobias_com,
        left_lookup=tobias_lookup,
        right_lookup=scenic_lookup,
        shared_columns=shared_tobias_scenic_all,
        result_prefix='tobias_scenic',
        left_key='var_name',
        right_key='TF_up'
    )

    df_sn_scenic_corr = compute_tf_pair_corr(
        adata_left=adata_sn_com,
        left_lookup=sn_lookup,
        right_lookup=scenic_lookup,
        shared_columns=shared_sn_scenic_all,
        result_prefix='sn_scenic',
        left_key='TF_up',
        right_key='TF_up'
    )

    df_sn_tobias_corr = compute_tf_pair_corr(
        adata_left=adata_tobias_com,
        left_lookup=tobias_lookup,
        right_lookup=sn_lookup,
        shared_columns=shared_sn_tobias_all,
        result_prefix='sn_tobias',
        left_key='var_name',
        right_key='TF_up'
    )
    cortmp = df_tobias_scenic_corr.merge(
        df_sn_tobias_corr.drop(columns=['TF_up_original']),
        on=['var_name', 'TF_up'],
        how='left'
    )
    cortmp = cortmp.merge(
        df_sn_scenic_corr.drop(columns=['TF_up_original']),
        on=['TF_up'],
        how='left'
    )
    df_tobias_scenic_corr = cortmp
    df_tobias_scenic_corr = df_tobias_scenic_corr.sort_values(
        ['spearman_r_tobias_scenic', 'spearman_r_sn_scenic', 'spearman_r_sn_tobias'],
        ascending=False
    )

    region_frames = []
    for region in regions:
        shared_tobias_scenic = shared_columns_by_region(tobias_lookup.columns, scenic_lookup.columns, region=region)
        shared_sn_scenic = shared_columns_by_region(sn_lookup.columns, scenic_lookup.columns, region=region)
        shared_sn_tobias = shared_columns_by_region(sn_lookup.columns, tobias_lookup.columns, region=region)

        region_tobias_scenic = compute_tf_pair_corr(
            adata_left=adata_tobias_com,
            left_lookup=tobias_lookup,
            right_lookup=scenic_lookup,
            shared_columns=shared_tobias_scenic,
            result_prefix='tobias_scenic',
            left_key='var_name',
            right_key='TF_up'
        )

        region_sn_scenic = compute_tf_pair_corr(
            adata_left=adata_sn_com,
            left_lookup=sn_lookup,
            right_lookup=scenic_lookup,
            shared_columns=shared_sn_scenic,
            result_prefix='sn_scenic',
            left_key='TF_up',
            right_key='TF_up'
        )

        region_sn_tobias = compute_tf_pair_corr(
            adata_left=adata_tobias_com,
            left_lookup=tobias_lookup,
            right_lookup=sn_lookup,
            shared_columns=shared_sn_tobias,
            result_prefix='sn_tobias',
            left_key='var_name',
            right_key='TF_up'
        )

        cortmp = region_tobias_scenic.merge(
            region_sn_tobias.drop(columns=['TF_up_original']),
            on=['var_name', 'TF_up'],
            how='left'
        )
        cortmp = cortmp.merge(
            region_sn_scenic.drop(columns=['TF_up_original']),
            on=['TF_up'],
            how='left'
        )
        region_df = cortmp
        region_df['Region'] = region
        region_df = region_df.sort_values(
            ['spearman_r_tobias_scenic', 'spearman_r_sn_scenic', 'spearman_r_sn_tobias'],
            ascending=False
        )
        region_frames.append(region_df)

    df_region_tobias_scenic_corr = pd.concat(region_frames, axis=0, ignore_index=True)

    region_nt_frames = []
    for region, neurotransmitter in region_nt_pairs:
        shared_tobias_scenic = shared_columns_by_region_nt(
            tobias_lookup.columns, scenic_lookup.columns, tobias_group_map, scenic_group_map, region=region, neurotransmitter=neurotransmitter
        )
        shared_sn_scenic = shared_columns_by_region_nt(
            sn_lookup.columns, scenic_lookup.columns, sn_group_map, scenic_group_map, region=region, neurotransmitter=neurotransmitter
        )
        shared_sn_tobias = shared_columns_by_region_nt(
            sn_lookup.columns, tobias_lookup.columns, sn_group_map, tobias_group_map, region=region, neurotransmitter=neurotransmitter
        )

        region_nt_tobias_scenic = compute_tf_pair_corr(
            adata_left=adata_tobias_com,
            left_lookup=tobias_lookup,
            right_lookup=scenic_lookup,
            shared_columns=shared_tobias_scenic,
            result_prefix='tobias_scenic',
            left_key='var_name',
            right_key='TF_up'
        )

        region_nt_sn_scenic = compute_tf_pair_corr(
            adata_left=adata_sn_com,
            left_lookup=sn_lookup,
            right_lookup=scenic_lookup,
            shared_columns=shared_sn_scenic,
            result_prefix='sn_scenic',
            left_key='TF_up',
            right_key='TF_up'
        )

        region_nt_sn_tobias = compute_tf_pair_corr(
            adata_left=adata_tobias_com,
            left_lookup=tobias_lookup,
            right_lookup=sn_lookup,
            shared_columns=shared_sn_tobias,
            result_prefix='sn_tobias',
            left_key='var_name',
            right_key='TF_up'
        )

        cortmp = region_nt_tobias_scenic.merge(
            region_nt_sn_tobias.drop(columns=['TF_up_original']),
            on=['var_name', 'TF_up'],
            how='left'
        )
        cortmp = cortmp.merge(
            region_nt_sn_scenic.drop(columns=['TF_up_original']),
            on=['TF_up'],
            how='left'
        )
        region_nt_df = cortmp
        region_nt_df['Region'] = region
        region_nt_df['Neurotransmitter'] = neurotransmitter
        region_nt_df = region_nt_df.sort_values(
            ['spearman_r_tobias_scenic', 'spearman_r_sn_scenic', 'spearman_r_sn_tobias'],
            ascending=False
        )
        region_nt_frames.append(region_nt_df)

    df_region_nt_tobias_scenic_corr = pd.concat(region_nt_frames, axis=0, ignore_index=True)

    return {
        'tobias_matrix': tobias_matrix,
        'scenic_matrix': scenic_matrix,
        'sn_matrix': sn_matrix,
        'tobias_lookup': tobias_lookup,
        'scenic_lookup': scenic_lookup,
        'sn_lookup': sn_lookup,
        'df_tobias_scenic_corr': df_tobias_scenic_corr,
        'df_region_tobias_scenic_corr': df_region_tobias_scenic_corr,
        'df_region_nt_tobias_scenic_corr': df_region_nt_tobias_scenic_corr,
        'df_sn_scenic_corr': df_sn_scenic_corr,
        'df_sn_tobias_corr': df_sn_tobias_corr,
        'region_sn_tobias_corr': region_sn_tobias
    }

corr_outputs = compute_region_corr_tables(
    adata_tobias_com=adata_tobias_com,
    adata_scenic_com=adata_scenic_com,
    adata_sn_com=adata_sn_com,
    use_zscore=False
)

tobias_matrix = corr_outputs['tobias_matrix']
scenic_matrix = corr_outputs['scenic_matrix']
sn_matrix = corr_outputs['sn_matrix']
tobias_lookup = corr_outputs['tobias_lookup']
scenic_lookup = corr_outputs['scenic_lookup']
sn_lookup = corr_outputs['sn_lookup']
df_tobias_scenic_corr = corr_outputs['df_tobias_scenic_corr']
df_region_tobias_scenic_corr = corr_outputs['df_region_tobias_scenic_corr']
df_region_nt_tobias_scenic_corr = corr_outputs['df_region_nt_tobias_scenic_corr']
df_sn_scenic_corr = corr_outputs['df_sn_scenic_corr']
df_sn_tobias_corr = corr_outputs['df_sn_tobias_corr']

df_region_nt_tobias_scenic_corr.head()

# %%
df_tobias_scenic_corr.to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_tobias_correlation_all.csv', index=False)

# %%
df_region_tobias_scenic_corr.to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_tobias_correlation_by_region.csv', index=False)

# %%
df_region_nt_tobias_scenic_corr.to_csv(
    '/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_tobias_correlation_by_region_nt.csv',
    index=False
)

# %%
df_region_nt_tobias_scenic_corr

# %%
df_tf_overlap_by_region_nt.merge(
    df_region_nt_tobias_scenic_corr,
    left_on=['Region', 'Neurotransmitter', 'TF'],
    right_on=['Region', 'Neurotransmitter', 'TF_up'],
    how='left').to_csv('/data2st2/junyi/output/stg1028/scenic_wilcoxon_all/scenic_tobias_overlap_correlation_by_region_nt.csv', index=False)

# %%
df_region_tobias_scenic_corr['sig'] = df_region_tobias_scenic_corr['pearson_p_tobias_scenic'] < 0.05

# %%
df_region_tobias_scenic_corr

# %%
df_region_sig= df_region_tobias_scenic_corr[df_region_tobias_scenic_corr['sig']].copy()
df_region_sig[df_region_sig.pearson_r_tobias_scenic>0]

# %%
df_region_sig_summary = (
    df_region_sig.loc[df_region_sig['pearson_r_tobias_scenic'] != 0, ['Region', 'TF_up']]
    .drop_duplicates()
    .groupby('Region')
    .size()
    .rename('n_sig_tf')
    .reset_index()
)

df_region_sig_summary['n_common_tf'] = len(common_TFs)
df_region_sig_summary['pct_common_tf'] = (
    df_region_sig_summary['n_sig_tf'] / df_region_sig_summary['n_common_tf'] * 100
)

fig, ax1 = plt.subplots(figsize=(8, 4.5))
bars = ax1.bar(
    df_region_sig_summary['Region'],
    df_region_sig_summary['n_sig_tf'],
    color='#4C78A8',
    alpha=0.9
 )
ax1.set_xlabel('Region')
ax1.set_ylabel('Number of significant TFs', color='#4C78A8')
ax1.tick_params(axis='y', labelcolor='#4C78A8')

ax2 = ax1.twinx()
ax2.plot(
    df_region_sig_summary['Region'],
    df_region_sig_summary['pct_common_tf'],
    color='#F58518',
    marker='o',
    linewidth=2
 )
ax2.set_ylabel('Percent of common_TFs (%)', color='#F58518')
ax2.tick_params(axis='y', labelcolor='#F58518')

for bar, pct in zip(bars, df_region_sig_summary['pct_common_tf']):
    ax1.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f'{pct:.1f}%',
        ha='center',
        va='bottom',
        fontsize=9
    )

ax1.set_title('Significant TFs by region')
fig.tight_layout()

df_region_sig_summary

# %%
df_region_sig.to_csv('/data2st2/junyi/output/stg1028/scenic_ctxregulon/sig_regulon/region_sig_corr.csv', index=False)

# %%
full_tobias['TF_up'] = full_tobias['name'].str.upper()
full_tobias['TF_up'] = full_tobias['TF_up'].str.split('::')
full_tobias_exp = full_tobias.explode('TF_up').reset_index(drop=True)
full_tobias_exp['TF_up'] = full_tobias_exp['TF_up'].str.strip()

# %%
full_tobias_exp['fname'] = full_tobias_exp['Region'] +"_"+ full_tobias_exp['Subclass']

# %%
df_all_filtered_CUSUS_M = df_all_filtered_CUSUS[df_all_filtered_CUSUS.Sex=='M']

# %%
df_all_filtered_CUSUS_M3R = df_all_filtered_CUSUS_M[df_all_filtered_CUSUS_M.Region.isin(['AMY','PFC','HPF'])]

# %%
df_all_filtered_CUSUS_M3R.drop_duplicates(subset=['TF_up','Direction','fname'])

# %%
len(set(df_all_filtered_CUSUS_M3R.TF_up))

# %%
len(set(full_tobias_exp.TF_up))

# %%
interset_tf = set(df_all_filtered_CUSUS_M3R.TF_up).intersection(set(full_tobias_exp.TF_up))

# %%
len(set(df_all_filtered_CUSUS_M3R.TF_up).intersection(set(full_tobias_exp.TF_up)))

# %%
df_merge_tobias = full_tobias_exp.merge(df_all_filtered_CUSUS_M3R, on=['TF_up','Direction','fname','Region'], how='inner')

# %%
len(set(df_merge_tobias.TF_up))

# %%
df_meta_3Rsusm = df_meta[df_meta['region'].isin(['AMY','PFC','HPF']) & (df_meta['status']=='SUS') & (df_meta['sex']=='M')]

# %%
df_meta_3Rsusm_counts = df_meta_3Rsusm['celltype.L2'].value_counts()

# %%
df_meta_3Rsusm_counts = df_meta_3Rsusm_counts.reset_index()

# %%
df_meta_3Rsusm_counts['fname'] = df_meta_3Rsusm_counts['index']

# %%
df_meta_3Rsusm_counts['fname'] = df_meta_3Rsusm_counts['fname'].replace('/', '-')
df_meta_3Rsusm_counts['fname'] = df_meta_3Rsusm_counts['fname'].str.replace(' ', '_')

# %%
df_meta_3Rsusm

# %%
df_meta_3Rsusm_counts

# %%
# scenic_TF = len(set(df_all_filtered_CUSUS_M3R.TF_up))
# tobias_TF = len(set(full_tobias_exp.TF_up))
# sig_TF = len(set(df_tf_corsig.TF_up))
# venn2(subsets=(scenic_TF - sig_TF, tobias_TF - sig_TF, sig_TF), set_labels=('CUSUS', 'Tobias'))
# plt.title('Overlap of TFs between CUSUS and Tobias')
# plt.show()

# %%
# ven diagram of the overlap between df_merge_tobias.TF_up and df_all_filtered_CUSUS.TF_up
# using number 
# tobias = len(full_tobias_exp.drop_duplicates(subset=['TF_up','Direction','fname']))
# cusus = len((df_all_filtered_CUSUS_M3R.drop_duplicates(subset=['TF_up','Direction','fname'])))
# overlap = len(df_merge_tobias.drop_duplicates(subset=['TF_up','Direction','fname']))
# print(f"Number of TFs in full_tobias_exp: {tobias}")
# print(f"Number of TFs in df_all_filtered_CUSUS: {cusus}")
# print(f"Number of overlapping TFs: {overlap}")
# venn2(subsets=(cusus - overlap, tobias - overlap, overlap), set_labels=('CUSUS', 'Tobias'))
# plt.title('Overlap of TFs between CUSUS and Tobias')
# plt.show()

# %%
def get_celltype_to_nt_mapping():
    if 'dict_celltype_L2_nt' in globals():
        return dict_celltype_L2_nt
    if 'dict_celltype_L2_to_nt' in globals():
        return dict_celltype_L2_to_nt
    if 'dict_l2_nt' in globals():
        return dict_l2_nt
    raise KeyError('No celltype-to-neurotransmitter mapping found in kernel.')

def lookup_to_long(df, value_name, score_type):
    long_df = df.copy()
    long_df['feature_id'] = long_df.index
    long_df = long_df.reset_index(drop=True)
    long_df = long_df.melt(id_vars=['feature_id'], var_name='Re_Sc_St_Se', value_name=value_name)
    long_df['score_type'] = score_type
    if score_type == 'SCENIC':
        long_df['TF_up'] = long_df['feature_id']
    else:
        long_df['TF_up'] = adata_tobias_com.var.loc[long_df['feature_id'], 'TF_up'].values
    return long_df[['TF_up', 'Re_Sc_St_Se', value_name, 'score_type']]

def parse_group_metadata(group_name):
    parts = str(group_name).split('_')
    region = parts[0] if len(parts) >= 1 else np.nan
    sex = parts[-1] if len(parts) >= 1 else np.nan
    status = parts[-2] if len(parts) >= 2 else np.nan
    nt_token = parts[-3] if len(parts) >= 3 else np.nan
    if nt_token in {'GABA', 'Glut', 'NN'} and len(parts) >= 6:
        celltype = '_'.join(parts[2:-3])
        neurotransmitter = nt_token
    else:
        celltype = '_'.join(parts[1:-2]) if len(parts) >= 4 else np.nan
        neurotransmitter = np.nan
    return pd.Series({
        'Region': region,
        'Sex': sex,
        'status': status,
        'celltype': celltype,
        'Neurotransmitter_parsed': neurotransmitter
    })

celltype_to_nt = get_celltype_to_nt_mapping()

region_delta_input = lookup_to_long(tobias_lookup, 'score', 'TOBIAS')
region_delta_scenic = lookup_to_long(scenic_lookup, 'score', 'SCENIC')
region_delta_input = pd.concat([region_delta_input, region_delta_scenic], axis=0, ignore_index=True)

parsed_meta = region_delta_input['Re_Sc_St_Se'].apply(parse_group_metadata)
region_delta_input = pd.concat([region_delta_input, parsed_meta], axis=1)
region_delta_input = region_delta_input[region_delta_input['status'].isin(['CON', 'SUS'])].copy()
region_delta_input['Neurotransmitter'] = region_delta_input['Neurotransmitter_parsed']
region_delta_input.loc[region_delta_input['Neurotransmitter'].isna(), 'Neurotransmitter'] = region_delta_input.loc[
    region_delta_input['Neurotransmitter'].isna(), 'celltype'
].map(celltype_to_nt)
region_delta_input = region_delta_input.dropna(subset=['Neurotransmitter', 'celltype']).copy()

region_delta_wide = (
    region_delta_input
    .pivot_table(
        index=['TF_up', 'Region', 'Neurotransmitter', 'celltype', 'score_type'],
        columns='status',
        values='score'
    )
    .reset_index()
    .dropna(subset=['CON', 'SUS'])
)
region_delta_wide['delta_sus_con'] = region_delta_wide['SUS'] - region_delta_wide['CON']

scenic_delta = (
    region_delta_wide[region_delta_wide['score_type'] == 'SCENIC']
    .loc[:, ['TF_up', 'Region', 'Neurotransmitter', 'celltype', 'delta_sus_con']]
    .rename(columns={'delta_sus_con': 'SCENIC'})
)
tobias_delta = (
    region_delta_wide[region_delta_wide['score_type'] == 'TOBIAS']
    .loc[:, ['TF_up', 'Region', 'Neurotransmitter', 'celltype', 'delta_sus_con']]
    .rename(columns={'delta_sus_con': 'TOBIAS'})
)
region_delta_compare = scenic_delta.merge(
    tobias_delta,
    on=['TF_up', 'Region', 'Neurotransmitter', 'celltype'],
    how='inner'
 )

region_delta_rows = []
for (region, neurotransmitter, tf_up), df_group in region_delta_compare.groupby(['Region', 'Neurotransmitter', 'TF_up']):
    n_celltypes = df_group['celltype'].nunique()
    if n_celltypes < 2:
        continue

    scenic_values = df_group['SCENIC'].astype(float)
    tobias_values = df_group['TOBIAS'].astype(float)

    pearson_r, pearson_p = pearsonr(scenic_values, tobias_values)
    spearman_r, spearman_p = spearmanr(scenic_values, tobias_values)
    sign_match_rate = (np.sign(scenic_values) == np.sign(tobias_values)).mean()

    region_delta_rows.append({
        'Region': region,
        'Neurotransmitter': neurotransmitter,
        'TF_up': tf_up,
        'n_celltypes': n_celltypes,
        'pearson_r_delta': pearson_r,
        'pearson_p_delta': pearson_p,
        'spearman_r_delta': spearman_r,
        'spearman_p_delta': spearman_p,
        'sign_match_rate': sign_match_rate,
        'mean_abs_delta_scenic': scenic_values.abs().mean(),
        'mean_abs_delta_tobias': tobias_values.abs().mean()
    })

df_region_nt_delta_consistency = pd.DataFrame(region_delta_rows)
if df_region_nt_delta_consistency.empty:
    top_tf_region_nt_delta = pd.DataFrame(columns=[
        'Region', 'Neurotransmitter', 'TF_up', 'n_celltypes', 'pearson_r_delta', 'pearson_p_delta',
        'spearman_r_delta', 'spearman_p_delta', 'sign_match_rate', 'mean_abs_delta_scenic', 'mean_abs_delta_tobias'
    ])
else:
    df_region_nt_delta_consistency = df_region_nt_delta_consistency.sort_values(
        ['Region', 'Neurotransmitter', 'sign_match_rate', 'spearman_r_delta', 'pearson_r_delta', 'mean_abs_delta_scenic'],
        ascending=[True, True, False, False, False, False]
    ).reset_index(drop=True)
    top_tf_region_nt_delta = (
        df_region_nt_delta_consistency
        .groupby(['Region', 'Neurotransmitter'], group_keys=False)
        .apply(lambda x: x.nlargest(10, ['sign_match_rate', 'spearman_r_delta', 'pearson_r_delta', 'mean_abs_delta_scenic']))
        .reset_index(drop=True)
    )

top_tf_region_nt_delta

# %%
top_tf_overlap_by_region_nt

# %%
region_order_plot = [region for region in ['AMY', 'HPF', 'PFC'] if region in top_tf_overlap_by_region_nt['Region'].unique()]
nt_order_plot = [nt for nt in ['GABA', 'Glut', 'NN'] if nt in top_tf_overlap_by_region_nt['Neurotransmitter'].unique()]
tobias_var_map = adata_tobias_com.var[['TF_up']].copy()

for region in region_order_plot:
    for neurotransmitter in nt_order_plot:
        tf_order = (
            top_tf_overlap_by_region_nt[
                (top_tf_overlap_by_region_nt['Region'] == region)
                & (top_tf_overlap_by_region_nt['Neurotransmitter'] == neurotransmitter)
            ]
            .sort_values(
                ['n_overlap_pairs', 'n_matching_pairs', 'n_up', 'n_down', 'n_ns', 'matching_rate', 'TF'],
                ascending=[False, False, False, False, False, False, True]
            )
            ['TF']
            .drop_duplicates()
            .head(10)
            .tolist()
        )
        if not tf_order:
            continue

        scenic_region_cols = [col for col in scenic_lookup.columns if str(col).startswith(f'{region}_')]
        tobias_region_cols = [col for col in tobias_lookup.columns if str(col).startswith(f'{region}_')]

        plot_scenic_region = scenic_lookup.loc[scenic_lookup.index.intersection(tf_order), scenic_region_cols].copy()
        plot_scenic_region['feature_id'] = plot_scenic_region.index
        plot_scenic_region = plot_scenic_region.reset_index(drop=True).melt(
            id_vars=['feature_id'],
            var_name='Re_Sc_St_Se',
            value_name='score'
        )
        plot_scenic_region['TF'] = plot_scenic_region['feature_id']
        plot_scenic_region['score_type'] = 'SCENIC'

        tobias_var_keep = tobias_var_map[tobias_var_map['TF_up'].isin(tf_order)].index
        plot_tobias_region = tobias_lookup.loc[tobias_var_keep, tobias_region_cols].copy()
        plot_tobias_region['feature_id'] = plot_tobias_region.index
        plot_tobias_region = plot_tobias_region.reset_index(drop=True).melt(
            id_vars=['feature_id'],
            var_name='Re_Sc_St_Se',
            value_name='score'
        )
        plot_tobias_region['TF'] = adata_tobias_com.var.loc[plot_tobias_region['feature_id'], 'TF_up'].values
        plot_tobias_region['score_type'] = 'TOBIAS'

        df_region_nt_plot = pd.concat([plot_scenic_region, plot_tobias_region], axis=0, ignore_index=True)
        parsed_meta = df_region_nt_plot['Re_Sc_St_Se'].apply(parse_group_metadata)
        df_region_nt_plot = pd.concat([df_region_nt_plot, parsed_meta], axis=1)
        df_region_nt_plot = df_region_nt_plot[df_region_nt_plot['status'].isin(['CON', 'SUS'])].copy()
        df_region_nt_plot['Neurotransmitter'] = df_region_nt_plot['Neurotransmitter_parsed']
        df_region_nt_plot.loc[df_region_nt_plot['Neurotransmitter'].isna(), 'Neurotransmitter'] = df_region_nt_plot.loc[
            df_region_nt_plot['Neurotransmitter'].isna(), 'celltype'
        ].map(celltype_to_nt)
        df_region_nt_plot = df_region_nt_plot[
            (df_region_nt_plot['Region'] == region)
            & (df_region_nt_plot['Neurotransmitter'] == neurotransmitter)
            & (df_region_nt_plot['Sex'] == 'M')
            & (df_region_nt_plot['TF'].isin(tf_order))
        ].copy()
        if df_region_nt_plot.empty:
            continue

        df_region_nt_plot['TF'] = pd.Categorical(df_region_nt_plot['TF'], categories=tf_order, ordered=True)
        df_region_nt_plot['status'] = pd.Categorical(df_region_nt_plot['status'], categories=['CON', 'SUS'], ordered=True)
        df_region_nt_plot['score_type'] = pd.Categorical(df_region_nt_plot['score_type'], categories=['SCENIC', 'TOBIAS'], ordered=True)

        g = sns.catplot(
            data=df_region_nt_plot,
            x='TF',
            y='score',
            hue='status',
            col='score_type',
            kind='bar',
            order=tf_order,
            hue_order=['CON', 'SUS'],
            height=4.2,
            aspect=1.4,
            sharey=False
        )
        g.set_titles(f'{region} | {neurotransmitter} | {{col_name}}')
        g.set_axis_labels('TF', 'Score')
        for ax in g.axes.flat:
            ax.tick_params(axis='x', rotation=45, labelsize=9)
        g.fig.suptitle(f'{region} {neurotransmitter}: top 10 overlap TFs', y=1.04)
        g.fig.tight_layout()
        plt.show()

# %%
output_dir = os.path.join(os.getcwd(), 'figures', 'top_tf_overlap_by_region_nt_per_tf')
os.makedirs(output_dir, exist_ok=True)

tobias_var_map = adata_tobias_com.var[['TF_up']].copy()
region_order_plot = [region for region in ['AMY', 'HPF', 'PFC'] if region in top_tf_overlap_by_region_nt['Region'].unique()]
nt_order_plot = [nt for nt in ['GABA', 'Glut', 'NN'] if nt in top_tf_overlap_by_region_nt['Neurotransmitter'].unique()]

for region in region_order_plot:
    scenic_region_cols = [col for col in scenic_lookup.columns if str(col).startswith(f'{region}_')]
    tobias_region_cols = [col for col in tobias_lookup.columns if str(col).startswith(f'{region}_')]

    for neurotransmitter in nt_order_plot:
        tf_list = (
            top_tf_overlap_by_region_nt[
                (top_tf_overlap_by_region_nt['Region'] == region)
                & (top_tf_overlap_by_region_nt['Neurotransmitter'] == neurotransmitter)
            ]
            ['TF']
            .drop_duplicates()
            .tolist()
        )
        if not tf_list:
            continue

        for tf_name in tf_list:
            plot_scenic_region = scenic_lookup.loc[scenic_lookup.index.intersection([tf_name]), scenic_region_cols].copy()
            if plot_scenic_region.empty:
                continue
            plot_scenic_region['feature_id'] = plot_scenic_region.index
            plot_scenic_region = plot_scenic_region.reset_index(drop=True).melt(
                id_vars=['feature_id'],
                var_name='Re_Sc_St_Se',
                value_name='score'
            )
            plot_scenic_region['TF'] = plot_scenic_region['feature_id']
            plot_scenic_region['score_type'] = 'SCENIC'

            tobias_var_keep = tobias_var_map[tobias_var_map['TF_up'].eq(tf_name)].index
            plot_tobias_region = tobias_lookup.loc[tobias_var_keep, tobias_region_cols].copy()
            if plot_tobias_region.empty:
                continue
            plot_tobias_region['feature_id'] = plot_tobias_region.index
            plot_tobias_region = plot_tobias_region.reset_index(drop=True).melt(
                id_vars=['feature_id'],
                var_name='Re_Sc_St_Se',
                value_name='score'
            )
            plot_tobias_region['TF'] = adata_tobias_com.var.loc[plot_tobias_region['feature_id'], 'TF_up'].values
            plot_tobias_region['score_type'] = 'TOBIAS'

            df_tf_plot = pd.concat([plot_scenic_region, plot_tobias_region], axis=0, ignore_index=True)
            parsed_meta = df_tf_plot['Re_Sc_St_Se'].apply(parse_group_metadata)
            df_tf_plot = pd.concat([df_tf_plot, parsed_meta], axis=1)
            df_tf_plot = df_tf_plot[df_tf_plot['status'].isin(['CON', 'SUS'])].copy()
            df_tf_plot['Neurotransmitter'] = df_tf_plot['Neurotransmitter_parsed']
            df_tf_plot.loc[df_tf_plot['Neurotransmitter'].isna(), 'Neurotransmitter'] = df_tf_plot.loc[
                df_tf_plot['Neurotransmitter'].isna(), 'celltype'
            ].map(celltype_to_nt)
            df_tf_plot = df_tf_plot[
                (df_tf_plot['Region'] == region)
                & (df_tf_plot['Neurotransmitter'] == neurotransmitter)
                & (df_tf_plot['TF'] == tf_name)
            ].copy()
            if df_tf_plot.empty:
                continue

            df_tf_plot = (
                df_tf_plot
                .groupby(['celltype', 'score_type', 'status'], as_index=False)['score']
                .mean()
            )
            ct_order = sorted(df_tf_plot['celltype'].dropna().unique().tolist())
            if not ct_order:
                continue

            df_tf_plot['celltype'] = pd.Categorical(df_tf_plot['celltype'], categories=ct_order, ordered=True)
            df_tf_plot['status'] = pd.Categorical(df_tf_plot['status'], categories=['CON', 'SUS'], ordered=True)
            df_tf_plot['score_type'] = pd.Categorical(df_tf_plot['score_type'], categories=['SCENIC', 'TOBIAS'], ordered=True)

            fig, axes = plt.subplots(1, 2, figsize=(max(10, len(ct_order) * 0.9), 4.8), sharey=False)
            for ax, score_type in zip(axes, ['SCENIC', 'TOBIAS']):
                sns.barplot(
                    data=df_tf_plot[df_tf_plot['score_type'] == score_type],
                    x='celltype',
                    y='score',
                    hue='status',
                    order=ct_order,
                    hue_order=['CON', 'SUS'],
                    ax=ax
                )
                ax.set_title(score_type)
                ax.set_xlabel('ctname')
                ax.set_ylabel('Score')
                ax.tick_params(axis='x', rotation=45, labelsize=9)
            fig.suptitle(f'{region} | {neurotransmitter} | {tf_name}', y=1.02)
            fig.tight_layout()

            output_path = os.path.join(output_dir, f'{region}_{neurotransmitter}_{tf_name}_scores.png')
            fig.savefig(output_path, dpi=200, bbox_inches='tight')
            plt.show()
            plt.close(fig)

print(output_dir)

# %%
pearson_top_tf_region_nt_delta = (
    df_region_nt_delta_consistency
    .sort_values(
        ['Region', 'Neurotransmitter', 'pearson_r_delta', 'sign_match_rate', 'spearman_r_delta', 'mean_abs_delta_scenic'],
        ascending=[True, True, False, False, False, False]
    )
    .groupby(['Region', 'Neurotransmitter'], group_keys=False)
    .head(10)
    .reset_index(drop=True)
 )

region_order_plot = [region for region in ['AMY', 'HPF', 'PFC'] if region in pearson_top_tf_region_nt_delta['Region'].unique()]
nt_order_plot = [nt for nt in ['GABA', 'Glut', 'NN'] if nt in pearson_top_tf_region_nt_delta['Neurotransmitter'].unique()]
tobias_var_map = adata_tobias_com.var[['TF_up']].copy()

for region in region_order_plot:
    for neurotransmitter in nt_order_plot:
        tf_order = (
            pearson_top_tf_region_nt_delta[
                (pearson_top_tf_region_nt_delta['Region'] == region)
                & (pearson_top_tf_region_nt_delta['Neurotransmitter'] == neurotransmitter)
            ]
            .sort_values(
                ['pearson_r_delta', 'sign_match_rate', 'spearman_r_delta', 'mean_abs_delta_scenic', 'TF_up'],
                ascending=[False, False, False, False, True]
            )
            ['TF_up']
            .drop_duplicates()
            .head(10)
            .tolist()
        )
        if not tf_order:
            continue

        scenic_region_cols = [col for col in scenic_lookup.columns if str(col).startswith(f'{region}_')]
        tobias_region_cols = [col for col in tobias_lookup.columns if str(col).startswith(f'{region}_')]

        plot_scenic_region = scenic_lookup.loc[scenic_lookup.index.intersection(tf_order), scenic_region_cols].copy()
        plot_scenic_region['feature_id'] = plot_scenic_region.index
        plot_scenic_region = plot_scenic_region.reset_index(drop=True).melt(
            id_vars=['feature_id'],
            var_name='Re_Sc_St_Se',
            value_name='score'
        )
        plot_scenic_region['TF'] = plot_scenic_region['feature_id']
        plot_scenic_region['score_type'] = 'SCENIC'

        tobias_var_keep = tobias_var_map[tobias_var_map['TF_up'].isin(tf_order)].index
        plot_tobias_region = tobias_lookup.loc[tobias_var_keep, tobias_region_cols].copy()
        plot_tobias_region['feature_id'] = plot_tobias_region.index
        plot_tobias_region = plot_tobias_region.reset_index(drop=True).melt(
            id_vars=['feature_id'],
            var_name='Re_Sc_St_Se',
            value_name='score'
        )
        plot_tobias_region['TF'] = adata_tobias_com.var.loc[plot_tobias_region['feature_id'], 'TF_up'].values
        plot_tobias_region['score_type'] = 'TOBIAS'

        df_region_nt_plot = pd.concat([plot_scenic_region, plot_tobias_region], axis=0, ignore_index=True)
        parsed_meta = df_region_nt_plot['Re_Sc_St_Se'].apply(parse_group_metadata)
        df_region_nt_plot = pd.concat([df_region_nt_plot, parsed_meta], axis=1)
        df_region_nt_plot = df_region_nt_plot[df_region_nt_plot['status'].isin(['CON', 'SUS'])].copy()
        df_region_nt_plot['Neurotransmitter'] = df_region_nt_plot['Neurotransmitter_parsed']
        df_region_nt_plot.loc[df_region_nt_plot['Neurotransmitter'].isna(), 'Neurotransmitter'] = df_region_nt_plot.loc[
            df_region_nt_plot['Neurotransmitter'].isna(), 'celltype'
        ].map(celltype_to_nt)
        df_region_nt_plot = df_region_nt_plot[
            (df_region_nt_plot['Region'] == region)
            & (df_region_nt_plot['Neurotransmitter'] == neurotransmitter)
            & (df_region_nt_plot['Sex'] == 'M')
            & (df_region_nt_plot['TF'].isin(tf_order))
        ].copy()
        if df_region_nt_plot.empty:
            continue

        df_region_nt_plot['TF'] = pd.Categorical(df_region_nt_plot['TF'], categories=tf_order, ordered=True)
        df_region_nt_plot['status'] = pd.Categorical(df_region_nt_plot['status'], categories=['CON', 'SUS'], ordered=True)
        df_region_nt_plot['score_type'] = pd.Categorical(df_region_nt_plot['score_type'], categories=['SCENIC', 'TOBIAS'], ordered=True)

        g = sns.catplot(
            data=df_region_nt_plot,
            x='TF',
            y='score',
            hue='status',
            col='score_type',
            kind='bar',
            order=tf_order,
            hue_order=['CON', 'SUS'],
            height=4.2,
            aspect=1.4,
            sharey=False
        )
        g.set_titles(f'{region} | {neurotransmitter} | {{col_name}}')
        g.set_axis_labels('TF', 'Score')
        for ax in g.axes.flat:
            ax.tick_params(axis='x', rotation=45, labelsize=9)
        g.fig.suptitle(f'{region} {neurotransmitter}: top 10 TFs by pearson delta', y=1.04)
        g.fig.tight_layout()
        plt.show()

# %%
df_merge_tobias_sig = df_merge_tobias[df_merge_tobias.TF_up.isin(df_region_sig.TF_up)].copy()

# %%
df_merge_tobias

# %%
df_merge_tobias_sig.to_csv('/data2st1/junyi/output/atac1112/tobias/tobias_scenic_corsig_overlap.csv', index=False)

# %%
df_merge_tobias.to_csv('/data2st1/junyi/output/atac1112/tobias/tobias_CUSUS_overlap.csv', index=False)

# %%
df_merge_tobias

# %%
test_region_delta_input = pd.concat([
    lookup_to_long(tobias_lookup, 'score', 'TOBIAS'),
    lookup_to_long(scenic_lookup, 'score', 'SCENIC')
], axis=0, ignore_index=True)
test_split_parts = test_region_delta_input['Re_Sc_St_Se'].str.split('_')
test_region_delta_input['Region'] = test_split_parts.str[0]
test_region_delta_input['Sex'] = test_split_parts.str[-1]
test_region_delta_input['status'] = test_split_parts.str[-2]
test_region_delta_input['celltype'] = test_split_parts.str[1:-2].apply(lambda x: '_'.join(x) if isinstance(x, list) else np.nan)
test_region_delta_input['Neurotransmitter'] = test_region_delta_input['celltype'].map(celltype_to_nt)
test_region_delta_input = test_region_delta_input[test_region_delta_input['status'].isin(['CON', 'SUS'])].dropna(subset=['Neurotransmitter']).copy()
print(test_region_delta_input['score_type'].value_counts(dropna=False))
display(test_region_delta_input.groupby(['score_type', 'Region', 'Neurotransmitter'])['celltype'].nunique().reset_index().head(20))

# %%
df_merge_tobias_plot = df_merge_tobias.copy()
df_merge_tobias_plot['nlogp'] = df_merge_tobias_plot['nlogp_x']
df_merge_tobias_plot['TF'] = df_merge_tobias_plot['TF_up'] if 'TF_up' in df_merge_tobias_plot.columns else df_merge_tobias_plot['name'].str.upper()
df_merge_tobias_plot['Region subclass'] = (
    df_merge_tobias_plot['Region'].astype(str) + '_' + df_merge_tobias_plot['Subclass'].astype(str)
    if {'Region', 'Subclass'}.issubset(df_merge_tobias_plot.columns)
    else df_merge_tobias_plot['fname'].astype(str)
 )
if 'Neurotransmitter' not in df_merge_tobias_plot.columns:
    df_merge_tobias_plot['Neurotransmitter'] = df_merge_tobias_plot['Neurotransmitter_y']
if 'Sex' not in df_merge_tobias_plot.columns:
    if 'fname' in df_merge_tobias_plot.columns:
        df_merge_tobias_plot['Sex'] = 'M'
    else:
        df_merge_tobias_plot['Sex'] = 'NA'
df_merge_tobias_plot_N = df_merge_tobias_plot[df_merge_tobias_plot['Neurotransmitter']!='NN']
df_merge_tobias_plot_NN = df_merge_tobias_plot[df_merge_tobias_plot['Neurotransmitter']=='NN']
plot_heatmap(
    df_merge_tobias_plot_N[['TF', 'Region subclass', 'nlogp', 'Region', 'Neurotransmitter', 'Sex']].dropna(subset=['TF', 'Region subclass', 'nlogp', 'Region']),
    col_split='Region',
    row_cluster=True,
    fig_size=(8, 30),
    clip=(-50, 50),
    pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/tobias_overlap_CUSUS_N_heatmap.pdf'
 )

# %%
df_merge_tobias_plot = df_all_filtered_CUSUS_M3R.copy()
df_merge_tobias_plot['nlogp'] = df_merge_tobias_plot['nlogp']
df_merge_tobias_plot['TF'] = df_merge_tobias_plot['TF_up'] if 'TF_up' in df_merge_tobias_plot.columns else df_merge_tobias_plot['name'].str.upper()
df_merge_tobias_plot= df_merge_tobias_plot[df_merge_tobias_plot['TF_up'].isin(df_tf_corsig.TF_up)]
df_merge_tobias_plot['Region subclass'] = (
    df_merge_tobias_plot['Region'].astype(str) + '_' + df_merge_tobias_plot['Subclass'].astype(str)
    if {'Region', 'Subclass'}.issubset(df_merge_tobias_plot.columns)
    else df_merge_tobias_plot['fname'].astype(str)
 )
if 'Neurotransmitter' not in df_merge_tobias_plot.columns:
    df_merge_tobias_plot['Neurotransmitter'] = df_merge_tobias_plot['Neurotransmitter_y']
if 'Sex' not in df_merge_tobias_plot.columns:
    if 'fname' in df_merge_tobias_plot.columns:
        df_merge_tobias_plot['Sex'] = 'M'
    else:
        df_merge_tobias_plot['Sex'] = 'NA'
df_merge_tobias_plot_N = df_merge_tobias_plot[df_merge_tobias_plot['Neurotransmitter']!='NN']
df_merge_tobias_plot_NN = df_merge_tobias_plot[df_merge_tobias_plot['Neurotransmitter']=='NN']
plot_heatmap(
    df_merge_tobias_plot_N[['TF', 'Region subclass', 'nlogp', 'Region', 'Neurotransmitter', 'Sex']].dropna(subset=['TF', 'Region subclass', 'nlogp', 'Region']),
    col_split='Region',
    row_cluster=True,
    fig_size=(8, 15),
    clip=(-5, 5),
    pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/tobias_overlap_CUSUS_N_heatmap.pdf'
 )

# %%
df_merge_tobias_plot = full_tobias_exp.copy()
df_merge_tobias_plot['nlogp'] = df_merge_tobias_plot['nlogp']
df_merge_tobias_plot['TF'] = df_merge_tobias_plot['TF_up'] if 'TF_up' in df_merge_tobias_plot.columns else df_merge_tobias_plot['name'].str.upper()
df_merge_tobias_plot= df_merge_tobias_plot[df_merge_tobias_plot['TF_up'].isin(df_tf_corsig.TF_up)]
df_merge_tobias_plot['Region subclass'] = (
    df_merge_tobias_plot['Region'].astype(str) + '_' + df_merge_tobias_plot['Subclass'].astype(str)
    if {'Region', 'Subclass'}.issubset(df_merge_tobias_plot.columns)
    else df_merge_tobias_plot['fname'].astype(str)
 )
if 'Neurotransmitter' not in df_merge_tobias_plot.columns:
    df_merge_tobias_plot['Neurotransmitter'] = df_merge_tobias_plot['Neurotransmitter_y']
if 'Sex' not in df_merge_tobias_plot.columns:
    if 'fname' in df_merge_tobias_plot.columns:
        df_merge_tobias_plot['Sex'] = 'M'
    else:
        df_merge_tobias_plot['Sex'] = 'NA'
df_merge_tobias_plot_N = df_merge_tobias_plot[df_merge_tobias_plot['Neurotransmitter']!='NN']
df_merge_tobias_plot_NN = df_merge_tobias_plot[df_merge_tobias_plot['Neurotransmitter']=='NN']
plot_heatmap(
    df_merge_tobias_plot_N[['TF', 'Region subclass', 'nlogp', 'Region', 'Neurotransmitter', 'Sex']].dropna(subset=['TF', 'Region subclass', 'nlogp', 'Region']),
    col_split='Region',
    row_cluster=True,
    fig_size=(8, 15),
    clip=(-300, 300),
    pdf_file='/data2st2/junyi/output/stg1028/CUMS_4VN/scenicwil_tfs_fdr_log2fc0/tobias_overlap_CUSUS_N_heatmap.pdf'
 )

# %%
df_merge_tobias_plot_NN['Sex'] = 'M'

# %%
df_meta_match = df_meta.drop_duplicates(subset=['celltype.L1', 'celltype.L2'])

# %%
df_meta_match = df_meta_match.dropna(subset=['celltype.L1'])

# %%
dict_NNL1 = dict(zip(df_meta_match['celltype.L2'], df_meta_match['celltype.L1']))

# %%
df_merge_tobias_plot_NN

# %%
df_merge_tobias_plot_NN['Neurotransmitter'] = df_merge_tobias_plot_NN['Subclass'].map(dict_NNL1)

# %%
plot_heatmap(
    df_merge_tobias_plot_NN[['TF', 'Region subclass', 'nlogp', 'Region', 'Neurotransmitter', 'Sex']].dropna(subset=['TF', 'Region subclass', 'nlogp', 'Region']),
    col_split='Region',
    row_cluster=False,
    fig_size=(8, 30)
 )

# %%
df_counts  = df_merge_tobias_plot.groupby(['Region', 'TF']).size().reset_index(name='count')

# %%
df_counts

# %%
df_top5 = (df_counts
           .groupby('Region')
           .apply(lambda x: x.nlargest(10, 'count'))
           .reset_index(drop=True))

# %%
df_meta_match['celltype'] = df_meta_match['celltype.L2'].str.replace('/', '-').str.replace(' ', '_')

# %%
df_meta_match

# %%
corsig_head = set(df_top5.TF)

# %%
tf_keep = sorted(df_tf_corsig['TF_up'].dropna().unique())

plot_tobias_bar = tobias_long[tobias_long['TF_up'].isin(tf_keep)].copy()
plot_tobias_bar = plot_tobias_bar[['TF_up', 'Re_Sc_St_Se', 'tobias_score']]
plot_tobias_bar['score_type'] = 'TOBIAS'
plot_tobias_bar = plot_tobias_bar.rename(columns={'tobias_score': 'score'})

plot_scenic_bar = scenic_long[scenic_long['TF_up'].isin(tf_keep)].copy()
plot_scenic_bar['score_type'] = 'SCENIC'
plot_scenic_bar = plot_scenic_bar.rename(columns={'scenic_score': 'score'})

plot_sn_bar = sn_long[sn_long['TF_up'].isin(tf_keep)].copy()
plot_sn_bar['score_type'] = 'SN'
plot_sn_bar = plot_sn_bar.rename(columns={'sn_score': 'score'})
plot_bar = pd.concat([plot_tobias_bar, plot_scenic_bar, plot_sn_bar], axis=0, ignore_index=True)
split_parts = plot_bar['Re_Sc_St_Se'].str.split('_')
plot_bar['Region'] = split_parts.str[0]
plot_bar['Sex'] = split_parts.str[-1]
plot_bar['status'] = split_parts.str[-2]
plot_bar['celltype'] = split_parts.str[1:-2].apply(lambda x: '_'.join(x) if isinstance(x, list) else np.nan)
plot_bar = plot_bar[plot_bar['status'].isin(['CON', 'SUS'])].copy()
plot_bar['status'] = pd.Categorical(plot_bar['status'], categories=['CON', 'SUS'], ordered=True)
plot_bar['score_type'] = pd.Categorical(plot_bar['score_type'], categories=['SCENIC', 'TOBIAS', 'SN'], ordered=True)

# %%
region_order_plot = [region for region in ['AMY', 'HPF', 'PFC'] if region in plot_bar['Region'].unique()]
for region in region_order_plot:
    df_region_plot = plot_bar[plot_bar['Region'] == region].copy()
    df_region_plot = df_region_plot[df_region_plot['TF_up'].isin(corsig_head)]
    df_region_plot = df_region_plot[df_region_plot['score_type'] != 'SN']
    df_region_plot['Neurotransmitter'] = df_region_plot['celltype'].map(dict_celltype_L2_nt)
    df_region_plot['Neurotransmitter'] = df_region_plot['celltype'].map(dict_celltype_L2_nt)
    df_region_plot = df_region_plot[df_region_plot['Neurotransmitter']!='NN']
    df_region_plot['score_type'] = df_region_plot['score_type'].cat.remove_unused_categories()
    g = sns.catplot(
        data=df_region_plot,
        x='TF_up',
        y='score',
        hue='status',
        col='score_type',
        kind='bar',
        order=sorted(df_region_plot['TF_up'].unique()),
        hue_order=['CON', 'SUS'],
        height=4.5,
        aspect=1.4,
        sharey=False
    )
    g.set_titles('{col_name}')
    g.set_axis_labels('TF', 'Score')
    for ax in g.axes.flat:
        ax.tick_params(axis='x', rotation=90, labelsize=7)
    g.fig.suptitle(f'{region}: SCENIC / TOBIAS / SN scores in CON vs SUS', y=1.05)
    plt.tight_layout()
    plt.show()

# %%
regions = sorted(df_top5['Region'].dropna().unique())
n_regions = len(regions)
ncols = min(3, n_regions) if n_regions else 1
nrows = (n_regions + ncols - 1) // ncols

fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(6 * ncols, 4.5 * nrows),
    constrained_layout=True
 )
if hasattr(axes, 'flatten'):
    axes = axes.flatten()
else:
    axes = [axes]

for ax, region in zip(axes, regions):
    plot_df = (
        df_top5[df_top5['Region'] == region]
        .sort_values('count', ascending=False)
    )
    sns.barplot(
        data=plot_df,
        x='TF',
        y='count',
        color='C0',
        ax=ax
    )
    ax.set_title(region)
    ax.set_xlabel('TF')
    ax.set_ylabel('count')
    ax.tick_params(axis='x', rotation=90)

for ax in axes[n_regions:]:
    ax.set_visible(False)

plt.show()

# %%
set(df_top5.TF)

# %%
# Calculate the regulon for each TF that are significant

# %%
nts = ['Glut','GABA','Sero','Dopa','Chol','Hist']

# %%
def plot_region_tf_group_bubble(
    data,
    region_col='Region',
    group_col='Group',
    tf_col='TF',
    color_col='jaccard',
    size_col='intersection_size',
    aggregate=True,
    aggfunc='mean',
    nrows=2,
    ncols=4,
    min_bubble_size=24,
    max_bubble_size=220,
    figsize=None,
    title='Bubble Plot by Region',
    cmap='Reds',
    save_path=None
):
    plot_df = data.copy()

    required_cols = [region_col, group_col, tf_col, color_col, size_col]
    missing_cols = [col for col in required_cols if col not in plot_df.columns]
    if missing_cols:
        raise ValueError(f'Missing required columns: {missing_cols}')

    if aggregate:
        plot_df = (
            plot_df
            .groupby([region_col, group_col, tf_col], as_index=False)[[color_col, size_col]]
            .agg(aggfunc)
        )

    plot_df = plot_df.sort_values(
        [region_col, group_col, color_col, size_col, tf_col],
        ascending=[True, True, False, False, True]
    ).reset_index(drop=True)

    regions = sorted(plot_df[region_col].dropna().unique())
    tf_order = list(plot_df.groupby(tf_col)[color_col].mean().sort_values(ascending=False).index)
    group_order = list(plot_df.groupby(group_col)[color_col].mean().sort_values(ascending=False).index)

    plot_df[tf_col] = pd.Categorical(plot_df[tf_col], categories=tf_order, ordered=True)
    plot_df[group_col] = pd.Categorical(plot_df[group_col], categories=group_order, ordered=True)
    plot_df = plot_df.sort_values([region_col, group_col, tf_col])

    color_min = plot_df[color_col].min()
    color_max = plot_df[color_col].max()
    size_min = plot_df[size_col].min()
    size_max = plot_df[size_col].max()

    def scale_sizes(values):
        values = np.asarray(values, dtype=float)
        if size_min == size_max:
            return np.full(values.shape, (min_bubble_size + max_bubble_size) / 2)
        return min_bubble_size + (values - size_min) / (size_max - size_min) * (max_bubble_size - min_bubble_size)

    if figsize is None:
        figsize = (
            max(12, ncols * len(tf_order) * 0.42),
            max(5.8, nrows * len(group_order) * 0.55)
        )

    fig, axes = plt.subplots(
        nrows=nrows,
        ncols=ncols,
        sharex=True,
        sharey=True,
        figsize=figsize,
        squeeze=False
    )
    axes_flat = axes.flatten()

    scatter = None
    for idx, ax in enumerate(axes_flat):
        if idx >= len(regions):
            ax.axis('off')
            continue

        region = regions[idx]
        region_df = plot_df[plot_df[region_col] == region].copy()
        x_values = region_df[tf_col].cat.codes
        y_values = region_df[group_col].cat.codes
        scatter = ax.scatter(
            x_values,
            y_values,
            c=region_df[color_col],
            s=scale_sizes(region_df[size_col]),
            cmap=cmap,
            vmin=color_min,
            vmax=color_max,
            edgecolors='black',
            linewidths=0.3,
            alpha=0.9
        )
        ax.set_title(region, pad=5)
        ax.set_xticks(range(len(tf_order)))
        ax.set_yticks(range(len(group_order)))

        row_idx, col_idx = divmod(idx, ncols)
        if row_idx == nrows - 1:
            ax.set_xticklabels(tf_order, rotation=90, fontsize=8)
            ax.set_xlabel(tf_col)
        else:
            ax.tick_params(axis='x', labelbottom=False)

        if col_idx == 0:
            ax.set_yticklabels(group_order, fontsize=9)
            ax.set_ylabel(group_col)
        else:
            ax.tick_params(axis='y', labelleft=False)
            ax.set_ylabel('')

        ax.grid(axis='x', linestyle=':', alpha=0.2)
        ax.grid(axis='y', linestyle=':', alpha=0.2)
        ax.tick_params(axis='x', pad=1)

    colorbar = fig.colorbar(scatter, ax=axes, fraction=0.016, pad=0.01)
    colorbar.set_label(color_col)

    size_levels = sorted(set([size_min, np.median(plot_df[size_col]), size_max]))
    size_handles = [
        plt.scatter([], [], s=scale_sizes([value])[0], facecolor='gray', edgecolor='black', linewidth=0.3)
        for value in size_levels
    ]
    fig.legend(
        size_handles,
        [str(int(value)) if float(value).is_integer() else f'{value:.1f}' for value in size_levels],
        title=size_col,
        bbox_to_anchor=(0.995, 0.98),
        loc='upper right',
        frameon=True,
        borderaxespad=0.2,
        fontsize=8,
        title_fontsize=9
    )
    fig.suptitle(title, y=0.98)
    fig.subplots_adjust(left=0.07, right=0.9, top=0.88, bottom=0.2, wspace=0.06, hspace=0.18)

    if save_path is not None:
        plt.savefig(save_path, bbox_inches='tight')
    plt.show()

# %%
def get_group_ovlp(outputdir,df_NT,group_col='Group',tf_col='TF',ctx_glob='/data2st2/junyi/output/stg1028/scenic_ctxregulon/*_tf_DEG_sets.csv'):

    output_nt_dir = outputdir
    os.path.exists(output_nt_dir) or os.makedirs(output_nt_dir)
    df_NT_jaccard = pd.DataFrame()
    df_sig_tfs= glob.glob(ctx_glob)
    #print(f"Found {len(df_sig_tfs)} files matching the pattern.")
    for file_gs in df_sig_tfs:
        #print(f"Processing file: {file_gs}")
        try:
            df_tf_list_sig = pd.read_csv(file_gs)
        except Exception as e:
            print(f"Error reading file {file_gs}: {e}")
            continue
        
        if len(df_tf_list_sig) == 0:
            print(f"Warning: No significant TFs found in file {file_gs}")
            continue
        # df_tf=df_tf.dropna()
        # df_tf_list = Process_tf_target(df_tf)
        fname = file_gs.split('/')[-1].replace('.csv','')
        fname = fname.replace('ctx_','')
        fname = fname.replace('_Sig_tf_regulon','')

        tf_gene_sets = (
            df_tf_list_sig[[tf_col, 'targetgene']]
            .dropna()
            .drop_duplicates()
            .groupby(tf_col)['targetgene']
            .apply(set)
        )

        # df_tf_list_sig.to_csv(os.path.join(output_dir,f'{fname}_tf_DEG_sets.csv'))

        group_gene_sets = (
            df_NT[[group_col, 'Gene']]
            .dropna()
            .drop_duplicates()
            .groupby(group_col)['Gene']
            .apply(set)
        )

        jaccard_results = []
        for tf, tf_genes in tf_gene_sets.items():
            regulon_size = len(tf_genes)
            for group, group_genes in group_gene_sets.items():
                group_gene_size = len(group_genes)
                intersection_genes = tf_genes & group_genes
                union_genes = tf_genes | group_genes
                jaccard_results.append({
                    'TF': tf,
                    'Group': group,
                    'regulon_size': regulon_size,
                    'group_gene_size': group_gene_size,
                    'intersection_size': len(intersection_genes),
                    'union_size': len(union_genes),
                    'jaccard': len(intersection_genes) / len(union_genes) if union_genes else 0,
                    'intersection_genes': sorted(intersection_genes)
                })
        if len(jaccard_results) == 0:
            print(f"Warning: No Jaccard results for file {file_gs}")
            continue
        df_tf_group_jaccard = pd.DataFrame(jaccard_results).sort_values(
            ['jaccard', 'intersection_size', 'regulon_size', 'group_gene_size'],
            ascending=[False, False, False, False]
        )
        df_tf_group_jaccard = df_tf_group_jaccard[df_tf_group_jaccard['jaccard']>0]
        df_tf_group_jaccard['fname'] = fname
        #df_tf_group_jaccard.to_csv(os.path.join(output_nt_dir,f'{fname}_tf_NT_jaccard.csv'), index=False)
        df_NT_jaccard = pd.concat([df_NT_jaccard, df_tf_group_jaccard], axis=0)
    ### Final process
    df_NT_jaccard['NT'] = df_NT_jaccard['fname'].apply(lambda x: x.split('_')[-2])
    df_NT_jaccard['NT'] = df_NT_jaccard['fname'].apply(lambda x: x.split('_')[-2])
    df_NT_jaccard['Region'] = df_NT_jaccard['fname'].apply(lambda x: x.split('_')[0])
    df_NT_jaccard['TF_up'] = df_NT_jaccard['TF'].str.upper()

    return df_NT_jaccard

# %%
df_meta_match = df_meta.drop_duplicates(subset=['celltype.L1', 'celltype.L2'])

# %%
df_meta_match

# %%
df_meta_match['fname'] =df_meta_match['celltype.L2'].str.replace('/', '-')
df_meta_match['fname'] = df_meta_match['fname'].str.replace(' ', '_')
df_meta_match['fname'] = df_meta_match['region'] + "_" + df_meta_match['fname']
dict_fn_nt = dict(zip(df_meta_match['fname'], df_meta_match['Neurotransmitter']))

# %%
dict_fn_nt

# %%
nts = ['Glut', 'GABA', 'Sero', 'Dopa', 'Chol', 'Hist']

# %%
df_transport = pd.read_excel('/data2st1/junyi/output/atac1112/genefunction/02_transport_v0511.xlsx')
df_transport_jaccard = get_group_ovlp(
    outputdir='/data2st2/junyi/output/stg1028/scenic_ctxregulon/02_transport_jaccard',
    df_NT=df_transport,
    group_col='Type',
    tf_col='TF',
    ctx_glob='/data2st2/junyi/output/stg1028/scenic_ctxregulon/sig_regulon/*Sig_tf_regulon.csv'
)
df_transport_jaccard['NT'] = df_transport_jaccard['fname'].str.split('_').str[-1]
df_transport_jaccard_N = df_transport_jaccard[df_transport_jaccard.NT.isin(nts)]
df_transport_jaccard_N = df_transport_jaccard_N[df_transport_jaccard_N.intersection_size>=3]
df_transport_jaccard_N = df_transport_jaccard_N[df_transport_jaccard_N.TF_up.isin(set(df_top5.TF))]
df_transport_jaccard_N_MEAN = df_transport_jaccard_N.groupby(['Group','Region','TF']).mean()
df_transport_jaccard_N_MEAN.reset_index(['Group','Region','TF'], inplace=True)
plot_region_tf_group_bubble(
    df_transport_jaccard_N_MEAN,
    title='df_transport_jaccard_N Bubble Plot by Region',
    save_path='/data2st2/junyi/output/stg1028/scenic_ctxregulon/02_transport_jaccard/df_transport_jaccard_N_bubble_plot.pdf'
)

# %%
for ftyp in df_G317['major_type'].unique():
    print(ftyp)
    try:    
        df_ftype = df_G317[df_G317['major_type']==ftyp]
        out_ftype= f'/data2st2/junyi/output/stg1028/scenic_ctxregulon/{ftyp}_jaccard'
        df_ftype_jaccard = get_group_ovlp(
            outputdir=out_ftype,
            df_NT=df_ftype,
            group_col='final_type',
            tf_col='TF',
            ctx_glob='/data2st2/junyi/output/stg1028/scenic_ctxregulon/sig_regulon/*Sig_tf_regulon.csv'
        )
        df_ftype_jaccard['NT'] = df_ftype_jaccard['fname'].str.split('_').str[-1]

        df_ftype_jaccard_N = df_ftype_jaccard[df_ftype_jaccard.NT.isin(nts)]
        df_ftype_jaccard_N = df_ftype_jaccard_N[df_ftype_jaccard_N.intersection_size>=3]
        df_ftype_jaccard_N = df_ftype_jaccard_N[df_ftype_jaccard_N.TF_up.isin(set(df_top5.TF))]
        df_ftype_jaccard_N_MEAN = df_ftype_jaccard_N.groupby(['Group','Region','TF']).mean()
        df_ftype_jaccard_N_MEAN.reset_index(['Group','Region','TF'], inplace=True)
        plot_region_tf_group_bubble(
            df_ftype_jaccard_N_MEAN,
            title='df_ftype_jaccard_N Bubble Plot by Region',
            save_path=f'{out_ftype}/{ftyp}jaccard_N_bubble_plot.pdf'
        )
    except Exception as e:
        print(f"Error processing {ftyp}: {e}")

# %%
def visualize_regulatory_network(metadata_df, importance_col='importance', weight_col='importance_TF2G',figure_size=(7, 7),
                               top_n=100, output_html='figures/network.html',title='SCENIC+ Regulatory Network',df_deg=None):
    """
    Visualize SCENIC+ regulatory network with TF-gene relationships
    
    Parameters:
        metadata_df: DataFrame with columns ['TF', 'gene', importance_col, 'region']
        importance_col: Column name for TF-gene importance scores
        top_n: Number of top interactions to visualize
        output_html: Output file name for interactive visualization
    """
    # Prepare data
    # Sort by the absolute importance and select top_n interactions

    df = metadata_df.sort_values(importance_col, ascending=False).head(top_n)
    #df = metadata_df.sort_values(importance_col, ascending=False)
    
    # Create network graph
    G = nx.DiGraph()
    
    # Add nodes and edges with importance as weight
    for _, row in df.iterrows():
        G.add_edge(row['TF'], row['Gene'], 
                  weight=row[weight_col],
                  title=f"Importance: {row[weight_col]:.2f}")
        
    degrees = dict(G.degree())
    max_degree = max(degrees.values()) if degrees else 1

    
    # Node colors (TFs in red, genes in blue)
    # Node colores, where TFs are orange and genes are magenta, not in df_deg are gray

    node_colors = {}
    node_edge_colors = {}
    node_edge_widths = {}

    for node in G.nodes():
        if node in df['TF'].unique() and node in df_deg['gene'].unique():
            if df_deg[df_deg['gene'] == node]['condition'].values[0] == 'UP':
                node_colors[node] = '#F6607C'
                node_edge_colors[node] = '#F6607C'  # Light red outline
                node_edge_widths[node] = 3
            else:
                node_colors[node] = '#B2DF8A'
                node_edge_colors[node] = '#B2DF8A'  # Light green outline
                node_edge_widths[node] = 3

        elif node in df['Gene'].unique() and node in df_deg['gene'].unique():
            if df_deg[df_deg['gene'] == node]['condition'].values[0] == 'UP':
                node_colors[node] = 'lightcoral'
                node_edge_colors[node] = 'lightcoral'
                node_edge_widths[node] = 3

            else:
                node_colors[node] = '#D2ECBB'
                node_edge_colors[node] = '#D2ECBB'
                node_edge_widths[node] = 3

        else:
            node_colors[node] = 'lightgray'  # For nodes not in df_deg
            node_edge_colors[node] = 'lightgray'
            node_edge_widths[node] = 0


    # node_colors = {
    #     node: 'orange' if node in df['TF'].unique() else 'magenta'
    #     for node in G.nodes()
    # }
    
    # Static visualization
    plt.figure(figsize=figure_size)
    pos = nx.spring_layout(G, k=0.1, iterations=50,scale=0.5)
    #pos = nx.kamada_kawai_layout(G, scale=0.8)
    
    # Draw nodes


    #node_sizes_d = [degrees[n] * 800 / max_degree for n in G.nodes()]
    #node size = abs log2 fold change in df_deg
    node_sizes = []
    for n in G.nodes():
        if n in df_deg['gene'].unique():
            fold_change = df_deg[df_deg['gene'] == n]['de_coef'].values[0]
            node_sizes.append(abs(fold_change) * 400 + degrees[n]*400 / max_degree)
        else:
            node_sizes.append(100)

    # node_sizes = [degrees[n] * 800 / max_degree for n in G.nodes()]
    # nx.draw_networkx_nodes(G, pos, node_color=[node_colors[n] for n in G.nodes()],
    #                                edgecolors=[node_edge_colors[n] for n in G.nodes()],
    #                 linewidths=[node_edge_widths[n] for n in G.nodes()],
    #                       node_size=node_sizes, alpha=0.8)


    node_shapes = {n: 'h' if n in df['TF'].unique() else 'o' for n in G.nodes()}

# 分批次绘制不同形状的节点
    for shape in set(node_shapes.values()):
        nx.draw_networkx_nodes(
            G, pos,
            nodelist=[n for n in G.nodes() if node_shapes[n] == shape],
            node_shape=shape,
            node_color=[node_colors[n] for n in G.nodes() if node_shapes[n] == shape],
            edgecolors=[node_edge_colors[n] for n in G.nodes() if node_shapes[n] == shape],
            linewidths=[node_edge_widths[n] for n in G.nodes() if node_shapes[n] == shape],
            node_size=[node_sizes[i] for i, n in enumerate(G.nodes()) if node_shapes[n] == shape],
            alpha=0.8
        )


    # Draw edges with width proportional to importance
    edge_widths = [d['weight']*2 for u, v, d in G.edges(data=True)]
    # nx.draw_networkx_edges(G, pos, width=edge_widths, 
    #                       edge_color='gray', alpha=0.6, 
    #                       arrowstyle='-|>', arrowsize=15)
    for u, v, d in G.edges(data=True):
        arrowstyle = '-|>' if d['weight'] >= 0 else '|-|'
        color = '#FBC2C3' if d['weight'] >= 0 else '#D2ECBB'
        nx.draw_networkx_edges(
            G, pos, edgelist=[(u, v)],
            width=abs(d['weight'])*4,
            edge_color=color,
            alpha=0.6,
            arrowstyle=arrowstyle,
             connectionstyle="arc3, rad=0.2",
            arrowsize=15
        )
    import matplotlib.patheffects as path_effects

    # Draw labels
    text_labels = nx.draw_networkx_labels(G, pos, font_size=10, font_family='sans-serif',bbox=dict(facecolor='none',  pad=0.1, edgecolor='none'))
    for _, label in text_labels.items():
        label.set_path_effects([
            path_effects.Stroke(linewidth=2, foreground='white'),
            path_effects.Normal()
        ])

    plt.title(title)
    plt.axis('off')
    plt.tight_layout()
    plt.savefig(output_html+".png", dpi=300)
    plt.show()
    
    # Interactive visualization
    net = Network(height='800px', width='100%', directed=True)
    net.from_nx(G)


    for node in net.nodes:
        if node['id'] in df['TF'].unique():
            node['shape'] = 'triangle'

    # Save interactive version
    net.show_buttons(filter_=['physics'])
    net.save_graph(output_html)
    print(f"Interactive visualization saved to {output_html}")

# %%
cac_gene_dict = {'α1 subunit': ['Cacna1a',
  'Cacna1b',
  'Cacna1c',
  'Cacna1d',
  'Cacna1e',
  'Cacna1g',
  'Cacna1h',
  'Cacna1i'],
 'α2δ subunit': ['Cacna2d1', 'Cacna2d2', 'Cacna2d3', 'Cacna2d4'],
 'β subunit': ['Cacnb1', 'Cacnb2', 'Cacnb3', 'Cacnb4'],
 'γ subunit': ['Cacng2', 'Cacng3', 'Cacng4', 'Cacng5', 'Cacng7', 'Cacng8'],
 'None': ['Cacfd1', 'Cachd1']}

ca_genes = ['Cacna1a', 'Cacna1b', 'Cacna1c', 'Cacna1d', 'Cacna1e', 'Cacna1g', 
            'Cacna1h', 'Cacna1i', 'Cacna2d1', 'Cacna2d2', 'Cacna2d3', 'Cacna2d4', 
            'Cacnb1', 'Cacnb2', 'Cacnb3', 'Cacnb4', 'Cacng2', 'Cacng3', 'Cacng4', 
            'Cacng5', 'Cacng7', 'Cacng8', 'Cacfd1', 'Cachd1']


ligand = ['Slc18a2', 'Slc18a1', 'Ddc', 'Th', 'Slc17a7', 'Slc17a8', 'Gls',
       'Slc17a6', 'Slc18a3', 'Chat', 'Slc32a1', 'Dbh', 'Tph2', 'Tph1', 'Gad2',
       'Gad1', 'Pnmt', 'Shmt2', 'Shmt1', 'Hmox2', 'Nos3', 'Hmox1', 'Cort',
       'Nos2', 'Nos1', 'Sst', 'Adcyap1', 'Rln1', 'Nrxn3', 'Npy', 'Nrxn2',
       'Nrxn1', 'Pdyn', 'Vip', 'Trh', 'Crh', 'Nts', 'Penk', 'Tac1', 'Pthlh',
       'Pnoc', 'Tac2', 'Gjc1', 'Gjc2', 'Gjc3', 'Gjd2', 'Gjd3', 'Gjd4', 'Gje1',
       'Gjb6', 'Gjb5', 'Gjb4', 'Gjb3', 'Gjb2', 'Gjb1', 'Gja8', 'Gja6', 'Cck',
       'Grp', 'Gja5', 'Gja4', 'Gja1', 'Gja3', 'Gja10', 'Nmb']

receptor = ['Oprl1', 'Gabra6', 'Grik3', 'Gabrb3', 'Grik5', 'Adrb1', 'Oprd1', 'Gabra4', 
            'Grm5', 'Drd4', 'Npy1r', 'Grin2c', 'Slc6a4', 'Gjc3', 'Chrna7', 'Rxfp1', 'Adra1b', 
            'Gjb1', 'Oprm1', 'Nlgn2', 'Drd5', 'Chrm5', 'Gabra1', 'Htr5a', 'Pth1r', 'Oprk1', 'Tacr3', 
            'Chrna1', 'Grm7', 'Grik2', 'Chrna6', 'Adra1a', 'Gucy1b2', 'Slc6a3', 'Adra2b', 'Gabbr1', 'Chrna4', 
            'Gjb4', 'Htr1b', 'Gja1', 'Npy2r', 'Gucy1a1', 'Gabrb1', 'Grin1', 'Adra2a', 'Tacr1', 'Adrb2', 'Sstr2', 
            'Grin3a', 'Glra2', 'Slc6a2', 'Drd3', 'Htr1d', 'Adra2c', 'Htr2c', 'Grin2d', 'Chrnb1', 'Chrnb2', 'Gja4', 'Htr7', 
            'Htr2b', 'Gabra3', 'Ache', 'Grik4', 'Htr6', 'Grm1', 'Sstr4', 'Gjb2', 'Grm6', 'Adcyap1r1', 'Adra1d', 'Gria2', 
            'Chrna2', 'Grm3', 'Grik1', 'Chrm3', 'Rxfp3', 'Chrna10', 'Chrng', 'Gjb3', 'Crhr2', 'Grin3b', 'Gria3', 'Vipr1', 'Gria1', 
            'Grin2b', 'Htr4', 'Slc6a9', 'Npy5r', 'Gja3', 'Htr1f', 'Chrnb3', 'Gjd4', 'Nlgn3', 'Gjd2', 'Grm4', 'Sstr1', 'Grin2a', 'Gabrg2', 
            'Adrb3', 'Grm2', 'Gja8', 'Glra3', 'Gje1', 'Comt', 'Sstr3', 'Gjb5', 'Gabra2', 'Rxfp2', 'Chrne', 'Gabrg3', 'Vipr2', 'Cckbr', 'Htr1a', 
            'Chrm2', 'Gucy1a2', 'Htr2a', 'Ntsr2', 'Ntsr1', 'Htr3b', 'Gabrb2', 'Gja6', 'Drd2', 'Glra1', 'Grm8', 'Chrnd', 'Nmbr', 'Glrb', 'Trhr', 
            'Gria4', 'Gja5', 'Chrna9', 'Gucy1b1', 'Nlgn1', 'Drd1', 'Gjc1', 'Glra4', 'Crhr1', 'Chrna5', 'Gjc2', 'Gjd3', 'Trhr2', 'Gabra5', 'Htr1e', 
            'Htr3a', 'Slc6a5', 'Gja10', 'Chrna3', 'Chrm4', 'Gjb6', 'Chrnb4', 'Chrm1', 'Gabrg1', 'Gabbr2', 'Grpr']


respriotory = ['mt-Co1', 'mt-Co2', 'mt-Co3', 'mt-Atp6', 'mt-Nd4', 'mt-Nd1', 'Cox6c',
       'Cox8a', 'Cox4i1', 'Sdha', 'Ndufa4', 'Ndufs4', 'Cox7c', 'Ndufc2',
       'Ndufaf7', 'Ndufa13', 'Atp5f1', 'Ndufaf4', 'Cox7a2', 'Cox7b', 'Cox6a1',
       'Ndufs1', 'Ndufv2', 'Ndufb5', 'Uqcrh', 'Uqcrc2', 'Ndufaf2', 'Ndufb9',
       'Cox5a', 'Ndufa10', 'Ndufb1-ps', 'mt-Nd2', 'Ndufa6', 'Cox5b', 'Ndufb11',
       'Ndufb3', 'Cox6b1', 'Ndufs3', 'Uqcrq', 'Cyc1', 'Ndufb4', 'Coq2', 'Sdhb',
       'Ndufa7', 'Ndufs7', 'Ndufa12', 'Ndufb8', 'Ndufa11', 'Ndufb10', 'Ndufa3',
       'Coa3', 'Uqcrb', 'Ndufab1', 'Ndufa5', 'Uqcrc1', 'Sod2', 'Uqcr11',
       'Uqcr10', 'Sdhc', 'Ndufb2', 'Ndufa2', 'Ndufv3', 'Ndufs2', 'Ndufa1',
       'Ndufb7', 'Cycs', 'Ndufv1', 'Ndufa8', 'Coq3', 'Ndufc1', 'Ndufa9',
       'Coq5', 'Ndufb6', 'Coq8b', 'Ndufs8', 'Ndufaf5', 'Coq9', 'Ndufaf6',
       'Ndufs6', 'Tfam', 'mt-Nd3', 'mt-Nd5', 'Coq4', 'Sdhd', 'Coq7', 'Ndufaf3',
       'mt-Nd4l', 'Coa5', 'Coa7', 'Cox6a2', 'Cox4i2']

# %% [markdown]
#             DEGs    Non-DEGs	Total
#     ​DARs​	    a	    b	        a+b
# ​Non-DARs​	    c	    d	        c+d
#     ​Total  ​	a+c	    b+d	          N

# %%
# df_deg_glut = pd.read_csv('/home/junyichen/code/scmmd/data/degs/Memento_Glut_DEGs_each_region_diff_gender_v1.csv',index_col=0)
# df_deg_gaba = pd.read_csv('/home/junyichen/code/scmmd/data/degs/Memento_GABA_DEGs_each_region_diff_gender_v1.csv',index_col=0)
# df_deg_glut['ctname'] = df_deg_glut['region'] + '_Glut'
# df_deg_gaba['ctname'] = df_deg_gaba['region'] + '_GABA'
# df_deg = pd.concat([df_deg_glut,df_deg_gaba],axis=0,ignore_index=True)
# df_deg = df_deg[df_deg['gender'] == "M"]
# df_deg_select = df_deg[(df_deg.de_pval<0.05) & (df_deg.gender=="M") & (df_deg.region.isin(['AMY','HIP','PFC']))]
# df_deg['condition'] = 'DOWN'
# df_deg.loc[df_deg.de_coef>0,'condition'] = 'UP'

df_deg = pd.read_csv("/data2st1/junyi/data/127_DEGs overlap/Overlapped_DEGs_Merge_L2_each_region_diff_gender_padj05.csv",index_col=0)

# %%
df_deg['celltype.L2'] = df_deg['celltype'].str.replace(" ", "_").str.replace("/", "_")

# %%
df_dar = pd.read_csv('/data2st1/junyi/output/atac0627/dar/celltype.L2/mementob_dar_ncelltype.csv')

# %%
meta=pd.read_csv('/data2st1/junyi/data/L2_anno_meta_add_mementovsmast.csv')
meta['celltype.L2'] = meta['L2'].str.replace(' ','_').str.replace('/','_')
l2nntype = dict(zip( meta['celltype.L2'],meta['Neurotransmitter_celltype']))

# %%
df_deg['Neurotransmitter'] = df_deg['celltype.L2'].map(l2nntype)

# %%
# cellltype = 'AMY_AMY_Glut'
# oudir = f'/data1st2/junyi/output/atac0627/scenic/{cellltype}/Snakemake'
# scplus_mdata = mudata.read(f'{oudir}/scplusmdata.h5mu')

# direct_AUC = scplus_mdata['extended_region_based_AUC']

# %%
# # ignore output in this cell
# import warnings
# warnings.filterwarnings("ignore")  # 忽略所有警告[2,4,6](@ref)
# cellltypes = ['AMY_AMY_Glut', 'AMY_AMY_GABA', 'HIP_HIP_Glut', 'PFC_PFC_Glut']

# #if not os.path.exists('/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC_filterd.csv'):
# df_region_auc_all = pd.DataFrame()
# df_gene_auc_all = pd.DataFrame()

# for cellltype in cellltypes[:1]:
#     oudir = f'/data1st2/junyi/output/atac0627/scenic/{cellltype}/Snakemake'
#     scplus_mdata = mudata.read(f'{oudir}/scplusmdata.h5mu')
#     for TFtype in ['extended', 'direct']:
#         direct_AUC = scplus_mdata[f'{TFtype}_region_based_AUC']
#         direct_AUC.obs['condition'] = direct_AUC.obs.index.str.split('_').str[-2]
#         # join the  index name except the last two parts
#         direct_AUC.obs['celltype.L2'] = direct_AUC.obs.index.str.split('_').str[:-2].str.join('_')

# %%
# direct= direct_AUC[direct_AUC.obs.condition == 'MW']

# %%
# ignore output in this cell
warnings.filterwarnings("ignore")  # 忽略所有警告[2,4,6](@ref)
cellltypes = ['AMY_AMY_Glut', 'AMY_AMY_GABA', 'HIP_HIP_Glut', 'HIP_HIP_GABA', 'PFC_PFC_Glut', 'PFC_PFC_GABA']

if not os.path.exists('/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC_filterd.csv'):
    df_region_auc_all = pd.DataFrame()
    df_gene_auc_all = pd.DataFrame()

    for cellltype in cellltypes:
        oudir = f'/data1st2/junyi/output/atac0627/scenic/{cellltype}/Snakemake'
        scplus_mdata = mudata.read(f'{oudir}/scplusmdata.h5mu')
        for TFtype in ['extended', 'direct']:
            direct_AUC = scplus_mdata[f'{TFtype}_region_based_AUC']
            direct_AUC.obs['condition'] = direct_AUC.obs.index.str.split('_').str[-2]
            # join the  index name except the last two parts
            direct_AUC.obs['celltype.L2'] = direct_AUC.obs.index.str.split('_').str[:-2].str.join('_')
            for cellltype in direct_AUC.obs['celltype.L2'].unique():
                # calculate the diffrential auc for each cell type
                direct_AUC_cell = direct_AUC[direct_AUC.obs['celltype.L2'] == cellltype]
                sc.tl.rank_genes_groups(direct_AUC_cell, groupby='condition', method='wilcoxon')
                df_MC = sc.get.rank_genes_groups_df(direct_AUC_cell, group='MC', key='rank_genes_groups',log2fc_min=0)
                df_MC['status'] = 'up'
                df_MC['celltype.L2'] = cellltype
                df_MW = sc.get.rank_genes_groups_df(direct_AUC_cell, group='MW', key='rank_genes_groups',log2fc_min=0)
                df_MW['status'] = 'down'
                df_MW['celltype.L2'] = cellltype
                df_deg_cell = pd.concat([df_MC, df_MW], axis=0, ignore_index=True)
                df_region_auc_all = pd.concat([df_region_auc_all, df_deg_cell], axis=0, ignore_index=True)

        for TFtype in ['extended', 'direct']:
            direct_AUC = scplus_mdata[f'{TFtype}_gene_based_AUC']
            direct_AUC.obs['condition'] = direct_AUC.obs.index.str.split('_').str[-2]
            # join the  index name except the last two parts
            direct_AUC.obs['celltype.L2'] = direct_AUC.obs.index.str.split('_').str[:-2].str.join('_')
            for cellltype in direct_AUC.obs['celltype.L2'].unique():
                # calculate the diffrential auc for each cell type
                direct_AUC_cell = direct_AUC[direct_AUC.obs['celltype.L2'] == cellltype]
                sc.tl.rank_genes_groups(direct_AUC_cell, groupby='condition', method='wilcoxon')
                df_MC = sc.get.rank_genes_groups_df(direct_AUC_cell, group='MC', key='rank_genes_groups',log2fc_min=0)
                df_MC['status'] = 'up'
                df_MC['celltype.L2'] = cellltype
                df_MW = sc.get.rank_genes_groups_df(direct_AUC_cell, group='MW', key='rank_genes_groups',log2fc_min=0)
                df_MW['status'] = 'down'
                df_MW['celltype.L2'] = cellltype
                df_deg_cell = pd.concat([df_MC, df_MW], axis=0, ignore_index=True)
                df_gene_auc_all = pd.concat([df_gene_auc_all, df_deg_cell], axis=0, ignore_index=True)


    df_region_auc_all['TF'] = df_region_auc_all['names'].str.split('_').str[0]
    df_gene_auc_all['TF'] = df_gene_auc_all['names'].str.split('_').str[0]
    df_gene_auc_all['sample'] = df_gene_auc_all['celltype.L2']
    df_gene_auc_all['sex'] = 'Male'
    df_gene_auc_all['Neurotransmitter'] = df_gene_auc_all['celltype.L2'].map(l2nntype)

    df_region_auc_all['sample'] = df_region_auc_all['celltype.L2']
    df_region_auc_all['sex'] = 'Male'
    df_region_auc_all['Neurotransmitter'] = df_region_auc_all['celltype.L2'].map(l2nntype)
    df_region_auc_all['nlog10_p_val_adj'] = -np.log10(df_region_auc_all['pvals_adj'])* df_region_auc_all['status'].apply(lambda x: -1 if x == 'down' else 1)
    df_gene_auc_all['nlog10_p_val_adj'] = -np.log10(df_gene_auc_all['pvals_adj'])* df_gene_auc_all['status'].apply(lambda x: -1 if x == 'down' else 1)
    df_gene_auc_all['TF_reg'] = df_gene_auc_all['names'].str.split('_').str[0]+"_" +df_gene_auc_all['names'].str.split('_').str[2]
    df_region_auc_all['TF_reg'] = df_region_auc_all['names'].str.split('_').str[0]+"_" +df_region_auc_all['names'].str.split('_').str[2]
    # filter the pvals_adj < 0.05
    df_region_auc_all = df_region_auc_all[df_region_auc_all['pvals_adj'] < 0.05]
    df_gene_auc_all = df_gene_auc_all[df_gene_auc_all['pvals_adj'] < 0.05]
    df_region_auc_all['region'] = df_region_auc_all['sample'].str.split('_').str[0]
    df_gene_auc_all['region'] = df_gene_auc_all['sample'].str.split('_').str[0]
    df_region_auc_all.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC.csv')
    df_gene_auc_all.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_gene_based_AUC.csv')
    df_gene_auc_all.sort_values(['sample','logfoldchanges'], ascending=[True,False], inplace=True)
    df_region_auc_all.sort_values(['sample','logfoldchanges'], ascending=[True,False], inplace=True)

    df_region_auc_all = pd.read_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC.csv', index_col=0)
    df_gene_auc_all = pd.read_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_gene_based_AUC.csv', index_col=0)
    df_gene_auc_filterd = df_gene_auc_all.drop_duplicates(subset=['TF_reg', 'sample'], keep='first')
    df_gene_auc_filterd.sort_values(['sample','nlog10_p_val_adj'], ascending=[True,False], inplace=True)
    df_region_auc_filterd = df_region_auc_all.drop_duplicates(subset=['TF_reg', 'sample'], keep='first')
    df_region_auc_filterd.sort_values(['sample','nlog10_p_val_adj'], ascending=[True,False], inplace=True)

    df_region_auc_filterd.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC_filterd.csv')
    df_gene_auc_filterd.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_gene_based_AUC_filterd.csv')

else:
    df_region_auc_filterd = pd.read_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC_filterd.csv', index_col=0)
    df_gene_auc_filterd = pd.read_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_gene_based_AUC_filterd.csv', index_col=0)

# %%
df_region_auc_filterd['logFC'] = df_region_auc_filterd['logfoldchanges'] * df_region_auc_filterd['status'].apply(lambda x: -1 if x == 'down' else 1)

# %%
warnings.filterwarnings("ignore")  # 忽略所有警告[2,4,6](@ref)
cellltypes = ['AMY_NN','PFC_NN','HIP_NN']

if not os.path.exists('/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC_filtered_NN.csv'):
    df_region_auc_all = pd.DataFrame()
    df_gene_auc_all = pd.DataFrame()

    for cellltype in cellltypes:
        oudir = f'/data1st2/junyi/output/atac0627/scenic/{cellltype}/Snakemake'
        scplus_mdata = mudata.read(f'{oudir}/scplusmdata.h5mu')
        for TFtype in ['extended', 'direct']:
            direct_AUC = scplus_mdata[f'{TFtype}_region_based_AUC']
            direct_AUC.obs['condition'] = direct_AUC.obs.index.str.split('_').str[-2]
            # join the  index name except the last two parts
            direct_AUC.obs['celltype.L2'] = direct_AUC.obs.index.str.split('_').str[:-2].str.join('_')
            for cellltype in direct_AUC.obs['celltype.L2'].unique():
                # calculate the diffrential auc for each cell type
                direct_AUC_cell = direct_AUC[direct_AUC.obs['celltype.L2'] == cellltype]
                sc.tl.rank_genes_groups(direct_AUC_cell, groupby='condition', method='wilcoxon')
                df_MC = sc.get.rank_genes_groups_df(direct_AUC_cell, group='MC', key='rank_genes_groups',log2fc_min=0)
                df_MC['status'] = 'up'
                df_MC['celltype.L2'] = cellltype
                df_MW = sc.get.rank_genes_groups_df(direct_AUC_cell, group='MW', key='rank_genes_groups',log2fc_min=0)
                df_MW['status'] = 'down'
                df_MW['celltype.L2'] = cellltype
                df_deg_cell = pd.concat([df_MC, df_MW], axis=0, ignore_index=True)
                df_region_auc_all = pd.concat([df_region_auc_all, df_deg_cell], axis=0, ignore_index=True)

        for TFtype in ['extended', 'direct']:
            direct_AUC = scplus_mdata[f'{TFtype}_gene_based_AUC']
            direct_AUC.obs['condition'] = direct_AUC.obs.index.str.split('_').str[-2]
            # join the  index name except the last two parts
            direct_AUC.obs['celltype.L2'] = direct_AUC.obs.index.str.split('_').str[:-2].str.join('_')
            for cellltype in direct_AUC.obs['celltype.L2'].unique():
                # calculate the diffrential auc for each cell type
                direct_AUC_cell = direct_AUC[direct_AUC.obs['celltype.L2'] == cellltype]
                sc.tl.rank_genes_groups(direct_AUC_cell, groupby='condition', method='wilcoxon')
                df_MC = sc.get.rank_genes_groups_df(direct_AUC_cell, group='MC', key='rank_genes_groups',log2fc_min=0)
                df_MC['status'] = 'up'
                df_MC['celltype.L2'] = cellltype
                df_MW = sc.get.rank_genes_groups_df(direct_AUC_cell, group='MW', key='rank_genes_groups',log2fc_min=0)
                df_MW['status'] = 'down'
                df_MW['celltype.L2'] = cellltype
                df_deg_cell = pd.concat([df_MC, df_MW], axis=0, ignore_index=True)
                df_gene_auc_all = pd.concat([df_gene_auc_all, df_deg_cell], axis=0, ignore_index=True)


    df_region_auc_all['TF'] = df_region_auc_all['names'].str.split('_').str[0]
    df_gene_auc_all['TF'] = df_gene_auc_all['names'].str.split('_').str[0]
    df_gene_auc_all['sample'] = df_gene_auc_all['celltype.L2']
    df_gene_auc_all['sex'] = 'Male'
    df_gene_auc_all['Neurotransmitter'] = df_gene_auc_all['celltype.L2'].map(l2nntype)

    df_region_auc_all['sample'] = df_region_auc_all['celltype.L2']
    df_region_auc_all['sex'] = 'Male'
    df_region_auc_all['Neurotransmitter'] = df_region_auc_all['celltype.L2'].map(l2nntype)
    df_region_auc_all['nlog10_p_val_adj'] = -np.log10(df_region_auc_all['pvals_adj'])* df_region_auc_all['status'].apply(lambda x: -1 if x == 'down' else 1)
    df_gene_auc_all['nlog10_p_val_adj'] = -np.log10(df_gene_auc_all['pvals_adj'])* df_gene_auc_all['status'].apply(lambda x: -1 if x == 'down' else 1)
    df_gene_auc_all['TF_reg'] = df_gene_auc_all['names'].str.split('_').str[0]+"_" +df_gene_auc_all['names'].str.split('_').str[2]
    df_region_auc_all['TF_reg'] = df_region_auc_all['names'].str.split('_').str[0]+"_" +df_region_auc_all['names'].str.split('_').str[2]
    # filter the pvals_adj < 0.05
    df_region_auc_all = df_region_auc_all[df_region_auc_all['pvals_adj'] < 0.05]
    df_gene_auc_all = df_gene_auc_all[df_gene_auc_all['pvals_adj'] < 0.05]
    df_region_auc_all['region'] = df_region_auc_all['sample'].str.split('_').str[0]
    df_gene_auc_all['region'] = df_gene_auc_all['sample'].str.split('_').str[0]
    # df_region_auc_all.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC.csv')
    # df_gene_auc_all.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_gene_based_AUC.csv')
    df_gene_auc_all.sort_values(['sample','logfoldchanges'], ascending=[True,False], inplace=True)
    df_region_auc_all.sort_values(['sample','logfoldchanges'], ascending=[True,False], inplace=True)

    # df_region_auc_all = pd.read_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC.csv', index_col=0)
    # df_gene_auc_all = pd.read_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_gene_based_AUC.csv', index_col=0)
    df_gene_auc_filterd_NN = df_gene_auc_all.drop_duplicates(subset=['TF_reg', 'sample'], keep='first')
    df_gene_auc_filterd_NN.sort_values(['sample','nlog10_p_val_adj'], ascending=[True,False], inplace=True)
    df_region_auc_filterd_NN = df_region_auc_all.drop_duplicates(subset=['TF_reg', 'sample'], keep='first')
    df_region_auc_filterd_NN.sort_values(['sample','nlog10_p_val_adj'], ascending=[True,False], inplace=True)

    df_region_auc_filterd_NN.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC_filtered_NN.csv')
    df_gene_auc_filterd_NN.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_gene_based_AUC_filtered_NN.csv')

else:
    df_region_auc_filterd_NN = pd.read_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_region_based_AUC_filtered_NN.csv', index_col=0)
    df_gene_auc_filterd_NN = pd.read_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_gene_based_AUC_filtered_NN.csv', index_col=0)

# %%
df_gene_auc_filterd_NN['region'] = 'NN'
df_gene_auc_filterd_NN['logFC'] = df_gene_auc_filterd_NN['logfoldchanges'] * df_gene_auc_filterd_NN['status'].apply(lambda x: -1 if x == 'down' else 1)

# %%
df_region_all = pd.concat([df_region_auc_filterd, df_region_auc_filterd_NN], axis=0, ignore_index=True)

# %%
df_gene_all = pd.concat([df_gene_auc_filterd, df_gene_auc_filterd_NN], axis=0, ignore_index=True)

# %%
df_reshape_gene = df_gene_all.pivot_table(index='TF_reg', columns='sample', values='nlog10_p_val_adj', fill_value=0)

# %%
df_reshape_region = df_region_all.pivot_table(index='TF_reg', columns='sample', values='nlog10_p_val_adj', fill_value=0)

# %%
df_tfimportant = pd.read_csv('/data2st1/junyi/output/atac0627/genes_clusters.csv', index_col=0)

# %%
df_tfimportant

# %%
# reorder the columns based on the order in df_tfimportant
# if the column contains strings in the df_tfimportant['gene'] column
df_match = pd.DataFrame({"TF_plus":df_reshape.index})

# %%
df_match['TF'] = df_match['TF_plus'].str.split('_').str[0]

# %%
df_match_merge = df_match.merge(df_tfimportant, left_on='TF', right_on='gene', how='right')

# %%
df_match_merge.dropna(inplace=True)

# %%
df_match_merge

# %%
# show all rows in sns.heatmap
plt.figure(figsize=(12, 30))
sns.heatmap(df_reshape.loc[df_match_merge.TF_plus], cmap='coolwarm',vmax=30, vmin=-30, center=0)
plt.title('Region-based AUC Heatmap')
plt.xlabel('Cell Type')

# %%
# show all rows in sns.heatmap
plt.figure(figsize=(12, 30))
sns.heatmap(df_reshape_region.loc[df_match_merge.TF_plus], cmap='coolwarm',vmax=30, vmin=-30, center=0)
plt.title('Region-based AUC Heatmap')
plt.xlabel('Cell Type')

# %%
def draw_volcano(df, title='Volcano Plot', xlabel='Log2 Fold Change', ylabel='-Log10 Adjusted P-value', output_file=None,x_threashold=0.3, y_threshold=20):
    """
    Draw a volcano plot for the given DataFrame.
    
    Parameters:
        df: DataFrame containing 'logFC' and 'pvals_adj' columns
        title: Title of the plot
        xlabel: Label for the x-axis
        ylabel: Label for the y-axis
        output_file: If provided, save the plot to this file
    """
    plt.figure(figsize=(8, 6))
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.scatter(x=df[xlabel],y=df[ylabel].apply(lambda x:-np.log10(x)),s=1,label="Not significant")

    # Scatter plot
    #plt.scatter(x=df[xlabel], y=df[ylabel].apply(lambda x: -np.log10(x)), s=1)
# highlight down- or up- regulated genes
    down = df[(df[xlabel]<=-1*x_threashold)&(df[ylabel]<=(10 ** (-1*y_threshold)))]
    up = df[(df[xlabel]>=x_threashold)&(df[ylabel]<=(10 ** (-1*y_threshold)))]
    plt.scatter(x=down[xlabel],y=down[ylabel].apply(lambda x:-np.log10(x)),s=3,label="Down-regulated",color="blue")
    plt.scatter(x=up[xlabel],y=up[ylabel].apply(lambda x:-np.log10(x)),s=3,label="Up-regulated",color="red")
    for i,r in up.iterrows():
        rx = r[xlabel] if r[xlabel] < 1 else 1
        plt.text(x=rx,y=-np.log10(r[ylabel]),s=r['TF_reg'])
    for i,r in down.iterrows():
        rx= r[xlabel] if r[xlabel] > -1 else -1
        plt.text(x=rx,y=-np.log10(r[ylabel]),s=r['TF_reg'])


    # set x and y axis limits
    plt.xlim(-1, 1)
    plt.axvline(x_threashold * -1, color="grey", linestyle="--")
    plt.axvline(x_threashold, color="grey", linestyle="--")
    plt.axhline(y_threshold, color="grey", linestyle="--")


for region in df_region_auc_filterd['region'].unique():
    df_region_auc_filterd_cell = df_region_auc_filterd[df_region_auc_filterd['region'] == region]
    draw_volcano(df_region_auc_filterd_cell, title=f'SCENIC+ {region} Region-based AUC Volcano Plot', xlabel='logFC', ylabel='pvals_adj', output_file=f'figures/{region}_region_based_AUC_volcano.png')

#draw_volcano(df_region_auc_filterd, title='SCENIC+ Region-based AUC Volcano Plot', xlabel='logFC', ylabel='pvals_adj')

# %%
df_sign_table = pd.read_csv('/data2st1/junyi/output/atac0627/snregulation/TFtarget_AUC_significant.csv')

# %%
# if AUC_T < 0 status down then us down
df_sign_table['status'] = 'up'
df_sign_table.loc[df_sign_table['AUC_t'] < 0, 'status'] = 'down'

# %%
df_sign_table['region'] = df_sign_table['celltype'].str.split('_').str[0]
df_sign_table['gender'] = df_sign_table['celltype'].str.split('_').str[-1]
df_sign_table['celltype.L2'] = df_sign_table['celltype'].str.split('_').str[:-1].str.join('_')

# %%
df_sign_table_3r = df_sign_table[(df_sign_table['region'].isin(['AMY', 'HPF', 'PFC'])) & (df_sign_table['gender']=='M')]

# %%
df_sign_table_3r

# %%
df_region_auc_filterd['celltype.L2'] = df_region_auc_filterd['celltype.L2'].str.replace('-', '_')

# %%
df_region_auc_filterd

# %%
df_region_auc_filterd_join = df_region_auc_filterd.merge(df_sign_table_3r, on=['TF', 'celltype.L2','status','region'])

# %%
df_region_auc_filterd_join['Neurotransmitter'] = df_region_auc_filterd_join['celltype.L2'].map(l2nntype)

# %%
df_region_auc_filterd_join['n_gene_down'] = 0
df_region_auc_filterd_join['n_gene_up'] = 0
df_region_auc_filterd_join['n_gene_reg'] = 0

# %%
df_region_auc_filterd_join['region_nt'] = df_region_auc_filterd_join['region']+"_"+df_region_auc_filterd_join['Neurotransmitter']
df_region_auc_filterd_join['region_nt'] = df_region_auc_filterd_join['region_nt'].str.replace('Gaba', 'GABA')

# %%
df_region_auc_filterd_join['p_value_up'] = 1
df_region_auc_filterd_join['p_value_down'] = 1

# %%
n_universe = 30804
cellltypes = ['PFC_PFC_GABA', 
              'AMY_AMY_GABA', 
              'HIP_HIP_GABA',
              'PFC_PFC_Glut', 
              'AMY_AMY_Glut', 
              'HIP_HIP_Glut'
              ]
df_fisher_all = pd.DataFrame()
df_enahcner_all = pd.DataFrame()
for cellltype in cellltypes:
    ctname = cellltype[4:]
    ctname = ctname.replace('HIP', 'HPF')

    #df_deg_select = df_deg[df_deg['ctname'] == ctname]
    oudir = f'/data1st2/junyi/output/atac0627/scenic/{cellltype}/Snakemake'
    #scplus_mdata = mudata.read(f'{oudir}/scplusmdata.h5mu')

    #direct_er = scplus_mdata.uns["direct_e_regulon_metadata"]
    direct_er = pd.read_csv(f'{oudir}/eRegulon_direct.tsv',sep='\t')
    extended_er = pd.read_csv(f'{oudir}/eRegulons_extended.tsv',sep='\t')
    er = pd.concat([direct_er, extended_er], axis=0, ignore_index=True)
    df_auc_selected = df_region_auc_filterd_join[df_region_auc_filterd_join['region_nt'] == ctname]

    for indx,row in df_auc_selected.iterrows():
        er_selected = er[er['Region_signature_name'] == row['names']]
        df_deg_ct = df_deg.loc[(df_deg['celltype.L2'] == row['celltype.L2']) & (df_deg['gene'].isin(er_selected['Gene']))]
        df_deg_this = df_deg.loc[(df_deg['celltype.L2'] == row['celltype.L2'])]
        regulon_size = len(er_selected)
        df_deg_ct['TF'] = row['TF']
        n_gene_down =0
        n_gene_up = 0
        UP_DOW= df_deg_ct.status.value_counts()
        if 'Down' in UP_DOW.index:
            n_gene_down = UP_DOW['Down']
        if 'Up' in UP_DOW.index:
            n_gene_up = UP_DOW['Up']
        up_down_type = df_deg_this.status.value_counts()
        n_Up = 0
        n_Down = 0
        if 'Up' in up_down_type.index:
            n_Up = up_down_type['Up']
        if 'Down' in up_down_type.index:
            n_Down = up_down_type['Down']
        
        if len(df_deg_ct) == 0:
            continue
        else:
            #print(f"Processing {ctname} {row['names']} {row['TF']}")
            df_region_auc_filterd_join.iloc[indx, df_region_auc_filterd_join.columns.get_loc('n_gene_down')] = n_gene_down
            df_region_auc_filterd_join.iloc[indx, df_region_auc_filterd_join.columns.get_loc('n_gene_up')] = n_gene_up
            df_region_auc_filterd_join.iloc[indx, df_region_auc_filterd_join.columns.get_loc('n_gene_reg')] = regulon_size
            p_value_up = hypergeom.sf(n_gene_up - 1, n_universe, regulon_size, n_Up)
            p_value_down = hypergeom.sf(n_gene_down - 1, n_universe, regulon_size, n_Down)
            df_region_auc_filterd_join.iloc[indx, df_region_auc_filterd_join.columns.get_loc('p_value_up')] = p_value_up
            df_region_auc_filterd_join.iloc[indx, df_region_auc_filterd_join.columns.get_loc('p_value_down')] = p_value_down

# %%
df_region_auc_filterd_join.to_csv(f'/data1st2/junyi/output/atac0627/scenic/scplus_with_up_down_genes.csv')

# %%
# biclustering of heatmap
df_heat_region = pd.read_csv('/data1st2/junyi/output/atac0627/regulon_analysis/scplus_region_based_AUC_filterd_selected_heatmap_40_40_cutoff8.csv',index_col=0)

# %%
df_heat_region.index = df_heat_region.index.str.replace('-','_')+ '_M'

# %%
df_heat_scenic = pd.read_csv('/data1st2/junyi/output/atac0627/regulon_analysis/example_go_input_3regions_heatmap_40_40_cutoff8.csv',index_col=0)

# %%
df_heat_region.columns = df_heat_region.columns.str.split('_').str[0]

# %%
# intersect the row index of df_heat_region and df_heat_scenic
df_heat_region_s = df_heat_region[df_heat_region.index.isin(df_heat_scenic.index)]
df_heat_scenic_s = df_heat_scenic[df_heat_scenic.index.isin(df_heat_region.index)]

# %%
# intersect the columns of df_heat_region and df_heat_scenic
df_heat_region_s = df_heat_region_s[df_heat_region_s.columns.intersection(df_heat_scenic.columns)]
df_heat_scenic_s = df_heat_scenic_s[df_heat_scenic_s.columns.intersection(df_heat_region.columns)]

# %%
# reoder the columns and rows of df_heat_region and df_heat_scenic
df_heat_region_s = df_heat_region_s.loc[df_heat_scenic_s.index]
df_heat_region_s = df_heat_region_s[df_heat_scenic_s.columns]

# %%
# for each column, calculte the cosine similarity between the columns of df_heat_region_s and df_heat_scenic_s, ignore 0 values
cosine = []
n_zerosr = []
n_zerosc = []
for column in df_heat_region_s.columns:
    if column in df_heat_scenic_s.columns:
        # calculate the cosine similarity between the columns of df_heat_region_s and df_heat_scenic_s
        sim = cosine_similarity(df_heat_region_s[column].values.reshape(1, -1), df_heat_scenic_s[column].values.reshape(1, -1))
        region_n_zeros = np.count_nonzero(df_heat_region_s[column].values)
        scenic_n_zeros = np.count_nonzero(df_heat_scenic_s[column].values)
        cosine.append(sim[0][0])
        n_zerosr.append(region_n_zeros)
        n_zerosc.append(scenic_n_zeros)

df_result_cosine = pd.DataFrame({
    'scenic': df_heat_scenic_s.columns,
    'cosine_similarity': cosine,
    'n_zeros_region': n_zerosr,
    'n_zeros_scenic': n_zerosc
})

# %%
df_result_cosine.sort_values(by='cosine_similarity', ascending=False, inplace=True)

# %%
selected_tf=df_result_cosine[df_result_cosine['cosine_similarity'] > 0.2].scenic.tolist()

# %%
# draw heatmap as suplots
# figure zize (10, 10)
sns.heatmap(df_heat_scenic_s[selected_tf], cmap='coolwarm', vmax=8, vmin=-8)

# %%
sns.heatmap(df_heat_region_s[selected_tf], cmap='coolwarm', vmax=8, vmin=-8)

# %%
# Bicluster visualize the heatmap
df_TF_F = pd.read_csv('/data1st1/yejun/df_reordered_F.csv', index_col=0)

# %%
df_TF_F_clip = df_TF_F.clip(lower=-8, upper=8)

# %%
def visual_bcluster(data, df_heat_region,n_clusters=20):

    model = SpectralBiclustering(n_clusters=n_clusters, random_state=0)
    model.fit(data)
    reordered_rows = data[np.argsort(model.row_labels_)]
    reordered_data = reordered_rows[:, np.argsort(model.column_labels_)]
    plt.matshow(reordered_data, cmap=plt.cm.Blues)
    plt.title("After biclustering; rearranged to show biclusters")
    plt.show()
    plt.close()

    for i in range(n_clusters):
        print(f"Bicluster {i}:")

        idx_row = model.row_labels_ == i
        idx_col = model.column_labels_ == i
        df_selected = df_heat_region.iloc[idx_row,idx_col]
        sns.heatmap(df_selected, cmap='coolwarm', annot=False,vmin=-8,vmax=8)
        plt.show()
        plt.close()
data = df_TF_F_clip.copy().values
visual_bcluster(data, df_TF_F_clip, n_clusters=5)

# %%
def fisher_TF2gene(metadata_df, TF_selected, df_dar_ct,df_deg_ct):
    """
    Perform Fisher's exact test for TF-DAR-gene interactions.

    Parameters:
        metadata_df: DataFrame with columns ['TF', 'Gene', 'importance_TF2G']
        TF_col: Column name for transcription factors
        gene_col: Column name for genes
        weight_col: Column name for importance scores
    """
    # Subset the metadata for the selected TF
    direct_er_s = metadata_df[metadata_df['TF'] == TF_selected]
    df_dar_tmp = df_dar_ct.copy()
    df_deg_tmp = df_deg_ct.copy()
    df_dar_tmp['regulation'] = -1
    df_dar_tmp.loc[df_dar_tmp['de_coef']>0,'regulation'] = 1
    df_dar_reg = df_dar_tmp[['names','regulation']].rename(columns={'names': 'Region'})
    df_deg_tmp['regulation'] =  -1
    df_deg_tmp.loc[df_deg_tmp['de_coef']>0,'regulation'] = 1
    df_deg_tmp.rename(columns={'gene': 'Gene'}, inplace=True)
    direct_dar = direct_er_s.merge(df_dar_reg,how='left', left_on='Region', right_on='Region', suffixes=('', '_dar'))
    direct_dar.fillna({'regulation_dar': 0}, inplace=True)
    direct_dar_deg = direct_dar.merge(df_deg_tmp[['Gene','regulation']], how='left', left_on='Gene', right_on='Gene', suffixes=('', '_deg'))
    direct_dar_deg.fillna({'regulation_deg': 0}, inplace=True)
    direct_dar_deg['regulation_TF'] = -1
    direct_dar_deg.loc[direct_dar_deg['eRegulon_name'].str.contains('\+\/\+'), 'regulation_TF'] = 1
    #direct_dar_deg['real_regulation'] = direct_dar_deg['regulation_TF'] * direct_dar_deg['regulation_dar'] * direct_dar_deg['regulation_deg']
    direct_dar_deg['real_regulation'] = direct_dar_deg['regulation_dar'] * direct_dar_deg['regulation_deg']

    # DEG and DAR
    a = len(direct_dar_deg[direct_dar_deg['real_regulation'] == 1].drop_duplicates(subset=['Region']))
    # DAR but not DEG
    b = len(direct_dar_deg[(direct_dar_deg['real_regulation'] != 1) & (direct_dar_deg['regulation_dar'] != 0)].drop_duplicates(subset=['Region']))
    # DEG but not DAR
    c = len(direct_dar_deg[(direct_dar_deg['real_regulation'] != 1) & (direct_dar_deg['regulation_deg'] != 0)].drop_duplicates(subset=['Region']))
    # Neither DEG nor DAR
    #d = len(direct_dar_deg) - a - b - c
    d = len(direct_dar_deg[(direct_dar_deg['regulation_dar'] == 0) & (direct_dar_deg['regulation_deg'] == 0)].drop_duplicates(subset=['Region']))
    odds_ratio, p_value = fisher_exact([[a, b], [c, d]], alternative='two-sided')
    return odds_ratio, p_value

# %%
cellltypes = ['PFC_PFC_GABA', 
              'AMY_AMY_GABA', 
              'HIP_HIP_GABA',
              'PFC_PFC_Glut', 
              'AMY_AMY_Glut', 
              'HIP_HIP_Glut'
              ]
df_fisher_all = pd.DataFrame()
df_enahcner_all = pd.DataFrame()
for cellltype in cellltypes:
    ctname = cellltype[4:]
    df_deg_select = df_deg[df_deg['ctname'] == ctname]
    oudir = f'/data1st2/junyi/output/atac0627/scenic/{cellltype}/Snakemake'
    #scplus_mdata = mudata.read(f'{oudir}/scplusmdata.h5mu')

    #direct_er = scplus_mdata.uns["direct_e_regulon_metadata"]
    direct_er = pd.read_csv(f'{oudir}/eRegulon_direct.tsv',sep='\t')
    direct_er.sort_values(['importance_TF2G'], ascending=False, inplace=True)
    deg = direct_er[direct_er.Gene.isin(df_deg_select.gene)].copy()
    visualize_regulatory_network(deg,importance_col='importance_TF2G',weight_col='rho_TF2G',df_deg=df_deg_select, top_n=min(400,len(deg)),title='DEG Regulatory Network',output_html=f'figures/{cellltype}_deg_network.html')

    dar = direct_er[direct_er['Region'].isin(df_dar['names'].unique())].copy()
    visualize_regulatory_network(dar,importance_col='importance_TF2G',weight_col='rho_TF2G',df_deg=df_deg_select, top_n=min(250,len(dar)),title='DAR Regulatory Network',output_html=f'figures/{cellltype}_dar_network.html')


    TF_gcount = pd.DataFrame(direct_er.groupby(['TF']).nunique()['Gene'].sort_values(ascending=False))
    TF_degcount = pd.DataFrame(deg.groupby(['TF']).nunique()['Gene'])

    TF_rcount = pd.DataFrame(direct_er.groupby(['TF']).nunique()['Region'].sort_values(ascending=False))
    TF_darcount = pd.DataFrame(dar.groupby(['TF']).nunique()['Region'])

    df_importance = TF_degcount.merge(TF_gcount, left_index=True, right_index=True, how='right', suffixes=('_deg', '_all')).fillna(0)
    df_importance['deg_ratio'] = df_importance['Gene_deg'] / df_importance['Gene_all']
    df_importance.sort_values('deg_ratio', ascending=False, inplace=True)
    df_importance['ctname'] = ctname
    df_rimportance = TF_darcount.merge(TF_rcount, left_index=True, right_index=True, how='right', suffixes=('_deg', '_all')).fillna(0)
    df_rimportance['dar_ratio'] = df_rimportance['Region_deg'] / df_rimportance['Region_all']
    df_importance = df_importance.merge(df_rimportance, left_index=True, right_index=True, how='left', suffixes=('', '_TF2G'))
    df_importance.to_csv(f'figures/{cellltype}_TF_deg_ratio.csv')
    ca_df = direct_er[direct_er.Gene.isin(ca_genes)].copy()
    visualize_regulatory_network(ca_df,importance_col='importance_TF2G',weight_col='rho_TF2G',df_deg=df_deg_select, top_n=len(ca_df),title='Cacn Regulatory Network',output_html=f'figures/{cellltype}_ca_network.html')

    ligand_df = direct_er[direct_er.Gene.isin(ligand)].copy()

    visualize_regulatory_network(ligand_df,importance_col='importance_TF2G',weight_col='rho_TF2G', top_n=len(ligand_df),title='Ligand Regulatory Network',df_deg=df_deg_select,output_html=f'figures/{cellltype}_ligand_network.html')

    atp_df = direct_er[direct_er.Gene.isin(respriotory)].copy()

    visualize_regulatory_network(atp_df,importance_col='importance_TF2G',weight_col='rho_TF2G',df_deg=df_deg_select, top_n=len(atp_df),title='Respiratory Regulatory Network',output_html=f'figures/{cellltype}_respiratory_network.html')

    receptor_df = direct_er[direct_er.Gene.isin(receptor)].copy()

    visualize_regulatory_network(receptor_df,importance_col='importance_TF2G',weight_col='rho_TF2G', top_n=len(receptor_df),title='Receptor Regulatory Network',df_deg=df_deg_select,output_html=f'figures/{cellltype}_receptor_network.html')


    df_dar_ctgrn = df_dar_select.merge(direct_er, left_on='names', right_on='Region', how='inner')
    df_c_enhancer = df_dar_ctgrn[df_dar_ctgrn.primary_region.isin(['distal','downstream','intergenic'])]
    df_target_promoters = df_dar_select[(df_dar_select['gene'].isin(df_c_enhancer.Gene)) & (df_dar_select['primary_region'] == 'promoter')]
    df_target_promoters = df_target_promoters[['names','de_coef','de_pval','gene']]
    df_target_promoters.rename(columns={'names': 'promoter_region','de_coef': 'promoter_de_coef','de_pval': 'promoter_de_pval'}, inplace=True)
    df_protential_enhancer = df_c_enhancer.merge(df_target_promoters, left_on='Gene', right_on='gene', how='inner')
    df_protential_enhancer = df_protential_enhancer[df_protential_enhancer.de_coef * df_protential_enhancer.promoter_de_coef > 0]
    df_protential_enhancer.to_csv(f'figures/{cellltype}_potential_enhancer.csv', index=False)
    df_enahcner_all = pd.concat([df_enahcner_all, df_protential_enhancer], axis=0, ignore_index=True)

    df_protential_enhancer.rename(columns={'regulation_y':'regulation'}, inplace=True)
    enhancerdf = df_protential_enhancer[ca_df.columns]
    visualize_regulatory_network(enhancerdf,importance_col='importance_TF2G',weight_col='rho_TF2G', top_n=min(len(enhancerdf),300),title='Enhancer Regulatory Network',
                                 df_deg=df_deg_select,output_html=f'figures/{cellltype}_enhancer_network.html')

    

    odds_ratios = []
    p_values = []

    df_dar_select = df_dar[df_dar['ctname'] == ctname]

    for TF in direct_er['TF'].unique():
        odds_ratio, p_value = fisher_TF2gene(direct_er, TF, df_dar_select, df_deg_select)
        # print(f"TF: {TF}, Odds Ratio: {odds_ratio:.2f}, p-value: {p_value:.4e}")
        odds_ratios.append(odds_ratio)
        p_values.append(p_value)
    fisher_df = pd.DataFrame({
        'TF': direct_er['TF'].unique(),
        'Odds Ratio': odds_ratios,
        'p-value': p_values
    })
    fisher_df['ctname'] = cellltype

    fisher_df = fisher_df.merge(df_importance, on='TF', how='left')

    df_fisher_all = pd.concat([df_fisher_all, fisher_df], axis=0, ignore_index=True)


    # df_protential_enhancer.rename(columns={'gene_y': 'gene'}, inplace=True)
    # visualize_regulatory_network(df_protential_enhancer,importance_col='importance_TF2G',weight_col='rho_TF2G', top_n=len(df_protential_enhancer),title='Enhancer Regulatory Network',
    #                          df_deg=df_deg_select,output_html=f'figures/{cellltype}_enhancer_network.html')

# %%
bed_encode = "/data2st1/junyi/output/atac0416/cCRE/mm10-cCREs.bed"

# %%
df_encode = pd.read_csv(bed_encode, sep='\t', header=None)

# %%
def intersect_bed_objects(bed_file1, bed_file2):
    bed1 = bed_file1.sort()
    bed2 = bed_file2.sort()

    # Intersect and split regions
    # Retain annotations from bed_file2 for overlapping regions
    merged = bed1.intersect(bed2, wa=True, wb=True)#.saveas("output/temp_intersect.bed")

    # Split non-overlapping regions from bed_file1
    non_overlapping = bed1.subtract(bed2)#.saveas("output/temp_non_overlapping.bed")

    return merged, non_overlapping

# %%
df_enahcner_all.rename(columns={'gene_y': 'gene'}, inplace=True)

# %%
df_enahcner_all.to_csv('figures/potential_enhancer_all.csv', index=False)

# %%
pcolumn = 'ctname'
df_enahcner_all.groupby(pcolumn).size().reset_index(name='counts').set_index(pcolumn).plot.pie(
    y='counts',
    autopct=lambda p: f'{p:.1f}%' if p >= 5 else '',
    legend=False
)

# %%
df_fisher_all.sort_values('p-value', ascending=True, inplace=True)

# %%
# adjust p-values
pvals = df_fisher_all['p-value'].values
_, pvals_corrected, _, _ = multipletests(pvals, method='fdr_bh')
df_fisher_all['pval_adj'] = pvals_corrected

# %%
df_fisher_all.to_csv('figures/fisher_TF2gene.csv', index=False)

# %%
df_fisher_all

# %%
# select pvalue < 0.05 and odds ratio > 0.1
df_fisher_s = df_fisher_all[(df_fisher_all['pval_adj'] < 0.05) & (df_fisher_all['Odds Ratio'] > 0.1)]

# %%
df_fisher_s['ct'] = df_fisher_s['ctname_y'].apply(lambda x: x.split('_')[1])

# %%
df_top = df_fisher_s.groupby(['TF','ct']).count()['ctname_x'].sort_values(ascending=False).reset_index()

# %%
subset_name = list(set(df_top.head(10).TF.values))

# %%
df_fisher_s

# %%
df_deg_glut = pd.read_csv('/home/junyichen/code/scmmd/data/degs/Memento_Glut_DEGs_each_region_diff_gender_v1.csv',index_col=0)
df_deg_gaba = pd.read_csv('/home/junyichen/code/scmmd/data/degs/Memento_GABA_DEGs_each_region_diff_gender_v1.csv',index_col=0)
df_deg_glut['ctname'] = df_deg_glut['region'] + '_Glut'
df_deg_gaba['ctname'] = df_deg_gaba['region'] + '_GABA'
df_deg = pd.concat([df_deg_glut,df_deg_gaba],axis=0,ignore_index=True)
df_deg_select = df_deg[(df_deg.de_pval<0.05) & (df_deg.gender=="M")]
df_deg_select['condition'] = 'MW'
df_deg_select.loc[df_deg_select.de_coef>0,'condition'] = 'MC'

# %%
df_gene_select = df_deg_select[df_deg_select['gene'].isin(df_enahcner_all.Gene.unique())].copy()

# %%
df_heatmap = df_gene_select.pivot_table(index='ctname', columns='gene', values='de_coef', aggfunc='mean').fillna(0).clip(lower=-1, upper=1)

# %%
sns.heatmap(df_heatmap, cmap='coolwarm', center=0)

# %%
df_deg_select

# %%
df_tf_select = df_deg_select[df_deg_select['gene'].isin(df_fisher_s.TF.unique())].copy()
df_tf = df_tf_select.pivot_table(index='ctname', columns='gene', values='de_coef', aggfunc='mean').fillna(0).clip(lower=-1, upper=1)

# %%
sns.heatmap(df_tf, cmap='coolwarm', center=0)

# %%
df_globs = glob.glob('figures/*_TF**csv')

# %%
all_df = pd.DataFrame()
for df_glob in df_globs:
    df = pd.read_csv(df_glob).head(20)
    
    all_df = pd.concat([all_df, df], axis=0, ignore_index=True)

# %%
all_df.TF

# %%
all_df["NT"] = all_df["ctname"].str.split('_').str[1]
all_df["Region"] = all_df["ctname"].str.split('_').str[0]

# %%
all_df.groupby(['TF']).nunique()['ctname'].reset_index().sort_values('ctname', ascending=False).to_csv('figures/TF_allcount.csv', index=False)

# %%
all_df.groupby(['TF','NT']).nunique()['ctname'].reset_index().sort_values('ctname', ascending=False).to_csv('figures/TF_NTcount.csv', index=False)

# %%
eRegulon_gene_AUC = anndata.concat(
    [scplus_mdata["direct_gene_based_AUC"], scplus_mdata["extended_gene_based_AUC"]],
    axis = 1,
)

# %%
scplus_mdata['direct_region_based_AUC'].var

# %%
scplus_mdata['direct_region_based_AUC']

# %%
scplus_mdata.uns["direct_e_regulon_metadata"].to_csv(
    "/data1st2/junyi/output/atac0627/scenic/AMY_AMY_Glut/direct_e_regulon_metadata.csv"
)

# %%
eRegulon_gene_AUC.obs = scplus_mdata.obs.loc[eRegulon_gene_AUC.obs_names]

# %%
sc.pp.neighbors(eRegulon_gene_AUC, use_rep = "X")

# %%
sc.tl.umap(eRegulon_gene_AUC)

# %%
eRegulon_gene_AUC.obs['celltype.L2'] = eRegulon_gene_AUC.obs.index.str.split("_").str[:-1].str.join("_")

# %%
sc.pl.umap(eRegulon_gene_AUC, color = ['celltype.L2'])

# %%
scplus_mdata.obs['celltype.L2'] = scplus_mdata.obs.index.str.split("_").str[:-1].str.join("_")

# %%
rss = regulon_specificity_scores(
    scplus_mudata = scplus_mdata,
    variable = "celltype.L2",
    modalities = ["direct_gene_based_AUC", "extended_gene_based_AUC"]
)

# %%
plot_rss(
    data_matrix = rss,
    top_n = 3,
    num_columns = 3
)

# %%
heatmap_dotplot(
    scplus_mudata = scplus_mdata,
    color_modality = "direct_gene_based_AUC",
    size_modality = "direct_region_based_AUC",
    group_variable = "celltype.L2",
    eRegulon_metadata_key = "direct_e_regulon_metadata",
    color_feature_key = "Gene_signature_name",
    size_feature_key = "Region_signature_name",
    feature_name_key = "eRegulon_name",
    sort_data_by = "direct_gene_based_AUC",
    orientation = "horizontal",
    figsize = (16, 5)
)

# %%
direction_counts_region_nt = (
    df_match_direction_region_nt
    .assign(
        Direction_scenic_upper=lambda d: d['Direction_scenic'].astype(str).str.upper(),
        Direction_tobias_upper=lambda d: d['Direction_tobias'].astype(str).str.upper()
    )
    .groupby(['Region', 'Neurotransmitter', 'TF'], as_index=False)
    .agg(
        n_scenic_UP=('Direction_scenic_upper', lambda s: int((s == 'UP').sum())),
        n_scenic_DOWN=('Direction_scenic_upper', lambda s: int((s == 'DOWN').sum())),
        n_tobias_UP=('Direction_tobias_upper', lambda s: int((s == 'UP').sum())),
        n_tobias_DOWN=('Direction_tobias_upper', lambda s: int((s == 'DOWN').sum()))
    )
)

df_tf_overlap_by_region_nt = (
    df_tf_overlap_by_region_nt
    .drop(columns=['n_scenic_UP', 'n_scenic_DOWN', 'n_tobias_UP', 'n_tobias_DOWN'], errors='ignore')
    .merge(direction_counts_region_nt, on=['Region', 'Neurotransmitter', 'TF'], how='left')
)

count_cols = ['n_scenic_UP', 'n_scenic_DOWN', 'n_tobias_UP', 'n_tobias_DOWN']
df_tf_overlap_by_region_nt[count_cols] = df_tf_overlap_by_region_nt[count_cols].fillna(0).astype(int)

top_tf_overlap_by_region_nt = (
    df_tf_overlap_by_region_nt
    .sort_values(['Region', 'Neurotransmitter', 'matching_rate', 'n_matching_pairs'], ascending=[True, True, False, False])
    .groupby(['Region', 'Neurotransmitter'], group_keys=False)
    .head(20)
    .reset_index(drop=True)
)

top_tf_overlap_by_region_nt
