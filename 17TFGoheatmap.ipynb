# %%
# 在绘图前设置随机种子
set.seed(123)

library(tidyr)
library(dplyr)
library(ComplexHeatmap)
library(circlize)
library(ggplot2)
library(ggforce)
source("plotfunction.r")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: grid
#
# ...
# ComplexHeatmap version 2.18.0
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ...
#
#
# ...

# %%
df_path <- '/data2st1/junyi/output/atac0627/snregulation/gosummary_module/1_gosummary.csv'

# %%
df_plot <- read.csv(df_path)

# %%
head(df_plot)
# Out:
#   term_name                                            celltype_x
# 1 'de novo' AMP biosynthetic process                   PFC_Vip_GABA
# 2 'de novo' AMP biosynthetic process                   TH_Col27a1_Npsr1_Glut
# 3 'de novo' IMP biosynthetic process                   HY_Onecut1_Pmfbp1_GABA
# 4 'de novo' IMP biosynthetic process                   PFC_Vip_GABA
# 5 'de novo' IMP biosynthetic process                   TH_Col27a1_Npsr1_Glut
# 6 'de novo' NAD biosynthetic process from L-tryptophan Perivascular_Macrophage
#   gender count celltype.gender           module celltype_y
# 1 F      1     PFC_Vip_GABA_F            1      PFC_Vip_GABA_F
# 2 F      1     TH_Col27a1_Npsr1_Glut_F   1      TH_Col27a1_Npsr1_Glut_F
# 3 M      1     HY_Onecut1_Pmfbp1_GABA_M  1      HY_Onecut1_Pmfbp1_GABA_M
# 4 F      1     PFC_Vip_GABA_F            1      PFC_Vip_GABA_F
# 5 F      1     TH_Col27a1_Npsr1_Glut_F   1      TH_Col27a1_Npsr1_Glut_F
# ...

# %%
df_plot$nl10p <- df_plot$nlog10_p_val_adj

# %%
df_plot$nlog10_p_val_adj <-  df_plot$reg_count

# %%
regions <- c('AMY', 'PFC', 'HPF', 'MB', 'TH', 'STR', 'HY', 'Isocortex')

# %%
df_plot$region <- sapply(strsplit(as.character(df_plot$celltype_x), "_"), function(x) x[1])
# if the region is not in the predefined list, set it to "Other"
df_plot$region[!df_plot$region %in% regions] <- "NN"

# %%
df_plot$sample <- df_plot$celltype.gender
df_plot$sex <- df_plot$gender
# df_plot$region the firstpart of df_plot$celltype siplit by '_'

# %%
goheatmap(df_plot)
# Out:
# [1] 14575   444
#     [1] "postsynaptic membrane"
#     [2] "axon"
#     [3] "postsynapse"
#     [4] "glutamatergic synapse"
#     [5] "neuron projection"
#     [6] "plasma membrane bounded cell projection"
#     [7] "regulation of cellular component organization"
#     [8] "somatodendritic compartment"
#     [9] "presynapse"
#    [10] "cell projection"
#    [11] "cell junction"
#    [12] "synapse"
#    [13] "nervous system development"
#    [14] "neuronal cell body"
#    [15] "plasma membrane region"
#    [16] "cell body"
#    [17] "system development"
#    [18] "neuron to neuron synapse"
#    [19] "postsynaptic density"
#    [20] "postsynaptic specialization"
#    [21] "asymmetric synapse"
#    [22] "neuron projection development"
#    [23] "cellular localization"
#    [24] "neuron development"
#    [25] "dendrite"
#    [26] "dendritic tree"
#    [27] "plasma membrane bounded cell projection organization"
#    [28] "cell projection organization"
#    [29] "generation of neurons"
# ...
